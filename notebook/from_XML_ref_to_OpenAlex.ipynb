# %%
# %cd ../

import re
from lxml import etree
# Out:
# /home/zhangtianning.di/projects_local/unarXive/src

# %%
tmp_xml_path = "data/whole_arxiv_quant_ph_json/quant-ph_0001001/reference.xml"

# %%
parser = etree.XMLParser(remove_comments=True)
with open(tmp_xml_path) as f:
    tree = etree.parse(f, parser)  # get tree of XML hierarchy

# %%
result = Works().search_filter(title="Improved two-party and multi-party purification protocols").get()

# %%
result[0]
# Out:
# {'id': 'https://openalex.org/W1506089199',
#  'doi': 'https://doi.org/10.1090/conm/305/05220',
#  'title': 'Improved two-party and multi-party purification protocols',
#  'display_name': 'Improved two-party and multi-party purification protocols',
#  'relevance_score': 892.96625,
#  'publication_year': 2002,
#  'publication_date': '2002-01-01',
#  'ids': {'openalex': 'https://openalex.org/W1506089199',
#   'doi': 'https://doi.org/10.1090/conm/305/05220',
#   'mag': '1506089199'},
#  'language': 'en',
#  'primary_location': {'is_oa': False,
#   'landing_page_url': 'https://doi.org/10.1090/conm/305/05220',
#   'pdf_url': None,
#   'source': {'id': 'https://openalex.org/S2764899347',
#    'display_name': 'Contemporary mathematics',
#    'issn_l': '0271-4132',
#    'issn': ['1098-3627', '0271-4132'],
#    'is_oa': False,
#    'is_in_doaj': False,
#    'host_organization': 'https://openalex.org/P4310315719',
#    'host_organization_name': 'American Mathematical Society',
# ...

# %%
import pyalex
pyalex.config.email = "zhangtianning110@gmail.com"

# %%
from pyalex import Works, Authors, Sources, Institutions, Concepts, Publishers, Funders
