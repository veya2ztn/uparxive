# %%
# %cd ../
# Out:
# /nas/zhangtianning.di/projects/unique_data_build

# %%
from tqdm.auto import tqdm

# %%
import redis

# %%
import redis
redis_host = "localhost"
redis_port = 6379
redis_password = ""
r = redis.StrictRedis(host=redis_host, port=redis_port, password=redis_password, decode_responses=True)

# %% [markdown]
# ### read redis

# %%
alias_type = 'doi'  # The type of the alias you are looking for
alias_value = '10.1007/bf03046720'  # The alias for which you want to find the index

# Retrieve the index
index = get_index_by_alias(r,alias_type, alias_value)
print(f"The index for {alias_type} '{alias_value}' is: {index}")
a = get_alias_by_index(index)
print(a)
# Out:
# ---------------------------------------------------------------------------
# BusyLoadingError                          Traceback (most recent call last)
# Cell In[84], line 5
#       2 alias_value = '10.1007/bf03046720'  # The alias for which you want to find the index
#       4 # Retrieve the index
# ----> 5 index = get_index_by_alias(r,alias_type, alias_value)
#       6 print(f"The index for {alias_type} '{alias_value}' is: {index}")
#       7 a = get_alias_by_index(index)
#
# File /nas/zhangtianning.di/projects/unique_data_build/python_script/build_redis_database/utils.py:8, in get_index_by_alias(r, alias_type, alias_value)
#       6 unique_name = format_alias(alias_type, alias_value)
#       7 # Get the index associated with the unique name
# ----> 8 return r.get(unique_name)
#
# File ~/anaconda3/envs/unarxive/lib/python3.10/site-packages/redis/commands/core.py:1830, in BasicKeyCommands.get(self, name)
#    1824 def get(self, name: KeyT) -> ResponseT:
#    1825     """
#    1826     Return the value at key ``name``, or None if the key doesn't exist
#    1827
#    1828     For more information see https://redis.io/commands/get
#    1829     """
# -> 1830     return self.execute_command("GET", name)
#
# File ~/anaconda3/envs/unarxive/lib/python3.10/site-packages/redis/client.py:540, in Redis.execute_command(self, *args, **options)
#     538 pool = self.connection_pool
#     539 command_name = args[0]
# --> 540 conn = self.connection or pool.get_connection(command_name, **options)
#     542 try:
#     543     return conn.retry.call_with_retry(
#     544         lambda: self._send_command_parse_response(
#     545             conn, command_name, *args, **options
#     546         ),
#     547         lambda error: self._disconnect_raise(conn, error),
#     548     )
#
# File ~/anaconda3/envs/unarxive/lib/python3.10/site-packages/redis/connection.py:1104, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1100     self._in_use_connections.add(connection)
#    1102 try:
#    1103     # ensure this connection is connected to Redis
# -> 1104     connection.connect()
#    1105     # connections that the pool provides should be ready to send
#    1106     # a command. if not, the connection was either returned to the
#    1107     # pool before all data has been read or the socket has been
#    1108     # closed. either way, reconnect and verify everything is good.
#    1109     try:
#
# File ~/anaconda3/envs/unarxive/lib/python3.10/site-packages/redis/connection.py:288, in AbstractConnection.connect(self)
#     285 try:
#     286     if self.redis_connect_func is None:
#     287         # Use the default on_connect function
# --> 288         self.on_connect()
#     289     else:
#     290         # Use the passed function redis_connect_func
#     291         self.redis_connect_func(self)
#
# File ~/anaconda3/envs/unarxive/lib/python3.10/site-packages/redis/connection.py:391, in AbstractConnection.on_connect(self)
#     389     if self.lib_name:
#     390         self.send_command("CLIENT", "SETINFO", "LIB-NAME", self.lib_name)
# --> 391         self.read_response()
#     392 except ResponseError:
#     393     pass
#
# File ~/anaconda3/envs/unarxive/lib/python3.10/site-packages/redis/connection.py:512, in AbstractConnection.read_response(self, disable_decoding, disconnect_on_error, push_request)
#     508         response = self._parser.read_response(
#     509             disable_decoding=disable_decoding, push_request=push_request
#     510         )
#     511     else:
# --> 512         response = self._parser.read_response(disable_decoding=disable_decoding)
#     513 except socket.timeout:
#     514     if disconnect_on_error:
#
# File ~/anaconda3/envs/unarxive/lib/python3.10/site-packages/redis/_parsers/resp2.py:15, in _RESP2Parser.read_response(self, disable_decoding)
#      13 pos = self._buffer.get_pos() if self._buffer else None
#      14 try:
# ---> 15     result = self._read_response(disable_decoding=disable_decoding)
#      16 except BaseException:
#      17     if self._buffer:
#
# File ~/anaconda3/envs/unarxive/lib/python3.10/site-packages/redis/_parsers/resp2.py:38, in _RESP2Parser._read_response(self, disable_decoding)
#      35 # if the error is a ConnectionError, raise immediately so the user
#      36 # is notified
#      37 if isinstance(error, ConnectionError):
# ---> 38     raise error
#      39 # otherwise, we're dealing with a ResponseError that might belong
#      40 # inside a pipeline response. the connection's read_response()
#      41 # and/or the pipeline's execute() will raise this error if
#      42 # necessary, so just return the exception instance here.
#      43 return error
#
# BusyLoadingError: Redis is loading the dataset in memory

# %% [markdown]
# ### update crossref

# %%
from pathlib import Path
from tqdm.auto import tqdm
import gzip,json

resource_dir = "/nvme/zhangtianning.di/crossref/CrossrefData/"
resource_files= list(Path(resource_dir).glob("*.gz"))

filename = resource_files[0]
with gzip.open(filename, 'r') as f:
    json_data = json.load(f)

# %%
from tqdm.notebook import tqdm
filename = resource_files[0]
conflict_doi_that_should_same_but_splited = []
for filename in tqdm(resource_files, position=1, leave=False):
    Prefix_Code = str(filename).split('/')[-1].replace('.json.gz','')
    with gzip.open(filename, 'r') as f:
        json_data = json.load(f)
        for slot, t in tqdm(enumerate(json_data['items']),total=len(json_data['items']), position=2, leave=False):
            if 'alternative-id' in t and len(set(t['alternative-id']))>1:
                alternative_pool = [l.lower() for l in t['alternative-id']]
                primiry_doi      = t['DOI'].lower()
                alternative_doi  = [primiry_doi.replace(alternative_pool[0], sss) for sss in alternative_pool[1:]]
                alternative_doi  = [primiry_doi] + alternative_doi 
                doi_and_indexes  = [[doi,get_index_by_alias('doi', doi)] for doi in alternative_doi]
                the_valid_indexes= [index for doi, index in doi_and_indexes if index is not None]
                if len(the_valid_indexes)>1:
                    multirecord_doi = [doi for doi, index in doi_and_indexes if index is not None]
                    conflict_doi_that_should_same_but_splited.append(multirecord_doi)
                    continue
                if len(the_valid_indexes)==0:
                    the_record_index = f"CR.{Prefix_Code}.{slot}"
                else:
                    the_record_index = the_valid_indexes[0]
                    
                for doi, index in doi_and_indexes:
                    if index is not None:continue
                    print(slot,'doi', doi, the_record_index)
                    #add_alias_with_unique_name(r,'doi', doi, the_record_index)
            else:
                doi  = t['DOI']
                the_record_index = get_index_by_alias('doi', doi)
                if the_record_index is not None:
                    continue
                else:
                    the_record_index = f"CR.{Prefix_Code}.{slot}"
                    #add_alias_with_unique_name(r,'doi', doi, the_record_index)
            #for doi in alternative_doi:
                #print('doi', doi, the_record_index)
                #add_alias_with_unique_name(r,'doi', doi, the_record_index)
    break
# Out:
#   0%|          | 0/28701 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
# 2964 doi 10.18632/oncotarget.30515265 234767104
# 3857 doi 10.1145/3240765 139877237
# 3970 doi 10.1145/3240765.3272126 CR.9361.3970
# 3970 doi 10.1145/3240765 CR.9361.3970
# 4186 doi 10.1145/3240765 216603872
# 4494 doi 10.1145/3240765 224708238
# 4951 doi 10.18632/oncotarget.30515271 143889148

# %%
json_data['items'][4186 ]['alternative-id']
# Out:
# ['10.1145/3240765.3240818', '10.1145/3240765']

# %%
get_index_by_alias('doi', doi)

# %%
conflict_doi_that_should_same_but_splited
# Out:
# [['10.1108/978-1-78743-327-420181003', '10.1108/9781787433274'],
#  ['10.3920/978-90-8686-881-0_c09', '10.3920/978-90-8686-881-0'],
#  ['10.3920/978-90-8686-881-0_c05', '10.3920/978-90-8686-881-0'],
#  ['10.1002/9781119460435.refs', '10.1002/9781119460435'],
#  ['10.3920/978-90-8686-881-0_fm', '10.3920/978-90-8686-881-0'],
#  ['10.3920/978-90-8686-881-0_3', '10.3920/978-90-8686-881-0'],
#  ['10.3920/978-90-8686-881-0_c13', '10.3920/978-90-8686-881-0'],
#  ['10.1142/9789814528139', '10.1142/3914'],
#  ['10.1108/978-1-78743-809-520181001', '10.1108/9781787438095'],
#  ['10.1108/978-1-78743-809-520181006', '10.1108/9781787438095'],
#  ['10.1108/978-1-78743-809-520181002', '10.1108/9781787438095'],
#  ['10.1108/s0743-41542018000036c005',
#   '10.1108/rhet',
#   '10.1108/s0743-4154201836c'],
#  ['10.1108/978-1-78754-531-120181007', '10.1108/9781787545311'],
#  ['10.1145/3274247.3274516', '10.1145/3274247'],
#  ['10.1108/978-1-78754-531-120181014', '10.1108/9781787545311'],
#  ['10.1108/978-1-78754-531-120181001', '10.1108/9781787545311'],
#  ['10.1108/978-1-78754-531-120181013', '10.1108/9781787545311'],
#  ['10.1108/978-1-78769-431-620181001',
#   '10.1108/nhmoc',
#   '10.1108/s2397-52102018'],
#  ['10.1108/s1569-376720180000019008',
#   '10.1108/ifr',
#   '10.1108/s1569-3767201819'],
#  ['10.3362/9781908176707.001', '10.3362/9781908176707'],
#  ['10.2478/9783110644166-010', '10.2478/9783110644166'],
#  ['10.2478/9783110644166-007', '10.2478/9783110644166'],
#  ['10.3362/9781908176707.007', '10.3362/9781908176707'],
#  ['10.1108/978-1-78754-531-120181004', '10.1108/9781787545311'],
#  ['10.1108/s0743-41542018000036c001',
#   '10.1108/rhet',
#   '10.1108/s0743-4154201836c'],
#  ['10.1108/s1569-3767201819', '10.1108/ifr']]

# %%
resource_dir = "/nvme/zhangtianning.di/crossref/CrossrefData/"
resource_files= list(Path(resource_dir).glob("*.gz"))

# %%
resource_files = [str(t) for t in resource_files]

# %%
resource_dir = "/nvme/zhangtianning.di/crossref/crossref.filelist.json"
with open(resource_dir,'r') as f:
    resource_files= json.load(f)

# %%
import os
os.makedirs('/nvme/zhangtianning.di/crossref/CrossrefData_Conflict')

# %%
json_data['items'][2095]
# Out:
# {'URL': 'http://dx.doi.org/10.1108/978-1-78743-809-520181006',
#  'resource': {'primary': {'URL': 'https://www.emerald.com/insight/content/doi/10.1108/978-1-78743-809-520181006/full/html'}},
#  'member': '140',
#  'score': 0.0,
#  'created': {'date-parts': [[2018, 11, 7]],
#   'date-time': '2018-11-07T06:45:51Z',
#   'timestamp': 1541573151000},
#  'license': [{'start': {'date-parts': [[2018, 11, 7]],
#     'date-time': '2018-11-07T00:00:00Z',
#     'timestamp': 1541548800000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'http://www.emeraldinsight.com/page/tdm'},
#   {'start': {'date-parts': [[2018, 11, 7]],
#     'date-time': '2018-11-07T00:00:00Z',
#     'timestamp': 1541548800000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'http://www.emeraldinsight.com/page/tdm'}],
#  'container-title': ['Platform Economics: Rhetoric and Reality in the ‘Sharing Economy’'],
#  'issued': {'date-parts': [[2018, 11, 7]]},
#  'prefix': '10.1108',
#  'reference-count': 0,
#  'indexed': {'date-parts': [[2022, 4, 3]],
#   'date-time': '2022-04-03T02:42:08Z',
#   'timestamp': 1648953728620},
#  'author': [{'given': 'Cristiano',
#    'family': 'Codagnone',
#    'sequence': 'first',
#    'affiliation': []},
#   {'given': 'Athina',
#    'family': 'Karatzogianni',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Jacob',
#    'family': 'Matthews',
#    'sequence': 'additional',
#    'affiliation': []}],
#  'DOI': '10.1108/978-1-78743-809-520181006',
#  'is-referenced-by-count': 0,
#  'published': {'date-parts': [[2018, 11, 7]]},
#  'published-print': {'date-parts': [[2018, 12, 3]]},
#  'alternative-id': ['10.1108/978-1-78743-809-520181006',
#   '10.1108/9781787438095'],
#  'published-online': {'date-parts': [[2018, 11, 7]]},
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'title': ['Chapter 5 Conclusions and Research Agenda for the Future'],
#  'link': [{'URL': 'https://www.emeraldinsight.com/doi/full-xml/10.1108/978-1-78743-809-520181006',
#    'content-type': 'application/xml',
#    'content-version': 'vor',
#    'intended-application': 'text-mining'},
#   {'URL': 'https://www.emeraldinsight.com/doi/full/10.1108/978-1-78743-809-520181006',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'source': 'Crossref',
#  'type': 'book-chapter',
#  'publisher': 'Emerald Publishing Limited',
#  'references-count': 0,
#  'deposited': {'date-parts': [[2019, 9, 3]],
#   'date-time': '2019-09-03T15:25:34Z',
#   'timestamp': 1567524334000},
#  'page': '151-168'}

# %%
json_data['items'][2060]
# Out:
# {'URL': 'http://dx.doi.org/10.1108/978-1-78743-809-520181001',
#  'resource': {'primary': {'URL': 'https://www.emerald.com/insight/content/doi/10.1108/978-1-78743-809-520181001/full/html'}},
#  'member': '140',
#  'score': 0.0,
#  'created': {'date-parts': [[2018, 11, 7]],
#   'date-time': '2018-11-07T06:45:51Z',
#   'timestamp': 1541573151000},
#  'license': [{'start': {'date-parts': [[2018, 11, 7]],
#     'date-time': '2018-11-07T00:00:00Z',
#     'timestamp': 1541548800000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'http://www.emeraldinsight.com/page/tdm'},
#   {'start': {'date-parts': [[2018, 11, 7]],
#     'date-time': '2018-11-07T00:00:00Z',
#     'timestamp': 1541548800000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'http://www.emeraldinsight.com/page/tdm'}],
#  'container-title': ['Platform Economics: Rhetoric and Reality in the ‘Sharing Economy’'],
#  'issued': {'date-parts': [[2018, 11, 7]]},
#  'prefix': '10.1108',
#  'reference-count': 0,
#  'indexed': {'date-parts': [[2022, 3, 29]],
#   'date-time': '2022-03-29T01:44:04Z',
#   'timestamp': 1648518244676},
#  'author': [{'given': 'Cristiano',
#    'family': 'Codagnone',
#    'sequence': 'first',
#    'affiliation': []},
#   {'given': 'Athina',
#    'family': 'Karatzogianni',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Jacob',
#    'family': 'Matthews',
#    'sequence': 'additional',
#    'affiliation': []}],
#  'DOI': '10.1108/978-1-78743-809-520181001',
#  'is-referenced-by-count': 0,
#  'published': {'date-parts': [[2018, 11, 7]]},
#  'published-print': {'date-parts': [[2018, 12, 3]]},
#  'alternative-id': ['10.1108/978-1-78743-809-520181001',
#   '10.1108/9781787438095'],
#  'published-online': {'date-parts': [[2018, 11, 7]]},
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'title': ['Introduction'],
#  'link': [{'URL': 'https://www.emeraldinsight.com/doi/full-xml/10.1108/978-1-78743-809-520181001',
#    'content-type': 'application/xml',
#    'content-version': 'vor',
#    'intended-application': 'text-mining'},
#   {'URL': 'https://www.emeraldinsight.com/doi/full/10.1108/978-1-78743-809-520181001',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'source': 'Crossref',
#  'type': 'book-chapter',
#  'publisher': 'Emerald Publishing Limited',
#  'references-count': 0,
#  'deposited': {'date-parts': [[2019, 11, 7]],
#   'date-time': '2019-11-07T17:20:35Z',
#   'timestamp': 1573147235000},
#  'page': '1-15'}

# %% [markdown]
# ### update unarxive

# %%
done_file_names = [x.name for x in Path('/nvme/zhangtianning.di/datasets/unarxive/').glob('**/*.jsonl')]
all_raw_files   = list(Path('/nvme/zhangtianning.di/datasets/unarxive/').glob('**/*.jsonl'))
all_raw_files = [str(t) for t  in all_raw_files]
with open("/nvme/zhangtianning.di/datasets/unarxive/whole_filelist.json",'w') as f:
    json.dump(all_raw_files, f)

# %%
done_file_names = [x.name for x in Path('/nvme/zhangtianning.di/datasets/unarxive/').glob('**/*.jsonl')]

# %%
all_raw_files   = list(Path('/nvme/zhangtianning.di/datasets/unarxive/').glob('**/*.jsonl'))

# %%
all_raw_files[0]
# Out:
# '/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0004_001.jsonl'

# %%
with open(all_raw_files[0],'r') as f:
    for line in f:
        data = json.loads(line)
       
        break
        for key, val in data['bib_entries'].items():
            print(val['ids'])

# %% [markdown]
# #### convert unarxive format into uparxive format

# %%
from clean_unarXive_data import *

# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")

# %%
metadata_i['id']
# Out:
# 'nucl-th/0004066'

# %%
#def processing_data(data):
metadata_i    = data['metadata']
body_text_i   = data['body_text']
bib_entries_i = data['bib_entries']
ref_entries_i = data['ref_entries']

# get a dict for format citation/reference data
insert_data = {}
type_list = []

# for formula, figure, table
figure_ref  = {}
table_ref   = {}
equation_ref= {}
figures_metadata ={}
tables_metadata  ={}

paper_unique_id  = identify_string_type(metadata_i['id'])
for _id, item in ref_entries_i.items():
    type_list.append(item['type'])
    key = "{}:{}".format(item['type'], _id)
    if item['type'] == 'formula':
        value = """${}$""".format(item['latex'])
    elif item['type'] == 'table':
        value = f"""[Table.{len(tables_metadata)} of {paper_unique_id}]"""
        tables_metadata[_id] = item
        table_ref[_id] =[ 'Table', len(tables_metadata)]
    elif item['type'] == 'figure':
        value = f"""[Figure.{len(figures_metadata)} of {paper_unique_id}]"""
        figures_metadata[_id] = item
        figure_ref[_id]  = ['Figure',len(figures_metadata)]
    else:
        print('='*20)
        print(item)
        print('='*20)
        value = ""
    insert_data[key] = value

# remove duplicate
type_list = list(set(type_list)) 

# for citation
type_list.append('cite')

for i,(_id, item) in enumerate(bib_entries_i.items()):
    key = "{}:{}".format('cite', _id)
    value = get_name(item)
    value = f"[Ref.{i} of {paper_unique_id}]" if value is None else value
    insert_data[key] = value

all_text = []
Reference= []
ReferenceQ= False
acknowledgement = None
for paragraph in body_text_i:
    #print(paragraph.keys())
    text = paragraph['text']

    start_string = text.strip()[:20]
    if 'REFERENCES' in start_string or 'Reference' in start_string:
        ReferenceQ=True
        raise

    new_text = format_text_with_values(text, insert_data, type_list,paper_unique_id)
    if 'Acknowledgement' in start_string:
        acknowledgement = new_text
        continue
    if len(new_text)==0:
        continue

    if all_text and new_text.strip() and (new_text.strip()[0].islower()or new_text.strip()[:5] == 'Proof'):
        all_text[-1]+=' '+new_text.strip()
    elif all_text and all_text[-1].strip() and (all_text[-1].strip()[-1]=="$" or all_text[-1].strip()[-1]==":") and len(all_text[-1].split())<128:
        all_text[-1]+=' '+new_text
    else:
        if ReferenceQ:
            Reference.append(new_text.replace('\n'," "))
        else:
            all_text.append(new_text.replace('\n'," "))
    paragraph['format_text'] = new_text

# %%
def split_by_indentation(all_text):
    all_text = "".join(all_text)
    all_text = all_text.replace("\n"," ")
    #all_text = all_text.split('[SENTENCE_START]')
    all_text = re.split(r'\s{2,}', all_text)
    return all_text

# %%
sections = []
structued_paragraph = {}
for flatten_paragraph in body_text_i:
    section_num  = flatten_paragraph['sec_number']
    section_num  = int(section_num)
    if section_num not in structued_paragraph:
        structued_paragraph[section_num] = {'section_content':[]}
    
    section_name = flatten_paragraph['section']
    section_name = better_latex_sentense_string(section_name)
    if section_name in structued_paragraph[section_num]:
        assert section_name == structued_paragraph[section_num], f"why we get two different section name for [{section_name}] and ]"
    if 'format_text' not in flatten_paragraph:
        #print(flatten_paragraph)
        continue
    structued_paragraph[section_num]['section_content'].append(flatten_paragraph['format_text'])

# %%
sections = []
appendix = []
section_num_keys = list(structued_paragraph.keys())
section_num_keys.sort()

for section_num in section_num_keys:
    sections = structued_paragraph[section_num]
    section_title = sections['section_name']
    appendex_mode = False
    if section_num<0 or section_title.lower() in ['appendix','supplementary']:
        appendex_mode = True
    if not section_name: 
        if not appendex_mode:
            section_name = f'Section {section_num}'
        else:
            section_name = f'Appendix {abs(section_num)}'
    now_section = {'section_title':section_name}
    for section_num, text_list in sections.items():
        print(text_list)
# Out:
# ['With the introduction of his celebrated inequalities in 1964, John Bell (See [DOI:10.1119/1.13804]) provided the basis for an experimental test to distinguish quantum mechanics from local hidden-variable theories. Since that time the universal interpretation of the results has been that quantum mechanics violates Bell\'s inequalities due to its “nonlocal" character, whereas local hidden variable theories satisfy the inequalities because, as their name implies, they are “local." ', 'The situation is actually not so transparent. Bohr taught us to be aware of ambiguous language. Although derivations of Bell\'s inequalities are evidently based on Einstein\'s “locality" condition, couched in various phrases such as “principle of separability" and so forth, mathematically all derivations make an identical assumption, specifically: hidden-variable theories introduce a set of a priori positive-definite probabilities P that are not predicted by quantum mechanics. In Bohm\'s classic version of the Einstein-Podolsky-Rosen experiment, for example, a particle in a spin-singlet state decays into two daughter particles with zero total angular momentum (see, e.g., Sakurai\'s text (See [DOI:10.1017/9781108587280]) or Sudarshan and Rothman (See [Ref.2 of quant-ph/0004109]), henceforth SR). According to local hidden-variable theories there is an a priori positive-definite probability that the daughter particles will be detected with spins “up" along a chosen axis. Quantum mechanics, on the other hand, assumes that the daughter particles are in a superposition of states and so, by definition, there can be no a priori probability P such that their spins will be detected along a given direction. ', 'Contrary to this view, in SR we pointed out that quantum mechanics does predict a set of a priori probabilities, in exactly the same way as do hidden-variable theories, but the quantum probabilities are not positive-definite. They are nevertheless meaningful in that when applied to physical situations they give the standard quantum-mechanical answers, in particular the usual violation of Bell\'s inequalities. Given the exact analogy in producing the two sets of probabilities the distinction between “local" hidden-variable theories and “non-local" quantum mechanics is dissolved. From this point of view one merely has two competing theories that give two different sets of probabilities; it is unsurprising that hidden-variables theories fail experimental tests of Bell\'s inequalities because they used the wrong set of probabilities for a quantum-mechanical problem. ', 'The notion of “extended" probabilities dates back to Dirac and we have not been the only authors to suggest that they can resolve the EPR paradox (see [Ref.3 of quant-ph/0004109, Ref.4 of quant-ph/0004109]) but, needless to say, the SR argument has not found widespread acceptance. Recently, several rather old papers, in particular one by Eberhard (See [Ref.5 of quant-ph/0004109]) entitled “Bell\'s Theorem Without Hidden Variables," have come to our attention. Eberhard\'s paper is of interest because it claims to show that a more general version of Bell\'s inequalities, known as the CHSH inequality (after Clauser, Horne, Shimony and Holt) (See [DOI:10.1103/physrevlett.23.880]), is violated by quantum mechanics, and that the CHSH inequality can be demonstrated solely on the basis of the locality principle, without the introduction of hidden variables. (A slightly later paper by Peres (See [Ref.7 of quant-ph/0004109]) gives an almost identical argument; one by Stapp (See [Ref.8 of quant-ph/0004109]) is in some respects similar.) At first sight these proofs appear to assume little more than $2 < 2\\sqrt{2}$ . On closer inspection, however, we find that they “play into our hands," i.e., they may not make an explicit statement about hidden variables but they do assume a set of positive-definite probabilities. We now demonstrate this is so, reinforcing the contention in SR that, despite any words ...
# ['Eberhard considers two identical apparata, $A$ and $B$ , at two different locations. On apparatus $A$ is a knob $a$ that can be turned to two positions, 1 and 2. On apparatus $B$ is a knob $b$ that can also be turned to two positions, 1 and 2. With its knob at either position apparatus $A$ can record a series of events. It is not important exactly what the events are, but we assume that for each event each apparatus can measure only one of two possible outcomes, which for simplicity we take to be $\\pm 1$ . When the knob $a$ is in the 1 position, we designate the outcome of the $jth$ event as $\\alpha _{1j}$ , with similar notation for position 2 and knob $b$ . For each event we can thus in principle have: $\\alpha _{1j} = \\pm 1,\\ \\alpha _{2j} = \\pm 1,\\ \\beta _{1j} = \\pm 1,\\beta _{2j} = \\pm 1$ . However, for each measurement we will choose only one setting on each apparatus, so a given event will produce a pair of readings, such as $\\alpha _1 = 1, \\beta _2 = -1$ . (Here and below we suppress the subscript $j$ when it will not cause confusion.) ', 'For a series of $N$ measurements Eberhard next defines a quantity $C$ , such that $C = \\frac{1}{N}\\sum _{j=1}^N\\alpha _j\\beta _j$ ', "We see that $C = <\\alpha _j\\beta _j>$ , the statistical mean of the $N$ products $\\alpha _j\\beta _j$ . No restriction is placed on the fraction of the $N$ measurements for which the $\\alpha $ 's and $\\beta $ 's come out positive or negative, but note that each product $\\alpha _j\\beta _j = 1$ when $\\alpha $ and $\\beta $ have the same sign and $\\alpha _j\\beta _j = -1$ when they have opposite signs. Thus $C$ represents the fraction of events in which $\\alpha $ and $\\beta $ have the same sign minus the fraction in which they have opposite sign. ", 'Because each knob has two positions, there are four possible versions of $C$ . That is, we can define $C_{11} & = & <\\alpha _{1}\\beta _{1}> \\nonumber \\\\C_{12} & = & <\\alpha _{1}\\beta _{2}> \\nonumber \\\\C_{21} & = & <\\alpha _{2}\\beta _{1}> \\nonumber \\\\C_{22} & = & <\\alpha _{2}\\beta _{2}>$ ', '(sum on $j$ understood). Here, $C_{11}$ is just the above statistical mean when knobs $a$ and $b$ are both in position 1, and so forth. ', 'Now, for each event let $\\gamma \\equiv \\alpha _1\\beta _1 + \\alpha _1\\beta _2 +\\alpha _2\\beta _1 - \\alpha _2\\beta _2 .$ ', 'Then, the statistical mean of $\\gamma $ is just $<\\gamma > & = & \\frac{1}{N}\\sum _{j = 1}^N \\gamma _j \\nonumber \\\\& = & \\frac{1}{N}\\sum _{j = 1}^N(\\alpha _1\\beta _1 + \\alpha _1\\beta _2 +\\alpha _2\\beta _1 - \\alpha _2\\beta _2) \\nonumber \\\\& \\equiv & C_{11} + C_{12} + C_{21} - C_{22},$ ', 'where in the second line we have again suppressed $j$ . ', "The locality condition enters the discussion when we attempt to put bounds on $<\\gamma >$ . Recall that a knob will be set to either position 1 or 2 for each measurement. We assume that a measurement on $A$ is independent of a measurement on $B$ . The $\\alpha $ 's and $\\beta $ 's are thus treated independently. This is the locality condition. ", "At this point a digression is necessary. Eberhard states that only one setting of each knob (position 1 or 2) will be used for each measurement, and that thus only one $\\alpha $ or $\\beta $ is recorded for each event. However, if this were indeed the case, then for each measurement only one term in $\\gamma $ would survive (one product $\\alpha \\beta $ ) and the upper bound on $\\gamma $ would be 1 (cf. Eqs. (REF ) and (REF )). That the upper bound is 2 shows that mathematically all four possible terms $\\alpha \\beta $ are present in $\\gamma $ . Consequently, not only are the $\\alpha $ 's being taken to be independent of the $\\beta $ 's but $\\alpha _1$ ($\\beta _1$ ) is being treated as independent of $\\alpha _2$ ($\\beta _2$ ). The rationale for including all $\\alpha $ 's and $\\beta $ 's in $\\gamma $ simultaneously comes from a 1971 suggestion of Stapp (See [DOI:10.1103/physrevd.3.1303]). S ...
# ["Before deriving Eq.(REF ), it will be helpful to summarize the procedure for obtaining the standard Bell Inequalities in order to point out similarities to the CHSH-Eberhard experiment. The reader is referred to SR or Sakurai (See [DOI:10.1017/9781108587280]) for additional details; see also the Appendix. Like its successor, Bell's theorem is valid for local hidden-variable theories, which involve only classical probabilities. In a typical derivation such as Sakurai's one assumes that spin measurements may be made along any of three axes, a, b and c. A system of decaying atoms emits $N$ particles of which a certain fraction are taken to be, say, of the type (a+, b+, c+) $\\equiv (+++)$ , which designates spin up along all three axes. To ensure zero total angular momentum, each emitted particle of type (+++) must be paired with one of type ($ - - - $ ). There are eight such spin combinations in all, as listed in Table 1. ", "The probability that (+++) is emitted (and in the case of hidden variables, detected) is defined simply as $P(+++)= N(+++)/N$ . One can immediately object that such a probability is unphysical because to determine it requires three simultaneous spin measurements on a system of two particles, which is impossible. To eliminate this difficulty, one forms pairwise probabilities of the type $P({\\bf a}+,{\\bf b}+)\\equiv P(++)$ , which represents the joint probability that the first particle will be found + along a and the second particle + along b. This is easily done. From the table, the total number of particles such that the first particle's spin is + along a is $N(+-+) + N(+--)$ , which must be paired with $N(-+-) + N(-++)$ , the total number of particles for which the second particle's spin is + along b. This combination is labeled $N_3 + N_5$ . Next one forms triangle-type inequalities such as $N_3 + N_5 \\le (N_2 + N_5) + (N_3 + N_7), $ ", 'which is obviously true, since we have just added positive numbers to $N_3 + N_5$ . Dividing by $N$ gives by definition $P({\\bf a}+,{\\bf b}+) \\le P({\\bf a}+,{\\bf c}+) + P({\\bf c}+,{\\bf b}+),$ ', 'one of the Bell inequalities. Eq. (REF ) involves only one measurement on each particle and so represents a physically realizable situation. Note that the “three-probabilities" $P(+++)$ were reduced to pairwise probabilities $P(++)$ by summing over the spins on the extraneous axis, in the above example c. We emphasize that, just as was the case for the CHSH inequality, the Bell inequality is valid only if the N\'s and hence the P\'s are taken to be positive-definite. In SR we demonstrated that one can form quantum probabilities $P(+++)$ , analogous to the classical probabilities, then sum over the third argument exactly as above to get pairwise quantum probabilities $P(++)$ that violate (REF ) in the usual way. ', 'By this point the reader will have noticed a similarity between the $\\gamma $ \'s in Eberhard\'s experiment and the three-probabilities here. Authors who derive the generalized Bell inequalities introduce $\\gamma $ as a measure of correlations between real and imagined experiments but, as mentioned, if one takes it literally it amounts to having the apparatus knobs set on two positions simultaneously. This would seem to represent the same sort of physical impossibility as that of making three simultaneous spin measurements on two particles. Indeed, we will demonstrate in Section that the two procedures are identical: Introducing an ensemble of hypothetical measurements is exactly equivalent to assuming a “master probability distribution" that requires more than two simultaneous spin measurements on two particles. Before doing so, however, we return to the Eberhard derivation. ', "Eberhard's experiment involves four axes, ${\\bf a_1, a_2, b_1,b_2}$ , rather than three, but otherwise is almost identical to the standard derivation of Bell's inequalities and so it is not surprising that the above procedure can be followed to demonstrate a violation of the CH ...
# ['We have shown that, like the Bell inequalities, the CHSH inequality assumes positive-definite probabilities and that quantum mechanics breaks both inequalities effectively because it introduces negative weights to the measurements. These negative four-probabilities enter the derivation in exactly the same way as the classical three-probabilities entered the derivation of the Bell\'s inequalities. If they are unphysical, it is not necessarily because they are negative, but because it is impossible to make four simultaneous spin measurements on two particles. By the same token, it is impossible to make three simultaneous spin measurements on two particles. In any case, neither the classical three-probabilities found in Bell\'s theorem, nor the four-probabilities that figure here are actually measured. Both merely serve as “master distributions" from which to derive the usual pairwise probabilities, classical and quantum, which are both positive-definite. To reiterate our earlier remarks, from this point of view it is not surprising that the Bell and CHSH inequalities are violated by experimental tests; they merely used the wrong set of probabilities for a quantum-mechanical problem. ', "Although one might choose to reject negative probabilities as unphysical, one should not reject the notion of master probability distributions in favor of correlations between real and imaginary experiments because the two procedures are identical! Recall again that Eberhard's quantity $C_{11}$ was $C_{11} =\\frac{1}{N}\\sum _{j=1}^N\\alpha _{1j}\\beta _{1j}$ , which represented the fraction of events $\\alpha _1\\beta _1$ that had the same sign minus the fraction that had opposite sign. Thus by definition we can write $C_{11} = P({\\bf a_1+, b_1+}) + P({\\bf a_1-, b_1-})-[P({\\bf a_1+, b_1-})+P({\\bf a_1+, b_1-})].$ ", 'Now, in exact analogy with the procedure of Section we imagine that these pairwise probabilities can be derived from a master distribution involving all four axes ${\\bf a_1, a_2, b_2,b_3}$ . In that case, as in Eq (REF ), $P(++)= P({\\bf a_1+,b_1+}) = P(++++) + P(+++-)+P(+-+-)+P(++-+)$ , with analogous expressions for $P(--), P(+-)$ and $P(-+)$ . There are thus 16 terms that contribute to $C_{11}$ , similarly for $C_{12}, C_{21}$ and $C_{22}$ . Writing out all 64 terms yields for ${\\cal C} =<\\gamma >$ : ${\\cal C} = &&2\\lbrace P(++++) + P(----) +P(+++-) + P(---+)\\nonumber \\\\&& + P(+-++) + P(-+--) + P(+--+) + P(-++-)\\nonumber \\\\&& - P(++-+) - P(--+-) - P(-+++) -P(+---)\\nonumber \\\\&& - P(++--) - P(--++) - P(+-+-) - P(-+-+)\\rbrace $ ', "These $P$ 's are general and may be taken to be either classical or quantum. Notice half enter with positive sign and half with negative. If all the probabilities are equal, then ${\\cal C} = 0$ . If those that enter with negative sign are zero, then ${\\cal C} =2$ and if those that enter with positive sign are zero, then ${\\cal C} = -2$ . All this is in complete agreement with the analysis of Section . Clearly, if the $P$ 's are positive-definite then ${\\cal C} \\le 2$ , but if the probabilities are allowed to become negative then this bound is violated. If the $P$ 's are assumed to be quantum, they take on the values given by Table II. In this case, inserting those values into (REF ) gives exactly (REF ), as before. ", "This demonstration shows clearly that the $\\gamma $ 's can be derived from a master probability distribution which involves simultaneous spin measurements along four axes. The only difference between the classical and quantum cases is that in the former we assume the probabilities are positive-definite. The master distributions themselves cannot be regarded as any more or less meaningful than the space of hypothetical measurements, because the procedures are exactly equivalent. Indeed, we see that there is no difference between the Eberhard procedure and the usual derivation of Bell's inequalities. ", 'There remains the problem of interpretation. Most people insis ...
# ["Many researchers appear unwilling to accept that any assumptions beyond locality are employed in the derivations of Bell's inequalities. We now list a few of the proofs we have found and point out explicitly where the assumption of positive probabilities enters. ", "Bell 64. In Bell's original proof (See [DOI:10.1119/1.13804]) he defines two quantities $A(\\vec{a},\\lambda ) = \\pm 1$ , $B (\\vec{b},\\lambda )= \\pm 1$ . He defines a normalized probability distribution $\\rho (\\lambda )$ , such that $\\int d\\lambda \\;\\rho (\\lambda ) = 1$ . The expectation value of the spin components $\\vec{\\sigma _1}\\cdot \\vec{a}$ and $\\vec{\\sigma _2}\\cdot \\vec{b}$ is $P(\\vec{a},\\vec{b}) = \\int d\\lambda \\;\\rho (\\lambda )A(\\vec{a},\\lambda )B (\\vec{b},\\lambda ),$ ", 'which he shows can be written (his equation 14) as $P(\\vec{a},\\vec{b}) = - \\int d\\lambda \\;\\rho (\\lambda )A(\\vec{a},\\lambda ) A(\\vec{b},\\lambda ).$ ', 'When another vector $\\vec{c}$ is involved, one has $P(\\vec{a},\\vec{b}) - P(\\vec{a},\\vec{c})=- \\int d\\lambda \\;\\rho (\\lambda ) [A(\\vec{a},\\lambda )A (\\vec{b},\\lambda ) -A(\\vec{a},\\lambda )A (\\vec{c},\\lambda )]$ ', 'Bearing in mind that$A(\\vec{b},\\lambda ) = 1/A(\\vec{b},\\lambda )$ one can rewrite this as $P(\\vec{a},\\vec{b}) - P(\\vec{a},\\vec{c})=\\int d\\lambda \\;\\rho (\\lambda )A(\\vec{a},\\lambda )A(\\vec{b},\\lambda )[A(\\vec{b},\\lambda )A (\\vec{c},\\lambda ) -1].$ ', 'Bell then asserts $|P(\\vec{a},\\vec{b}) - P(\\vec{a},\\vec{c})| \\le \\int d\\lambda \\;\\rho (\\lambda )[A(\\vec{b},\\lambda )A (\\vec{c},\\lambda ) -1],$ ', 'where, of course, $|A(\\vec{a},\\lambda )A(\\vec{b},\\lambda )| = 1$ . However, stricly speaking the triangle inequality gives $|P(\\vec{a},\\vec{b}) - P(\\vec{a},\\vec{c}) | \\le \\int d\\lambda \\;|\\rho (\\lambda )|[A(\\vec{b},\\lambda )A (\\vec{c},\\lambda ) -1],$ ', 'which is equal to (REF ) only when $|\\rho | = \\rho $ , i.e., when $\\rho \\ge 0$ . ', 'CHSH. The CHSH paper (See [DOI:10.1103/physrevlett.23.880]) makes the same assumption at the identical point in their derivation, in their first (unnumbered) equation. ', "Peres. Peres' derivation (See [Ref.7 of quant-ph/0004109]) is almost identical to Eberhard's and makes the same assumption of positive weights in the same step, i.e. between steps 1 and 2 of Eq. (REF ) of this paper. ", "Stapp 71. Stapp's 1971 proof (See [DOI:10.1103/physrevd.3.1303]) is very similar to Bell's. He arrives at an expression (below his equation 8) $\\sqrt{2} \\le \\frac{1}{N}\\sum _j|n_{2j}^{\\prime \\prime }n_{2j}^{\\prime } - 1|,$ ", "where $n_{2j}^{\\prime \\prime } = \\pm 1$ and $n_{2j}^{\\prime } = \\pm 1$ . He then shows this leads to the contradiction $\\sqrt{2} \\le 1$ . However, if the $n$ 's are $\\pm 1$ , then the summand can only have values 0,2. If $N_1$ and $N_2$ are the frequencies with which these two values occur, and $N_1 + N_2 = N$ , then the right hand side can be written $\\frac{1}{N}[N_1 \\times 0 + N_2 \\times 2] = \\frac{2N_2}{N} =\\frac{2(N - N_1)}{N} = 2(1 - \\frac{N_1}{N}).$ ", 'As in the Eberhard argument, a contradiction can always be avoided by taking $N_1$ negative. ', 'Stapp 85. Stapp (See [Ref.8 of quant-ph/0004109]) establishes a contradiction by demonstrating (his Eq. 8) that $\\frac{1}{n}\\sum _{i = 1}^n\\left[\\sqrt{2}\\; r_{Ai}(\\hat{\\lambda }_a) +r_{Bi}(\\hat{\\lambda }_a) + r_{Bi}(\\hat{\\lambda }_b)\\right]^2> (\\sqrt{2} - 2)^2,$ ', "where $r_{Ai}(\\hat{\\lambda }_a) = \\pm 1$ , $ r_{Bi}(\\hat{\\lambda }_a) =\\pm 1$ and $r_{Bi}(\\hat{\\lambda }_b) = \\pm 1$ . However, since the $r$ 's are $\\pm 1$ , the summand can have only one of three values: $(\\sqrt{2})^2$ , $(2 + \\sqrt{2})^2$ and $(2 -\\sqrt{2})^2$ . Then the above expression can be written as $\\frac{1}{n}\\left[n_1(\\sqrt{2})^2 + n_2 (\\sqrt{2} + 2)^2 + n_3(2 - \\sqrt{2})^2\\right],$ ", 'where $n_1, n_2, n_3$ are the frequencies with which the three terms occur and $n_1 + n_2 + n_3 = n$ . Squaring out and co ...

# %%
cat_final_i, sec_final_i = concatenate_text(all_text, body_text_i, metadata_i, encoding=encoding)
Reference = "|.|".join(Reference)

undo_citation_keys   = []
undo_citation_string = []
done_citation_keys   = []
done_citation_string = []
done_citation_doi    = []
for key, valpool in data['bib_entries'].items():

    citation = valpool.get('bib_entry_raw',"")
    if not citation:continue

    ids = valpool.get('ids',None)
    unique_id = UniqueID.from_dict(ids)
    if unique_id.is_nan():
        undo_citation_keys.append(key)  
        undo_citation_string.append(citation)  
    else:
        done_citation_keys.append(key)  
        done_citation_string.append(citation)
        done_citation_doi.append({k:val for k,val in unique_id.to_dict().items() if val})

bibitem_ref_metadata = {k:v for k,v in zip(undo_citation_keys, undo_citation_string)}
bibitem_ref_metadata = bibitem_ref_metadata| {k:v for k,v in zip(done_citation_keys, done_citation_string)}
whole_metadata = {'figures_metadata':figures_metadata,
                  'tables_metadata':tables_metadata,
                  'bibitem_ref_metadata':bibitem_ref_metadata}
whole_ref_to_labels = table_ref|figure_ref
abstract = better_latex_sentense_string(data.get('abstract')['text'])
output_dict = {'abstract':abstract,
               'acknowledge':acknowledgement,
               'sections':{cat_final_i},
               'appendix':[],
               'metadata':whole_metadata,
               'paper_id':paper_id,
               'whole_ref_to_labels':whole_ref_to_labels,
               'missing_citation_labels':missing_citation_labels}

# %%
body_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[257], line 1
# ----> 1 body_text
#
# NameError: name 'body_text' is not defined

# %%
from dataclasses import dataclass

# %%
from typing import List

# %%
from python_script.reference_reterive.Reference import flatten_dict
from xml_to_dense_text import better_latex_sentense_string
class BaseElement:
    def to_dict(self):
        return vars(self)
    
    def to_flatten_dict(self):
        out = flatten_dict(self.to_dict())
        
        return out
    

@dataclass
class Section(BaseElement):
    section_title: str = None
    section_content: List[str] = None

@dataclass
class PaperMetadata(BaseElement):
    figures_metadata: dict = None
    tables_metadata: dict = None
    bibitem_ref_metadata: dict = None

@dataclass
class Paper(BaseElement):
    paper_id: str = None
    abstract: str = None
    acknowledge: str = None
    sections: List[Section] = None
    appendix: List[Section] = None
    metadata: PaperMetadata = None
    whole_ref_to_labels: Dict[str, list] = None
    missing_citation_labels: dict = None
    def to_dict(self):
        return vars(self)
    
    def to_flatten_dict(self):
        out = flatten_dict(self.to_dict())
        return out
    @staticmethod
    def get_paper_id(pool):
        return pool.get('paper_id', None)
    
    
    
    @staticmethod
    def abstract(pool):
        abstract =  pool.get('abstract', None)
        if isinstance(abstract, dict):
            abstract = abstract['text']
        abstract = better_latex_sentense_string(abstract)
        return abstract

# %%
print(data['abstract']['text'].strip().replace('\n', ' '))
# Out:
# Despite claims that Bell's inequalities are based on the Einstein locality condition, or equivalent, all derivations make an identical mathematical assumption: that local hidden-variable theories produce a set of positive-definite probabilities for detecting a particle with a given spin orientation. The standard argument is that because quantum mechanics assumes that particles are emitted in a superposition of states the theory cannot produce such a set of probabilities. We examine a paper by Eberhard, and several similar papers, which claim to show that a generalized Bell inequality, the CHSH inequality, can be derived solely on the basis of the locality condition, without recourse to hidden variables. We point out that these authors nonetheless assumes a set of positive-definite probabilities, which supports the claim that hidden variables or "locality" is not at issue here, positive-definite probabilities are. We demonstrate that quantum mechanics does predict a set of probabilities that violate the CHSH inequality; however these probabilities are not positive-definite. Nevertheless, they are physically meaningful in that they give the usual quantum-mechanical predictions in physical situations. We discuss in what sense our results are related to the Wigner distribution.

# %%
abstract = better_latex_sentense_string(data.get('abstract')['text'])

# %%
missing_citation_labels = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 missing_citation_labels
#
# NameError: name 'missing_citation_labels' is not defined

# %%
#os.makedirs(output_dir, exist_ok=True)

#Content_Paht = os.path.join(output_dir, f'{_paper_id}.retrieved.json') if reterive_result_mode else os.path.join(output_dir, f'{_paper_id}.json')
# with open(Content_Paht, 'w') as f:json.dump(output_dict, f, indent=2)
# if not reterive_result_mode:
#     keys  = list(bibitem_ref_metadata.keys())
#     citation_string = [bibitem_ref_metadata[key] for key in keys]
#     with open(os.path.join(output_dir, f'reference.keys'), 'w') as f:
#         for key in keys:f.write(key+'\n')
#     with open(os.path.join(output_dir, f'reference.txt'), 'w') as f:
#         for string in citation_string:f.write(string+'\n')
#     with open(os.path.join(output_dir, f'bibitem_ref_metadata_not_in_context.json'), 'w') as f:
#         json.dump(bibitem_ref_metadata_not_in_context, f, indent=2)
#     with open(os.path.join(output_dir, f'note_ref_metadata_not_in_context.json'), 'w') as f:
#         json.dump(note_ref_metadata_not_in_context, f, indent=2)

# %%
for key, val in data['bib_entries'].items():
    print(UniqueID.from_dict(val['ids']))
    break
# Out:
# Paper:
# doi |-> 10.1119/1.13804
# openalex |-> w1987630316
# semopenalex |-> w1987630316

# %%
from python_script.reference_reterive.Reference import UniqueID

# %%
paper = UniqueID.from_dict(val['ids'])

# %%
with open("/nvme/zhangtianning.di/openalex/paper_identity.jsonl",'r') as f:
    for line in f:
        identity_set = json.loads(line)
        break

# %%
identity_set
# Out:
# {'openalex': 'W4312243914', 'doi': '10.3030/750533'}

# %%
paper.to_dict()
# Out:
# {'doi': '10.1119/1.13804',
#  'openalex': 'w1987630316',
#  'semopenalex': 'w1987630316'}

# %%
all_raw_files[0]
# Out:
# '/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0004_001.jsonl'

# %%
paper.to_dict()
# Out:
# {'doi': '10.1119/1.13804',
#  'openalex': 'w1987630316',
#  'semopenalex': 'w1987630316'}

# %%
conflict_doi_that_should_same_but_splited_dir
# Out:
# '/nvme/zhangtianning.di/datasets/unarxive_Conflict/00'

# %%
filename = all_raw_files[0]
Prefix_Code = str(filename).split('/')[-1].replace('arXiv_src_','').replace('jsonl','')
conflict_doi_that_should_same_but_splited = []
conflict_doi_that_should_same_but_splited_path = str(filename).replace('unarxive','unarxive_Conflict').replace('.jsonl','.json')
conflict_doi_that_should_same_but_splited_dir  = os.path.dirname(conflict_doi_that_should_same_but_splited_path)
os.makedirs(conflict_doi_that_should_same_but_splited_dir)

# %%
#if os.path.exists(conflict_doi_that_should_same_but_splited_path):continue
with open(filename, 'r') as f:
    length = len(f.readlines())
with open(filename, 'r') as f:
    for slot, line in tqdm(enumerate(f),total=length, position=2, leave=False):
        data = json.loads(line)
        if 'bib_entries' in data:
            for key, val in data['bib_entries'].items():
                if 'ids' not in val:continue
                paper = UniqueID.from_dict(val['ids'])
                if paper.is_nan():continue
                doi_and_indexes= []
                for alias_type,alias_value in paper.to_dict().items():
                    if alias_type == 'semopenalex':continue
                    if 'openalex' in alias_type:alias_value = alias_value.replace('w','W')
                    doi_and_indexes.append([alias_type, alias_value, get_index_by_alias(r,alias_type, alias_value)])
                the_valid_indexes= list(set([index for alias_type, alias_value, index in doi_and_indexes if index is not None]))
                if len(the_valid_indexes)>1:
                    multirecord_doi = [[alias_type, alias_value] for alias_type, alias_value, index in doi_and_indexes if index is not None]
                    conflict_doi_that_should_same_but_splited.append(multirecord_doi)
                    continue
                if len(the_valid_indexes)==0:
                    the_record_index = f"UA.{Prefix_Code}.{slot}"
                    for alias_type, alias_value, index in doi_and_indexes:
                        unique_name = format_alias(alias_type, alias_value)
                        add_alias_with_unique_name(r,alias_type, alias_value, the_record_index)
                else:
                    the_record_index = the_valid_indexes[0]
                    old_set = get_alias_by_index(r,the_record_index)
                    for alias_type, alias_value, index in doi_and_indexes:
                        unique_name = format_alias(alias_type, alias_value)
                        if unique_name in old_set:continue
                        add_alias_with_unique_name(r,alias_type, alias_value, the_record_index)
# Out:
#   0%|          | 0/1876 [00:00<?, ?it/s]
# pubmed:10045028
# pubmed:10038115
# pubmed:10034381
# pubmed:10056476
# arxiv:hep-th/9306039
# pubmed:10057575
# pubmed:10058410
# pubmed:10059978
# pubmed:10059979
# arxiv:quant-ph/9811018
# pubmed:10058408
# arxiv:quant-ph/9503017
# pubmed:10058409
# pubmed:9912655
# pubmed:9912645
# arxiv:quant-ph/9503016
# arxiv:quant-ph/9902071
# pubmed:10059671
# arxiv:quant-ph/9604034v1
# pubmed:9902079
# pubmed:9899572
# pubmed:9960745
# pubmed:9963242
# openalex:W2502808615
# pubmed:9963241
# pubmed:10044956
# pubmed:10060692
# arxiv:quant-ph/9602004
# pubmed:10061534
# arxiv:quant-ph/9511027
# openalex:W3005571154
# pubmed:9903985
# pubmed:9913432
# pubmed:10045774
# pubmed:9897735
# pubmed:10058872
# openalex:W2028406173
# arxiv:quant-ph/9806029
# pubmed:10046665
# arxiv:cs/9910010
# arxiv:quant-ph/9704026
# arxiv:quant-ph/9711065
# arxiv:quant-ph/9605044
# arxiv:quant-ph/9710013
# pubmed:9913930
# arxiv:quant-ph/9604024
# pubmed:9910380
# arxiv:hep-th/9305062
# arxiv:quant-ph/9711021
# arxiv:quant-ph/9711049
# arxiv:quant-ph/9810082
# pubmed:9913410
# openalex:W3117619190
# pubmed:9902211
# arxiv:quant-ph/9810018
# pubmed:10062305
# openalex:W3021492718
# pubmed:10044000
# pubmed:9911677
# arxiv:hep-th/9406058
# arxiv:quant-ph/9812075
# openalex:W1988520084
# pubmed:10053414
# pubmed:9911903
# arxiv:quant-ph/9711021
# pubmed:9911893
# pubmed:9910380
# arxiv:hep-th/9305062
# arxiv:quant-ph/9710013
# arxiv:quant-ph/9808040
# arxiv:quant-ph/9807020
# pubmed:9911893
# pubmed:9911679
# arxiv:cond-mat/9407022
# openalex:W2146537406
# arxiv:quant-ph/9712011
# arxiv:quant-ph/9508027
# pubmed:9913770
# arxiv:quant-ph/9604034v1
# openalex:W2085163160
# pubmed:9913673
# pubmed:9902422
# arxiv:quant-ph/9707019
# pubmed:9903678
# arxiv:quant-ph/0006019
# pubmed:10053414
# pubmed:17837304
# pubmed:10047097
# pubmed:9911315
# pubmed:9913435
# pubmed:9913202
# pubmed:9913909
# pubmed:9909307
# pubmed:10046119
# arxiv:quant-ph/9810035
# pubmed:9908086
# pubmed:10054856
# pubmed:10054507
# pubmed:10061622
# pubmed:9911745
# pubmed:10059978
# openalex:W1976045784
# pubmed:9907570
# pubmed:9908638
# pubmed:10060877
# pubmed:10062013
# arxiv:atom-ph/9608001
# openalex:W1965506886
# pubmed:10062685
# pubmed:10042377
# pubmed:10053414
# pubmed:10059782
# arxiv:quant-ph/9807088
# arxiv:cond-mat/9902293
# arxiv:cond-mat/9905425
# arxiv:cond-mat/9901109
# openalex:W2569293185
# arxiv:quant-ph/9702036
# arxiv:quant-ph/9806088
# openalex:W3038125555
# arxiv:quant-ph/9804010
# arxiv:quant-ph/9808001
# arxiv:quant-ph/9804001
# pubmed:10044956
# pubmed:10033345
# pubmed:9895586
# pubmed:9895773
# pubmed:9896345
# pubmed:9907778
# pubmed:9908625
# pubmed:10054313
# pubmed:9913018
# pubmed:10062393
# pubmed:11970551
# arxiv:quant-ph/0606134
# pubmed:9912937
# arxiv:quant-ph/9506019
# pubmed:9903741
# pubmed:9897826
# pubmed:9910582
# pubmed:9910955
# pubmed:9962289
# arxiv:gr-qc/9402026
# pubmed:10033776
# pubmed:10046747
# pubmed:10043074
# openalex:W2075496155
# pubmed:10044229
# pubmed:10039540
# pubmed:10056088
# pubmed:9896342
# pubmed:9898161
# openalex:W2086737343
# pubmed:17837304
# pubmed:9913930
# arxiv:quant-ph/9604024
# pubmed:9913578
# arxiv:quant-ph/9512032
# pubmed:9913672
# arxiv:quant-ph/9604038
# arxiv:quant-ph/9610042
# arxiv:quant-ph/9604034v1
# arxiv:quant-ph/9702058
# pubmed:10061806
# pubmed:10062908
# pubmed:10044858
# pubmed:10061265
# pubmed:9895773
# pubmed:10015735
# pubmed:10060523
# openalex:W2044462545
# pubmed:10061502
# arxiv:cond-mat/9904399
# arxiv:quant-ph/9710044
# openalex:W1994358697
# pubmed:9901493
# pubmed:9957165
# pubmed:9903779
# pubmed:10056705
# pubmed:9904128
# pubmed:9904746
# arxiv:quant-ph/9904047
# pubmed:9914002
# pubmed:9910167
# arxiv:quant-ph/0001065
# openalex:W2157005274
# arxiv:quant-ph/9706033
# pubmed:10053414
# pubmed:10062908
# arxiv:quant-ph/9604034v1
# pubmed:9913672
# arxiv:quant-ph/9604038
# arxiv:quant-ph/9703040
# arxiv:quant-ph/9612003
# arxiv:quant-ph/9708042
# arxiv:quant-ph/9705044
# arxiv:quant-ph/9705045
# arxiv:quant-ph/9705045
# arxiv:quant-ph/9807004
# arxiv:quant-ph/9809081
# openalex:W2746613842
# arxiv:quant-ph/9902041
# arxiv:quant-ph/9907096
# arxiv:quant-ph/0003134v1
# arxiv:quant-ph/9901047
# pubmed:9911679
# arxiv:cond-mat/9407022
# pubmed:10058409
# pubmed:11018926
# arxiv:quant-ph/9604034
# pubmed:11030936
# arxiv:quant-ph/0002072
# arxiv:quant-ph/9910016
# openalex:W1969246646
# arxiv:quant-ph/9702029
# openalex:W2524287724
# arxiv:quant-ph/9906129
# pubmed:9912645
# arxiv:quant-ph/9503016
# pubmed:10061806
# arxiv:quant-ph/9903099
# arxiv:quant-ph/9810080
# openalex:W2076311580
# pubmed:9913923
# arxiv:quant-ph/9611006
# arxiv:quant-ph/9904023
# openalex:W2099111195
# arxiv:quant-ph/9703043
# openalex:W2085163160
# pubmed:9913673
# arxiv:quant-ph/9809023
# pubmed:10060970
# pubmed:10054093
# openalex:W2036421274
# pubmed:10041050
# openalex:W1610274090
# pubmed:10975610
# pubmed:9912862
# arxiv:quant-ph/9812018
# pubmed:9911559
# arxiv:quant-ph/9704037
# pubmed:10044144
# pubmed:9908989
# pubmed:9913427
# arxiv:quant-ph/9812028
# pubmed:9909468
# pubmed:10062500
# openalex:W122965473
# pubmed:10044786
# arxiv:cond-mat/9709091
# openalex:W2091261194
# pubmed:10062660
# pubmed:9913018
# pubmed:9895586
# pubmed:10011915
# pubmed:9913868
# pubmed:11017376
# arxiv:quant-ph/9910027
# pubmed:10054313
# pubmed:9909115
# arxiv:quant-ph/9811026
# pubmed:10053542
# pubmed:10061872
# pubmed:9912776
# arxiv:quant-ph/9703012
# arxiv:quant-ph/9911058
# arxiv:math-ph/9807032
# arxiv:quant-ph/9802052
# pubmed:10053414
# pubmed:10058410
# pubmed:10059732
# arxiv:quant-ph/9810087
# pubmed:10059979
# arxiv:quant-ph/9806012
# arxiv:quant-ph/9909038
# arxiv:quant-ph/9802058
# pubmed:10033521
# pubmed:10033522
# arxiv:quant-ph/9810035
# pubmed:10046665
# pubmed:10061348
# arxiv:quant-ph/9706033
# pubmed:10053414
# arxiv:quant-ph/9704026
# arxiv:quant-ph/9810040
# arxiv:quant-ph/9810039
# arxiv:quant-ph/9803023
# pubmed:5493790
# pubmed:19564780
# arxiv:quant-ph/9702036
# arxiv:quant-ph/9708032
# arxiv:quant-ph/9611027
# pubmed:9957165
# openalex:W1994358697
# pubmed:9901493
# pubmed:9903779
# pubmed:10011915
# pubmed:9913106
# arxiv:quant-ph/9511030
# pubmed:10053414
# arxiv:quant-ph/9811036
# arxiv:quant-ph/9806021
# arxiv:quant-ph/9810087
# openalex:W4298228909
# arxiv:quant-ph/9706033
# pubmed:10045931
# arxiv:quant-ph/9902036
# pubmed:10053414
# pubmed:10061534
# arxiv:quant-ph/9511027
# pubmed:11019121
# arxiv:quant-ph/9908036
# arxiv:quant-ph/9904023
# pubmed:9913770
# pubmed:9913771
# arxiv:quant-ph/9604022
# arxiv:quant-ph/9703041
# pubmed:9913930
# arxiv:quant-ph/9604024
# arxiv:quant-ph/9709029
# openalex:W2030713877
# arxiv:quant-ph/9806058
# arxiv:quant-ph/9710013
# arxiv:quant-ph/9812018
# arxiv:quant-ph/0001075
# arxiv:quant-ph/0001110
# arxiv:quant-ph/9910022
# arxiv:quant-ph/0002026
# pubmed:10063072
# arxiv:quant-ph/9604005
# arxiv:quant-ph/9910001
# pubmed:10056087
# arxiv:quant-ph/0004079
# openalex:W1985771852
# pubmed:10059449
# arxiv:quant-ph/9809037
# pubmed:10063030
# pubmed:10055346
# pubmed:10057027
# arxiv:quant-ph/9804018
# openalex:W1610274090
# arxiv:quant-ph/0002055
# openalex:W2099111195
# pubmed:9911903
# openalex:W2085163160
# pubmed:9913673
# arxiv:quant-ph/9611006
# openalex:W2142453065
# arxiv:quant-ph/9911079
# pubmed:9911903
# pubmed:9913770
# openalex:W1977821353
# pubmed:9913771
# arxiv:quant-ph/9604022
# openalex:W1970302872
# arxiv:quant-ph/9706061
# arxiv:quant-ph/0011014
# pubmed:9913930
# arxiv:quant-ph/9604024
# pubmed:9957054
# arxiv:quant-ph/9706033
# pubmed:9913235
# arxiv:quant-ph/9512001
# pubmed:9912632
# arxiv:quant-ph/9705044
# arxiv:quant-ph/9807004
# arxiv:quant-ph/9804014
# arxiv:quant-ph/9811003
# pubmed:10059732
# pubmed:9903355
# pubmed:9914009
# pubmed:9904801
# pubmed:9912449
# arxiv:quant-ph/9601030
# pubmed:10033345
# pubmed:9897743
# pubmed:10061265
# pubmed:10058593
# pubmed:10061265
# arxiv:quant-ph/9708022
# arxiv:quant-ph/9806021
# pubmed:7885880
# arxiv:quant-ph/9706001
# arxiv:math-ph/9807024
# arxiv:gr-qc/9405029
# pubmed:10058975
# arxiv:quant-ph/9707028
# pubmed:10044000
# pubmed:10063072
# arxiv:quant-ph/9604005
# arxiv:quant-ph/9901072
# arxiv:physics/9712001
# pubmed:17837304
# openalex:W1964004466
# pubmed:10039885
# pubmed:10041727
# pubmed:10055102
# pubmed:10038691
# pubmed:9913469
# pubmed:9909100
# pubmed:9912530
# arxiv:quant-ph/9810003
# arxiv:quant-ph/9908081
# openalex:W2093708734
# pubmed:10054467
# openalex:W1991859066
# arxiv:quant-ph/9912043
# pubmed:9912645
# arxiv:quant-ph/9503016
# pubmed:10749200
# openalex:W2109741106
# arxiv:quant-ph/9708016
# arxiv:quant-ph/9709001
# arxiv:quant-ph/9803072
# openalex:W2142453065
# arxiv:quant-ph/9911079
# pubmed:9913770
# arxiv:quant-ph/9801002
# arxiv:quant-ph/9708022
# arxiv:quant-ph/0010071
# pubmed:9912645
# arxiv:quant-ph/9503016
# pubmed:10059978
# pubmed:9914004
# pubmed:10053518
# pubmed:10053519
# pubmed:9910711
# arxiv:quant-ph/0409050
# pubmed:9895773
# pubmed:10054327
# pubmed:9911405
# pubmed:11018883
# arxiv:quant-ph/9611045
# pubmed:9895586
# openalex:W2091261194
# pubmed:10062660
# arxiv:quant-ph/9604034v1
# arxiv:quant-ph/9806012
# pubmed:9912183
# arxiv:quant-ph/9803045
# pubmed:9907607
# openalex:W2091382889
# pubmed:9911669
# pubmed:9903779
# openalex:W1610274090
# pubmed:10975610
# pubmed:11017377
# pubmed:17837304
# pubmed:10039398
# pubmed:10053414
# pubmed:10062053
# arxiv:quant-ph/9604039
# pubmed:9913106
# arxiv:quant-ph/9511030
# arxiv:quant-ph/9610044
# arxiv:quant-ph/9811091
# arxiv:quant-ph/9703041
# pubmed:9913930
# arxiv:quant-ph/9604024
# arxiv:quant-ph/9809082
# pubmed:10063072
# arxiv:quant-ph/9604005
# arxiv:physics/9712001
# arxiv:quant-ph/9809082
# openalex:W2028406173
# arxiv:quant-ph/9806029
# arxiv:quant-ph/9711065
# arxiv:quant-ph/9605044
# openalex:W2083014227
# pubmed:11136018
# arxiv:quant-ph/0003072
# doi:10.1142/0613
# openalex:W1571300791
# arxiv:quant-ph/9706033
# pubmed:10059978
# pubmed:10060523
# arxiv:quant-ph/9904096
# pubmed:10058410
# arxiv:quant-ph/9810039
# arxiv:quant-ph/9810040
# arxiv:quant-ph/9810087
# arxiv:quant-ph/9806021
# arxiv:quant-ph/9903044
# openalex:W2057883617
# pubmed:9909547
# pubmed:9910869
# arxiv:quant-ph/9801025
# openalex:W2031016911
# pubmed:10060907
# arxiv:quant-ph/9511007
# openalex:W2167050139
# openalex:W2799150811
# pubmed:10096793
# pubmed:17837304
# pubmed:10043760
# pubmed:11299042
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/31338
# openalex:W1785119608
# pubmed:9910979
# pubmed:19559947
# pubmed:3797887
# openalex:W1979700341
# pubmed:10060366
# pubmed:10062233
# arxiv:cond-mat/9904399
# pubmed:9908238
# pubmed:9910453
# arxiv:quant-ph/9801076
# arxiv:hep-th/9712038
# arxiv:quant-ph/0406158
# arxiv:quant-ph/9903098
# arxiv:hep-th/9210067
# pubmed:9959337
# arxiv:physics/9805038
# arxiv:quant-ph/9906062
# pubmed:9908632
# pubmed:9913077
# arxiv:quant-ph/9711039
# arxiv:quant-ph/9803031
# pubmed:9913432
# pubmed:9913637
# pubmed:10063159
# pubmed:9909314
# arxiv:quant-ph/9806077
# pubmed:9902272
# pubmed:9909982
# pubmed:11017684
# arxiv:quant-ph/9908065
# arxiv:quant-ph/9707043
# pubmed:10990653
# arxiv:quant-ph/9912046
# pubmed:11017309
# arxiv:quant-ph/9908056
# openalex:W2157005274
# pubmed:10045729
# pubmed:9913328
# pubmed:9910464
# pubmed:9903068
# pubmed:9913891
# arxiv:hep-th/9801069
# arxiv:quant-ph/9811037
# openalex:W1524707262
# openalex:W599030216
# pubmed:12780268
# pubmed:10054200
# openalex:W2083095544
# openalex:W2088572661
# pubmed:9901420
# openalex:W2084463141
# pubmed:10041054
# pubmed:10040407
# openalex:W2013210086
# pubmed:10043562
# pubmed:10044268
# pubmed:9907873
# pubmed:10062361
# pubmed:10061444
# pubmed:10062973
# arxiv:quant-ph/9810051
# pubmed:10040098
# pubmed:9910161
# pubmed:15222900
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/459214
# pubmed:10044954
# pubmed:9904394
# pubmed:10055796
# pubmed:9965744
# pubmed:11969874
# pubmed:11969689
# arxiv:physics/9810019
# openalex:W1978275108
# pubmed:9964707
# pubmed:9961819
# pubmed:11970001
# pubmed:9895693
# openalex:W1978067532
# pubmed:9962279
# pubmed:9965141
# openalex:W2002729739
# pubmed:10008017
# pubmed:9976324
# pubmed:10003333
# pubmed:10038122
# pubmed:10038855
# pubmed:9985776
# pubmed:9912142
# openalex:W3035162019
# pubmed:9909184
# pubmed:10058557
# pubmed:9910395
# pubmed:10058557
# pubmed:9912637
# arxiv:astro-ph/9811018
# pubmed:10058224
# pubmed:10012435
# pubmed:9956708
# pubmed:9957856
# openalex:W1496132708
# pubmed:10411109
# pubmed:10012435
# openalex:W2099111195
# pubmed:12780098
# pubmed:10046586
# openalex:W1999135680
# pubmed:16593261
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/347408
# openalex:W2038874225
# pubmed:6323997
# pubmed:2197990
# openalex:W30415900
# pubmed:2185240
# pubmed:440969
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/327755
# pubmed:1871119
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/52230
# pubmed:5040245
# pubmed:2714249
# openalex:W2013048450
# pubmed:10390337
# pubmed:3670410
# pubmed:2928304
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/286795
# pubmed:8515463
# pubmed:2482765
# pubmed:2704739
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/286969
# openalex:W2002337126
# pubmed:9912067
# pubmed:10039440
# openalex:W2055029819
# pubmed:10053632
# arxiv:cond-mat/9906035
# pubmed:9913175
# pubmed:10054556
# pubmed:9910464
# pubmed:9913452
# pubmed:9907375
# openalex:W2061846298
# pubmed:9560386
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/1460098
# pubmed:4603159
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/1213122
# openalex:W2101994201
# pubmed:797306
# pubmed:6304533
# pubmed:9192894
# pubmed:9121553
# pubmed:7922307
# pubmed:10553899
# pubmed:28563590
# pubmed:17246489
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/1203599
# openalex:W1999135680
# pubmed:16593261
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/347408
# openalex:W2038874225
# pubmed:6323997
# pubmed:6087336
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/391544
# openalex:W1963658914
# pubmed:3960133
# pubmed:3600796
# pubmed:3001314
# pubmed:2197990
# openalex:W30415900
# pubmed:2185240
# pubmed:6265793
# pubmed:6265794
# pubmed:7285918
# pubmed:2726457
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/317725
# openalex:W2047728595
# pubmed:1418738
# pubmed:3670410
# pubmed:2928304
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/286795
# pubmed:8515463
# pubmed:450714
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/327812
# pubmed:6933438
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/349717
# pubmed:2006170
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/51221
# pubmed:440969
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/327755
# pubmed:1871119
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/52230
# pubmed:5040245
# pubmed:2482765
# pubmed:2714249
# openalex:W2013048450
# pubmed:10390337
# pubmed:1095931
# pubmed:884201
# pubmed:3370295
# pubmed:7816643
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/332108
# pubmed:3017412
# pubmed:2704739
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/286969
# pubmed:3030560
# pubmed:3912515
# pubmed:7997878
# openalex:W1584476217
# pubmed:2619942
# pubmed:9907704
# arxiv:physics/9904028
# pubmed:17246489
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/1203599
# pubmed:8409356
# pubmed:28568879
# pubmed:10062617
# openalex:W3117390298
# pubmed:10060532
# pubmed:10043422
# openalex:W1969161884
# pubmed:10054198
# pubmed:10045729
# pubmed:10054556
# pubmed:9910464
# openalex:W2086771785
# openalex:W2077326470
# arxiv:0907.0668
# arxiv:physics/9909038
# arxiv:quant-ph/9902028
# pubmed:9960410
# pubmed:9962683
# pubmed:10044954
# pubmed:11969689
# arxiv:physics/9810019
# pubmed:10055796
# pubmed:9982495
# pubmed:9943498
# arxiv:physics/9806003
# openalex:W2083973080
# pubmed:9938219
# openalex:W2071679734
# pubmed:9982136
# arxiv:cond-mat/9511108
# pubmed:10004801
# arxiv:quant-ph/9807070
# arxiv:physics/9707019
# pubmed:9912331
# pubmed:9961908
# pubmed:9965413
# openalex:W2099111195
# arxiv:physics/0002035
# arxiv:physics/0004001
# openalex:W1965280195
# arxiv:physics/0002035
# openalex:W1675234207
# openalex:W1965280195
# arxiv:hep-ph/9912388
# pubmed:10019904
# arxiv:hep-ph/9512262
# arxiv:hep-ph/9802378
# pubmed:10014752
# arxiv:nucl-th/9903012
# pubmed:9971699
# arxiv:hep-ph/9606471
# arxiv:hep-ph/9801345
# pubmed:11018876
# arxiv:hep-ph/9908512
# arxiv:nucl-th/9903040
# pubmed:10018402
# arxiv:nucl-th/9406001
# pubmed:10411109
# pubmed:10014754
# pubmed:9969521
# openalex:W2058834119
# pubmed:9968891
# pubmed:9970037
# arxiv:nucl-th/9608044
# arxiv:nucl-th/9808012
# arxiv:hep-ph/9812287
# arxiv:hep-ph/0004095v1
# arxiv:nucl-th/9907086
# arxiv:hep-ph/9910295
# arxiv:hep-ph/9711396
# arxiv:nucl-th/9811104
# arxiv:hep-ph/9811473
# arxiv:nucl-th/9802057v1
# openalex:W4214840129
# pubmed:10043599
# pubmed:10043558
# arxiv:nucl-ex/9901005
# pubmed:9970362
# arxiv:nucl-th/9711002
# openalex:W2049364693
# pubmed:10062353
# pubmed:9969985
# arxiv:nucl-th/9406008
# pubmed:9969007
# pubmed:10056587
# pubmed:10032209
# pubmed:10055858
# arxiv:nucl-th/9406012
# pubmed:10053676
# pubmed:10059319
# arxiv:nucl-th/9506013
# arxiv:nucl-th/9902073
# pubmed:10045549
# arxiv:hep-ph/9712492
# pubmed:9968281
# pubmed:9971250
# openalex:W1978777985
# arxiv:nucl-th/9803057
# pubmed:9966693
# pubmed:9954092
# pubmed:9970667
# arxiv:hep-ph/9502218
# pubmed:9967436
# pubmed:10042611
# arxiv:hep-lat/9902016
# openalex:W2155070207
# openalex:W2107120226
# openalex:W2034224352
# pubmed:10019941
# arxiv:hep-ph/9409430
# arxiv:nucl-th/9812032
# arxiv:hep-ph/9804273
# arxiv:hep-ph/9902326
# arxiv:hep-ph/9804391
# arxiv:hep-ph/9907491
# openalex:W2064771291
# arxiv:nucl-th/9712069
# arxiv:hep-ph/9609229
# arxiv:nucl-th/9802066
# arxiv:nucl-th/9908037
# pubmed:11015928
# arxiv:nucl-th/9911067
# pubmed:10054896
# pubmed:10056210
# arxiv:nucl-ex/9905002
# pubmed:10033194
# pubmed:9971211
# arxiv:nucl-th/9508047
# pubmed:10060190
# pubmed:10038017
# pubmed:11017458
# arxiv:nucl-ex/9908014
# arxiv:nucl-th/9810022
# arxiv:nucl-th/9706003
# pubmed:9968891
# openalex:W4214840129
# arxiv:nucl-th/9703009
# pubmed:10060190
# pubmed:10056833
# pubmed:10053941
# pubmed:9969931
# arxiv:nucl-ex/9810015
# pubmed:9971516
# pubmed:9969893
# pubmed:10057084
# arxiv:hep-ex/9405003
# arxiv:nucl-th/9812057
# pubmed:10056206
# pubmed:10053380
# pubmed:9970875
# arxiv:nucl-th/9509007
# arxiv:nucl-th/9610026
# pubmed:9971168
# arxiv:nucl-th/9506008
# pubmed:9969354
# pubmed:9971671
# arxiv:nucl-th/9609046
# arxiv:nucl-th/9811045
# arxiv:nucl-th/9705009
# pubmed:9970778
# arxiv:nucl-th/9507011
# arxiv:q-alg/9601007
# arxiv:hep-th/9501141
# openalex:W2083960709
# pubmed:11969923
# arxiv:chao-dyn/9807018
# pubmed:11088666
# pubmed:10042549
# pubmed:10042487
# pubmed:11970584
# pubmed:11970229
# openalex:W2077667513
# arxiv:0709.3108
# pubmed:10055594
# pubmed:10011572
# pubmed:10041657
# pubmed:11969843
# arxiv:solv-int/9712004
# openalex:W2005228777
# arxiv:solv-int/9505004
# openalex:W1496798092
# openalex:W2056454305
# pubmed:9906033
# pubmed:9960170
# pubmed:10055901
# arxiv:gr-qc/9402006
# pubmed:9960005
# openalex:W2058520137
# pubmed:9963666
# pubmed:9965340
# pubmed:9961653
# pubmed:10042735
# pubmed:11970576
# pubmed:9962755
# pubmed:10054617
# openalex:W2467536189
# openalex:W1560060148
# openalex:W2010154591
# pubmed:7701342
# openalex:W1936774573
# pubmed:4559589
# pubmed:9441817
# arxiv:physics/9806046
# pubmed:11969649
# pubmed:10039074
# arxiv:cond-mat/9803340
# arxiv:chao-dyn/9705007v1
# pubmed:9963660
# pubmed:9898277
# openalex:W3101415193
# arxiv:nlin/0004022
# arxiv:hep-th/9712232
# openalex:W2008891504
# arxiv:solv-int/9706006v1
# arxiv:solv-int/9808008
# openalex:W2045394134
# pubmed:9898882
# pubmed:9904456
# pubmed:10786783
# pubmed:9964954
# pubmed:10046278
# arxiv:math/9912143
# openalex:W1691157804
# arxiv:math/9909010
# arxiv:math-ph/9907025v1
# arxiv:math/9907165
# openalex:W2062565740
# arxiv:math/9201261v1
# arxiv:solv-int/9706002
# openalex:W1512385898
# openalex:W2083884937
# openalex:W3100333039
# arxiv:math/9903134
# arxiv:math/9906120
# arxiv:math/9907127v3
# arxiv:solv-int/9810004
# arxiv:math/9912025
# arxiv:math/9904042
# arxiv:hep-th/9306042
# doi:10.1142/9789814531450
# openalex:W2765595164
# openalex:W2083960709
# pubmed:10061448
# pubmed:10058476
# arxiv:adap-org/9501001
# arxiv:cond-mat/9711299
# arxiv:patt-sol/9310005v1
# arxiv:patt-sol/9706005
# arxiv:patt-sol/9706003
# arxiv:patt-sol/9706005
# pubmed:10039906
# arxiv:hep-th/9703002
# openalex:W2179428325
# arxiv:solv-int/9811001
# openalex:W1642629289
# arxiv:patt-sol/9611001
# arxiv:patt-sol/9712004
# pubmed:11046470
# pubmed:11970436
# pubmed:10061366
# arxiv:patt-sol/9605005
# openalex:W1990205020
# openalex:W3100771129
# arxiv:hep-th/9307196
# arxiv:solv-int/9809004
# arxiv:solv-int/9901008v1
# arxiv:solv-int/9707009
# pubmed:10033184
# openalex:W2056454305
# pubmed:10044988
# arxiv:quant-ph/9906087
# pubmed:10038560
# pubmed:10042549
# pubmed:10045718
# pubmed:11046406
# arxiv:cond-mat/9906361
# openalex:W2031184003
# pubmed:10044957
# pubmed:10042450
# pubmed:9906937
# pubmed:10041194
# arxiv:cond-mat/9812249
# arxiv:cond-mat/9807365
# pubmed:10032226
# arxiv:cond-mat/9807145
# pubmed:9984881
# arxiv:cond-mat/9510007
# arxiv:cond-mat/9709091
# pubmed:11015835
# pubmed:10038871
# pubmed:9897220
# openalex:W2046046747
# pubmed:9901698
# pubmed:9962840
# arxiv:chao-dyn/9502006
# pubmed:9963247
# pubmed:17790194
# pubmed:9907159
# arxiv:solv-int/9803016
# arxiv:hep-th/9308143
# arxiv:hep-th/9306155
# arxiv:solv-int/9904003
# arxiv:solv-int/9711010
# arxiv:solv-int/9908002
# arxiv:hep-th/9412170
# arxiv:solv-int/9504001
# arxiv:hep-th/9308143
# arxiv:hep-th/9306155
# arxiv:solv-int/9701004
# arxiv:solv-int/9702006
# pubmed:9945434
# pubmed:9947324
# openalex:W2038810321
# pubmed:9945443
# pubmed:10037930
# openalex:W4242849907
# openalex:W3004031069
# pubmed:9902379
# arxiv:math-ph/9910020
# arxiv:math-ph/9804007
# arxiv:math-ph/9809002v1
# arxiv:chao-dyn/9610019
# openalex:W1986119538
# openalex:W1978561325
# pubmed:10017501
# arxiv:hep-ph/9211301
# pubmed:10019074
# arxiv:hep-th/9709229
# arxiv:math-ph/0004005
# arxiv:math-ph/0002032
# arxiv:math-ph/9904007
# arxiv:hep-th/9911108
# arxiv:hep-th/9904062
# openalex:W2090952208
# openalex:W2088627817
# arxiv:cond-mat/9702213
# pubmed:10060962
# arxiv:cond-mat/9508026
# openalex:W1995596360
# pubmed:10038562
# arxiv:math-ph/0003008
# openalex:W2093315095
# arxiv:quant-ph/9811025
# openalex:W1498458032
# openalex:W1991302355
# openalex:W2525272888
# arxiv:dg-ga/9503001
# arxiv:dg-ga/9505004
# arxiv:dg-ga/9707001
# arxiv:math-ph/9904007
# arxiv:math-ph/9907007
# arxiv:math-ph/9904028
# openalex:W2090952208
# doi:10.48550/arxiv.math-ph/9901013
# openalex:W1787754314
# arxiv:hep-th/9709229
# openalex:W2088627817
# openalex:W204294715
# openalex:W2027448618
# arxiv:quant-ph/9808017
# arxiv:math-ph/0001033
# openalex:W2026640659
# pubmed:10061033
# pubmed:10057199
# arxiv:cond-mat/9410091
# arxiv:cond-mat/9807360
# arxiv:math-ph/9910023
# arxiv:math-ph/0002054
# openalex:W145184629
# pubmed:9961121
# pubmed:10058746
# pubmed:10058668
# pubmed:17821641
# openalex:W2067265108
# openalex:W2023590249
# arxiv:math/0004179
# openalex:W1978274876
# openalex:W2749486094
# pubmed:18290074
# pubmed:18276259
# pubmed:18276262
# arxiv:physics/0004074
# openalex:W1665644395
# pubmed:21869365
# openalex:W1057021034
# openalex:W2745851297
# openalex:W2024314216
# openalex:W2057815787
# arxiv:alg-geom/9503007v1
# arxiv:math/9906059
# arxiv:math/9811128
# openalex:W1964715082
# arxiv:hep-th/9310183
# arxiv:math/9906059
# arxiv:math/9811128
# arxiv:hep-th/9408006
# arxiv:math-ph/0004031
# arxiv:math/9811054
# openalex:W2061596669
# pubmed:16592646
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/383544
# openalex:W4233535297
# openalex:W2077140021
# arxiv:math/0106030v1
# openalex:W2027842332
# arxiv:math/9907007v1
# openalex:W1480660276
# openalex:W2593805616
# arxiv:hep-th/9902029
# arxiv:hep-th/9611092
# arxiv:hep-th/9211119
# openalex:W2058834119
# openalex:W4206688401
# arxiv:math/0007198
# openalex:W1499500817
# openalex:W2462010383
# arxiv:math/9301201
# openalex:W1533213248
# openalex:W1533213248
# openalex:W2022670009
# arxiv:math/9301201
# openalex:W1533213248
# openalex:W2034901905
# openalex:W3100344791
# arxiv:math/9805134
# arxiv:q-alg/9704020v2
# arxiv:math/9804041
# arxiv:gr-qc/9902017
# openalex:W3105845589
# arxiv:q-alg/9503002
# openalex:W1992608520
# openalex:W2020765042
# openalex:W1695659029
# arxiv:math/9902104
# arxiv:math/9812026v2
# arxiv:math/9910004
# openalex:W1642629289
# arxiv:math/9907127v3
# arxiv:funct-an/9705003v1
# arxiv:math/0004010
# openalex:W2053844940
# arxiv:math/9905101
# arxiv:hep-th/0001074
# pubmed:10001006
# arxiv:math/0306302
# openalex:W2057817591
# openalex:W2020688938
# pubmed:10062070
# arxiv:math/9809111
# arxiv:math/0003227
# doi:10.1201/9780203507643.ch7
# openalex:W2316418224
# openalex:W2328085946
# openalex:W2049520610
# arxiv:gr-qc/9712065
# openalex:W2027761034
# pubmed:10033779
# arxiv:gr-qc/9708071
# arxiv:gr-qc/0001103
# openalex:W2076576844
# pubmed:10016227
# openalex:W3105438070
# arxiv:hep-th/9207016
# arxiv:gr-qc/9704006
# arxiv:math/9604217v1
# arxiv:math/9512209v1
# arxiv:math/9403208
# arxiv:math/9201225
# openalex:W2075136665
# openalex:W1608855903
# openalex:W2075727870
# openalex:W2082446071
# openalex:W1576820654
# openalex:W2035228443
# openalex:W2171949108
# arxiv:math/9803066
# arxiv:math/0109210
# openalex:W2082239038
# pubmed:16591156
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/300113
# arxiv:math/9912128
# openalex:W1809529033
# openalex:W2317423124
# openalex:W1691157804
# arxiv:math/9906120
# openalex:W3100333039
# arxiv:math/9903134
# arxiv:cond-mat/9910273
# arxiv:math/9807033v2
# arxiv:math/9804120
# arxiv:math/9912095v1
# openalex:W2316475421
# pubmed:16577406
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/1076138
# pubmed:16591604
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/224676
# pubmed:16577432
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/1076162
# arxiv:hep-th/9507125
# arxiv:dg-ga/9610008v1
# arxiv:math/9902128
# arxiv:math-ph/9906027
# arxiv:physics/9709046
# openalex:W2145508915
# arxiv:dg-ga/9703001v1
# openalex:W2261738981
# arxiv:funct-an/9608002
# openalex:W4251158208
# openalex:W4251158208
# openalex:W4205293050
# openalex:W1984533458
# openalex:W2150986573
# arxiv:math/0012021
# openalex:W2105972215
# arxiv:math/9801082
# openalex:W2143048602
# arxiv:math/0002237v1
# arxiv:hep-th/9510182
# arxiv:hep-th/9609017
# arxiv:hep-th/9710198
# arxiv:alg-geom/9701016v2
# openalex:W2085391542
# openalex:W1491682511
# arxiv:math/0008014
# openalex:W2085391542
# openalex:W1491682511
# openalex:W1491682511
# arxiv:math/9907007v1
# arxiv:hep-th/9909030
# pubmed:11017594
# arxiv:hep-th/9909140
# arxiv:cond-mat/0002330
# arxiv:hep-th/9708141
# arxiv:hep-th/9805026
# arxiv:hep-th/9811211
# arxiv:q-alg/9611024v1
# openalex:W2160671804
# arxiv:solv-int/9808019
# arxiv:solv-int/9705013
# arxiv:hep-th/9410048
# arxiv:hep-th/9405096
# openalex:W2491079642
# openalex:W3100472847
# arxiv:q-alg/9601023
# arxiv:math/0002007
# arxiv:math/9801104v1
# openalex:W3101358450
# arxiv:hep-th/9907136
# arxiv:math/9903085
# arxiv:math/9406212
# openalex:W2034901905
# arxiv:hep-th/9508011
# arxiv:math-ph/0003032v1
# arxiv:math/0003167
# pubmed:16589877
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/459214
# arxiv:hep-th/0003117
# arxiv:hep-ph/0003129
# arxiv:hep-ph/9908530
# arxiv:hep-ph/9909262
# arxiv:hep-th/0002140
# arxiv:hep-th/0003100
# pubmed:10038431
# pubmed:8378254
# pubmed:15222900
# pmc:https://www.ncbi.nlm.nih.gov/pmc/articles/459214
# pubmed:10966653
# openalex:W1560378513
# arxiv:hep-th/9807069
# pubmed:10057022
# arxiv:hep-th/9405005
# pubmed:10053982
# arxiv:hep-th/9303012
# pubmed:10055907
# arxiv:hep-th/9401059
# arxiv:hep-th/9912207
# pubmed:9736684
# openalex:W4206688401
# arxiv:hep-th/9704142v1
# openalex:W2038031604
# arxiv:hep-th/9207091
# arxiv:hep-th/9903046
# arxiv:hep-th/9603100
# openalex:W2008610740
# arxiv:hep-th/9611094
# arxiv:hep-th/9801161
# arxiv:hep-th/9702015
# openalex:W3103311487
# arxiv:hep-th/9804177
# arxiv:hep-th/9708103
# arxiv:hep-th/9511108
# arxiv:hep-th/9810227
# arxiv:hep-th/9809065
# arxiv:hep-th/9902066
# arxiv:hep-th/9901139
# arxiv:hep-th/9904011
# arxiv:hep-th/9310011
# openalex:W2090069870
# arxiv:hep-th/9712251
# arxiv:hep-th/9703082
# arxiv:hep-th/9811107
# pubmed:10046331
# arxiv:hep-th/9204099
# openalex:W2150781355
# arxiv:hep-th/9711138
# arxiv:hep-th/9801053
# pubmed:10061936
# arxiv:hep-th/9602051
# KeyboardInterrupt

# %%
keys

# %%
with open(os.path.join(output_dir, f'reference.keys'), 'w') as f:
    for key in keys:f.write(key+'\n')
with open(os.path.join(output_dir, f'reference.txt'), 'w') as f:
    for string in citation_string:f.write(string+'\n')

# %%
conflict_doi_that_should_same_but_splited
# Out:
# [[['doi', '10.1007/b100336'], ['openalex', 'W1534848731']],
#  [['doi', '10.1007/b100336'], ['openalex', 'W1534848731']],
#  [['doi', '10.1007/b100336'], ['openalex', 'W1534848731']],
#  [['doi', '10.1038/155772b0'], ['openalex', 'W3189468045']],
#  [['doi', '10.1103/physrevb.37.3575'], ['openalex', 'W2007433768']],
#  [['doi', '10.1126/science'], ['openalex', 'W4214911971']]]

# %%
get_index_by_alias(r,'doi', '10.1119/1.13804')
# Out:
# '136446769'

# %%
get_index_by_alias(r,'openalex', 'W1987630316')
# Out:
# '136446769'

# %%
conflict_doi_that_should_same_but_splited
# Out:
# []

# %%
with tqdm.tqdm(range(start, end), desc="Main", ncols=100, ascii=True) as pbar:
    for i in pbar:
        file_name = all_files[i]
        convert_a_file(file_name)
        pbar.update(1)
# Out:
# [PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0004_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0002_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0001_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0003_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0005_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0006_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0007_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0009_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0008_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0010_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0011_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/00/arXiv_src_0012_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0102_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0101_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0103_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0104_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0107_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0106_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0105_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0108_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0109_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0111_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0112_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/01/arXiv_src_0110_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/02/arXiv_src_0201_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/02/arXiv_src_0202_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/02/arXiv_src_0203_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive
jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_013.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_003.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_003.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_002.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_004.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_008.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_003.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_010.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_005.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_006.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_004.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_011.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_006.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_005.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_007.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_007.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_008.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_009.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_009.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_010.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_006.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_013.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_012.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_012.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1401_011.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_005.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_014.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_013.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_005.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_002.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_014.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_003.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_007.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_004.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_004.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_006.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_004.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_009.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_002.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_008.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_003.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_007.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_016.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_011.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_002.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_010.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_010.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_012.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_007.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1402_013.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_008.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_002.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_001.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_003.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_003.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_004.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_009.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_005.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_010.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_006.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_014.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_008.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_011.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_007.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_005.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_009.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1403_011.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_004.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_005.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_012.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_006.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_009.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_008.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_009.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1406_013.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_011.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_002.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_013.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1404_012.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1405_002.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_008.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_006.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_007.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_010.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_011.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_012.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_013.jsonl'),
#  PosixPath('/nvme/zhangtianning.di/datasets/unarxive/14/arXiv_src_1407_015.jsonl')]

# %% [markdown]
# ### update arxive-office

# %%
from tqdm.auto import tqdm
i=0
with open('/nvme/zhangtianning.di/datasets/whole_arxiv_data/arxiv-metadata-oai-snapshot.json','r') as f:
    for line in tqdm(f):
        i+=1
# Out:
# 0it [00:00, ?it/s]

# %%
end_index = 10 
start_index=0

# %%
resource_dir = '/nvme/zhangtianning.di/datasets/whole_arxiv_data/arxiv-metadata-oai-snapshot.json'

# %%
import json,os
conflict_doi_that_should_same_but_splited=[]

# %%
from python_script.reference_reterive.Reference import UniqueID

# %%
from python_script.build_redis_database.utils import *

# %%
"doi", "10.1109/5992.774844"], ["arxiv", "cond-mat/9809122"

# %%
get_index_by_alias(r,"doi", "10.1103/PhysRevLett.88.013601")
# Out:
# '120886759'

# %%
redis = r

# %%
get_alias_by_index(redis,'120886759')
# Out:
# {'arxiv:quant-ph/0111112',
#  'arxiv_id:quant-ph/0111112',
#  'doi:10.1103/PhysRevLett.88.013601',
#  'doi:10.1103/physrevlett.88.013601',
#  'mag:2067430275',
#  'openalex:W2067430275',
#  'pmid:11800943',
#  'pubmed:11800943'}

# %%
paper = UniqueID.from_dict({'arxiv':"cond-mat/9809122", 'doi':"10.1109/5992.774844"})
doi_and_indexes= []

# %%
doi_and_indexes= []
for alias_type,alias_value in paper.to_dict().items():
    doi_and_indexes.append([alias_type, alias_value, get_index_by_alias(r,alias_type, alias_value)])
the_valid_indexes= list(set([index for alias_type, alias_value, index in doi_and_indexes if index is not None]))

# %%
import json
with open("/nvme/zhangtianning.di/datasets/whole_arxiv_data/arxiv-metadata_conflict/0_2.json",'r') as f:
    arxiv_conflict_pool = json.load(f)

# %%
arxivpool = set([arxiv[1] for doi, arxiv in arxiv_conflict_pool])

# %%
from pathlib import Path

# %%
from tqdm.auto import tqdm

# %%
Files
# Out:
# <generator object Path.glob at 0x7efcd0686a40>

# %%
len(ListP)
# Out:
# 1148

# %%
Files = list(Path('/nvme/zhangtianning.di/crossref/updateitem/unused_doi').glob('*.escape_by_too_less_information'))
ListP = []
for File in tqdm(Files):
    with open(File,'r' ) as f:
        for line in f:
            ListP.append(line.strip())
with open('/nvme/zhangtianning.di/crossref/updateitem/escape_by_too_less_information','w' ) as f:
    for line in ListP:
        f.write(line+'\n')
# Out:
#   0%|          | 0/28701 [00:00<?, ?it/s]

# %%
Files = list(Path('/nvme/zhangtianning.di/crossref/updateitem/unused_doi').glob('*.escape_by_no_unique_id'))
ListP = []
for File in tqdm(Files):
    with open(File,'r' ) as f:
        for line in f:
            ListP.append(line.strip())
with open('/nvme/zhangtianning.di/crossref/updateitem/escape_by_no_unique_id','w' ) as f:
    for line in ListP:
        f.write(line+'\n')
# Out:
#   0%|          | 0/28701 [00:00<?, ?it/s]

# %%
AnalysisFiles = Path('/nvme/zhangtianning.di/crossref/updateitem/unused_doi').glob('*.Analysis.json')
Analysis={}
for AnalysisFile in tqdm(AnalysisFiles):
    with open(AnalysisFile, 'r') as f:
        AnalysisNow = json.load(f)
    for key, val in AnalysisNow.items():
        if key not in Analysis:
            Analysis[key] = val
        else:
            Analysis[key] += val

# %%
Analysis
# Out:
# {'update': 89012700, 'new_add': 26504477, 'crossref_normal_skip': 4111124}

# %%
with open('/nvme/zhangtianning.di/crossref/updateitem/Analysis.json','w') as f:
    json.dump(Analysis, f)

# %% [markdown]
# ### semnitic scholar

# %%
from pathlib import Path

# %%
all_paths = list(Path("/nvme/zhangtianning.di/semantic_scholar/split/").glob('20231201*'))
all_paths = [str(t) for t in all_paths]

# %%
with open("/nvme/zhangtianning.di/semantic_scholar/all_filepath.json", 'w') as f:
    json.dump(all_paths, f)

# %%
with open("/nvme/zhangtianning.di/semantic_scholar/vene_alias_map.json", 'r') as f:
    vene_name_to_alias = json.load(f)

# %%
_id_names        = ['DOI', 'ArXiv', 'DBLP', 'ACL', 'PubMed', 'PubMedCentral']
short_id_names   = ['DOI', 'ArXiv', 'DBLP', 'ACL', 'PubMed', 'PubMedCentral']
exteral_id_names = ['externalids.{}'.format(_id_name) for _id_name in _id_names]

# %%
with open(all_paths[0], mode="r") as f:
    for line in f:
        data = json.loads(line)
        break

# %%
filename = all_paths[0]

# %%
filename
# Out:
# '/nvme/zhangtianning.di/semantic_scholar/split/20231201_080654_00026_4iy4k_07c2399c-a2a7-4045-9616-864e9d817ebc.part_aa'

# %%
num = 1
part = filename.split('/')[-1].split('.')[-1]

# %%
@dataclass
class UniqueID:
    doi: Optional[str] = None
    openalex: Optional[str] = None
    pubmed: Optional[str] = None
    semopenalex: Optional[str] = None
    arxiv: Optional[str] = None
    pmc: Optional[str] = None
    dblp: Optional[str] = None
    mag: Optional[str] = None
    pii: Optional[str] = None
    acl: Optional[str] = None
        
    def is_same(a, b):
        pool_a = a.to_dict()
        pool_b = b.to_dict()
        for key, val_a in pool_a.items():
            if key in pool_b:
                val_b = pool_b[key]
            else:
                nkey = UniqueID.unique_key(key)
                if nkey in pool_b:
                    val_b = pool_b[nkey]
                else:
                    continue
            if val_a == val_b:return True
        return  False

    def is_nan(self):
        return all([v is None for v in self.__dict__.values()])
    
    

    @staticmethod
    def unique_key(key):
        key = key.lower().replace('_',"").strip()
        if key.endswith('id'): key = key[:-2]
        if key in ['pubmed', 'pm']:
            return 'pubmed'
        elif key in ['pubmedcentral', 'pmc']:
            return 'pmc'
        return key
    
    @staticmethod
    def from_dict(d:Dict[str,str]):
        new_ids = {}
        for key in ["DOI", "ArXiv", "DBLP",'PubMed','PMID','PMC','MagID','Pii','Pmcid','ArXivId','PMCID']:
            _id = d.get(f'externalids.{key}',None)
            if _id is not None and len(_id)>0:
                new_ids[UniqueID.unique_key(k)] = _id.lower()

        for k,v in d.items():
            if v is None:continue
            if len(v) ==0:continue
            v = v.lower()
            k = UniqueID.unique_key(k)
            if k == 'openalex':
                v = v.replace('https://openalex.org/','')
            elif k == 'semopenalex':
                v = v.replace('https://semopenalex.org/work/','')
            elif k == 'pubmed':
                v = v.replace('https://pubmed.ncbi.nlm.nih.gov/','')
            else:
                v = v
            
            new_ids[k] = v
        return UniqueID(**new_ids)
    
    def __repr__(self):
        info = "\n".join([f"{key} |-> {val}" for key, val in self.to_dict().items() if val is not None])
        return f"Paper:\n{info}"   

    def to_dict(self):
        return {k:v for k,v in vars(self).items() if v is not None}

# %%
part = os.path.split(filename)[-1].split('.')[-1]

# %%
part
# Out:
# 'part_aa'

# %%
Prefix_Code = f'SS{num}.{part}'
conflict_doi_that_should_same_but_splited = []
conflict_doi_that_should_same_but_splited_dir  = os.path.join(os.path.dirname(os.path.dirname(filename)),'semantic_scholar_conflict')
conflict_doi_that_should_same_but_splited_path = os.path.join(conflict_doi_that_should_same_but_splited_dir, f"{Prefix_Code}.json")
os.makedirs(conflict_doi_that_should_same_but_splited_dir, exist_ok=True)
with open(filename, 'r') as f:
    length = len(f.readlines())
with open(filename, 'r') as f:
    for slot, line in tqdm(enumerate(f),total=length, position=2, leave=False):
        data = json.loads(line)
        ids  = data['externalids']
        ids.pop('CorpusId')
        paper = UniqueID.from_dict(ids)
        if paper.is_nan():continue
        doi_and_indexes= []
        for alias_type,alias_value in paper.to_dict().items():
            if alias_type == 'semopenalex':continue
            if 'openalex' in alias_type:alias_value = alias_value.replace('w','W')
            doi_and_indexes.append([alias_type, alias_value, get_index_by_alias(r,alias_type, alias_value)])
        the_valid_indexes= list(set([index for alias_type, alias_value, index in doi_and_indexes if index is not None]))
        if len(the_valid_indexes)>1:
            multirecord_doi = [[alias_type, alias_value] for alias_type, alias_value, index in doi_and_indexes if index is not None]
            conflict_doi_that_should_same_but_splited.append(multirecord_doi)
            continue
        if len(the_valid_indexes)==0:
            the_record_index = f"UA.{Prefix_Code}.{slot}"
            for alias_type, alias_value, index in doi_and_indexes:
                unique_name = format_alias(alias_type, alias_value)
                #add_alias_with_unique_name(r,alias_type, alias_value, the_record_index)
        else:
            the_record_index = the_valid_indexes[0]
            old_set = get_alias_by_index(r,the_record_index)
            #print(the_valid_indexes)
            #print(old_set)
            for alias_type, alias_value, index in doi_and_indexes:
                unique_name = format_alias(alias_type, alias_value)
                if unique_name in old_set:continue
# Out:
#   0%|          | 0/72000 [00:00<?, ?it/s]
