# %%
# %cd ../
# Out:
# /nas/zhangtianning.di/projects/unique_data_build

# %%
redefine_commands = ['\\def','\\Declare', '\\define',
                         '\\newcommand', '\\let',
                         '\\def', '\\usepackage',
                         '\\eqnobysec','\\newenvironment',
                         '\\newtheorem',
                         '\\providecommand',
                         '\\renewcommand', 
                         '\\documentclass',"\\global"
                        ]
layout_commands=[]

# %%
content = r"""\begin{document}


\newcommand{\abra}[2]{\ensuremath{\langle #1 #2\rangle}}

\newcommand{\sbra}[2]{\ensuremath{[ #1 #2]}}

\newcommand{\form}[2]{\ensuremath{\left\{ #1 #2\right\}}}

\newcommand{\bradot}[3]{\ensuremath{\langle #1|\, #2|#3]}}


\newcommand{\calN}{\mathcal{N}}
\newcommand{\calM}{\mathcal{M}}

\newcommand{\calS}{\mathcal{S}}
\newcommand{\calF}{\mathscr{F}}

\newcommand{\calZ}{\mathcal{Z}}
\newcommand{\calC}{\mathcal{C}}

\newcommand{\calA}{\mathcal{A}}
\newcommand{\calO}{\mathcal{O}}

\newcommand{\calOg}{\mathcal{O}}

\newcommand{\calOs}{\mathcal{O}'}


\newcommand{\Tr}{\text{Tr}}

\newcommand{\CC}{\mathbb{C}}

\newcommand{\RR}{\mathbb{R}}

\newcommand{\intd}{\int\mathrm{d}}

\newcommand{\dd}{\mathrm{d}}

\newcommand{\DD}{\mathrm{D}}

\newcommand{\AAA}{\mathcal{A}}

\newcommand{\WWW}{\mathcal{W}}

\newcommand{\ZZZ}{\mathcal{Z}}

\newcommand{\FFF}{\mathcal{F}}

\newcommand{\OOO}{\mathcal{O}}

\newcommand{\PPP}{\mathbf{F}}

\newcommand{\la}{\lambda}

\newcommand{\lat}{\tilde{\lambda}}

\newcommand{\si}{\sigma}

\newcommand{\sit}{\tilde{\sigma}}

\newcommand{\m}{\textbf{m}}
\newcommand{\n}{\textbf{n}}

\newcommand{\fA}{\mathsf{A}}

\newcommand{\fP}{\mathsf{P}}
\newcommand{\fQ}{\mathsf{Q}}

\newcommand{\fp}{\mathsf{p}}

\newcommand{\ftau}{\mathsf{\tau}}

\newcommand{\fq}{\mathsf{q}}

\newcommand{\fR}{\mathsf{R}}

\newcommand{\fw}{\mathsf{w}}

\newcommand{\iconst}{4\pi^2}

\newcommand{\constA}{-2\pi i}

\newcommand{\constB}{\frac{1}{2(2\pi i)^2}}


\newcommand{\beq}{\begin{equation}}

\newcommand{\eeq}{\end{equation}}

\newcommand{\eqndot}{\, .}

\newcommand{\eqncom}{\, ,}

\newcommand{\eqnsem}{\, ;}

\newcommand{\YM}{{\mathrm{\scriptscriptstyle YM}}}

\newcommand{\phaneq}{\phantom{{}=}}


\newcommand{\e}{\operatorname{e}}


\newcommand{\bra}[1]{\ensuremath{\left< #1\,\right|}}

\newcommand{\ket}[1]{\ensuremath{\left|\, #1\right>}}

\newcommand{\vac}[1]{\ensuremath{\left< \, #1\, \right>}}

\newcommand{\vev}[3]{\ensuremath{\big< #1\,\big| #2\,\big| #3\big>}}




\preprint{HU-Mathematik-16-05,
\ HU-EP-16/09,\ MITP/16-024}


\title{\texorpdfstring{Composite Operators in the Twistor Formulation of $\boldsymbol{\mathcal{N}=4}$ SYM Theory}{Composite Operators in the Twistor Formulation of N=4 SYM Theory}}

\author{Laura Koster$^{a}$}
\email{laurakoster@physik.hu-berlin.de}
\author{Vladimir Mitev$^{a,b}$}
\email{vmitev@uni-mainz.de}
\author{Matthias Staudacher$^a$}
\email{matthias@math.hu-berlin.de}
\author{Matthias Wilhelm$^{a,c}$}
\email{matthias.wilhelm@nbi.ku.dk}

\affiliation{
\(^{a}\)Institut f\"ur Mathematik und Institut f\"ur Physik, Humboldt-Universit\"at zu Berlin,
IRIS Haus, Zum Gro{\ss}en Windkanal 6,  12489 Berlin, Germany
\\
\(^{b}\)PRISMA Cluster of Excellence, Institut f\"ur Physik, WA THEP,
Johannes Gutenberg-Universit\"at Mainz,
Staudingerweg 7, 55128 Mainz, Germany
\\
\(^{c}\)Niels Bohr Institute, Copenhagen University,
Blegdamsvej 17, 2100 Copenhagen \O{}, Denmark  }



\begin{abstract}
We incorporate gauge-invariant local composite operators into the twistor-space formulation of $\calN=4$ Super Yang-Mills theory.
In this formulation, the interactions of the elementary fields are reorganized into infinitely many interaction vertices and we argue that the same applies to composite operators.
To test our definition of the local composite operators in twistor space, we compute several corresponding form factors, thereby also initiating the study of form factors using the position twistor-space framework.
Throughout this letter, we use the composite operator built from two identical complex scalars as a pedagogical example; we treat the general case in a follow-up paper.
\end{abstract}



\maketitle
\section{Introduction}"""

# %%
def filter_out_preamble_block(content, redefine_commands=None, layout_commands=None, end="\n"):
    """
    scan line by line rather than char by char.
    
    """
    assert redefine_commands is not None
    assert layout_commands is not None
    for cmd in redefine_commands:
        content = content.replace(cmd,"\n"+cmd)
    included_commands = redefine_commands + layout_commands
    brace_counts = {'curly': 0, 'square': 0, 'round': 0}
    
    commented_content = []
    
    # Helper function to check if all braces are balanced
    def braces_balanced(brace_counts):
        return all(count == 0 for count in brace_counts.values())

    # Define commands to exclude from commenting
    
    
    lines = [re.sub(r"%.*", "", line) for line in content.splitlines(True) if  line.strip()]
    lines = [line for line in lines if  line.strip()]
    elements =[]
    preamble_block=[]
    layerout_block=[]
    element  =""
    in_command = False ## False mean new line

    for i in range(len(lines)):
        line = lines[i]  # Keep linebreaks
        
        if line.strip().startswith('%'): continue
        
        if not in_command:
            if included_commands is None:
                in_command = "should_comment" if line.lstrip().startswith("\\") else "donot_comment"
            else:
                if any(line.lstrip().startswith(cmd) for cmd in included_commands):
                    in_command = "should_comment"
                    
                else:
                    in_command = "donot_comment"

        # If we are inside an excluded command, count braces
        if in_command:
            brace_counts['curly']  += line.count('{') - line.count('}')
            brace_counts['square'] += line.count('[') - line.count(']')
            brace_counts['round']  += line.count('(') - line.count(')')

            # If all braces are balanced, the command has ended
            is_commandQ = braces_balanced(brace_counts) and (i==len(lines)-1 or lines[i+1].strip()[0]=='\\') 
            if is_commandQ:
                
                in_command = f"end_of_comment.{in_command}"
        #print(brace_counts)
        # Add line to commented_content
        element += line.rstrip('\n') + end

        if in_command.startswith("end_of_comment"):
            COMMENTQ=not in_command.endswith('donot_comment')
            
            if COMMENTQ:
                if any(element.lstrip().startswith(cmd) for cmd in layout_commands):
                    elements.append("\n%%-->layerout<--%%"+element+'\n')
                    layerout_block.append(element)
                else:
                    preamble_block.append(element)
            else:
                elements.append(element)

            element=""
            in_command = False


    if not in_command or not in_command.startswith("end_of_comment"):
        elements.append(element)
    return '\n'.join(elements), "\n".join(preamble_block), layerout_block

# %%
_, command_str, _  = filter_out_preamble_block(content, redefine_commands=redefine_commands, layout_commands=[])
# Out:
# \begin{document}
#
# \newcommand{\abra}[2]{\ensuremath{\langle #1 #2\rangle}}
#
# \newcommand{\sbra}[2]{\ensuremath{[ #1 #2]}}
#
# \newcommand{\form}[2]{\ensuremath{\left\{ #1 #2\right\}}}

# %%
print(command_str)
# Out:
# \newcommand{\abra}[2]{\ensuremath{\langle #1 #2\rangle}}
#
# \newcommand{\sbra}[2]{\ensuremath{[ #1 #2]}}
#
# \newcommand{\form}[2]{\ensuremath{\left\{ #1 #2\right\}}}

# %%
from uparxive.lougat.markdown_pdf_align import *

# %%
html_path = "/nvme/zhangtianning.di/sharefold/whole_arxiv_all_files/archive_tex.colorful.nobbl/1603/1603.04471/temp/COTwistor.colorful.html"

# %%
# html = read_and_standardlize_html(html_path)
# with open('test.html','w') as f:f.write(html.prettify())
# mmd,fig = soup2mdtext(html)
# mmd = re.sub(r"\\definecolor(\s*\[.*?\])?\s*\{[^}]*\}\s*\{\s*rgb\s*}\s*\{[^}]*\}", "", mmd)
# with open('test.mmd','w') as f:f.write(mmd)

# %%
html = read_and_standardlize_html(html_path)
mmd,fig = soup2mdtext(html)
_,fig_captions = extract_captions_new(fig)
mmd_color_dct,block_equation_color_map = colored_dct(mmd)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 4
#       2 mmd,fig = soup2mdtext(html)
#       3 _,fig_captions = extract_captions_new(fig)
# ----> 4 mmd_color_dct,block_equation_color_map = colored_dct(mmd)
#
# File /nas/zhangtianning.di/projects/unique_data_build/uparxive/lougat/markdown_pdf_align.py:590, in colored_dct(mmd, keep_structure, color)
#     588 if _type == 'text':
#     589     for line in block_content.splitlines():
# --> 590         if not line.strip():continue
#     591         line_dct_color = color_dct_line(line,color,keep_structure,color_manager)
#     592         dct_color = dct_color|line_dct_color
#
# File /nas/zhangtianning.di/projects/unique_data_build/uparxive/lougat/markdown_pdf_align.py:558, in color_dct_line(line, color, keep_structure, color_manager)
#     556 for c,text in simple_math_color_format(block_content[matheg.inline_s:-matheg.inline_e]):
#     557     if c and c!=(0,0,0):
# --> 558         assert c not in dct_color or len(text.strip())==0, f"""
#     559         color should be unique {c}, what we get now is
#     560         old text: {dct_color[c]}
#     561         new text: {text}
#     562         whole text: {block_content}
#     563         """
#     564         dct_color[c] = ["<inline_math>",text]
#     565         color = c
#
# AssertionError:
#                     color should be unique (5, 0, 25), what we get now is
#                     old text: ['<inline_math>', '{']
#                     new text: {

# %%
(mmd,
mmd_color_dct,
cap_color_dct,
fig_color_dct,
fig_captions_list,
color_figid_map,block_equation_color_map) = get_markdown_text_with_colored(html_path)

# %%
with open('test.mmd','w') as f:
    f.write(mmd)

# %%
from PIL import Image, ImageDraw
pdf_file_path  = html_path[:-5] + '.pdf'
now_table_figure_masked_pdf = pdf_file_path
pdf_file_path = pdf_file_path#.replace('.colorful.pdf','.colorful_all_colored.pdf')
pdf      = fitz.open(pdf_file_path)
pdf0     = fitz.open(now_table_figure_masked_pdf)
png_dir  = os.path.join(os.path.dirname(os.path.dirname(pdf_file_path)),'boxed_pdf_image')
os.makedirs(png_dir,exist_ok=True)

# %%
recommand_start = 0
for page_idx in range(0,2):
    page = pdf[page_idx]
    page0=pdf0[page_idx]
    clean_png_path = os.path.join(png_dir, 'clean',f"page_{page_idx}.png")
    os.makedirs(os.path.dirname(clean_png_path),exist_ok=True)
    with open(clean_png_path, "wb") as f:
        f.write(page0.get_pixmap(dpi=300).pil_tobytes(format="PNG"))      
    current_mmd_color_dct = mmd_color_dct
    pretext_and_prompts,true_match,recommand_start = deal_with_single_page(page,current_mmd_color_dct,block_equation_color_map,cap_color_dct,fig_color_dct,color_figid_map,fig_captions_list,recommand_start=recommand_start)
    print(f"recommand_start={recommand_start}")
    if pretext_and_prompts == None:
        print(f""" ============ fail to processing page {page_idx} ======================= """)
    else:
        _,_,page_w,page_h = page.rect
        normed_pretext_and_prompts = []
        for text,_,_,_, bbox in pretext_and_prompts:
            if isinstance(bbox,tuple) and len(bbox)==4:
                bbox  = norm_box(bbox,page_h,page_w)
            normed_pretext_and_prompts.append([text, bbox])
        print(f""" ============= for page {page_idx}, we get {len(normed_pretext_and_prompts)} box =================== """)
# Out:
# recommand_start=56
#  ============= for page 0, we get 31 box ===================
# recommand_start=875
#  ============= for page 1, we get 829 box ===================

# %%
_,_,page_w,page_h = page.rect
normed_pretext_and_prompts = []
for markdown, pdf_text, status, text_type, bbox in pretext_and_prompts:
    if bbox and isinstance(bbox,tuple) and len(bbox)==4:
        bbox  = norm_box(bbox,page_h,page_w)
    normed_pretext_and_prompts.append([markdown, pdf_text, status, text_type, bbox])

# %%
img = Image.open(clean_png_path)

for markdown, pdf_text, status, text_type, box in normed_pretext_and_prompts:
    if box is None:continue

    #if len(text_and_box)!=2:logging.debug(text_and_box)
    #text, box = text_and_box
    #if box is None:logging.debug(text_and_box)
    if len(box[0])!=2 or len(box[1])!=2: continue
    bbox = box
    width, height = img.size

    # Convert bbox from normalized to pixel coordinates
    pixel_bbox = [
        bbox[0][0] * width,  # xmin
        bbox[0][1] * height, # ymin
        bbox[1][0] * width,  # xmax
        bbox[1][1] * height  # ymax
    ]

    # Create a draw object
    draw = ImageDraw.Draw(img)

    # Draw the rectangle
    draw.rectangle(pixel_bbox, outline='red', width=2)

boxed_image = os.path.join(png_dir, 'boxed',f"boxed_page_{page_idx}.png")
#os.makedirs(os.path.dirname(boxed_image),exist_ok=True)
#img.save(boxed_image)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2550x3300>

# %%
content = ""
for text, _, _, text_type, bbox in pretext_and_prompts:
    end = "" if text_type =="<inline_math>" else " "
    content += text + end

# %%
print(content)
# Out:
# Radiative decays of charged leptons as constraints of unitarity polygons
#
#  for active - sterile neutrino mixing and CP violation
#
#  Zhi - zhong Xing 1,2 and Di Zhang Institute of High Energy Physics and School of Physical Sciences ,
#
#  University of Chinese Academy of Sciences , Beijing 100049, China
#
#  Center of High Energy Physics , Peking University , Beijing 100871, China
#
#  ###### Abstract
#
#  We calculate the rates of radiative \(\beta^{-}\to\alpha^{-}+\gamma \)decays for \((\alpha,\beta)=(e,\mu) \), \((e,\tau) \)and \((\mu,\tau) \)by taking the unitary gauge in the \((3+n) \)active - sterile neutrino mixing scheme , and make it clear that constraints on the unitarity of the \(3\times 3 \)Pontecorvo - Maki - Nakagawa - Sakata ( PMNS ) matrix \(U \)extracted from \(\beta^{-}\to \alpha^{-}+\gamma \)decays in the minimal unitarity violation scheme differ from those obtained in the canonical seesaw mechanism with \(n \)heavy Majorana neutrinos by a factor \(5/3 \). In such a natural seesaw case we show that the rates of \(\beta^{-}\to\alpha^{-}+\gamma \)can be used to cleanly and strongly constrain the effective apex of a unitarity polygon , and compare its geometry with the geometry of its three sub - triangles formed by two vectors \(U_{\alpha i}U^{*}_{\beta i}\)and \(U_{\alpha j}U^{*}_{\beta j}\)( for \(i\neq j \)) in the complex plane . We find that the areas of such sub - triangles can be described in terms of the Jarlskog - like invariants of CP violation \({\cal J}^{ij}_{\alpha\beta}\), and their small differences signify slight unitarity violation of the PMNS matrix \(U \).
#
#  ## 1 Introduction
#
#  The discoveries of solar , atmospheric , reactor and accelerator neutrino oscillations [ 0 ] have changed some of our previous ideas about the standard model ( SM ) of particle physics , especially about its lepton flavor sector . Now we are firmly convinced that neutrinos have mysteriously tiny masses and lepton flavors are significantly mixed . Behind these two important observations must be some kind of new physics beyond the SM [ 1 ] , which is responsible for the origin of neutrino masses and may have far - reaching implications for particle physics and cosmology .
#
#  In weak charged - current interactions it is the \(3\times 3 \)Pontecorvo - Maki - Nakagawa - Sakata ( PMNS ) matrix \(U \)that describes the effects of lepton flavor mixing and CP violation [ 2 ][ 3 ][ 4 ] . The smallest element of \(U \)is found to be \(|U_{e 3}|}|\simeq 0.15 \)[ 5 ] , much larger than \(|V_{ub}|}|\simeq 3.6\times 10^{-3}\)- - - the smallest element of the \(3\times 3 \)Cabibbo - Kobayashi - Maskawa ( CKM ) quark flavor mixing matrix \(V \)[ 6 ][ 7 ] . Moreover , the PMNS matrix \(U \)is very likely to accommodate significant CP violation in the lepton sector , as indicated by the latest T 2 K measurement at almost the \(3\sigma \)confidence level [ 8 ] . Given the unitarity of \(U \), there are three Dirac - type unitarity triangles defined by the orthogonality conditions [ 9
# \[
#  \]
#
#
#  <footnote>('FOOTNOTE', '<text>')</footnote>
#  <cap> E - mail : zhangdi @ ihep .ac .cn ( corresponding author </cap> <footnote>('FOOTNOTE', '<text>')</footnote>
#  <cap> There are also three Majorana - type triangles defined by the orthogonality relations \(U_{e i}U^{*}_{e j}+U_{\mu i}U^{*}_{\mu j}+U_{\tau i}U^{*}_{\tau j}=0 \)in the complex plane [ 9 ][ 10 ] , where \((i,j)=(1,2) \), \((2,3) \)or \((3,1) \). The configuration of each triangle is sensitive to the relative phases of three Majorana neutrino mass eigenstates \(\nu_{i}\)( for \(i=1,2,3 \)) [ 11 ] , but it is irrelevant to the radiative decays of charged leptons and hence will not be discussed in this paper </cap>

# %%
def rgb_to_hex(r, g, b):
    return f'#{r:02X}{g:02X}{b:02X}'
rgb_to_hex(50, 5, 175)
# Out:
# '#3205AF'

# %%
hex_to_rgb('0AFAA5')
# Out:
# (10, 250, 165)

# %% [markdown]
# # debug

# %%
sequence2boxed,caption_matched_in_this_page,figid_from_figure, figid_from_caption, pdf_draw_color_bbox_map,color_to_position = get_pdf_text_with_colored(page,block_equation_color_map,cap_color_dct,fig_color_dct,color_figid_map,fig_captions_list)

# %%
pretext_and_prompts,true_match,recommand_start  = sequence_sequence_alignment(current_mmd_color_dct,sequence2boxed)

# %%
caption_start_position = 0
pretext_and_prompts[-1][0]+='\n\n'
caption2boxed=[(c,t,b) for c,(t,b) in caption_matched_in_this_page.items()]
for figid in figid_from_figure:
    caption2boxed_now = caption2boxed[caption_start_position:]
    fig_cap = fig_captions_list[figid]
    fig = fig_cap['figure']
    cap = fig_cap['caption']
    for c, v in fig.items():
        if v[0] == "FOOTNOTE":
            pretext_and_prompts.append((f"<footnote>{v}</footnote>\n","",'invisable','mask',None))
        else:
            pretext_and_prompts.append((f"<fig>{v}</fig>\n","",'invisable','mask', pdf_draw_color_bbox_map[c]))
    if len(cap)>0:
        pretext_and_prompts.append((f"<cap>","",'invisable','mask',None))
        pretext_and_prompts2,true_match_caption, _ = sequence_sequence_alignment(cap,caption2boxed_now, align_side='right')
        caption_start_position = 0 #true_match_caption[-1][-1]
        pretext_and_prompts.extend(pretext_and_prompts2)
        pretext_and_prompts.append((f"</cap>","",'invisable','mask',None))

# %%
recommand_start=0
sequence1o = [(color, text, dtype) for color, (text, dtype) in current_mmd_color_dct.items()]

color_indexes_map = {color:i for i,(color, text, dtype) in enumerate(sequence1o) if color!=(0,0,0) and is_meaningful_markdonw_color(color)}
sequence_pdf = sequence2boxed
color_index_in_pdf = [color_indexes_map[color] for color,_,_ in sequence_pdf if color !=(0,0,0) and color in color_indexes_map] ### some color may appear in caption, then pass
mmd_sequence_start  = max(max(0,min(color_index_in_pdf)-1),recommand_start)
while mmd_sequence_start>0 and "math" in sequence1o[mmd_sequence_start][-1]:
    mmd_sequence_start-=1
mmd_sequence_end    = max(color_index_in_pdf[1:])+1
while "math" in sequence1o[mmd_sequence_end][-1]:
    mmd_sequence_end+=1
sequence_mmd = [(color, text, dtype) for color, text, dtype in sequence1o[mmd_sequence_start:mmd_sequence_end]]
sequence1=sequence_mmd
sequence2=sequence_pdf

pair = rough_split_by_color_pair(sequence2, sequence1)
fail_to_match = False

# %%
sequence1
# Out:
# [((230, 130, 120), 'Radiative', '<text>'),
#  ((230, 130, 125), 'decays', '<text>'),
#  ((230, 130, 130), 'of', '<text>'),
#  ((230, 130, 135), 'charged', '<text>'),
#  ((230, 130, 140), 'leptons', '<text>'),
#  ((230, 130, 145), 'as', '<text>'),
#  ((230, 130, 150), 'constraints', '<text>'),
#  ((230, 130, 155), 'of', '<text>'),
#  ((230, 130, 160), 'unitarity', '<text>'),
#  ((230, 130, 165), 'polygons\n\n', '<text>'),
#  ((230, 130, 170), 'for', '<text>'),
#  ((230, 130, 175), 'active', '<text>'),
#  ((230, 130, 180), '-', '<text>'),
#  ((230, 130, 185), 'sterile', '<text>'),
#  ((230, 130, 190), 'neutrino', '<text>'),
#  ((230, 130, 195), 'mixing', '<text>'),
#  ((230, 130, 200), 'and', '<text>'),
#  ((230, 130, 205), 'CP', '<text>'),
#  ((230, 130, 210), 'violation\n\n', '<text>'),
#  ((230, 130, 215), 'Zhi', '<text>'),
#  ((230, 130, 220), '-', '<text>'),
#  ((230, 130, 225), 'zhong', '<text>'),
#  ((230, 130, 230), 'Xing', '<text>'),
#  ((230, 130, 230.1), '1,2', '<text>'),
#  ((230, 130, 240), 'and', '<text>'),
#  ((230, 130, 245), 'Di', '<text>'),
#  ((230, 130, 250), 'Zhang', '<text>'),
#  ((230, 130, 250.1), '\\textonesuperior', '<text>'),
#  ((230, 130, 250.2), '*\n\n', '<text>'),
#  ((0, 0, 0.1), '\\textonesuperior', '<text>'),
#  ((230, 135, 75), 'Institute', '<text>'),
#  ((230, 135, 80), 'of', '<text>'),
#  ((230, 135, 85), 'High', '<text>'),
#  ((230, 135, 90), 'Energy', '<text>'),
#  ((230, 135, 95), 'Physics', '<text>'),
#  ((230, 135, 100), 'and', '<text>'),
#  ((230, 135, 105), 'School', '<text>'),
#  ((230, 135, 110), 'of', '<text>'),
#  ((230, 135, 115), 'Physical', '<text>'),
#  ((230, 135, 120), 'Sciences', '<text>'),
#  ((230, 135, 125), ',\n\n', '<text>'),
#  ((230, 135, 130), 'University', '<text>'),
#  ((230, 135, 135), 'of', '<text>'),
#  ((230, 135, 140), 'Chinese', '<text>'),
#  ((230, 135, 145), 'Academy', '<text>'),
#  ((230, 135, 150), 'of', '<text>'),
#  ((230, 135, 155), 'Sciences', '<text>'),
#  ((230, 135, 160), ',', '<text>'),
#  ((230, 135, 165), 'Beijing', '<text>'),
#  ((230, 135, 170), '100049,', '<text>'),
#  ((230, 135, 175), 'China\n\n', '<text>'),
#  ((0, 0, 0.2), '\\texttwosuperior', '<text>'),
#  ((230, 135, 185), 'Center', '<text>'),
#  ((230, 135, 190), 'of', '<text>'),
#  ((230, 135, 195), 'High', '<text>'),
#  ((230, 135, 200), 'Energy', '<text>'),
#  ((230, 135, 205), 'Physics', '<text>'),
#  ((230, 135, 210), ',', '<text>'),
#  ((230, 135, 215), 'Peking', '<text>'),
#  ((230, 135, 220), 'University', '<text>'),
#  ((230, 135, 225), ',', '<text>'),
#  ((230, 135, 230), 'Beijing', '<text>'),
#  ((230, 135, 235), '100871,', '<text>'),
#  ((230, 135, 240), 'China\n\n', '<text>'),
#  ((0, 0, 0.30000000000000004), '######', '<text>'),
#  ((0, 0, 0.4), 'Abstract\n\n', '<text>'),
#  ((230, 135, 245), 'We', '<text>'),
#  ((230, 135, 250), 'calculate', '<text>'),
#  ((230, 140, 0), 'the', '<text>'),
#  ((230, 140, 5), 'rates', '<text>'),
#  ((230, 140, 10), 'of', '<text>'),
#  ((230, 140, 15), 'radiative', '<text>'),
#  ((230, 140, 15.1), '\\(', '<inline_math>'),
#  ((230, 140, 20), '\\beta', '<inline_math>'),
#  ((230, 140, 20.1), '^{', '<inline_math>'),
#  ((230, 140, 25), '-', '<inline_math>'),
#  ((230, 140, 25.1), '}', '<inline_math>'),
#  ((230, 140, 30), '\\to', '<inline_math>'),
#  ((230, 140, 35), '\\alpha', '<inline_math>'),
#  ((230, 140, 35.1), '^{', '<inline_math>'),
#  ((230, 140, 40), '-', '<inline_math>'),
#  ((230, 140, 40.1), '}', '<inline_math>'),
#  ((230, 140, 45), '+', '<inline_math>'),
#  ((230, 140, 50), '\\gamma ', '<inline_math>'),
#  ((230, 140, 50.1), '\\)', '<inline_math>'),
#  ((230, 140, 55), 'decays', '<text>'),
#  ((230, 140, 60), 'for', '<text>'),
#  ((230, 140, 60.1), '\\(', '<inline_math>'),
#  ((230, 140, 65), '(', '<inline_math>'),
#  ((230, 140, 70), '\\alpha', '<inline_math>'),
#  ((230, 140, 75), ',', '<inline_math>'),
#  ((230, 140, 80), '\\beta', '<inline_math>'),
#  ((230, 140, 85), ')', '<inline_math>'),
#  ((230, 140, 90), '=', '<inline_math>'),
#  ((230, 140, 95), '(', '<inline_math>'),
#  ((230, 140, 100), 'e', '<inline_math>'),
#  ((230, 140, 105), ',', '<inline_math>'),
#  ((230, 140, 110), '\\mu', '<inline_math>'),
#  ((230, 140, 115), ') ', '<inline_math>'),
#  ((230, 140, 115.1), '\\)', '<inline_math>'),
#  ((230, 140, 120), ',', '<text>'),
#  ((230, 140, 120.1), '\\(', '<inline_math>'),
#  ((230, 140, 125), '(', '<inline_math>'),
#  ((230, 140, 130), 'e', '<inline_math>'),
#  ((230, 140, 135), ',', '<inline_math>'),
#  ((230, 140, 140), '\\tau', '<inline_math>'),
#  ((230, 140, 145), ') ', '<inline_math>'),
#  ((230, 140, 145.1), '\\)', '<inline_math>'),
#  ((230, 140, 150), 'and', '<text>'),
#  ((230, 140, 150.1), '\\(', '<inline_math>'),
#  ((230, 140, 155), '(', '<inline_math>'),
#  ((230, 140, 160), '\\mu', '<inline_math>'),
#  ((230, 140, 165), ',', '<inline_math>'),
#  ((230, 140, 170), '\\tau', '<inline_math>'),
#  ((230, 140, 175), ') ', '<inline_math>'),
#  ((230, 140, 175.1), '\\)', '<inline_math>'),
#  ((230, 140, 180), 'by', '<text>'),
#  ((230, 140, 185), 'taking', '<text>'),
#  ((230, 140, 190), 'the', '<text>'),
#  ((230, 140, 195), 'unitary', '<text>'),
#  ((230, 140, 200), 'gauge', '<text>'),
#  ((230, 140, 205), 'in', '<text>'),
#  ((230, 140, 210), 'the', '<text>'),
#  ((230, 140, 210.1), '\\(', '<inline_math>'),
#  ((230, 140, 215), '(', '<inline_math>'),
#  ((230, 140, 220), '3', '<inline_math>'),
#  ((230, 140, 225), '+', '<inline_math>'),
#  ((230, 140, 230), 'n', '<inline_math>'),
#  ((230, 140, 235), ') ', '<inline_math>'),
#  ((230, 140, 235.1), '\\)', '<inline_math>'),
#  ((230, 140, 240), 'active', '<text>'),
#  ((230, 140, 245), '-', '<text>'),
#  ((230, 140, 250), 'sterile', '<text>'),
#  ((230, 145, 0), 'neutrino', '<text>'),
#  ((230, 145, 5), 'mixing', '<text>'),
#  ((230, 145, 10), 'scheme', '<text>'),
#  ((230, 145, 15), ',', '<text>'),
#  ((230, 145, 20), 'and', '<text>'),
#  ((230, 145, 25), 'make', '<text>'),
#  ((230, 145, 30), 'it', '<text>'),
#  ((230, 145, 35), 'clear', '<text>'),
#  ((230, 145, 40), 'that', '<text>'),
#  ((230, 145, 45), 'constraints', '<text>'),
#  ((230, 145, 50), 'on', '<text>'),
#  ((230, 145, 55), 'the', '<text>'),
#  ((230, 145, 60), 'unitarity', '<text>'),
#  ((230, 145, 65), 'of', '<text>'),
#  ((230, 145, 70), 'the', '<text>'),
#  ((230, 145, 70.1), '\\(', '<inline_math>'),
#  ((230, 145, 75), '3', '<inline_math>'),
#  ((230, 145, 80), '\\times ', '<inline_math>'),
#  ((230, 145, 85), '3 ', '<inline_math>'),
#  ((230, 145, 85.1), '\\)', '<inline_math>'),
#  ((230, 145, 90), 'Pontecorvo', '<text>'),
#  ((230, 145, 95), '-', '<text>'),
#  ((230, 145, 100), 'Maki', '<text>'),
#  ((230, 145, 105), '-', '<text>'),
#  ((230, 145, 110), 'Nakagawa', '<text>'),
#  ((230, 145, 115), '-', '<text>'),
#  ((230, 145, 120), 'Sakata', '<text>'),
#  ((230, 145, 125), '(', '<text>'),
#  ((230, 145, 130), 'PMNS', '<text>'),
#  ((230, 145, 135), ')', '<text>'),
#  ((230, 145, 140), 'matrix', '<text>'),
#  ((230, 145, 140.1), '\\(', '<inline_math>'),
#  ((230, 145, 145), 'U ', '<inline_math>'),
#  ((230, 145, 145.1), '\\)', '<inline_math>'),
#  ((230, 145, 150), 'extracted', '<text>'),
#  ((230, 145, 155), 'from', '<text>'),
#  ((230, 145, 155.1), '\\(', '<inline_math>'),
#  ((230, 145, 160), '\\beta', '<inline_math>'),
#  ((230, 145, 160.1), '^{', '<inline_math>'),
#  ((230, 145, 165), '-', '<inline_math>'),
#  ((230, 145, 165.1), '}', '<inline_math>'),
#  ((230, 145, 170), '\\to ', '<inline_math>'),
#  ((230, 145, 175), '\\alpha', '<inline_math>'),
#  ((230, 145, 175.1), '^{', '<inline_math>'),
#  ((230, 145, 180), '-', '<inline_math>'),
#  ((230, 145, 180.1), '}', '<inline_math>'),
#  ((230, 145, 185), '+', '<inline_math>'),
#  ((230, 145, 190), '\\gamma ', '<inline_math>'),
#  ((230, 145, 190.1), '\\)', '<inline_math>'),
#  ((230, 145, 195), 'decays', '<text>'),
#  ((230, 145, 200), 'in', '<text>'),
#  ((230, 145, 205), 'the', '<text>'),
#  ((230, 145, 210), 'minimal', '<text>'),
#  ((230, 145, 215), 'unitarity', '<text>'),
#  ((230, 145, 220), 'violation', '<text>'),
#  ((230, 145, 225), 'scheme', '<text>'),
#  ((230, 145, 230), 'differ', '<text>'),
#  ((230, 145, 235), 'from', '<text>'),
#  ((230, 145, 240), 'those', '<text>'),
#  ((230, 145, 245), 'obtained', '<text>'),
#  ((230, 145, 250), 'in', '<text>'),
#  ((230, 150, 0), 'the', '<text>'),
#  ((230, 150, 5), 'canonical', '<text>'),
#  ((230, 150, 10), 'seesaw', '<text>'),
#  ((230, 150, 15), 'mechanism', '<text>'),
#  ((230, 150, 20), 'with', '<text>'),
#  ((230, 150, 20.1), '\\(', '<inline_math>'),
#  ((230, 150, 25), 'n ', '<inline_math>'),
#  ((230, 150, 25.1), '\\)', '<inline_math>'),
#  ((230, 150, 30), 'heavy', '<text>'),
#  ((230, 150, 35), 'Majorana', '<text>'),
#  ((230, 150, 40), 'neutrinos', '<text>'),
#  ((230, 150, 45), 'by', '<text>'),
#  ((230, 150, 50), 'a', '<text>'),
#  ((230, 150, 55), 'factor', '<text>'),
#  ((230, 150, 55.1), '\\(', '<inline_math>'),
#  ((230, 150, 60), '5', '<inline_math>'),
#  ((230, 150, 65), '/', '<inline_math>'),
#  ((230, 150, 70), '3 ', '<inline_math>'),
#  ((230, 150, 70.1), '\\)', '<inline_math>'),
#  ((230, 150, 75), '.', '<text>'),
#  ((230, 150, 80), 'In', '<text>'),
#  ((230, 150, 85), 'such', '<text>'),
#  ((230, 150, 90), 'a', '<text>'),
#  ((230, 150, 95), 'natural', '<text>'),
#  ((230, 150, 100), 'seesaw', '<text>'),
#  ((230, 150, 105), 'case', '<text>'),
#  ((230, 150, 110), 'we', '<text>'),
#  ((230, 150, 115), 'show', '<text>'),
#  ((230, 150, 120), 'that', '<text>'),
#  ((230, 150, 125), 'the', '<text>'),
#  ((230, 150, 130), 'rates', '<text>'),
#  ((230, 150, 135), 'of', '<text>'),
#  ((230, 150, 135.1), '\\(', '<inline_math>'),
#  ((230, 150, 140), '\\beta', '<inline_math>'),
#  ((230, 150, 140.1), '^{', '<inline_math>'),
#  ((230, 150, 145), '-', '<inline_math>'),
#  ((230, 150, 145.1), '}', '<inline_math>'),
#  ((230, 150, 150), '\\to', '<inline_math>'),
#  ((230, 150, 155), '\\alpha', '<inline_math>'),
#  ((230, 150, 155.1), '^{', '<inline_math>'),
#  ((230, 150, 160), '-', '<inline_math>'),
#  ((230, 150, 160.1), '}', '<inline_math>'),
#  ((230, 150, 165), '+', '<inline_math>'),
#  ((230, 150, 170), '\\gamma ', '<inline_math>'),
#  ((230, 150, 170.1), '\\)', '<inline_math>'),
#  ((230, 150, 175), 'can', '<text>'),
#  ((230, 150, 180), 'be', '<text>'),
#  ((230, 150, 185), 'used', '<text>'),
#  ((230, 150, 190), 'to', '<text>'),
#  ((230, 150, 195), 'cleanly', '<text>'),
#  ((230, 150, 200), 'and', '<text>'),
#  ((230, 150, 205), 'strongly', '<text>'),
#  ((230, 150, 210), 'constrain', '<text>'),
#  ((230, 150, 215), 'the', '<text>'),
#  ((230, 150, 220), 'effective', '<text>'),
#  ((230, 150, 225), 'apex', '<text>'),
#  ((230, 150, 230), 'of', '<text>'),
#  ((230, 150, 235), 'a', '<text>'),
#  ((230, 150, 240), 'unitarity', '<text>'),
#  ((230, 150, 245), 'polygon', '<text>'),
#  ((230, 150, 250), ',', '<text>'),
#  ((230, 155, 0), 'and', '<text>'),
#  ((230, 155, 5), 'compare', '<text>'),
#  ((230, 155, 10), 'its', '<text>'),
#  ((230, 155, 15), 'geometry', '<text>'),
#  ((230, 155, 20), 'with', '<text>'),
#  ((230, 155, 25), 'the', '<text>'),
#  ((230, 155, 30), 'geometry', '<text>'),
#  ((230, 155, 35), 'of', '<text>'),
#  ((230, 155, 40), 'its', '<text>'),
#  ((230, 155, 45), 'three', '<text>'),
#  ((230, 155, 50), 'sub', '<text>'),
#  ((230, 155, 55), '-', '<text>'),
#  ((230, 155, 60), 'triangles', '<text>'),
#  ((230, 155, 65), 'formed', '<text>'),
#  ((230, 155, 70), 'by', '<text>'),
#  ((230, 155, 75), 'two', '<text>'),
#  ((230, 155, 80), 'vectors', '<text>'),
#  ((230, 155, 80.1), '\\(', '<inline_math>'),
#  ((230, 155, 85), 'U', '<inline_math>'),
#  ((230, 155, 85.1), '_{', '<inline_math>'),
#  ((230, 155, 90), '\\alpha ', '<inline_math>'),
#  ((230, 155, 95), 'i', '<inline_math>'),
#  ((230, 155, 95.1), '}', '<inline_math>'),
#  ((230, 155, 100), 'U', '<inline_math>'),
#  ((230, 155, 100.1), '^{', '<inline_math>'),
#  ((230, 155, 105), '*', '<inline_math>'),
#  ((230, 155, 105.1), '}_{', '<inline_math>'),
#  ((230, 155, 110), '\\beta ', '<inline_math>'),
#  ((230, 155, 115), 'i', '<inline_math>'),
#  ((230, 155, 115.1), '}', '<inline_math>'),
#  ((230, 155, 115.19999999999999), '\\)', '<inline_math>'),
#  ((230, 155, 120), 'and', '<text>'),
#  ((230, 155, 120.1), '\\(', '<inline_math>'),
#  ((230, 155, 125), 'U', '<inline_math>'),
#  ((230, 155, 125.1), '_{', '<inline_math>'),
#  ((230, 155, 130), '\\alpha ', '<inline_math>'),
#  ((230, 155, 135), 'j', '<inline_math>'),
#  ((230, 155, 135.1), '}', '<inline_math>'),
#  ((230, 155, 140), 'U', '<inline_math>'),
#  ((230, 155, 140.1), '^{', '<inline_math>'),
#  ((230, 155, 145), '*', '<inline_math>'),
#  ((230, 155, 145.1), '}_{', '<inline_math>'),
#  ((230, 155, 150), '\\beta ', '<inline_math>'),
#  ((230, 155, 155), 'j', '<inline_math>'),
#  ((230, 155, 155.1), '}', '<inline_math>'),
#  ((230, 155, 155.2), '\\)', '<inline_math>'),
#  ((230, 155, 160), '(', '<text>'),
#  ((230, 155, 165), 'for', '<text>'),
#  ((230, 155, 165.1), '\\(', '<inline_math>'),
#  ((230, 155, 170), 'i', '<inline_math>'),
#  ((230, 155, 175), '\\neq ', '<inline_math>'),
#  ((230, 155, 180), 'j ', '<inline_math>'),
#  ((230, 155, 180.1), '\\)', '<inline_math>'),
#  ((230, 155, 185), ')', '<text>'),
#  ((230, 155, 190), 'in', '<text>'),
#  ((230, 155, 195), 'the', '<text>'),
#  ((230, 155, 200), 'complex', '<text>'),
#  ((230, 155, 205), 'plane', '<text>'),
#  ((230, 155, 210), '.', '<text>'),
#  ((230, 155, 215), 'We', '<text>'),
#  ((230, 155, 220), 'find', '<text>'),
#  ((230, 155, 225), 'that', '<text>'),
#  ((230, 155, 230), 'the', '<text>'),
#  ((230, 155, 235), 'areas', '<text>'),
#  ((230, 155, 240), 'of', '<text>'),
#  ((230, 155, 245), 'such', '<text>'),
#  ((230, 155, 250), 'sub', '<text>'),
#  ((230, 160, 0), '-', '<text>'),
#  ((230, 160, 5), 'triangles', '<text>'),
#  ((230, 160, 10), 'can', '<text>'),
#  ((230, 160, 15), 'be', '<text>'),
#  ((230, 160, 20), 'described', '<text>'),
#  ((230, 160, 25), 'in', '<text>'),
#  ((230, 160, 30), 'terms', '<text>'),
#  ((230, 160, 35), 'of', '<text>'),
#  ((230, 160, 40), 'the', '<text>'),
#  ((230, 160, 45), 'Jarlskog', '<text>'),
#  ((230, 160, 50), '-', '<text>'),
#  ((230, 160, 55), 'like', '<text>'),
#  ((230, 160, 60), 'invariants', '<text>'),
#  ((230, 160, 65), 'of', '<text>'),
#  ((230, 160, 70), 'CP', '<text>'),
#  ((230, 160, 75), 'violation', '<text>'),
#  ((230, 160, 75.1), '\\(', '<inline_math>'),
#  ((230, 160, 75.19999999999999), '{\\cal ', '<inline_math>'),
#  ((230, 160, 80), 'J', '<inline_math>'),
#  ((230, 160, 80.1), '}^{', '<inline_math>'),
#  ((230, 160, 85), 'ij', '<inline_math>'),
#  ((230, 160, 85.1), '}_{', '<inline_math>'),
#  ((230, 160, 90), '\\alpha', '<inline_math>'),
#  ((230, 160, 95), '\\beta', '<inline_math>'),
#  ((230, 160, 95.1), '}', '<inline_math>'),
#  ((230, 160, 95.19999999999999), '\\)', '<inline_math>'),
#  ((230, 160, 100), ',', '<text>'),
#  ((230, 160, 105), 'and', '<text>'),
#  ((230, 160, 110), 'their', '<text>'),
#  ((230, 160, 115), 'small', '<text>'),
#  ((230, 160, 120), 'differences', '<text>'),
#  ((230, 160, 125), 'signify', '<text>'),
#  ((230, 160, 130), 'slight', '<text>'),
#  ((230, 160, 135), 'unitarity', '<text>'),
#  ((230, 160, 140), 'violation', '<text>'),
#  ((230, 160, 145), 'of', '<text>'),
#  ((230, 160, 150), 'the', '<text>'),
#  ((230, 160, 155), 'PMNS', '<text>'),
#  ((230, 160, 160), 'matrix', '<text>'),
#  ((230, 160, 160.1), '\\(', '<inline_math>'),
#  ((230, 160, 165), 'U ', '<inline_math>'),
#  ((230, 160, 165.1), '\\)', '<inline_math>'),
#  ((230, 160, 170), '.\n\n', '<text>'),
#  ((0, 0, 0.5), '##', '<text>'),
#  ((0, 0, 0.6), '1', '<text>'),
#  ((230, 160, 175), 'Introduction\n\n', '<text>'),
#  ((230, 160, 180), 'The', '<text>'),
#  ((230, 160, 185), 'discoveries', '<text>'),
#  ((230, 160, 190), 'of', '<text>'),
#  ((230, 160, 195), 'solar', '<text>'),
#  ((230, 160, 200), ',', '<text>'),
#  ((230, 160, 205), 'atmospheric', '<text>'),
#  ((230, 160, 210), ',', '<text>'),
#  ((230, 160, 215), 'reactor', '<text>'),
#  ((230, 160, 220), 'and', '<text>'),
#  ((230, 160, 225), 'accelerator', '<text>'),
#  ((230, 160, 230), 'neutrino', '<text>'),
#  ((230, 160, 235), 'oscillations', '<text>'),
#  ((230, 160, 235.1), '[', '<text>'),
#  ((230, 160, 240), '0', '<text>'),
#  ((230, 160, 240.1), ']', '<text>'),
#  ((230, 160, 245), 'have', '<text>'),
#  ((230, 160, 250), 'changed', '<text>'),
#  ((230, 165, 0), 'some', '<text>'),
#  ((230, 165, 5), 'of', '<text>'),
#  ((230, 165, 10), 'our', '<text>'),
#  ((230, 165, 15), 'previous', '<text>'),
#  ((230, 165, 20), 'ideas', '<text>'),
#  ((230, 165, 25), 'about', '<text>'),
#  ((230, 165, 30), 'the', '<text>'),
#  ((230, 165, 35), 'standard', '<text>'),
#  ((230, 165, 40), 'model', '<text>'),
#  ((230, 165, 45), '(', '<text>'),
#  ((230, 165, 50), 'SM', '<text>'),
#  ((230, 165, 55), ')', '<text>'),
#  ((230, 165, 60), 'of', '<text>'),
#  ((230, 165, 65), 'particle', '<text>'),
#  ((230, 165, 70), 'physics', '<text>'),
#  ((230, 165, 75), ',', '<text>'),
#  ((230, 165, 80), 'especially', '<text>'),
#  ((230, 165, 85), 'about', '<text>'),
#  ((230, 165, 90), 'its', '<text>'),
#  ((230, 165, 95), 'lepton', '<text>'),
#  ((230, 165, 100), 'flavor', '<text>'),
#  ((230, 165, 105), 'sector', '<text>'),
#  ((230, 165, 110), '.', '<text>'),
#  ((230, 165, 115), 'Now', '<text>'),
#  ((230, 165, 120), 'we', '<text>'),
#  ((230, 165, 125), 'are', '<text>'),
#  ((230, 165, 130), 'firmly', '<text>'),
#  ((230, 165, 135), 'convinced', '<text>'),
#  ((230, 165, 140), 'that', '<text>'),
#  ((230, 165, 145), 'neutrinos', '<text>'),
#  ((230, 165, 150), 'have', '<text>'),
#  ((230, 165, 155), 'mysteriously', '<text>'),
#  ((230, 165, 160), 'tiny', '<text>'),
#  ((230, 165, 165), 'masses', '<text>'),
#  ((230, 165, 170), 'and', '<text>'),
#  ((230, 165, 175), 'lepton', '<text>'),
#  ((230, 165, 180), 'flavors', '<text>'),
#  ((230, 165, 185), 'are', '<text>'),
#  ((230, 165, 190), 'significantly', '<text>'),
#  ((230, 165, 195), 'mixed', '<text>'),
#  ((230, 165, 200), '.', '<text>'),
#  ((230, 165, 205), 'Behind', '<text>'),
#  ((230, 165, 210), 'these', '<text>'),
#  ((230, 165, 215), 'two', '<text>'),
#  ((230, 165, 220), 'important', '<text>'),
#  ((230, 165, 225), 'observations', '<text>'),
#  ((230, 165, 230), 'must', '<text>'),
#  ((230, 165, 235), 'be', '<text>'),
#  ((230, 165, 240), 'some', '<text>'),
#  ((230, 165, 245), 'kind', '<text>'),
#  ((230, 165, 250), 'of', '<text>'),
#  ((230, 170, 0), 'new', '<text>'),
#  ((230, 170, 5), 'physics', '<text>'),
#  ((230, 170, 10), 'beyond', '<text>'),
#  ((230, 170, 15), 'the', '<text>'),
#  ((230, 170, 20), 'SM', '<text>'),
#  ((230, 170, 20.1), '[', '<text>'),
#  ((230, 170, 25), '1', '<text>'),
#  ((230, 170, 25.1), ']', '<text>'),
#  ((230, 170, 30), ',', '<text>'),
#  ((230, 170, 35), 'which', '<text>'),
#  ((230, 170, 40), 'is', '<text>'),
#  ((230, 170, 45), 'responsible', '<text>'),
#  ((230, 170, 50), 'for', '<text>'),
#  ((230, 170, 55), 'the', '<text>'),
#  ((230, 170, 60), 'origin', '<text>'),
#  ((230, 170, 65), 'of', '<text>'),
#  ((230, 170, 70), 'neutrino', '<text>'),
#  ((230, 170, 75), 'masses', '<text>'),
#  ((230, 170, 80), 'and', '<text>'),
#  ((230, 170, 85), 'may', '<text>'),
#  ((230, 170, 90), 'have', '<text>'),
#  ((230, 170, 95), 'far', '<text>'),
#  ((230, 170, 100), '-', '<text>'),
#  ((230, 170, 105), 'reaching', '<text>'),
#  ((230, 170, 110), 'implications', '<text>'),
#  ((230, 170, 115), 'for', '<text>'),
#  ((230, 170, 120), 'particle', '<text>'),
#  ((230, 170, 125), 'physics', '<text>'),
#  ((230, 170, 130), 'and', '<text>'),
#  ((230, 170, 135), 'cosmology', '<text>'),
#  ((230, 170, 140), '.\n\n', '<text>'),
#  ((230, 170, 145), 'In', '<text>'),
#  ((230, 170, 150), 'weak', '<text>'),
#  ((230, 170, 155), 'charged', '<text>'),
#  ((230, 170, 160), '-', '<text>'),
#  ((230, 170, 165), 'current', '<text>'),
#  ((230, 170, 170), 'interactions', '<text>'),
#  ((230, 170, 175), 'it', '<text>'),
#  ((230, 170, 180), 'is', '<text>'),
#  ((230, 170, 185), 'the', '<text>'),
#  ((230, 170, 185.1), '\\(', '<inline_math>'),
#  ((230, 170, 190), '3', '<inline_math>'),
#  ((230, 170, 195), '\\times ', '<inline_math>'),
#  ((230, 170, 200), '3 ', '<inline_math>'),
#  ((230, 170, 200.1), '\\)', '<inline_math>'),
#  ((230, 170, 205), 'Pontecorvo', '<text>'),
#  ((230, 170, 210), '-', '<text>'),
#  ((230, 170, 215), 'Maki', '<text>'),
#  ((230, 170, 220), '-', '<text>'),
#  ((230, 170, 225), 'Nakagawa', '<text>'),
#  ((230, 170, 230), '-', '<text>'),
#  ((230, 170, 235), 'Sakata', '<text>'),
#  ((230, 170, 240), '(', '<text>'),
#  ((230, 170, 245), 'PMNS', '<text>'),
#  ((230, 170, 250), ')', '<text>'),
#  ((230, 175, 0), 'matrix', '<text>'),
#  ((230, 175, 0.1), '\\(', '<inline_math>'),
#  ((230, 175, 5), 'U ', '<inline_math>'),
#  ((230, 175, 5.1), '\\)', '<inline_math>'),
#  ((230, 175, 10), 'that', '<text>'),
#  ((230, 175, 15), 'describes', '<text>'),
#  ((230, 175, 20), 'the', '<text>'),
#  ((230, 175, 25), 'effects', '<text>'),
#  ((230, 175, 30), 'of', '<text>'),
#  ((230, 175, 35), 'lepton', '<text>'),
#  ((230, 175, 40), 'flavor', '<text>'),
#  ((230, 175, 45), 'mixing', '<text>'),
#  ((230, 175, 50), 'and', '<text>'),
#  ((230, 175, 55), 'CP', '<text>'),
#  ((230, 175, 60), 'violation', '<text>'),
#  ((230, 175, 60.1), '[', '<text>'),
#  ((230, 175, 65), '2', '<text>'),
#  ((230, 175, 65.1), '][', '<text>'),
#  ((230, 175, 70), '3', '<text>'),
#  ((230, 175, 70.1), '][', '<text>'),
#  ((230, 175, 75), '4', '<text>'),
#  ((230, 175, 75.1), ']', '<text>'),
#  ((230, 175, 80), '.', '<text>'),
#  ((230, 175, 85), 'The', '<text>'),
#  ((230, 175, 90), 'smallest', '<text>'),
#  ((230, 175, 95), 'element', '<text>'),
#  ((230, 175, 100), 'of', '<text>'),
#  ((230, 175, 100.1), '\\(', '<inline_math>'),
#  ((230, 175, 105), 'U ', '<inline_math>'),
#  ((230, 175, 105.1), '\\)', '<inline_math>'),
#  ((230, 175, 110), 'is', '<text>'),
#  ((230, 175, 115), 'found', '<text>'),
#  ((230, 175, 120), 'to', '<text>'),
#  ((230, 175, 125), 'be', '<text>'),
#  ((230, 175, 125.1), '\\(', '<inline_math>'),
#  ((230, 175, 125.19999999999999), '|', '<inline_math>'),
#  ((230, 175, 130), 'U', '<inline_math>'),
#  ((230, 175, 130.1), '_{', '<inline_math>'),
#  ((230, 175, 135), 'e ', '<inline_math>'),
#  ((230, 175, 140), '3', '<inline_math>'),
#  ((230, 175, 140.1), '}|', '<inline_math>'),
#  ((230, 175, 145), '\\simeq ', '<inline_math>'),
#  ((230, 175, 150), '0.15 ', '<inline_math>'),
#  ((230, 175, 150.1), '\\)', '<inline_math>'),
#  ((230, 175, 150.2), '[', '<text>'),
#  ((230, 175, 155), '5', '<text>'),
#  ((230, 175, 155.1), ']', '<text>'),
#  ((230, 175, 160), ',', '<text>'),
#  ((230, 175, 165), 'much', '<text>'),
#  ((230, 175, 170), 'larger', '<text>'),
#  ((230, 175, 175), 'than', '<text>'),
#  ((230, 175, 175.1), '\\(', '<inline_math>'),
#  ((230, 175, 175.2), '|', '<inline_math>'),
#  ((230, 175, 180), 'V', '<inline_math>'),
#  ((230, 175, 180.1), '_{', '<inline_math>'),
#  ((230, 175, 185), 'ub', '<inline_math>'),
#  ((230, 175, 185.1), '}|', '<inline_math>'),
#  ((230, 175, 190), '\\simeq ', '<inline_math>'),
#  ((230, 175, 195), '3.6', '<inline_math>'),
#  ((230, 175, 200), '\\times ', '<inline_math>'),
#  ((230, 175, 205), '10', '<inline_math>'),
#  ((230, 175, 205.1), '^{', '<inline_math>'),
#  ((230, 175, 210), '-', '<inline_math>'),
#  ((230, 175, 215), '3', '<inline_math>'),
#  ((230, 175, 215.1), '}', '<inline_math>'),
#  ((230, 175, 215.2), '\\)', '<inline_math>'),
#  ((230, 175, 220), '-', '<text>'),
#  ((230, 175, 225), '-', '<text>'),
#  ((230, 175, 230), '-', '<text>'),
#  ((230, 175, 235), 'the', '<text>'),
#  ((230, 175, 240), 'smallest', '<text>'),
#  ((230, 175, 245), 'element', '<text>'),
#  ((230, 175, 250), 'of', '<text>'),
#  ((230, 180, 0), 'the', '<text>'),
#  ((230, 180, 0.1), '\\(', '<inline_math>'),
#  ((230, 180, 5), '3', '<inline_math>'),
#  ((230, 180, 10), '\\times ', '<inline_math>'),
#  ((230, 180, 15), '3 ', '<inline_math>'),
#  ((230, 180, 15.1), '\\)', '<inline_math>'),
#  ((230, 180, 20), 'Cabibbo', '<text>'),
#  ((230, 180, 25), '-', '<text>'),
#  ((230, 180, 30), 'Kobayashi', '<text>'),
#  ((230, 180, 35), '-', '<text>'),
#  ((230, 180, 40), 'Maskawa', '<text>'),
#  ((230, 180, 45), '(', '<text>'),
#  ((230, 180, 50), 'CKM', '<text>'),
#  ((230, 180, 55), ')', '<text>'),
#  ((230, 180, 60), 'quark', '<text>'),
#  ((230, 180, 65), 'flavor', '<text>'),
#  ((230, 180, 70), 'mixing', '<text>'),
#  ((230, 180, 75), 'matrix', '<text>'),
#  ((230, 180, 75.1), '\\(', '<inline_math>'),
#  ((230, 180, 80), 'V ', '<inline_math>'),
#  ((230, 180, 80.1), '\\)', '<inline_math>'),
#  ((230, 180, 80.19999999999999), '[', '<text>'),
#  ((230, 180, 85), '6', '<text>'),
#  ((230, 180, 85.1), '][', '<text>'),
#  ((230, 180, 90), '7', '<text>'),
#  ((230, 180, 90.1), ']', '<text>'),
#  ((230, 180, 95), '.', '<text>'),
#  ((230, 180, 100), 'Moreover', '<text>'),
#  ((230, 180, 105), ',', '<text>'),
#  ((230, 180, 110), 'the', '<text>'),
#  ((230, 180, 115), 'PMNS', '<text>'),
#  ((230, 180, 120), 'matrix', '<text>'),
#  ((230, 180, 120.1), '\\(', '<inline_math>'),
#  ((230, 180, 125), 'U ', '<inline_math>'),
#  ((230, 180, 125.1), '\\)', '<inline_math>'),
#  ((230, 180, 130), 'is', '<text>'),
#  ((230, 180, 135), 'very', '<text>'),
#  ((230, 180, 140), 'likely', '<text>'),
#  ((230, 180, 145), 'to', '<text>'),
#  ((230, 180, 150), 'accommodate', '<text>'),
#  ((230, 180, 155), 'significant', '<text>'),
#  ((230, 180, 160), 'CP', '<text>'),
#  ((230, 180, 165), 'violation', '<text>'),
#  ((230, 180, 170), 'in', '<text>'),
#  ((230, 180, 175), 'the', '<text>'),
#  ((230, 180, 180), 'lepton', '<text>'),
#  ((230, 180, 185), 'sector', '<text>'),
#  ((230, 180, 190), ',', '<text>'),
#  ((230, 180, 195), 'as', '<text>'),
#  ((230, 180, 200), 'indicated', '<text>'),
#  ((230, 180, 205), 'by', '<text>'),
#  ((230, 180, 210), 'the', '<text>'),
#  ((230, 180, 215), 'latest', '<text>'),
#  ((230, 180, 220), 'T', '<text>'),
#  ((230, 180, 225), '2', '<text>'),
#  ((230, 180, 230), 'K', '<text>'),
#  ((230, 180, 235), 'measurement', '<text>'),
#  ((230, 180, 240), 'at', '<text>'),
#  ((230, 180, 245), 'almost', '<text>'),
#  ((230, 180, 250), 'the', '<text>'),
#  ((230, 180, 250.1), '\\(', '<inline_math>'),
#  ((230, 185, 0), '3', '<inline_math>'),
#  ((230, 185, 5), '\\sigma ', '<inline_math>'),
#  ((230, 185, 5.1), '\\)', '<inline_math>'),
#  ((230, 185, 10), 'confidence', '<text>'),
#  ((230, 185, 15), 'level', '<text>'),
#  ((230, 185, 15.1), '[', '<text>'),
#  ((230, 185, 20), '8', '<text>'),
#  ((230, 185, 20.1), ']', '<text>'),
#  ((230, 185, 25), '.', '<text>'),
#  ((230, 185, 30), 'Given', '<text>'),
#  ((230, 185, 35), 'the', '<text>'),
#  ((230, 185, 40), 'unitarity', '<text>'),
#  ((230, 185, 45), 'of', '<text>'),
#  ((230, 185, 45.1), '\\(', '<inline_math>'),
#  ((230, 185, 50), 'U ', '<inline_math>'),
#  ((230, 185, 50.1), '\\)', '<inline_math>'),
#  ((230, 185, 55), ',', '<text>'),
#  ((230, 185, 60), 'there', '<text>'),
#  ((230, 185, 65), 'are', '<text>'),
#  ((230, 185, 70), 'three', '<text>'),
#  ((230, 185, 75), 'Dirac', '<text>'),
#  ((230, 185, 80), '-', '<text>'),
#  ((230, 185, 85), 'type', '<text>'),
#  ((230, 185, 90), 'unitarity', '<text>'),
#  ((230, 185, 95), 'triangles', '<text>'),
#  ((230, 185, 100), 'defined', '<text>'),
#  ((230, 185, 105), 'by', '<text>'),
#  ((230, 185, 110), 'the', '<text>'),
#  ((230, 185, 115), 'orthogonality', '<text>'),
#  ((230, 185, 120), 'conditions', '<text>'),
#  ((230, 185, 120.1), '[', '<text>'),
#  ((230, 185, 125), '9', '<text>'),
#  ((230, 185, 125.1), ']\n\n', '<text>'),
#  ((0, 0, 0.7), '\\textonesuperior\n\n', '<text>'),
#  ((230, 195, 205.1), '\n\\[\n', '<block_math>'),
#  ((230, 195, 205),
#   ' U_{\\alpha 1}U^{*}_{\\beta 1}+U_{\\alpha 2}U^{*}_{\\beta 2}+U_{ \\alpha 3}U^{*}_{\\beta 3}=0\\;\n',
#   '<text>'),
#  ((230, 195, 205.2), '\\]\n', '<block_math>')]

# %%
while len(pair)>0 and pair[-1][0] == 'need':
    pair.pop(-1)  ### this while totally remove the last sequence match ability but make more accuracte when color is applied properly
if len(pair)==0:
    fail_to_match = True

# %%
for tag, i1,i2,j1,j2 in pair:
    print('{:7}   seq1[{}:{}] --> {}'.format(tag, i1, i2, [t[1] for t in sequence1[i1:i2]]))
    print('          seq2[{}:{}] --> {}\n'.format(j1, j2, [t[1] for t in sequence2[j1:j2]]))
# Out:
# aligned   seq1[0:1] --> ['Radiative']
#           seq2[0:1] --> ['Radiative']
#
# aligned   seq1[1:2] --> ['decays']
#           seq2[1:2] --> ['decays']
#
# aligned   seq1[2:3] --> ['of']
#           seq2[2:3] --> ['of']
#
# aligned   seq1[3:4] --> ['charged']
#           seq2[3:4] --> ['charged']
#
# aligned   seq1[4:5] --> ['leptons']
#           seq2[4:5] --> ['leptons']
#
# aligned   seq1[5:6] --> ['as']
#           seq2[5:6] --> ['as']
#
# aligned   seq1[6:7] --> ['constraints']
#           seq2[6:7] --> ['constraints']
#
# aligned   seq1[7:8] --> ['of']
#           seq2[7:8] --> ['of']
#
# aligned   seq1[8:9] --> ['unitarity']
#           seq2[8:9] --> ['unitarity']
#
# aligned   seq1[9:10] --> ['polygons\n\n']
#           seq2[9:10] --> ['polygons']
#
# aligned   seq1[10:11] --> ['for']
#           seq2[10:11] --> ['for']
#
# aligned   seq1[11:12] --> ['active']
#           seq2[11:12] --> ['active']
#
# aligned   seq1[12:13] --> ['-']
#           seq2[12:13] --> ['-']
#
# aligned   seq1[13:14] --> ['sterile']
#           seq2[13:14] --> ['sterile']
#
# aligned   seq1[14:15] --> ['neutrino']
#           seq2[14:15] --> ['neutrino']
#
# aligned   seq1[15:16] --> ['mixing']
#           seq2[15:16] --> ['mixing']
#
# aligned   seq1[16:17] --> ['and']
#           seq2[16:17] --> ['and']
#
# aligned   seq1[17:18] --> ['CP']
#           seq2[17:18] --> ['CP']
#
# aligned   seq1[18:19] --> ['violation\n\n']
#           seq2[18:19] --> ['violation']
#
# aligned   seq1[19:20] --> ['Zhi']
#           seq2[19:20] --> ['Zhi']
#
# aligned   seq1[20:21] --> ['-']
#           seq2[20:21] --> ['-']
#
# aligned   seq1[21:22] --> ['zhong']
#           seq2[21:22] --> ['zhong']
#
# aligned   seq1[22:23] --> ['Xing']
#           seq2[22:23] --> ['Xing']
#
# need      seq1[23:24] --> ['1,2']
#           seq2[23:24] --> ['1,2']
#
# aligned   seq1[24:25] --> ['and']
#           seq2[24:25] --> ['and']
#
# aligned   seq1[25:26] --> ['Di']
#           seq2[25:26] --> ['Di']
#
# aligned   seq1[26:27] --> ['Zhang']
#           seq2[26:27] --> ['Zhang']
#
# need      seq1[27:30] --> ['\\textonesuperior', '*\n\n', '\\textonesuperior']
#           seq2[27:30] --> ['1', '*', '1']
#
# aligned   seq1[30:31] --> ['Institute']
#           seq2[30:31] --> ['Institute']
#
# aligned   seq1[31:32] --> ['of']
#           seq2[31:32] --> ['of']
#
# aligned   seq1[32:33] --> ['High']
#           seq2[32:33] --> ['High']
#
# aligned   seq1[33:34] --> ['Energy']
#           seq2[33:34] --> ['Energy']
#
# aligned   seq1[34:35] --> ['Physics']
#           seq2[34:35] --> ['Physics']
#
# aligned   seq1[35:36] --> ['and']
#           seq2[35:36] --> ['and']
#
# aligned   seq1[36:37] --> ['School']
#           seq2[36:37] --> ['School']
#
# aligned   seq1[37:38] --> ['of']
#           seq2[37:38] --> ['of']
#
# aligned   seq1[38:39] --> ['Physical']
#           seq2[38:39] --> ['Physical']
#
# aligned   seq1[39:40] --> ['Sciences']
#           seq2[39:40] --> ['Sciences']
#
# aligned   seq1[40:41] --> [',\n\n']
#           seq2[40:41] --> [',']
#
# aligned   seq1[41:42] --> ['University']
#           seq2[41:42] --> ['University']
#
# aligned   seq1[42:43] --> ['of']
#           seq2[42:43] --> ['of']
#
# aligned   seq1[43:44] --> ['Chinese']
#           seq2[43:44] --> ['Chinese']
#
# aligned   seq1[44:45] --> ['Academy']
#           seq2[44:45] --> ['Academy']
#
# aligned   seq1[45:46] --> ['of']
#           seq2[45:46] --> ['of']
#
# aligned   seq1[46:47] --> ['Sciences']
#           seq2[46:47] --> ['Sciences']
#
# aligned   seq1[47:48] --> [',']
#           seq2[47:48] --> [',']
#
# aligned   seq1[48:49] --> ['Beijing']
#           seq2[48:49] --> ['Beijing']
#
# aligned   seq1[49:50] --> ['100049,']
#           seq2[49:50] --> ['100049,']
#
# aligned   seq1[50:51] --> ['China\n\n']
#           seq2[50:51] --> ['China']
#
# need      seq1[51:52] --> ['\\texttwosuperior']
#           seq2[51:52] --> ['2']
#
# aligned   seq1[52:53] --> ['Center']
#           seq2[52:53] --> ['Center']
#
# aligned   seq1[53:54] --> ['of']
#           seq2[53:54] --> ['of']
#
# aligned   seq1[54:55] --> ['High']
#           seq2[54:55] --> ['High']
#
# aligned   seq1[55:56] --> ['Energy']
#           seq2[55:56] --> ['Energy']
#
# aligned   seq1[56:57] --> ['Physics']
#           seq2[56:57] --> ['Physics']
#
# aligned   seq1[57:58] --> [',']
#           seq2[57:58] --> [',']
#
# aligned   seq1[58:59] --> ['Peking']
#           seq2[58:59] --> ['Peking']
#
# aligned   seq1[59:60] --> ['University']
#           seq2[59:60] --> ['University']
#
# aligned   seq1[60:61] --> [',']
#           seq2[60:61] --> [',']
#
# aligned   seq1[61:62] --> ['Beijing']
#           seq2[61:62] --> ['Beijing']
#
# aligned   seq1[62:63] --> ['100871,']
#           seq2[62:63] --> ['100871,']
#
# aligned   seq1[63:64] --> ['China\n\n']
#           seq2[63:64] --> ['China']
#
# need      seq1[64:66] --> ['######', 'Abstract\n\n']
#           seq2[64:65] --> ['Abstract']
#
# aligned   seq1[66:67] --> ['We']
#           seq2[65:66] --> ['We']
#
# aligned   seq1[67:68] --> ['calculate']
#           seq2[66:67] --> ['calculate']
#
# aligned   seq1[68:69] --> ['the']
#           seq2[67:68] --> ['the']
#
# aligned   seq1[69:70] --> ['rates']
#           seq2[68:69] --> ['rates']
#
# aligned   seq1[70:71] --> ['of']
#           seq2[69:70] --> ['of']
#
# aligned   seq1[71:72] --> ['radiative']
#           seq2[70:71] --> ['radiative']
#
# need      seq1[72:73] --> ['\\(']
#           seq2[71:71] --> []
#
# aligned   seq1[73:74] --> ['\\beta']
#           seq2[71:72] --> ['\\beta']
#
# need      seq1[74:75] --> ['^{']
#           seq2[72:72] --> []
#
# aligned   seq1[75:76] --> ['-']
#           seq2[72:73] --> ['-']
#
# need      seq1[76:77] --> ['}']
#           seq2[73:73] --> []
#
# aligned   seq1[77:78] --> ['\\to']
#           seq2[73:74] --> ['\\textrightarrow']
#
# aligned   seq1[78:79] --> ['\\alpha']
#           seq2[74:75] --> ['\\alpha']
#
# need      seq1[79:80] --> ['^{']
#           seq2[75:75] --> []
#
# aligned   seq1[80:81] --> ['-']
#           seq2[75:76] --> ['-']
#
# need      seq1[81:82] --> ['}']
#           seq2[76:76] --> []
#
# aligned   seq1[82:83] --> ['+']
#           seq2[76:77] --> ['+']
#
# aligned   seq1[83:84] --> ['\\gamma ']
#           seq2[77:78] --> ['\\gamma']
#
# need      seq1[84:85] --> ['\\)']
#           seq2[78:78] --> []
#
# aligned   seq1[85:86] --> ['decays']
#           seq2[78:79] --> ['decays']
#
# aligned   seq1[86:87] --> ['for']
#           seq2[79:80] --> ['for']
#
# need      seq1[87:88] --> ['\\(']
#           seq2[80:80] --> []
#
# aligned   seq1[88:89] --> ['(']
#           seq2[80:81] --> ['(']
#
# aligned   seq1[89:90] --> ['\\alpha']
#           seq2[81:82] --> ['\\alpha']
#
# aligned   seq1[90:91] --> [',']
#           seq2[82:83] --> [',']
#
# aligned   seq1[91:92] --> ['\\beta']
#           seq2[83:84] --> ['\\beta']
#
# aligned   seq1[92:93] --> [')']
#           seq2[84:85] --> [')']
#
# aligned   seq1[93:94] --> ['=']
#           seq2[85:86] --> ['=']
#
# aligned   seq1[94:95] --> ['(']
#           seq2[86:87] --> ['(']
#
# aligned   seq1[95:96] --> ['e']
#           seq2[87:88] --> ['e']
#
# aligned   seq1[96:97] --> [',']
#           seq2[88:89] --> [',']
#
# aligned   seq1[97:98] --> ['\\mu']
#           seq2[89:90] --> ['\\mu']
#
# aligned   seq1[98:99] --> [') ']
#           seq2[90:91] --> [')']
#
# need      seq1[99:100] --> ['\\)']
#           seq2[91:91] --> []
#
# aligned   seq1[100:101] --> [',']
#           seq2[91:92] --> [',']
#
# need      seq1[101:102] --> ['\\(']
#           seq2[92:92] --> []
#
# aligned   seq1[102:103] --> ['(']
#           seq2[92:93] --> ['(']
#
# aligned   seq1[103:104] --> ['e']
#           seq2[93:94] --> ['e']
#
# aligned   seq1[104:105] --> [',']
#           seq2[94:95] --> [',']
#
# aligned   seq1[105:106] --> ['\\tau']
#           seq2[95:96] --> ['\\tau']
#
# aligned   seq1[106:107] --> [') ']
#           seq2[96:97] --> [')']
#
# need      seq1[107:108] --> ['\\)']
#           seq2[97:97] --> []
#
# aligned   seq1[108:109] --> ['and']
#           seq2[97:98] --> ['and']
#
# need      seq1[109:110] --> ['\\(']
#           seq2[98:98] --> []
#
# aligned   seq1[110:111] --> ['(']
#           seq2[98:99] --> ['(']
#
# aligned   seq1[111:112] --> ['\\mu']
#           seq2[99:100] --> ['\\mu']
#
# aligned   seq1[112:113] --> [',']
#           seq2[100:101] --> [',']
#
# aligned   seq1[113:114] --> ['\\tau']
#           seq2[101:102] --> ['\\tau']
#
# aligned   seq1[114:115] --> [') ']
#           seq2[102:103] --> [')']
#
# need      seq1[115:116] --> ['\\)']
#           seq2[103:103] --> []
#
# aligned   seq1[116:117] --> ['by']
#           seq2[103:104] --> ['by']
#
# aligned   seq1[117:118] --> ['taking']
#           seq2[104:105] --> ['taking']
#
# aligned   seq1[118:119] --> ['the']
#           seq2[105:106] --> ['the']
#
# aligned   seq1[119:120] --> ['unitary']
#           seq2[106:107] --> ['unitary']
#
# aligned   seq1[120:121] --> ['gauge']
#           seq2[107:108] --> ['gauge']
#
# aligned   seq1[121:122] --> ['in']
#           seq2[108:109] --> ['in']
#
# aligned   seq1[122:123] --> ['the']
#           seq2[109:110] --> ['the']
#
# need      seq1[123:124] --> ['\\(']
#           seq2[110:110] --> []
#
# aligned   seq1[124:125] --> ['(']
#           seq2[110:111] --> ['(']
#
# aligned   seq1[125:126] --> ['3']
#           seq2[111:112] --> ['3']
#
# aligned   seq1[126:127] --> ['+']
#           seq2[112:113] --> ['+']
#
# aligned   seq1[127:128] --> ['n']
#           seq2[113:114] --> ['n']
#
# aligned   seq1[128:129] --> [') ']
#           seq2[114:115] --> [')']
#
# need      seq1[129:130] --> ['\\)']
#           seq2[115:115] --> []
#
# aligned   seq1[130:131] --> ['active']
#           seq2[115:116] --> ['active']
#
# aligned   seq1[131:132] --> ['-']
#           seq2[116:117] --> ['-']
#
# aligned   seq1[132:133] --> ['sterile']
#           seq2[117:118] --> ['sterile']
#
# aligned   seq1[133:134] --> ['neutrino']
#           seq2[118:119] --> ['neutrino']
#
# aligned   seq1[134:135] --> ['mixing']
#           seq2[119:120] --> ['mixing']
#
# aligned   seq1[135:136] --> ['scheme']
#           seq2[120:121] --> ['scheme']
#
# aligned   seq1[136:137] --> [',']
#           seq2[121:122] --> [',']
#
# aligned   seq1[137:138] --> ['and']
#           seq2[122:123] --> ['and']
#
# aligned   seq1[138:139] --> ['make']
#           seq2[123:124] --> ['make']
#
# aligned   seq1[139:140] --> ['it']
#           seq2[124:125] --> ['it']
#
# aligned   seq1[140:141] --> ['clear']
#           seq2[125:126] --> ['clear']
#
# aligned   seq1[141:142] --> ['that']
#           seq2[126:127] --> ['that']
#
# aligned   seq1[142:143] --> ['constraints']
#           seq2[127:128] --> ['constraints']
#
# aligned   seq1[143:144] --> ['on']
#           seq2[128:129] --> ['on']
#
# aligned   seq1[144:145] --> ['the']
#           seq2[129:130] --> ['the']
#
# aligned   seq1[145:146] --> ['unitarity']
#           seq2[130:131] --> ['unitarity']
#
# aligned   seq1[146:147] --> ['of']
#           seq2[131:132] --> ['of']
#
# aligned   seq1[147:148] --> ['the']
#           seq2[132:133] --> ['the']
#
# need      seq1[148:149] --> ['\\(']
#           seq2[133:133] --> []
#
# aligned   seq1[149:150] --> ['3']
#           seq2[133:134] --> ['3']
#
# aligned   seq1[150:151] --> ['\\times ']
#           seq2[134:135] --> ['\\times']
#
# aligned   seq1[151:152] --> ['3 ']
#           seq2[135:136] --> ['3']
#
# need      seq1[152:153] --> ['\\)']
#           seq2[136:136] --> []
#
# aligned   seq1[153:154] --> ['Pontecorvo']
#           seq2[136:137] --> ['Pontecorvo']
#
# aligned   seq1[154:155] --> ['-']
#           seq2[137:138] --> ['-']
#
# aligned   seq1[155:156] --> ['Maki']
#           seq2[138:139] --> ['Maki']
#
# aligned   seq1[156:157] --> ['-']
#           seq2[139:140] --> ['-']
#
# aligned   seq1[157:158] --> ['Nakagawa']
#           seq2[140:141] --> ['Nakagawa']
#
# aligned   seq1[158:159] --> ['-']
#           seq2[141:142] --> ['-']
#
# aligned   seq1[159:160] --> ['Sakata']
#           seq2[142:143] --> ['Sakata']
#
# aligned   seq1[160:161] --> ['(']
#           seq2[143:144] --> ['(']
#
# aligned   seq1[161:162] --> ['PMNS']
#           seq2[144:145] --> ['PMNS']
#
# aligned   seq1[162:163] --> [')']
#           seq2[145:146] --> [')']
#
# aligned   seq1[163:164] --> ['matrix']
#           seq2[146:147] --> ['matrix']
#
# need      seq1[164:165] --> ['\\(']
#           seq2[147:147] --> []
#
# aligned   seq1[165:166] --> ['U ']
#           seq2[147:148] --> ['U']
#
# need      seq1[166:167] --> ['\\)']
#           seq2[148:148] --> []
#
# aligned   seq1[167:168] --> ['extracted']
#           seq2[148:149] --> ['extracted']
#
# aligned   seq1[168:169] --> ['from']
#           seq2[149:150] --> ['from']
#
# need      seq1[169:170] --> ['\\(']
#           seq2[150:150] --> []
#
# aligned   seq1[170:171] --> ['\\beta']
#           seq2[150:151] --> ['\\beta']
#
# need      seq1[171:172] --> ['^{']
#           seq2[151:151] --> []
#
# aligned   seq1[172:173] --> ['-']
#           seq2[151:152] --> ['-']
#
# need      seq1[173:174] --> ['}']
#           seq2[152:152] --> []
#
# aligned   seq1[174:175] --> ['\\to ']
#           seq2[152:153] --> ['\\textrightarrow']
#
# aligned   seq1[175:176] --> ['\\alpha']
#           seq2[153:154] --> ['\\alpha']
#
# need      seq1[176:177] --> ['^{']
#           seq2[154:154] --> []
#
# aligned   seq1[177:178] --> ['-']
#           seq2[154:155] --> ['-']
#
# need      seq1[178:179] --> ['}']
#           seq2[155:155] --> []
#
# aligned   seq1[179:180] --> ['+']
#           seq2[155:156] --> ['+']
#
# aligned   seq1[180:181] --> ['\\gamma ']
#           seq2[156:157] --> ['\\gamma']
#
# need      seq1[181:182] --> ['\\)']
#           seq2[157:157] --> []
#
# aligned   seq1[182:183] --> ['decays']
#           seq2[157:158] --> ['decays']
#
# aligned   seq1[183:184] --> ['in']
#           seq2[158:159] --> ['in']
#
# aligned   seq1[184:185] --> ['the']
#           seq2[159:160] --> ['the']
#
# aligned   seq1[185:186] --> ['minimal']
#           seq2[160:161] --> ['minimal']
#
# aligned   seq1[186:187] --> ['unitarity']
#           seq2[161:162] --> ['unitarity']
#
# aligned   seq1[187:188] --> ['violation']
#           seq2[162:163] --> ['violation']
#
# aligned   seq1[188:189] --> ['scheme']
#           seq2[163:164] --> ['scheme']
#
# aligned   seq1[189:190] --> ['differ']
#           seq2[164:165] --> ['differ']
#
# aligned   seq1[190:191] --> ['from']
#           seq2[165:166] --> ['from']
#
# aligned   seq1[191:192] --> ['those']
#           seq2[166:167] --> ['those']
#
# aligned   seq1[192:193] --> ['obtained']
#           seq2[167:168] --> ['obtained']
#
# aligned   seq1[193:194] --> ['in']
#           seq2[168:169] --> ['in']
#
# aligned   seq1[194:195] --> ['the']
#           seq2[169:170] --> ['the']
#
# aligned   seq1[195:196] --> ['canonical']
#           seq2[170:171] --> ['canonical']
#
# aligned   seq1[196:197] --> ['seesaw']
#           seq2[171:172] --> ['seesaw']
#
# aligned   seq1[197:198] --> ['mechanism']
#           seq2[172:173] --> ['mechanism']
#
# aligned   seq1[198:199] --> ['with']
#           seq2[173:174] --> ['with']
#
# need      seq1[199:200] --> ['\\(']
#           seq2[174:174] --> []
#
# aligned   seq1[200:201] --> ['n ']
#           seq2[174:175] --> ['n']
#
# need      seq1[201:202] --> ['\\)']
#           seq2[175:175] --> []
#
# aligned   seq1[202:203] --> ['heavy']
#           seq2[175:176] --> ['heavy']
#
# aligned   seq1[203:204] --> ['Majorana']
#           seq2[176:177] --> ['Majorana']
#
# aligned   seq1[204:205] --> ['neutrinos']
#           seq2[177:178] --> ['neutrinos']
#
# aligned   seq1[205:206] --> ['by']
#           seq2[178:179] --> ['by']
#
# aligned   seq1[206:207] --> ['a']
#           seq2[179:180] --> ['a']
#
# aligned   seq1[207:208] --> ['factor']
#           seq2[180:181] --> ['factor']
#
# need      seq1[208:209] --> ['\\(']
#           seq2[181:181] --> []
#
# aligned   seq1[209:210] --> ['5']
#           seq2[181:182] --> ['5']
#
# aligned   seq1[210:211] --> ['/']
#           seq2[182:183] --> ['/']
#
# aligned   seq1[211:212] --> ['3 ']
#           seq2[183:184] --> ['3']
#
# need      seq1[212:213] --> ['\\)']
#           seq2[184:184] --> []
#
# aligned   seq1[213:214] --> ['.']
#           seq2[184:185] --> ['.']
#
# aligned   seq1[214:215] --> ['In']
#           seq2[185:186] --> ['In']
#
# aligned   seq1[215:216] --> ['such']
#           seq2[186:187] --> ['such']
#
# aligned   seq1[216:217] --> ['a']
#           seq2[187:188] --> ['a']
#
# aligned   seq1[217:218] --> ['natural']
#           seq2[188:189] --> ['natural']
#
# aligned   seq1[218:219] --> ['seesaw']
#           seq2[189:190] --> ['seesaw']
#
# aligned   seq1[219:220] --> ['case']
#           seq2[190:191] --> ['case']
#
# aligned   seq1[220:221] --> ['we']
#           seq2[191:192] --> ['we']
#
# aligned   seq1[221:222] --> ['show']
#           seq2[192:193] --> ['show']
#
# aligned   seq1[222:223] --> ['that']
#           seq2[193:194] --> ['that']
#
# aligned   seq1[223:224] --> ['the']
#           seq2[194:195] --> ['the']
#
# aligned   seq1[224:225] --> ['rates']
#           seq2[195:196] --> ['rates']
#
# aligned   seq1[225:226] --> ['of']
#           seq2[196:197] --> ['of']
#
# need      seq1[226:227] --> ['\\(']
#           seq2[197:197] --> []
#
# aligned   seq1[227:228] --> ['\\beta']
#           seq2[197:198] --> ['\\beta']
#
# need      seq1[228:229] --> ['^{']
#           seq2[198:198] --> []
#
# aligned   seq1[229:230] --> ['-']
#           seq2[198:199] --> ['-']
#
# need      seq1[230:231] --> ['}']
#           seq2[199:199] --> []
#
# aligned   seq1[231:232] --> ['\\to']
#           seq2[199:200] --> ['\\textrightarrow']
#
# aligned   seq1[232:233] --> ['\\alpha']
#           seq2[200:201] --> ['\\alpha']
#
# need      seq1[233:234] --> ['^{']
#           seq2[201:201] --> []
#
# aligned   seq1[234:235] --> ['-']
#           seq2[201:202] --> ['-']
#
# need      seq1[235:236] --> ['}']
#           seq2[202:202] --> []
#
# aligned   seq1[236:237] --> ['+']
#           seq2[202:203] --> ['+']
#
# aligned   seq1[237:238] --> ['\\gamma ']
#           seq2[203:204] --> ['\\gamma']
#
# need      seq1[238:239] --> ['\\)']
#           seq2[204:204] --> []
#
# aligned   seq1[239:240] --> ['can']
#           seq2[204:205] --> ['can']
#
# aligned   seq1[240:241] --> ['be']
#           seq2[205:206] --> ['be']
#
# aligned   seq1[241:242] --> ['used']
#           seq2[206:207] --> ['used']
#
# aligned   seq1[242:243] --> ['to']
#           seq2[207:208] --> ['to']
#
# aligned   seq1[243:244] --> ['cleanly']
#           seq2[208:209] --> ['cleanly']
#
# aligned   seq1[244:245] --> ['and']
#           seq2[209:210] --> ['and']
#
# aligned   seq1[245:246] --> ['strongly']
#           seq2[210:211] --> ['strongly']
#
# aligned   seq1[246:247] --> ['constrain']
#           seq2[211:212] --> ['constrain']
#
# aligned   seq1[247:248] --> ['the']
#           seq2[212:213] --> ['the']
#
# aligned   seq1[248:249] --> ['effective']
#           seq2[213:214] --> ['effective']
#
# aligned   seq1[249:250] --> ['apex']
#           seq2[214:215] --> ['apex']
#
# aligned   seq1[250:251] --> ['of']
#           seq2[215:216] --> ['of']
#
# aligned   seq1[251:252] --> ['a']
#           seq2[216:217] --> ['a']
#
# aligned   seq1[252:253] --> ['unitarity']
#           seq2[217:218] --> ['unitarity']
#
# aligned   seq1[253:254] --> ['polygon']
#           seq2[218:219] --> ['polygon']
#
# aligned   seq1[254:255] --> [',']
#           seq2[219:220] --> [',']
#
# aligned   seq1[255:256] --> ['and']
#           seq2[220:221] --> ['and']
#
# aligned   seq1[256:257] --> ['compare']
#           seq2[221:222] --> ['compare']
#
# aligned   seq1[257:258] --> ['its']
#           seq2[222:223] --> ['its']
#
# aligned   seq1[258:259] --> ['geometry']
#           seq2[223:224] --> ['geometry']
#
# aligned   seq1[259:260] --> ['with']
#           seq2[224:225] --> ['with']
#
# aligned   seq1[260:261] --> ['the']
#           seq2[225:226] --> ['the']
#
# aligned   seq1[261:262] --> ['geometry']
#           seq2[226:227] --> ['geometry']
#
# aligned   seq1[262:263] --> ['of']
#           seq2[227:228] --> ['of']
#
# aligned   seq1[263:264] --> ['its']
#           seq2[228:229] --> ['its']
#
# aligned   seq1[264:265] --> ['three']
#           seq2[229:230] --> ['three']
#
# aligned   seq1[265:266] --> ['sub']
#           seq2[230:231] --> ['sub']
#
# aligned   seq1[266:267] --> ['-']
#           seq2[231:232] --> ['-']
#
# aligned   seq1[267:268] --> ['triangles']
#           seq2[232:233] --> ['triangles']
#
# aligned   seq1[268:269] --> ['formed']
#           seq2[233:234] --> ['formed']
#
# aligned   seq1[269:270] --> ['by']
#           seq2[234:235] --> ['by']
#
# aligned   seq1[270:271] --> ['two']
#           seq2[235:236] --> ['two']
#
# aligned   seq1[271:272] --> ['vectors']
#           seq2[236:237] --> ['vectors']
#
# need      seq1[272:273] --> ['\\(']
#           seq2[237:237] --> []
#
# aligned   seq1[273:274] --> ['U']
#           seq2[237:238] --> ['U']
#
# need      seq1[274:275] --> ['_{']
#           seq2[238:238] --> []
#
# aligned   seq1[275:276] --> ['\\alpha ']
#           seq2[238:239] --> ['\\alpha']
#
# aligned   seq1[276:277] --> ['i']
#           seq2[239:240] --> ['i']
#
# need      seq1[277:278] --> ['}']
#           seq2[240:240] --> []
#
# aligned   seq1[278:279] --> ['U']
#           seq2[240:241] --> ['U']
#
# need      seq1[279:280] --> ['^{']
#           seq2[241:241] --> []
#
# aligned   seq1[280:281] --> ['*']
#           seq2[241:242] --> ['*']
#
# need      seq1[281:282] --> ['}_{']
#           seq2[242:242] --> []
#
# aligned   seq1[282:283] --> ['\\beta ']
#           seq2[242:243] --> ['\\beta']
#
# aligned   seq1[283:284] --> ['i']
#           seq2[243:244] --> ['i']
#
# need      seq1[284:286] --> ['}', '\\)']
#           seq2[244:244] --> []
#
# aligned   seq1[286:287] --> ['and']
#           seq2[244:245] --> ['and']
#
# need      seq1[287:288] --> ['\\(']
#           seq2[245:245] --> []
#
# aligned   seq1[288:289] --> ['U']
#           seq2[245:246] --> ['U']
#
# need      seq1[289:290] --> ['_{']
#           seq2[246:246] --> []
#
# aligned   seq1[290:291] --> ['\\alpha ']
#           seq2[246:247] --> ['\\alpha']
#
# aligned   seq1[291:292] --> ['j']
#           seq2[247:248] --> ['j']
#
# need      seq1[292:293] --> ['}']
#           seq2[248:248] --> []
#
# aligned   seq1[293:294] --> ['U']
#           seq2[248:249] --> ['U']
#
# need      seq1[294:295] --> ['^{']
#           seq2[249:249] --> []
#
# aligned   seq1[295:296] --> ['*']
#           seq2[249:250] --> ['*']
#
# need      seq1[296:297] --> ['}_{']
#           seq2[250:250] --> []
#
# aligned   seq1[297:298] --> ['\\beta ']
#           seq2[250:251] --> ['\\beta']
#
# aligned   seq1[298:299] --> ['j']
#           seq2[251:252] --> ['j']
#
# need      seq1[299:301] --> ['}', '\\)']
#           seq2[252:252] --> []
#
# aligned   seq1[301:302] --> ['(']
#           seq2[252:253] --> ['(']
#
# aligned   seq1[302:303] --> ['for']
#           seq2[253:254] --> ['for']
#
# need      seq1[303:304] --> ['\\(']
#           seq2[254:254] --> []
#
# aligned   seq1[304:305] --> ['i']
#           seq2[254:255] --> ['i']
#
# aligned   seq1[305:306] --> ['\\neq ']
#           seq2[255:256] --> ['=']
#
# aligned   seq1[306:307] --> ['j ']
#           seq2[256:257] --> ['j']
#
# need      seq1[307:308] --> ['\\)']
#           seq2[257:257] --> []
#
# aligned   seq1[308:309] --> [')']
#           seq2[257:258] --> [')']
#
# aligned   seq1[309:310] --> ['in']
#           seq2[258:259] --> ['in']
#
# aligned   seq1[310:311] --> ['the']
#           seq2[259:260] --> ['the']
#
# aligned   seq1[311:312] --> ['complex']
#           seq2[260:261] --> ['complex']
#
# aligned   seq1[312:313] --> ['plane']
#           seq2[261:262] --> ['plane']
#
# aligned   seq1[313:314] --> ['.']
#           seq2[262:263] --> ['.']
#
# aligned   seq1[314:315] --> ['We']
#           seq2[263:264] --> ['We']
#
# aligned   seq1[315:316] --> ['find']
#           seq2[264:265] --> ['find']
#
# aligned   seq1[316:317] --> ['that']
#           seq2[265:266] --> ['that']
#
# aligned   seq1[317:318] --> ['the']
#           seq2[266:267] --> ['the']
#
# aligned   seq1[318:319] --> ['areas']
#           seq2[267:268] --> ['areas']
#
# aligned   seq1[319:320] --> ['of']
#           seq2[268:269] --> ['of']
#
# aligned   seq1[320:321] --> ['such']
#           seq2[269:270] --> ['such']
#
# aligned   seq1[321:322] --> ['sub']
#           seq2[270:271] --> ['sub']
#
# aligned   seq1[322:323] --> ['-']
#           seq2[271:272] --> ['-']
#
# aligned   seq1[323:324] --> ['triangles']
#           seq2[272:273] --> ['triangles']
#
# aligned   seq1[324:325] --> ['can']
#           seq2[273:274] --> ['can']
#
# aligned   seq1[325:326] --> ['be']
#           seq2[274:275] --> ['be']
#
# aligned   seq1[326:327] --> ['described']
#           seq2[275:276] --> ['described']
#
# aligned   seq1[327:328] --> ['in']
#           seq2[276:277] --> ['in']
#
# aligned   seq1[328:329] --> ['terms']
#           seq2[277:278] --> ['terms']
#
# aligned   seq1[329:330] --> ['of']
#           seq2[278:279] --> ['of']
#
# aligned   seq1[330:331] --> ['the']
#           seq2[279:280] --> ['the']
#
# aligned   seq1[331:332] --> ['Jarlskog']
#           seq2[280:281] --> ['Jarlskog']
#
# aligned   seq1[332:333] --> ['-']
#           seq2[281:282] --> ['-']
#
# aligned   seq1[333:334] --> ['like']
#           seq2[282:283] --> ['like']
#
# aligned   seq1[334:335] --> ['invariants']
#           seq2[283:284] --> ['invariants']
#
# aligned   seq1[335:336] --> ['of']
#           seq2[284:285] --> ['of']
#
# aligned   seq1[336:337] --> ['CP']
#           seq2[285:286] --> ['CP']
#
# aligned   seq1[337:338] --> ['violation']
#           seq2[286:287] --> ['violation']
#
# need      seq1[338:340] --> ['\\(', '{\\cal ']
#           seq2[287:287] --> []
#
# aligned   seq1[340:341] --> ['J']
#           seq2[287:288] --> ['J']
#
# need      seq1[341:342] --> ['}^{']
#           seq2[288:288] --> []
#
# aligned   seq1[342:343] --> ['ij']
#           seq2[288:289] --> ['ij']
#
# need      seq1[343:344] --> ['}_{']
#           seq2[289:289] --> []
#
# aligned   seq1[344:345] --> ['\\alpha']
#           seq2[289:290] --> ['\\alpha']
#
# aligned   seq1[345:346] --> ['\\beta']
#           seq2[290:291] --> ['\\beta']
#
# need      seq1[346:348] --> ['}', '\\)']
#           seq2[291:291] --> []
#
# aligned   seq1[348:349] --> [',']
#           seq2[291:292] --> [',']
#
# aligned   seq1[349:350] --> ['and']
#           seq2[292:293] --> ['and']
#
# aligned   seq1[350:351] --> ['their']
#           seq2[293:294] --> ['their']
#
# aligned   seq1[351:352] --> ['small']
#           seq2[294:295] --> ['small']
#
# aligned   seq1[352:353] --> ['differences']
#           seq2[295:296] --> ['differences']
#
# aligned   seq1[353:354] --> ['signify']
#           seq2[296:297] --> ['signify']
#
# aligned   seq1[354:355] --> ['slight']
#           seq2[297:298] --> ['slight']
#
# aligned   seq1[355:356] --> ['unitarity']
#           seq2[298:299] --> ['unitarity']
#
# aligned   seq1[356:357] --> ['violation']
#           seq2[299:300] --> ['violation']
#
# aligned   seq1[357:358] --> ['of']
#           seq2[300:301] --> ['of']
#
# aligned   seq1[358:359] --> ['the']
#           seq2[301:302] --> ['the']
#
# aligned   seq1[359:360] --> ['PMNS']
#           seq2[302:303] --> ['PMNS']
#
# aligned   seq1[360:361] --> ['matrix']
#           seq2[303:304] --> ['matrix']
#
# need      seq1[361:362] --> ['\\(']
#           seq2[304:304] --> []
#
# aligned   seq1[362:363] --> ['U ']
#           seq2[304:305] --> ['U']
#
# need      seq1[363:364] --> ['\\)']
#           seq2[305:305] --> []
#
# aligned   seq1[364:365] --> ['.\n\n']
#           seq2[305:306] --> ['.']
#
# need      seq1[365:367] --> ['##', '1']
#           seq2[306:307] --> ['1']
#
# aligned   seq1[367:368] --> ['Introduction\n\n']
#           seq2[307:308] --> ['Introduction']
#
# aligned   seq1[368:369] --> ['The']
#           seq2[308:309] --> ['The']
#
# aligned   seq1[369:370] --> ['discoveries']
#           seq2[309:310] --> ['discoveries']
#
# aligned   seq1[370:371] --> ['of']
#           seq2[310:311] --> ['of']
#
# aligned   seq1[371:372] --> ['solar']
#           seq2[311:312] --> ['solar']
#
# aligned   seq1[372:373] --> [',']
#           seq2[312:313] --> [',']
#
# aligned   seq1[373:374] --> ['atmospheric']
#           seq2[313:314] --> ['atmospheric']
#
# aligned   seq1[374:375] --> [',']
#           seq2[314:315] --> [',']
#
# aligned   seq1[375:376] --> ['reactor']
#           seq2[315:316] --> ['reactor']
#
# aligned   seq1[376:377] --> ['and']
#           seq2[316:317] --> ['and']
#
# aligned   seq1[377:378] --> ['accelerator']
#           seq2[317:318] --> ['accelerator']
#
# aligned   seq1[378:379] --> ['neutrino']
#           seq2[318:319] --> ['neutrino']
#
# aligned   seq1[379:380] --> ['oscillations']
#           seq2[319:320] --> ['oscillations']
#
# need      seq1[380:381] --> ['[']
#           seq2[320:321] --> ['[']
#
# aligned   seq1[381:382] --> ['0']
#           seq2[321:322] --> ['0']
#
# need      seq1[382:383] --> [']']
#           seq2[322:323] --> [']']
#
# aligned   seq1[383:384] --> ['have']
#           seq2[323:324] --> ['have']
#
# aligned   seq1[384:385] --> ['changed']
#           seq2[324:325] --> ['changed']
#
# aligned   seq1[385:386] --> ['some']
#           seq2[325:326] --> ['some']
#
# aligned   seq1[386:387] --> ['of']
#           seq2[326:327] --> ['of']
#
# aligned   seq1[387:388] --> ['our']
#           seq2[327:328] --> ['our']
#
# aligned   seq1[388:389] --> ['previous']
#           seq2[328:329] --> ['previous']
#
# aligned   seq1[389:390] --> ['ideas']
#           seq2[329:330] --> ['ideas']
#
# aligned   seq1[390:391] --> ['about']
#           seq2[330:331] --> ['about']
#
# aligned   seq1[391:392] --> ['the']
#           seq2[331:332] --> ['the']
#
# aligned   seq1[392:393] --> ['standard']
#           seq2[332:333] --> ['standard']
#
# aligned   seq1[393:394] --> ['model']
#           seq2[333:334] --> ['model']
#
# aligned   seq1[394:395] --> ['(']
#           seq2[334:335] --> ['(']
#
# aligned   seq1[395:396] --> ['SM']
#           seq2[335:336] --> ['SM']
#
# aligned   seq1[396:397] --> [')']
#           seq2[336:337] --> [')']
#
# aligned   seq1[397:398] --> ['of']
#           seq2[337:338] --> ['of']
#
# aligned   seq1[398:399] --> ['particle']
#           seq2[338:339] --> ['particle']
#
# aligned   seq1[399:400] --> ['physics']
#           seq2[339:340] --> ['physics']
#
# aligned   seq1[400:401] --> [',']
#           seq2[340:341] --> [',']
#
# aligned   seq1[401:402] --> ['especially']
#           seq2[341:342] --> ['especially']
#
# aligned   seq1[402:403] --> ['about']
#           seq2[342:343] --> ['about']
#
# aligned   seq1[403:404] --> ['its']
#           seq2[343:344] --> ['its']
#
# aligned   seq1[404:405] --> ['lepton']
#           seq2[344:345] --> ['lepton']
#
# aligned   seq1[405:406] --> ['flavor']
#           seq2[345:346] --> ['flavor']
#
# aligned   seq1[406:407] --> ['sector']
#           seq2[346:347] --> ['sector']
#
# aligned   seq1[407:408] --> ['.']
#           seq2[347:348] --> ['.']
#
# aligned   seq1[408:409] --> ['Now']
#           seq2[348:349] --> ['Now']
#
# aligned   seq1[409:410] --> ['we']
#           seq2[349:350] --> ['we']
#
# aligned   seq1[410:411] --> ['are']
#           seq2[350:351] --> ['are']
#
# aligned   seq1[411:412] --> ['firmly']
#           seq2[351:352] --> ['firmly']
#
# aligned   seq1[412:413] --> ['convinced']
#           seq2[352:353] --> ['convinced']
#
# aligned   seq1[413:414] --> ['that']
#           seq2[353:354] --> ['that']
#
# aligned   seq1[414:415] --> ['neutrinos']
#           seq2[354:355] --> ['neutrinos']
#
# aligned   seq1[415:416] --> ['have']
#           seq2[355:356] --> ['have']
#
# aligned   seq1[416:417] --> ['mysteriously']
#           seq2[356:357] --> ['mysteriously']
#
# aligned   seq1[417:418] --> ['tiny']
#           seq2[357:358] --> ['tiny']
#
# aligned   seq1[418:419] --> ['masses']
#           seq2[358:359] --> ['masses']
#
# aligned   seq1[419:420] --> ['and']
#           seq2[359:360] --> ['and']
#
# aligned   seq1[420:421] --> ['lepton']
#           seq2[360:361] --> ['lepton']
#
# aligned   seq1[421:422] --> ['flavors']
#           seq2[361:362] --> ['flavors']
#
# aligned   seq1[422:423] --> ['are']
#           seq2[362:363] --> ['are']
#
# aligned   seq1[423:424] --> ['significantly']
#           seq2[363:364] --> ['significantly']
#
# aligned   seq1[424:425] --> ['mixed']
#           seq2[364:365] --> ['mixed']
#
# aligned   seq1[425:426] --> ['.']
#           seq2[365:366] --> ['.']
#
# aligned   seq1[426:427] --> ['Behind']
#           seq2[366:367] --> ['Behind']
#
# aligned   seq1[427:428] --> ['these']
#           seq2[367:368] --> ['these']
#
# aligned   seq1[428:429] --> ['two']
#           seq2[368:369] --> ['two']
#
# aligned   seq1[429:430] --> ['important']
#           seq2[369:370] --> ['important']
#
# aligned   seq1[430:431] --> ['observations']
#           seq2[370:371] --> ['observations']
#
# aligned   seq1[431:432] --> ['must']
#           seq2[371:372] --> ['must']
#
# aligned   seq1[432:433] --> ['be']
#           seq2[372:373] --> ['be']
#
# aligned   seq1[433:434] --> ['some']
#           seq2[373:374] --> ['some']
#
# aligned   seq1[434:435] --> ['kind']
#           seq2[374:375] --> ['kind']
#
# aligned   seq1[435:436] --> ['of']
#           seq2[375:376] --> ['of']
#
# aligned   seq1[436:437] --> ['new']
#           seq2[376:377] --> ['new']
#
# aligned   seq1[437:438] --> ['physics']
#           seq2[377:378] --> ['physics']
#
# aligned   seq1[438:439] --> ['beyond']
#           seq2[378:379] --> ['beyond']
#
# aligned   seq1[439:440] --> ['the']
#           seq2[379:380] --> ['the']
#
# aligned   seq1[440:441] --> ['SM']
#           seq2[380:381] --> ['SM']
#
# need      seq1[441:442] --> ['[']
#           seq2[381:382] --> ['[']
#
# aligned   seq1[442:443] --> ['1']
#           seq2[382:383] --> ['1']
#
# need      seq1[443:444] --> [']']
#           seq2[383:384] --> [']']
#
# aligned   seq1[444:445] --> [',']
#           seq2[384:385] --> [',']
#
# aligned   seq1[445:446] --> ['which']
#           seq2[385:386] --> ['which']
#
# aligned   seq1[446:447] --> ['is']
#           seq2[386:387] --> ['is']
#
# aligned   seq1[447:448] --> ['responsible']
#           seq2[387:388] --> ['responsible']
#
# aligned   seq1[448:449] --> ['for']
#           seq2[388:389] --> ['for']
#
# aligned   seq1[449:450] --> ['the']
#           seq2[389:390] --> ['the']
#
# aligned   seq1[450:451] --> ['origin']
#           seq2[390:391] --> ['origin']
#
# aligned   seq1[451:452] --> ['of']
#           seq2[391:392] --> ['of']
#
# aligned   seq1[452:453] --> ['neutrino']
#           seq2[392:393] --> ['neutrino']
#
# aligned   seq1[453:454] --> ['masses']
#           seq2[393:394] --> ['masses']
#
# aligned   seq1[454:455] --> ['and']
#           seq2[394:395] --> ['and']
#
# aligned   seq1[455:456] --> ['may']
#           seq2[395:396] --> ['may']
#
# aligned   seq1[456:457] --> ['have']
#           seq2[396:397] --> ['have']
#
# aligned   seq1[457:458] --> ['far']
#           seq2[397:398] --> ['far']
#
# aligned   seq1[458:459] --> ['-']
#           seq2[398:399] --> ['-']
#
# aligned   seq1[459:460] --> ['reaching']
#           seq2[399:400] --> ['reaching']
#
# aligned   seq1[460:461] --> ['implications']
#           seq2[400:401] --> ['implications']
#
# aligned   seq1[461:462] --> ['for']
#           seq2[401:402] --> ['for']
#
# aligned   seq1[462:463] --> ['particle']
#           seq2[402:403] --> ['particle']
#
# aligned   seq1[463:464] --> ['physics']
#           seq2[403:404] --> ['physics']
#
# aligned   seq1[464:465] --> ['and']
#           seq2[404:405] --> ['and']
#
# aligned   seq1[465:466] --> ['cosmology']
#           seq2[405:406] --> ['cosmology']
#
# aligned   seq1[466:467] --> ['.\n\n']
#           seq2[406:407] --> ['.']
#
# aligned   seq1[467:468] --> ['In']
#           seq2[407:408] --> ['In']
#
# aligned   seq1[468:469] --> ['weak']
#           seq2[408:409] --> ['weak']
#
# aligned   seq1[469:470] --> ['charged']
#           seq2[409:410] --> ['charged']
#
# aligned   seq1[470:471] --> ['-']
#           seq2[410:411] --> ['-']
#
# aligned   seq1[471:472] --> ['current']
#           seq2[411:412] --> ['current']
#
# aligned   seq1[472:473] --> ['interactions']
#           seq2[412:413] --> ['interactions']
#
# aligned   seq1[473:474] --> ['it']
#           seq2[413:414] --> ['it']
#
# aligned   seq1[474:475] --> ['is']
#           seq2[414:415] --> ['is']
#
# aligned   seq1[475:476] --> ['the']
#           seq2[415:416] --> ['the']
#
# need      seq1[476:477] --> ['\\(']
#           seq2[416:416] --> []
#
# aligned   seq1[477:478] --> ['3']
#           seq2[416:417] --> ['3']
#
# aligned   seq1[478:479] --> ['\\times ']
#           seq2[417:418] --> ['\\times']
#
# aligned   seq1[479:480] --> ['3 ']
#           seq2[418:419] --> ['3']
#
# need      seq1[480:481] --> ['\\)']
#           seq2[419:419] --> []
#
# aligned   seq1[481:482] --> ['Pontecorvo']
#           seq2[419:420] --> ['Pontecorvo']
#
# aligned   seq1[482:483] --> ['-']
#           seq2[420:421] --> ['-']
#
# aligned   seq1[483:484] --> ['Maki']
#           seq2[421:422] --> ['Maki']
#
# aligned   seq1[484:485] --> ['-']
#           seq2[422:423] --> ['-']
#
# aligned   seq1[485:486] --> ['Nakagawa']
#           seq2[423:424] --> ['Nakagawa']
#
# aligned   seq1[486:487] --> ['-']
#           seq2[424:425] --> ['-']
#
# aligned   seq1[487:488] --> ['Sakata']
#           seq2[425:426] --> ['Sakata']
#
# aligned   seq1[488:489] --> ['(']
#           seq2[426:427] --> ['(']
#
# aligned   seq1[489:490] --> ['PMNS']
#           seq2[427:428] --> ['PMNS']
#
# aligned   seq1[490:491] --> [')']
#           seq2[428:429] --> [')']
#
# aligned   seq1[491:492] --> ['matrix']
#           seq2[429:430] --> ['matrix']
#
# need      seq1[492:493] --> ['\\(']
#           seq2[430:430] --> []
#
# aligned   seq1[493:494] --> ['U ']
#           seq2[430:431] --> ['U']
#
# need      seq1[494:495] --> ['\\)']
#           seq2[431:431] --> []
#
# aligned   seq1[495:496] --> ['that']
#           seq2[431:432] --> ['that']
#
# aligned   seq1[496:497] --> ['describes']
#           seq2[432:433] --> ['describes']
#
# aligned   seq1[497:498] --> ['the']
#           seq2[433:434] --> ['the']
#
# aligned   seq1[498:499] --> ['effects']
#           seq2[434:435] --> ['effects']
#
# aligned   seq1[499:500] --> ['of']
#           seq2[435:436] --> ['of']
#
# aligned   seq1[500:501] --> ['lepton']
#           seq2[436:437] --> ['lepton']
#
# aligned   seq1[501:502] --> ['flavor']
#           seq2[437:438] --> ['flavor']
#
# aligned   seq1[502:503] --> ['mixing']
#           seq2[438:439] --> ['mixing']
#
# aligned   seq1[503:504] --> ['and']
#           seq2[439:440] --> ['and']
#
# aligned   seq1[504:505] --> ['CP']
#           seq2[440:441] --> ['CP']
#
# aligned   seq1[505:506] --> ['violation']
#           seq2[441:442] --> ['violation']
#
# need      seq1[506:507] --> ['[']
#           seq2[442:443] --> ['[']
#
# aligned   seq1[507:508] --> ['2']
#           seq2[443:444] --> ['2']
#
# need      seq1[508:509] --> ['][']
#           seq2[444:445] --> ['][']
#
# aligned   seq1[509:510] --> ['3']
#           seq2[445:446] --> ['3']
#
# need      seq1[510:511] --> ['][']
#           seq2[446:447] --> ['][']
#
# aligned   seq1[511:512] --> ['4']
#           seq2[447:448] --> ['4']
#
# need      seq1[512:513] --> [']']
#           seq2[448:449] --> [']']
#
# aligned   seq1[513:514] --> ['.']
#           seq2[449:450] --> ['.']
#
# aligned   seq1[514:515] --> ['The']
#           seq2[450:451] --> ['The']
#
# aligned   seq1[515:516] --> ['smallest']
#           seq2[451:452] --> ['smallest']
#
# aligned   seq1[516:517] --> ['element']
#           seq2[452:453] --> ['element']
#
# aligned   seq1[517:518] --> ['of']
#           seq2[453:454] --> ['of']
#
# need      seq1[518:519] --> ['\\(']
#           seq2[454:454] --> []
#
# aligned   seq1[519:520] --> ['U ']
#           seq2[454:455] --> ['U']
#
# need      seq1[520:521] --> ['\\)']
#           seq2[455:455] --> []
#
# aligned   seq1[521:522] --> ['is']
#           seq2[455:456] --> ['is']
#
# aligned   seq1[522:523] --> ['found']
#           seq2[456:457] --> ['found']
#
# aligned   seq1[523:524] --> ['to']
#           seq2[457:458] --> ['to']
#
# aligned   seq1[524:525] --> ['be']
#           seq2[458:459] --> ['be']
#
# need      seq1[525:527] --> ['\\(', '|']
#           seq2[459:460] --> ['|']
#
# aligned   seq1[527:528] --> ['U']
#           seq2[460:461] --> ['U']
#
# need      seq1[528:529] --> ['_{']
#           seq2[461:461] --> []
#
# aligned   seq1[529:530] --> ['e ']
#           seq2[461:462] --> ['e']
#
# aligned   seq1[530:531] --> ['3']
#           seq2[462:463] --> ['3']
#
# need      seq1[531:532] --> ['}|']
#           seq2[463:464] --> ['|']
#
# aligned   seq1[532:533] --> ['\\simeq ']
#           seq2[464:465] --> ['\\simeq']
#
# aligned   seq1[533:534] --> ['0.15 ']
#           seq2[465:466] --> ['0.15']
#
# need      seq1[534:536] --> ['\\)', '[']
#           seq2[466:467] --> ['[']
#
# aligned   seq1[536:537] --> ['5']
#           seq2[467:468] --> ['5']
#
# need      seq1[537:538] --> [']']
#           seq2[468:469] --> [']']
#
# aligned   seq1[538:539] --> [',']
#           seq2[469:470] --> [',']
#
# aligned   seq1[539:540] --> ['much']
#           seq2[470:471] --> ['much']
#
# aligned   seq1[540:541] --> ['larger']
#           seq2[471:472] --> ['larger']
#
# aligned   seq1[541:542] --> ['than']
#           seq2[472:473] --> ['than']
#
# need      seq1[542:544] --> ['\\(', '|']
#           seq2[473:474] --> ['|']
#
# aligned   seq1[544:545] --> ['V']
#           seq2[474:475] --> ['V']
#
# need      seq1[545:546] --> ['_{']
#           seq2[475:475] --> []
#
# aligned   seq1[546:547] --> ['ub']
#           seq2[475:476] --> ['ub']
#
# need      seq1[547:548] --> ['}|']
#           seq2[476:477] --> ['|']
#
# aligned   seq1[548:549] --> ['\\simeq ']
#           seq2[477:478] --> ['\\simeq']
#
# aligned   seq1[549:550] --> ['3.6']
#           seq2[478:479] --> ['3.6']
#
# aligned   seq1[550:551] --> ['\\times ']
#           seq2[479:480] --> ['\\times']
#
# aligned   seq1[551:552] --> ['10']
#           seq2[480:481] --> ['10']
#
# need      seq1[552:553] --> ['^{']
#           seq2[481:481] --> []
#
# aligned   seq1[553:554] --> ['-']
#           seq2[481:482] --> ['-']
#
# aligned   seq1[554:555] --> ['3']
#           seq2[482:483] --> ['3']
#
# need      seq1[555:557] --> ['}', '\\)']
#           seq2[483:483] --> []
#
# aligned   seq1[557:558] --> ['-']
#           seq2[483:484] --> ['-']
#
# aligned   seq1[558:559] --> ['-']
#           seq2[484:485] --> ['-']
#
# aligned   seq1[559:560] --> ['-']
#           seq2[485:486] --> ['-']
#
# aligned   seq1[560:561] --> ['the']
#           seq2[486:487] --> ['the']
#
# aligned   seq1[561:562] --> ['smallest']
#           seq2[487:488] --> ['smallest']
#
# aligned   seq1[562:563] --> ['element']
#           seq2[488:489] --> ['element']
#
# aligned   seq1[563:564] --> ['of']
#           seq2[489:490] --> ['of']
#
# aligned   seq1[564:565] --> ['the']
#           seq2[490:491] --> ['the']
#
# need      seq1[565:566] --> ['\\(']
#           seq2[491:491] --> []
#
# aligned   seq1[566:567] --> ['3']
#           seq2[491:492] --> ['3']
#
# aligned   seq1[567:568] --> ['\\times ']
#           seq2[492:493] --> ['\\times']
#
# aligned   seq1[568:569] --> ['3 ']
#           seq2[493:494] --> ['3']
#
# need      seq1[569:570] --> ['\\)']
#           seq2[494:494] --> []
#
# aligned   seq1[570:571] --> ['Cabibbo']
#           seq2[494:495] --> ['Cabibbo']
#
# aligned   seq1[571:572] --> ['-']
#           seq2[495:496] --> ['-']
#
# aligned   seq1[572:573] --> ['Kobayashi']
#           seq2[496:497] --> ['Kobayashi']
#
# aligned   seq1[573:574] --> ['-']
#           seq2[497:498] --> ['-']
#
# aligned   seq1[574:575] --> ['Maskawa']
#           seq2[498:499] --> ['Maskawa']
#
# aligned   seq1[575:576] --> ['(']
#           seq2[499:500] --> ['(']
#
# aligned   seq1[576:577] --> ['CKM']
#           seq2[500:501] --> ['CKM']
#
# aligned   seq1[577:578] --> [')']
#           seq2[501:502] --> [')']
#
# aligned   seq1[578:579] --> ['quark']
#           seq2[502:503] --> ['quark']
#
# aligned   seq1[579:580] --> ['flavor']
#           seq2[503:504] --> ['flavor']
#
# aligned   seq1[580:581] --> ['mixing']
#           seq2[504:505] --> ['mixing']
#
# aligned   seq1[581:582] --> ['matrix']
#           seq2[505:506] --> ['matrix']
#
# need      seq1[582:583] --> ['\\(']
#           seq2[506:506] --> []
#
# aligned   seq1[583:584] --> ['V ']
#           seq2[506:507] --> ['V']
#
# need      seq1[584:586] --> ['\\)', '[']
#           seq2[507:508] --> ['[']
#
# aligned   seq1[586:587] --> ['6']
#           seq2[508:509] --> ['6']
#
# need      seq1[587:588] --> ['][']
#           seq2[509:510] --> ['][']
#
# aligned   seq1[588:589] --> ['7']
#           seq2[510:511] --> ['7']
#
# need      seq1[589:590] --> [']']
#           seq2[511:512] --> [']']
#
# aligned   seq1[590:591] --> ['.']
#           seq2[512:513] --> ['.']
#
# aligned   seq1[591:592] --> ['Moreover']
#           seq2[513:514] --> ['Moreover']
#
# aligned   seq1[592:593] --> [',']
#           seq2[514:515] --> [',']
#
# aligned   seq1[593:594] --> ['the']
#           seq2[515:516] --> ['the']
#
# aligned   seq1[594:595] --> ['PMNS']
#           seq2[516:517] --> ['PMNS']
#
# aligned   seq1[595:596] --> ['matrix']
#           seq2[517:518] --> ['matrix']
#
# need      seq1[596:597] --> ['\\(']
#           seq2[518:518] --> []
#
# aligned   seq1[597:598] --> ['U ']
#           seq2[518:519] --> ['U']
#
# need      seq1[598:599] --> ['\\)']
#           seq2[519:519] --> []
#
# aligned   seq1[599:600] --> ['is']
#           seq2[519:520] --> ['is']
#
# aligned   seq1[600:601] --> ['very']
#           seq2[520:521] --> ['very']
#
# aligned   seq1[601:602] --> ['likely']
#           seq2[521:522] --> ['likely']
#
# aligned   seq1[602:603] --> ['to']
#           seq2[522:523] --> ['to']
#
# aligned   seq1[603:604] --> ['accommodate']
#           seq2[523:524] --> ['accommodate']
#
# aligned   seq1[604:605] --> ['significant']
#           seq2[524:525] --> ['significant']
#
# aligned   seq1[605:606] --> ['CP']
#           seq2[525:526] --> ['CP']
#
# aligned   seq1[606:607] --> ['violation']
#           seq2[526:527] --> ['violation']
#
# aligned   seq1[607:608] --> ['in']
#           seq2[527:528] --> ['in']
#
# aligned   seq1[608:609] --> ['the']
#           seq2[528:529] --> ['the']
#
# aligned   seq1[609:610] --> ['lepton']
#           seq2[529:530] --> ['lepton']
#
# aligned   seq1[610:611] --> ['sector']
#           seq2[530:531] --> ['sector']
#
# aligned   seq1[611:612] --> [',']
#           seq2[531:532] --> [',']
#
# aligned   seq1[612:613] --> ['as']
#           seq2[532:533] --> ['as']
#
# aligned   seq1[613:614] --> ['indicated']
#           seq2[533:534] --> ['indicated']
#
# aligned   seq1[614:615] --> ['by']
#           seq2[534:535] --> ['by']
#
# aligned   seq1[615:616] --> ['the']
#           seq2[535:536] --> ['the']
#
# aligned   seq1[616:617] --> ['latest']
#           seq2[536:537] --> ['latest']
#
# aligned   seq1[617:618] --> ['T']
#           seq2[537:538] --> ['T']
#
# aligned   seq1[618:619] --> ['2']
#           seq2[538:539] --> ['2']
#
# aligned   seq1[619:620] --> ['K']
#           seq2[539:540] --> ['K']
#
# aligned   seq1[620:621] --> ['measurement']
#           seq2[540:541] --> ['measurement']
#
# aligned   seq1[621:622] --> ['at']
#           seq2[541:542] --> ['at']
#
# aligned   seq1[622:623] --> ['almost']
#           seq2[542:543] --> ['almost']
#
# aligned   seq1[623:624] --> ['the']
#           seq2[543:544] --> ['the']
#
# need      seq1[624:625] --> ['\\(']
#           seq2[544:544] --> []
#
# aligned   seq1[625:626] --> ['3']
#           seq2[544:545] --> ['3']
#
# aligned   seq1[626:627] --> ['\\sigma ']
#           seq2[545:546] --> ['\\sigma']
#
# need      seq1[627:628] --> ['\\)']
#           seq2[546:546] --> []
#
# aligned   seq1[628:629] --> ['confidence']
#           seq2[546:547] --> ['confidence']
#
# aligned   seq1[629:630] --> ['level']
#           seq2[547:548] --> ['level']
#
# need      seq1[630:631] --> ['[']
#           seq2[548:549] --> ['[']
#
# aligned   seq1[631:632] --> ['8']
#           seq2[549:550] --> ['8']
#
# need      seq1[632:633] --> [']']
#           seq2[550:551] --> [']']
#
# aligned   seq1[633:634] --> ['.']
#           seq2[551:552] --> ['.']
#
# aligned   seq1[634:635] --> ['Given']
#           seq2[552:553] --> ['Given']
#
# aligned   seq1[635:636] --> ['the']
#           seq2[553:554] --> ['the']
#
# aligned   seq1[636:637] --> ['unitarity']
#           seq2[554:555] --> ['unitarity']
#
# aligned   seq1[637:638] --> ['of']
#           seq2[555:556] --> ['of']
#
# need      seq1[638:639] --> ['\\(']
#           seq2[556:556] --> []
#
# aligned   seq1[639:640] --> ['U ']
#           seq2[556:557] --> ['U']
#
# need      seq1[640:641] --> ['\\)']
#           seq2[557:557] --> []
#
# aligned   seq1[641:642] --> [',']
#           seq2[557:558] --> [',']
#
# aligned   seq1[642:643] --> ['there']
#           seq2[558:559] --> ['there']
#
# aligned   seq1[643:644] --> ['are']
#           seq2[559:560] --> ['are']
#
# aligned   seq1[644:645] --> ['three']
#           seq2[560:561] --> ['three']
#
# aligned   seq1[645:646] --> ['Dirac']
#           seq2[561:562] --> ['Dirac']
#
# aligned   seq1[646:647] --> ['-']
#           seq2[562:563] --> ['-']
#
# aligned   seq1[647:648] --> ['type']
#           seq2[563:564] --> ['type']
#
# aligned   seq1[648:649] --> ['unitarity']
#           seq2[564:565] --> ['unitarity']
#
# aligned   seq1[649:650] --> ['triangles']
#           seq2[565:566] --> ['triangles']
#
# aligned   seq1[650:651] --> ['defined']
#           seq2[566:567] --> ['defined']
#
# aligned   seq1[651:652] --> ['by']
#           seq2[567:568] --> ['by']
#
# aligned   seq1[652:653] --> ['the']
#           seq2[568:569] --> ['the']
#
# aligned   seq1[653:654] --> ['orthogonality']
#           seq2[569:570] --> ['orthogonality']
#
# aligned   seq1[654:655] --> ['conditions']
#           seq2[570:571] --> ['conditions']
#
# need      seq1[655:656] --> ['[']
#           seq2[571:572] --> ['[']
#
# aligned   seq1[656:657] --> ['9']
#           seq2[572:573] --> ['9']
#
# need      seq1[657:661] --> [']\n\n', '\\textonesuperior\n\n', '\n\\[\n', ' U_{\\alpha 1}U^{*}_{\\beta 1}+U_{\\alpha 2}U^{*}_{\\beta 2}+U_{ \\alpha 3}U^{*}_{\\beta 3}=0\\;\n']
#           seq2[573:577] --> [']', '1', 'U\\alpha1U*\\beta1+U\\alpha2U*\\beta2+U\\alpha3U*\\beta3= 0', '(1)']
#
# delete    seq1[661:662] --> ['\\]\n']
#           seq2[577:577] --> []

# %%
sequence1_text = []
for c, text, _type in sequence1:

    text = text.strip()
    if _type == '<inline_math>':
        text = regex.sub(fontpattern, lambda m:m[1][1:-1],text)
    sequence1_text.append(text) 
sequence2_text = [t[1].strip() for t in sequence2]

true_match = []
for tag, i1,i2,j1,j2 in pair:
    if tag == 'need':

        seq1 = sequence1_text[i1:i2]
        seq2 = sequence2_text[j1:j2]
        if len(seq2) == 0 and len(seq1)>0 and all([t[-1]== '<inline_math>' for t in sequence1[i1:i2]]):
            true_match.append([tag,i1,i2,j1,j2])
            continue
        if len(seq1) == 0 and len(seq2)>0:
            true_match.append([tag,i1,i2,j1,j2])
            continue
        if len(seq1) == 0 and len(seq2) == 0:
            continue

        for tag, i1_now, i2_now, j1_now, j2_now in get_real_match(seq1, seq2):
            true_match.append([tag,i1+i1_now, i1+i2_now,j1+j1_now, j1+j2_now])
    else:
        true_match.append([tag,i1, i2,j1, j2])

# %%
seq1 = sequence1_text[531:532]
seq2 = sequence2_text[463:464]

# %%
seq1, seq2
# Out:
# (['}|'], ['|'])

# %%
true_match = reorder_pair_match(true_match,sequence1,sequence2)

# %%
for tag, i1, i2, j1, j2 in true_match:
    print('{:7}   seq1[{}:{}] --> {}'.format(tag, i1, i2, sequence1[i1:i2]))
    print('          seq2[{}:{}] --> {}\n'.format(j1, j2, sequence2[j1:j2]))
# Out:
# aligned   seq1[0:1] --> [((230, 130, 120), 'Radiative', '<text>')]
#           seq2[0:1] --> [((230, 130, 120), 'Radiative', (51.196998596191406, 47.62334442138672, 118.59546661376953, 61.983890533447266))]
#
# aligned   seq1[1:2] --> [((230, 130, 125), 'decays', '<text>')]
#           seq2[1:2] --> [((230, 130, 125), 'decays', (118.59546661376953, 47.62334442138672, 169.75399780273438, 61.983890533447266))]
#
# aligned   seq1[2:3] --> [((230, 130, 130), 'of', '<text>')]
#           seq2[2:3] --> [((230, 130, 130), 'of', (169.75399780273438, 47.62334442138672, 188.1458282470703, 61.983890533447266))]
#
# aligned   seq1[3:4] --> [((230, 130, 135), 'charged', '<text>')]
#           seq2[3:4] --> [((230, 130, 135), 'charged', (188.1458282470703, 47.62334442138672, 248.06988525390625, 61.983890533447266))]
#
# aligned   seq1[4:5] --> [((230, 130, 140), 'leptons', '<text>')]
#           seq2[4:5] --> [((230, 130, 140), 'leptons', (248.06988525390625, 47.62334442138672, 303.94830322265625, 61.983890533447266))]
#
# aligned   seq1[5:6] --> [((230, 130, 145), 'as', '<text>')]
#           seq2[5:6] --> [((230, 130, 145), 'as', (303.94830322265625, 47.62334442138672, 323.54522705078125, 61.983890533447266))]
#
# aligned   seq1[6:7] --> [((230, 130, 150), 'constraints', '<text>')]
#           seq2[6:7] --> [((230, 130, 150), 'constraints', (323.54522705078125, 47.62334442138672, 405.90673828125, 61.983890533447266))]
#
# aligned   seq1[7:8] --> [((230, 130, 155), 'of', '<text>')]
#           seq2[7:8] --> [((230, 130, 155), 'of', (405.90673828125, 47.62334442138672, 424.2985534667969, 61.983890533447266))]
#
# aligned   seq1[8:9] --> [((230, 130, 160), 'unitarity', '<text>')]
#           seq2[8:9] --> [((230, 130, 160), 'unitarity', (424.2985534667969, 47.62334442138672, 491.6826171875, 61.983890533447266))]
#
# aligned   seq1[9:10] --> [((230, 130, 165), 'polygons\n\n', '<text>')]
#           seq2[9:10] --> [((230, 130, 165), 'polygons', (491.6826171875, 47.62334442138672, 559.0523681640625, 61.983890533447266))]
#
# aligned   seq1[10:11] --> [((230, 130, 170), 'for', '<text>')]
#           seq2[10:11] --> [((230, 130, 170), 'for', (125.67599487304688, 64.23632049560547, 145.27288818359375, 78.59687042236328))]
#
# aligned   seq1[11:12] --> [((230, 130, 175), 'active', '<text>')]
#           seq2[11:12] --> [((230, 130, 175), 'active', (145.27288818359375, 64.23632049560547, 191.8980255126953, 78.59687042236328))]
#
# aligned   seq1[12:13] --> [((230, 130, 180), '-', '<text>')]
#           seq2[12:13] --> [((230, 130, 180), '-', (191.8980255126953, 64.23632049560547, 197.27784729003906, 78.59687042236328))]
#
# aligned   seq1[13:14] --> [((230, 130, 185), 'sterile', '<text>')]
#           seq2[13:14] --> [((230, 130, 185), 'sterile', (197.27784729003906, 64.23632049560547, 240.23037719726562, 78.59687042236328))]
#
# aligned   seq1[14:15] --> [((230, 130, 190), 'neutrino', '<text>')]
#           seq2[14:15] --> [((230, 130, 190), 'neutrino', (240.23037719726562, 64.23632049560547, 305.3046875, 78.59687042236328))]
#
# aligned   seq1[15:16] --> [((230, 130, 195), 'mixing', '<text>')]
#           seq2[15:16] --> [((230, 130, 195), 'mixing', (305.3046875, 64.23632049560547, 358.6868591308594, 78.59687042236328))]
#
# aligned   seq1[16:17] --> [((230, 130, 200), 'and', '<text>')]
#           seq2[16:17] --> [((230, 130, 200), 'and', (358.6868591308594, 64.23632049560547, 389.86114501953125, 78.59687042236328))]
#
# aligned   seq1[17:18] --> [((230, 130, 205), 'CP', '<text>')]
#           seq2[17:18] --> [((230, 130, 205), 'CP', (389.86114501953125, 64.23632049560547, 417.92230224609375, 78.59687042236328))]
#
# aligned   seq1[18:19] --> [((230, 130, 210), 'violation\n\n', '<text>')]
#           seq2[18:19] --> [((230, 130, 210), 'violation', (417.92230224609375, 64.23632049560547, 484.56036376953125, 78.59687042236328))]
#
# aligned   seq1[19:20] --> [((230, 130, 215), 'Zhi', '<text>')]
#           seq2[19:20] --> [((230, 130, 215), 'Zhi', (197.48399353027344, 88.20156860351562, 216.91119384765625, 100.1687240600586))]
#
# aligned   seq1[20:21] --> [((230, 130, 220), '-', '<text>')]
#           seq2[20:21] --> [((230, 130, 220), '-', (216.9231414794922, 88.20156860351562, 221.40634155273438, 100.1687240600586))]
#
# aligned   seq1[21:22] --> [((230, 130, 225), 'zhong', '<text>')]
#           seq2[21:22] --> [((230, 130, 225), 'zhong', (221.40634155273438, 88.20156860351562, 255.7775421142578, 100.1687240600586))]
#
# aligned   seq1[22:23] --> [((230, 130, 230), 'Xing', '<text>')]
#           seq2[22:23] --> [((230, 130, 230), 'Xing', (255.7775421142578, 88.20156860351562, 288.367431640625, 100.1687240600586))]
#
# equal     seq1[23:24] --> [((230, 130, 230.1), '1,2', '<text>')]
#           seq2[23:24] --> [((230, 130, 235), '1,2', (292.82000732421875, 86.85237884521484, 303.63909912109375, 94.82247924804688))]
#
# aligned   seq1[24:25] --> [((230, 130, 240), 'and', '<text>')]
#           seq2[24:25] --> [((230, 130, 240), 'and', (312.52398681640625, 88.20156860351562, 331.3773498535156, 100.1687240600586))]
#
# aligned   seq1[25:26] --> [((230, 130, 245), 'Di', '<text>')]
#           seq2[25:26] --> [((230, 130, 245), 'Di', (331.3773498535156, 88.20156860351562, 349.3213806152344, 100.1687240600586))]
#
# aligned   seq1[26:27] --> [((230, 130, 250), 'Zhang', '<text>')]
#           seq2[26:27] --> [((230, 130, 250), 'Zhang', (349.3213806152344, 88.20156860351562, 390.2440185546875, 100.1687240600586))]
#
# delete    seq1[27:30] --> [((230, 130, 250.1), '\\textonesuperior', '<text>'), ((230, 130, 250.2), '*\n\n', '<text>'), ((0, 0, 0.1), '\\textonesuperior', '<text>')]
#           seq2[27:27] --> []
#
# insert    seq1[30:30] --> []
#           seq2[27:30] --> [((230, 135, 0), '1', (394.7229919433594, 86.85237884521484, 398.9551086425781, 94.82247924804688)), ((0, 0, 0), '*', (407.8399963378906, 85.35400390625, 412.0721130371094, 95.38038635253906)), ((230, 135, 70), '1', (144.23699951171875, 102.8133773803711, 148.4691162109375, 110.78347778320312))]
#
# aligned   seq1[30:31] --> [((230, 135, 75), 'Institute', '<text>')]
#           seq2[30:31] --> [((230, 135, 75), 'Institute', (148.4691162109375, 100.609130859375, 193.58058166503906, 115.47721099853516))]
#
# aligned   seq1[31:32] --> [((230, 135, 80), 'of', '<text>')]
#           seq2[31:32] --> [((230, 135, 80), 'of', (193.58058166503906, 104.568115234375, 205.99513244628906, 115.47721099853516))]
#
# aligned   seq1[32:33] --> [((230, 135, 85), 'High', '<text>')]
#           seq2[32:33] --> [((230, 135, 85), 'High', (205.99513244628906, 104.568115234375, 232.3733367919922, 115.47721099853516))]
#
# aligned   seq1[33:34] --> [((230, 135, 90), 'Energy', '<text>')]
#           seq2[33:34] --> [((230, 135, 90), 'Energy', (232.3733367919922, 104.568115234375, 269.8351745605469, 115.47721099853516))]
#
# aligned   seq1[34:35] --> [((230, 135, 95), 'Physics', '<text>')]
#           seq2[34:35] --> [((230, 135, 95), 'Physics', (269.8351745605469, 104.568115234375, 308.9006652832031, 115.47721099853516))]
#
# aligned   seq1[35:36] --> [((230, 135, 100), 'and', '<text>')]
#           seq2[35:36] --> [((230, 135, 100), 'and', (308.9006652832031, 104.568115234375, 330.118896484375, 115.47721099853516))]
#
# aligned   seq1[36:37] --> [((230, 135, 105), 'School', '<text>')]
#           seq2[36:37] --> [((230, 135, 105), 'School', (330.118896484375, 104.568115234375, 364.6679992675781, 115.47721099853516))]
#
# aligned   seq1[37:38] --> [((230, 135, 110), 'of', '<text>')]
#           seq2[37:38] --> [((230, 135, 110), 'of', (364.6679992675781, 104.568115234375, 377.09344482421875, 115.47721099853516))]
#
# aligned   seq1[38:39] --> [((230, 135, 115), 'Physical', '<text>')]
#           seq2[38:39] --> [((230, 135, 115), 'Physical', (377.09344482421875, 104.568115234375, 420.3480224609375, 115.47721099853516))]
#
# aligned   seq1[39:40] --> [((230, 135, 120), 'Sciences', '<text>')]
#           seq2[39:40] --> [((230, 135, 120), 'Sciences', (420.3480224609375, 104.568115234375, 462.8279724121094, 115.47721099853516))]
#
# aligned   seq1[40:41] --> [((230, 135, 125), ',\n\n', '<text>')]
#           seq2[40:41] --> [((230, 135, 125), ',', (462.8279724121094, 104.568115234375, 465.84979248046875, 115.47721099853516))]
#
# aligned   seq1[41:42] --> [((230, 135, 130), 'University', '<text>')]
#           seq2[41:42] --> [((230, 135, 130), 'University', (146.96701049804688, 120.14910888671875, 195.8397979736328, 131.05821228027344))]
#
# aligned   seq1[42:43] --> [((230, 135, 135), 'of', '<text>')]
#           seq2[42:43] --> [((230, 135, 135), 'of', (195.8397979736328, 120.14910888671875, 208.2761688232422, 131.05821228027344))]
#
# aligned   seq1[43:44] --> [((230, 135, 140), 'Chinese', '<text>')]
#           seq2[43:44] --> [((230, 135, 140), 'Chinese', (208.2761688232422, 120.14910888671875, 248.9453125, 131.05821228027344))]
#
# aligned   seq1[44:45] --> [((230, 135, 145), 'Academy', '<text>')]
#           seq2[44:45] --> [((230, 135, 145), 'Academy', (248.9453125, 120.14910888671875, 296.50897216796875, 131.05821228027344))]
#
# aligned   seq1[45:46] --> [((230, 135, 150), 'of', '<text>')]
#           seq2[45:46] --> [((230, 135, 150), 'of', (296.50897216796875, 120.14910888671875, 308.9344482421875, 131.05821228027344))]
#
# aligned   seq1[46:47] --> [((230, 135, 155), 'Sciences', '<text>')]
#           seq2[46:47] --> [((230, 135, 155), 'Sciences', (308.9344482421875, 120.14910888671875, 351.4144287109375, 131.05821228027344))]
#
# aligned   seq1[47:48] --> [((230, 135, 160), ',', '<text>')]
#           seq2[47:48] --> [((230, 135, 160), ',', (351.4144287109375, 120.14910888671875, 354.4362487792969, 131.05821228027344))]
#
# aligned   seq1[48:49] --> [((230, 135, 165), 'Beijing', '<text>')]
#           seq2[48:49] --> [((230, 135, 165), 'Beijing', (354.4362487792969, 120.14910888671875, 391.5816955566406, 131.05821228027344))]
#
# aligned   seq1[49:50] --> [((230, 135, 170), '100049,', '<text>')]
#           seq2[49:50] --> [((230, 135, 170), '100049,', (391.5816955566406, 120.14910888671875, 430.9635925292969, 131.05821228027344))]
#
# aligned   seq1[50:51] --> [((230, 135, 175), 'China\n\n', '<text>')]
#           seq2[50:51] --> [((230, 135, 175), 'China', (430.9635925292969, 120.14910888671875, 463.1017761230469, 131.05821228027344))]
#
# delete    seq1[51:52] --> [((0, 0, 0.2), '\\texttwosuperior', '<text>')]
#           seq2[51:51] --> []
#
# insert    seq1[52:52] --> []
#           seq2[51:52] --> [((230, 135, 180), '2', (125.7070083618164, 135.00735473632812, 129.9391326904297, 142.97744750976562))]
#
# aligned   seq1[52:53] --> [((230, 135, 185), 'Center', '<text>')]
#           seq2[52:53] --> [((230, 135, 185), 'Center', (129.9391326904297, 132.8031005859375, 165.90777587890625, 147.6711883544922))]
#
# aligned   seq1[53:54] --> [((230, 135, 190), 'of', '<text>')]
#           seq2[53:54] --> [((230, 135, 190), 'of', (165.90777587890625, 136.7620849609375, 178.34414672851562, 147.6711883544922))]
#
# aligned   seq1[54:55] --> [((230, 135, 195), 'High', '<text>')]
#           seq2[54:55] --> [((230, 135, 195), 'High', (178.34414672851562, 136.7620849609375, 204.71144104003906, 147.6711883544922))]
#
# aligned   seq1[55:56] --> [((230, 135, 200), 'Energy', '<text>')]
#           seq2[55:56] --> [((230, 135, 200), 'Energy', (204.71144104003906, 136.7620849609375, 242.1732940673828, 147.6711883544922))]
#
# aligned   seq1[56:57] --> [((230, 135, 205), 'Physics', '<text>')]
#           seq2[56:57] --> [((230, 135, 205), 'Physics', (242.1732940673828, 136.7620849609375, 281.2496643066406, 147.6711883544922))]
#
# aligned   seq1[57:58] --> [((230, 135, 210), ',', '<text>')]
#           seq2[57:58] --> [((230, 135, 210), ',', (281.2496643066406, 136.7620849609375, 284.271484375, 147.6711883544922))]
#
# aligned   seq1[58:59] --> [((230, 135, 215), 'Peking', '<text>')]
#           seq2[58:59] --> [((230, 135, 215), 'Peking', (284.271484375, 136.7620849609375, 320.19512939453125, 147.6711883544922))]
#
# aligned   seq1[59:60] --> [((230, 135, 220), 'University', '<text>')]
#           seq2[59:60] --> [((230, 135, 220), 'University', (320.19512939453125, 136.7620849609375, 372.71148681640625, 147.6711883544922))]
#
# aligned   seq1[60:61] --> [((230, 135, 225), ',', '<text>')]
#           seq2[60:61] --> [((230, 135, 225), ',', (372.722412109375, 136.7620849609375, 375.7442321777344, 147.6711883544922))]
#
# aligned   seq1[61:62] --> [((230, 135, 230), 'Beijing', '<text>')]
#           seq2[61:62] --> [((230, 135, 230), 'Beijing', (375.7442321777344, 136.7620849609375, 412.8787536621094, 147.6711883544922))]
#
# aligned   seq1[62:63] --> [((230, 135, 235), '100871,', '<text>')]
#           seq2[62:63] --> [((230, 135, 235), '100871,', (412.8787536621094, 136.7620849609375, 452.2606506347656, 147.6711883544922))]
#
# aligned   seq1[63:64] --> [((230, 135, 240), 'China\n\n', '<text>')]
#           seq2[63:64] --> [((230, 135, 240), 'China', (452.2606506347656, 136.7620849609375, 484.4097595214844, 147.6711883544922))]
#
# delete    seq1[64:65] --> [((0, 0, 0.30000000000000004), '######', '<text>')]
#           seq2[64:64] --> []
#
# equal     seq1[65:66] --> [((0, 0, 0.4), 'Abstract\n\n', '<text>')]
#           seq2[64:65] --> [((0, 0, 0), 'Abstract', (281.0270080566406, 157.903076171875, 329.0270690917969, 168.8121795654297))]
#
# aligned   seq1[66:67] --> [((230, 135, 245), 'We', '<text>')]
#           seq2[65:66] --> [((230, 135, 245), 'We', (91.2860107421875, 172.77105712890625, 106.43875122070312, 183.68016052246094))]
#
# aligned   seq1[67:68] --> [((230, 135, 250), 'calculate', '<text>')]
#           seq2[66:67] --> [((230, 135, 250), 'calculate', (106.43875122070312, 172.77105712890625, 152.84605407714844, 183.68016052246094))]
#
# aligned   seq1[68:69] --> [((230, 140, 0), 'the', '<text>')]
#           seq2[67:68] --> [((230, 140, 0), 'the', (152.84605407714844, 172.77105712890625, 172.60243225097656, 183.68016052246094))]
#
# aligned   seq1[69:70] --> [((230, 140, 5), 'rates', '<text>')]
#           seq2[68:69] --> [((230, 140, 5), 'rates', (172.60243225097656, 172.77105712890625, 200.31153869628906, 183.68016052246094))]
#
# aligned   seq1[70:71] --> [((230, 140, 10), 'of', '<text>')]
#           seq2[69:70] --> [((230, 140, 10), 'of', (200.31153869628906, 172.77105712890625, 213.69699096679688, 183.68016052246094))]
#
# aligned   seq1[71:72] --> [((230, 140, 15), 'radiative', '<text>')]
#           seq2[70:71] --> [((230, 140, 15), 'radiative', (213.69699096679688, 172.77105712890625, 260.1588439941406, 183.68016052246094))]
#
# need      seq1[72:73] --> [((230, 140, 15.1), '\\(', '<inline_math>')]
#           seq2[71:71] --> []
#
# aligned   seq1[73:74] --> [((230, 140, 20), '\\beta', '<inline_math>')]
#           seq2[71:72] --> [((230, 140, 20), '\\beta', (260.1588439941406, 172.77105712890625, 270.9156494140625, 183.68016052246094))]
#
# need      seq1[74:75] --> [((230, 140, 20.1), '^{', '<inline_math>')]
#           seq2[72:72] --> []
#
# aligned   seq1[75:76] --> [((230, 140, 25), '-', '<inline_math>')]
#           seq2[72:73] --> [((230, 140, 25), '-', (271.4980163574219, 170.78616333007812, 278.0813293457031, 184.6063232421875))]
#
# need      seq1[76:77] --> [((230, 140, 25.1), '}', '<inline_math>')]
#           seq2[73:73] --> []
#
# aligned   seq1[77:78] --> [((230, 140, 30), '\\to', '<inline_math>')]
#           seq2[73:74] --> [((230, 140, 30), '\\textrightarrow', (278.5830078125, 172.49832153320312, 289.4920959472656, 191.4256134033203))]
#
# aligned   seq1[78:79] --> [((230, 140, 35), '\\alpha', '<inline_math>')]
#           seq2[74:75] --> [((230, 140, 35), '\\alpha', (289.49200439453125, 172.77105712890625, 296.4629211425781, 183.68016052246094))]
#
# need      seq1[79:80] --> [((230, 140, 35.1), '^{', '<inline_math>')]
#           seq2[75:75] --> []
#
# aligned   seq1[80:81] --> [((230, 140, 40), '-', '<inline_math>')]
#           seq2[75:76] --> [((230, 140, 40), '-', (296.5110168457031, 170.78616333007812, 303.0943298339844, 184.6063232421875))]
#
# need      seq1[81:82] --> [((230, 140, 40.1), '}', '<inline_math>')]
#           seq2[76:76] --> []
#
# aligned   seq1[82:83] --> [((230, 140, 45), '+', '<inline_math>')]
#           seq2[76:77] --> [((230, 140, 45), '+', (303.59503173828125, 172.77105712890625, 312.0714111328125, 183.68016052246094))]
#
# aligned   seq1[83:84] --> [((230, 140, 50), '\\gamma ', '<inline_math>')]
#           seq2[77:78] --> [((230, 140, 50), '\\gamma', (312.08001708984375, 172.77105712890625, 317.72003173828125, 183.68016052246094))]
#
# need      seq1[84:85] --> [((230, 140, 50.1), '\\)', '<inline_math>')]
#           seq2[78:78] --> []
#
# aligned   seq1[85:86] --> [((230, 140, 55), 'decays', '<text>')]
#           seq2[78:79] --> [((230, 140, 55), 'decays', (317.72003173828125, 172.77105712890625, 353.89202880859375, 183.68016052246094))]
#
# aligned   seq1[86:87] --> [((230, 140, 60), 'for', '<text>')]
#           seq2[79:80] --> [((230, 140, 60), 'for', (353.89202880859375, 172.77105712890625, 371.55389404296875, 183.68016052246094))]
#
# need      seq1[87:88] --> [((230, 140, 60.1), '\\(', '<inline_math>')]
#           seq2[80:80] --> []
#
# aligned   seq1[88:89] --> [((230, 140, 65), '(', '<inline_math>')]
#           seq2[80:81] --> [((230, 140, 65), '(', (371.55389404296875, 172.77105712890625, 380.3902587890625, 183.68016052246094))]
#
# aligned   seq1[89:90] --> [((230, 140, 70), '\\alpha', '<inline_math>')]
#           seq2[81:82] --> [((230, 140, 70), '\\alpha', (380.4010009765625, 172.77105712890625, 387.3719177246094, 183.68016052246094))]
#
# aligned   seq1[90:91] --> [((230, 140, 75), ',', '<inline_math>')]
#           seq2[82:83] --> [((230, 140, 75), ',', (387.42645263671875, 172.77105712890625, 390.4482727050781, 183.68016052246094))]
#
# aligned   seq1[91:92] --> [((230, 140, 80), '\\beta', '<inline_math>')]
#           seq2[83:84] --> [((230, 140, 80), '\\beta', (390.45916748046875, 172.77105712890625, 396.622802734375, 183.68016052246094))]
#
# aligned   seq1[92:93] --> [((230, 140, 85), ')', '<inline_math>')]
#           seq2[84:85] --> [((230, 140, 85), ')', (397.1960144042969, 172.77105712890625, 401.4287414550781, 183.68016052246094))]
#
# aligned   seq1[93:94] --> [((230, 140, 90), '=', '<inline_math>')]
#           seq2[85:86] --> [((230, 140, 90), '=', (401.4396667480469, 172.77105712890625, 409.9160461425781, 183.68016052246094))]
#
# aligned   seq1[94:95] --> [((230, 140, 95), '(', '<inline_math>')]
#           seq2[86:87] --> [((230, 140, 95), '(', (409.92694091796875, 172.77105712890625, 414.15966796875, 183.68016052246094))]
#
# aligned   seq1[95:96] --> [((230, 140, 100), 'e', '<inline_math>')]
#           seq2[87:88] --> [((230, 140, 100), 'e', (414.166015625, 172.77105712890625, 419.2387390136719, 183.68016052246094))]
#
# aligned   seq1[96:97] --> [((230, 140, 105), ',', '<inline_math>')]
#           seq2[88:89] --> [((230, 140, 105), ',', (419.2496643066406, 172.77105712890625, 422.271484375, 183.68016052246094))]
#
# aligned   seq1[97:98] --> [((230, 140, 110), '\\mu', '<inline_math>')]
#           seq2[89:90] --> [((230, 140, 110), '\\mu', (422.2823791503906, 172.77105712890625, 428.84967041015625, 183.68016052246094))]
#
# aligned   seq1[98:99] --> [((230, 140, 115), ') ', '<inline_math>')]
#           seq2[90:91] --> [((230, 140, 115), ')', (428.8490295410156, 172.77105712890625, 433.0817565917969, 183.68016052246094))]
#
# need      seq1[99:100] --> [((230, 140, 115.1), '\\)', '<inline_math>')]
#           seq2[91:91] --> []
#
# aligned   seq1[100:101] --> [((230, 140, 120), ',', '<text>')]
#           seq2[91:92] --> [((230, 140, 120), ',', (433.0817565917969, 172.77105712890625, 440.7072448730469, 183.68016052246094))]
#
# need      seq1[101:102] --> [((230, 140, 120.1), '\\(', '<inline_math>')]
#           seq2[92:92] --> []
#
# aligned   seq1[102:103] --> [((230, 140, 125), '(', '<inline_math>')]
#           seq2[92:93] --> [((230, 140, 125), '(', (440.7072448730469, 172.77105712890625, 449.79449462890625, 183.68016052246094))]
#
# aligned   seq1[103:104] --> [((230, 140, 130), 'e', '<inline_math>')]
#           seq2[93:94] --> [((230, 140, 130), 'e', (449.8000183105469, 172.77105712890625, 454.87274169921875, 183.68016052246094))]
#
# aligned   seq1[104:105] --> [((230, 140, 135), ',', '<inline_math>')]
#           seq2[94:95] --> [((230, 140, 135), ',', (454.8836669921875, 172.77105712890625, 457.9054870605469, 183.68016052246094))]
#
# aligned   seq1[105:106] --> [((230, 140, 140), '\\tau', '<inline_math>')]
#           seq2[95:96] --> [((230, 140, 140), '\\tau', (457.9163818359375, 172.77105712890625, 462.68365478515625, 183.68016052246094))]
#
# aligned   seq1[106:107] --> [((230, 140, 145), ') ', '<inline_math>')]
#           seq2[96:97] --> [((230, 140, 145), ')', (463.9140319824219, 172.77105712890625, 468.1467590332031, 183.68016052246094))]
#
# need      seq1[107:108] --> [((230, 140, 145.1), '\\)', '<inline_math>')]
#           seq2[97:97] --> []
#
# aligned   seq1[108:109] --> [((230, 140, 150), 'and', '<text>')]
#           seq2[97:98] --> [((230, 140, 150), 'and', (468.1467590332031, 172.77105712890625, 490.32501220703125, 183.68016052246094))]
#
# need      seq1[109:110] --> [((230, 140, 150.1), '\\(', '<inline_math>')]
#           seq2[98:98] --> []
#
# aligned   seq1[110:111] --> [((230, 140, 155), '(', '<inline_math>')]
#           seq2[98:99] --> [((230, 140, 155), '(', (490.32501220703125, 172.77105712890625, 499.1722717285156, 183.68016052246094))]
#
# aligned   seq1[111:112] --> [((230, 140, 160), '\\mu', '<inline_math>')]
#           seq2[99:100] --> [((230, 140, 160), '\\mu', (499.1700439453125, 172.77105712890625, 505.7373352050781, 183.68016052246094))]
#
# aligned   seq1[112:113] --> [((230, 140, 165), ',', '<inline_math>')]
#           seq2[100:101] --> [((230, 140, 165), ',', (505.74822998046875, 172.77105712890625, 508.7700500488281, 183.68016052246094))]
#
# aligned   seq1[113:114] --> [((230, 140, 170), '\\tau', '<inline_math>')]
#           seq2[101:102] --> [((230, 140, 170), '\\tau', (508.78094482421875, 172.77105712890625, 513.5482177734375, 183.68016052246094))]
#
# aligned   seq1[114:115] --> [((230, 140, 175), ') ', '<inline_math>')]
#           seq2[102:103] --> [((230, 140, 175), ')', (514.7770385742188, 172.77105712890625, 519.009765625, 183.68016052246094))]
#
# need      seq1[115:116] --> [((230, 140, 175.1), '\\)', '<inline_math>')]
#           seq2[103:103] --> []
#
# aligned   seq1[116:117] --> [((230, 140, 180), 'by', '<text>')]
#           seq2[103:104] --> [((230, 140, 180), 'by', (519.009765625, 172.77105712890625, 535.1333618164062, 183.68016052246094))]
#
# aligned   seq1[117:118] --> [((230, 140, 185), 'taking', '<text>')]
#           seq2[104:105] --> [((230, 140, 185), 'taking', (74.92202758789062, 188.35302734375, 104.9329605102539, 199.2621307373047))]
#
# aligned   seq1[118:119] --> [((230, 140, 190), 'the', '<text>')]
#           seq2[105:106] --> [((230, 140, 190), 'the', (104.9329605102539, 188.35302734375, 124.26388549804688, 199.2621307373047))]
#
# aligned   seq1[119:120] --> [((230, 140, 195), 'unitary', '<text>')]
#           seq2[106:107] --> [((230, 140, 195), 'unitary', (124.26388549804688, 188.35302734375, 162.8721466064453, 199.2621307373047))]
#
# aligned   seq1[120:121] --> [((230, 140, 200), 'gauge', '<text>')]
#           seq2[107:108] --> [((230, 140, 200), 'gauge', (162.8721466064453, 188.35302734375, 194.3297576904297, 199.2621307373047))]
#
# aligned   seq1[121:122] --> [((230, 140, 205), 'in', '<text>')]
#           seq2[108:109] --> [((230, 140, 205), 'in', (194.3297576904297, 188.35302734375, 207.60614013671875, 199.2621307373047))]
#
# aligned   seq1[122:123] --> [((230, 140, 210), 'the', '<text>')]
#           seq2[109:110] --> [((230, 140, 210), 'the', (207.60614013671875, 188.35302734375, 226.94798278808594, 199.2621307373047))]
#
# need      seq1[123:124] --> [((230, 140, 210.1), '\\(', '<inline_math>')]
#           seq2[110:110] --> []
#
# aligned   seq1[124:125] --> [((230, 140, 215), '(', '<inline_math>')]
#           seq2[110:111] --> [((230, 140, 215), '(', (226.94798278808594, 188.35302734375, 235.36981201171875, 199.2621307373047))]
#
# aligned   seq1[125:126] --> [((230, 140, 220), '3', '<inline_math>')]
#           seq2[111:112] --> [((230, 140, 220), '3', (235.38072204589844, 188.35302734375, 240.83526611328125, 199.2621307373047))]
#
# aligned   seq1[126:127] --> [((230, 140, 225), '+', '<inline_math>')]
#           seq2[112:113] --> [((230, 140, 225), '+', (240.83526611328125, 188.35302734375, 249.31163024902344, 199.2621307373047))]
#
# aligned   seq1[127:128] --> [((230, 140, 230), 'n', '<inline_math>')]
#           seq2[113:114] --> [((230, 140, 230), 'n', (249.30702209472656, 188.35302734375, 255.85247802734375, 199.2621307373047))]
#
# aligned   seq1[128:129] --> [((230, 140, 235), ') ', '<inline_math>')]
#           seq2[114:115] --> [((230, 140, 235), ')', (255.8550262451172, 188.35302734375, 260.0877685546875, 199.2621307373047))]
#
# need      seq1[129:130] --> [((230, 140, 235.1), '\\)', '<inline_math>')]
#           seq2[115:115] --> []
#
# aligned   seq1[130:131] --> [((230, 140, 240), 'active', '<text>')]
#           seq2[115:116] --> [((230, 140, 240), 'active', (260.0877685546875, 188.35302734375, 292.1604919433594, 199.2621307373047))]
#
# aligned   seq1[131:132] --> [((230, 140, 245), '-', '<text>')]
#           seq2[116:117] --> [((230, 140, 245), '-', (292.1604919433594, 188.35302734375, 295.793212890625, 199.2621307373047))]
#
# aligned   seq1[132:133] --> [((230, 140, 250), 'sterile', '<text>')]
#           seq2[117:118] --> [((230, 140, 250), 'sterile', (295.793212890625, 188.35302734375, 324.3641052246094, 199.2621307373047))]
#
# aligned   seq1[133:134] --> [((230, 145, 0), 'neutrino', '<text>')]
#           seq2[118:119] --> [((230, 145, 0), 'neutrino', (324.3641052246094, 188.35302734375, 368.589599609375, 199.2621307373047))]
#
# aligned   seq1[134:135] --> [((230, 145, 5), 'mixing', '<text>')]
#           seq2[119:120] --> [((230, 145, 5), 'mixing', (368.589599609375, 188.35302734375, 405.21142578125, 199.2621307373047))]
#
# aligned   seq1[135:136] --> [((230, 145, 10), 'scheme', '<text>')]
#           seq2[120:121] --> [((230, 145, 10), 'scheme', (405.21142578125, 188.35302734375, 443.0768737792969, 199.2621307373047))]
#
# aligned   seq1[136:137] --> [((230, 145, 15), ',', '<text>')]
#           seq2[121:122] --> [((230, 145, 15), ',', (443.0768737792969, 188.35302734375, 446.09869384765625, 199.2621307373047))]
#
# aligned   seq1[137:138] --> [((230, 145, 20), 'and', '<text>')]
#           seq2[122:123] --> [((230, 145, 20), 'and', (446.09869384765625, 188.35302734375, 468.004150390625, 199.2621307373047))]
#
# aligned   seq1[138:139] --> [((230, 145, 25), 'make', '<text>')]
#           seq2[123:124] --> [((230, 145, 25), 'make', (468.004150390625, 188.35302734375, 497.044189453125, 199.2621307373047))]
#
# aligned   seq1[139:140] --> [((230, 145, 30), 'it', '<text>')]
#           seq2[124:125] --> [((230, 145, 30), 'it', (497.044189453125, 188.35302734375, 508.4878234863281, 199.2621307373047))]
#
# aligned   seq1[140:141] --> [((230, 145, 35), 'clear', '<text>')]
#           seq2[125:126] --> [((230, 145, 35), 'clear', (508.4878234863281, 188.35302734375, 535.1278076171875, 199.2621307373047))]
#
# aligned   seq1[141:142] --> [((230, 145, 40), 'that', '<text>')]
#           seq2[126:127] --> [((230, 145, 40), 'that', (74.92301940917969, 203.93402099609375, 94.91940307617188, 214.84312438964844))]
#
# aligned   seq1[142:143] --> [((230, 145, 45), 'constraints', '<text>')]
#           seq2[127:128] --> [((230, 145, 45), 'constraints', (94.91940307617188, 203.93402099609375, 150.5667266845703, 214.84312438964844))]
#
# aligned   seq1[143:144] --> [((230, 145, 50), 'on', '<text>')]
#           seq2[128:129] --> [((230, 145, 50), 'on', (150.5667266845703, 203.93402099609375, 165.74127197265625, 214.84312438964844))]
#
# aligned   seq1[144:145] --> [((230, 145, 55), 'the', '<text>')]
#           seq2[129:130] --> [((230, 145, 55), 'the', (165.74127197265625, 203.93402099609375, 184.55946350097656, 214.84312438964844))]
#
# aligned   seq1[145:146] --> [((230, 145, 60), 'unitarity', '<text>')]
#           seq2[130:131] --> [((230, 145, 60), 'unitarity', (184.55946350097656, 203.93402099609375, 230.0831298828125, 214.84312438964844))]
#
# aligned   seq1[146:147] --> [((230, 145, 65), 'of', '<text>')]
#           seq2[131:132] --> [((230, 145, 65), 'of', (230.0831298828125, 203.93402099609375, 242.5413055419922, 214.84312438964844))]
#
# aligned   seq1[147:148] --> [((230, 145, 70), 'the', '<text>')]
#           seq2[132:133] --> [((230, 145, 70), 'the', (242.5413055419922, 203.93402099609375, 261.3703918457031, 214.84312438964844))]
#
# need      seq1[148:149] --> [((230, 145, 70.1), '\\(', '<inline_math>')]
#           seq2[133:133] --> []
#
# aligned   seq1[149:150] --> [((230, 145, 75), '3', '<inline_math>')]
#           seq2[133:134] --> [((230, 145, 75), '3', (261.3703918457031, 203.93402099609375, 270.49041748046875, 214.84312438964844))]
#
# aligned   seq1[150:151] --> [((230, 145, 80), '\\times ', '<inline_math>')]
#           seq2[134:135] --> [((230, 145, 80), '\\times', (270.44500732421875, 203.66128540039062, 278.92138671875, 222.5885772705078))]
#
# aligned   seq1[151:152] --> [((230, 145, 85), '3 ', '<inline_math>')]
#           seq2[135:136] --> [((230, 145, 85), '3', (278.92999267578125, 203.93402099609375, 284.3845520019531, 214.84312438964844))]
#
# need      seq1[152:153] --> [((230, 145, 85.1), '\\)', '<inline_math>')]
#           seq2[136:136] --> []
#
# aligned   seq1[153:154] --> [((230, 145, 90), 'Pontecorvo', '<text>')]
#           seq2[136:137] --> [((230, 145, 90), 'Pontecorvo', (284.3845520019531, 203.93402099609375, 340.9591979980469, 214.84312438964844))]
#
# aligned   seq1[154:155] --> [((230, 145, 95), '-', '<text>')]
#           seq2[137:138] --> [((230, 145, 95), '-', (340.9591979980469, 203.93402099609375, 344.5919189453125, 214.84312438964844))]
#
# aligned   seq1[155:156] --> [((230, 145, 100), 'Maki', '<text>')]
#           seq2[138:139] --> [((230, 145, 100), 'Maki', (344.5919189453125, 203.93402099609375, 368.8319396972656, 214.84312438964844))]
#
# aligned   seq1[156:157] --> [((230, 145, 105), '-', '<text>')]
#           seq2[139:140] --> [((230, 145, 105), '-', (368.84283447265625, 203.93402099609375, 372.4755554199219, 214.84312438964844))]
#
# aligned   seq1[157:158] --> [((230, 145, 110), 'Nakagawa', '<text>')]
#           seq2[140:141] --> [((230, 145, 110), 'Nakagawa', (372.4755554199219, 203.93402099609375, 420.35565185546875, 214.84312438964844))]
#
# aligned   seq1[158:159] --> [((230, 145, 115), '-', '<text>')]
#           seq2[141:142] --> [((230, 145, 115), '-', (420.35565185546875, 203.93402099609375, 423.9883728027344, 214.84312438964844))]
#
# aligned   seq1[159:160] --> [((230, 145, 120), 'Sakata', '<text>')]
#           seq2[142:143] --> [((230, 145, 120), 'Sakata', (423.9883728027344, 203.93402099609375, 455.8211669921875, 214.84312438964844))]
#
# aligned   seq1[160:161] --> [((230, 145, 125), '(', '<text>')]
#           seq2[143:144] --> [((230, 145, 125), '(', (455.8211669921875, 203.93402099609375, 463.7193603515625, 214.84312438964844))]
#
# aligned   seq1[161:162] --> [((230, 145, 130), 'PMNS', '<text>')]
#           seq2[144:145] --> [((230, 145, 130), 'PMNS', (463.73028564453125, 203.93402099609375, 495.38848876953125, 214.84312438964844))]
#
# aligned   seq1[162:163] --> [((230, 145, 135), ')', '<text>')]
#           seq2[145:146] --> [((230, 145, 135), ')', (495.3994140625, 203.93402099609375, 499.63214111328125, 214.84312438964844))]
#
# aligned   seq1[163:164] --> [((230, 145, 140), 'matrix', '<text>')]
#           seq2[146:147] --> [((230, 145, 140), 'matrix', (499.63214111328125, 203.93402099609375, 535.1521606445312, 214.84312438964844))]
#
# need      seq1[164:165] --> [((230, 145, 140.1), '\\(', '<inline_math>')]
#           seq2[147:147] --> []
#
# aligned   seq1[165:166] --> [((230, 145, 145), 'U ', '<inline_math>')]
#           seq2[147:148] --> [((230, 145, 145), 'U', (74.9219970703125, 219.5159912109375, 82.36199951171875, 230.4250946044922))]
#
# need      seq1[166:167] --> [((230, 145, 145.1), '\\)', '<inline_math>')]
#           seq2[148:148] --> []
#
# aligned   seq1[167:168] --> [((230, 145, 150), 'extracted', '<text>')]
#           seq2[148:149] --> [((230, 145, 150), 'extracted', (82.36199951171875, 219.5159912109375, 131.87767028808594, 230.4250946044922))]
#
# aligned   seq1[168:169] --> [((230, 145, 155), 'from', '<text>')]
#           seq2[149:150] --> [((230, 145, 155), 'from', (131.87767028808594, 219.5159912109375, 157.7976837158203, 230.4250946044922))]
#
# need      seq1[169:170] --> [((230, 145, 155.1), '\\(', '<inline_math>')]
#           seq2[150:150] --> []
#
# aligned   seq1[170:171] --> [((230, 145, 160), '\\beta', '<inline_math>')]
#           seq2[150:151] --> [((230, 145, 160), '\\beta', (157.7976837158203, 219.5159912109375, 167.71063232421875, 230.4250946044922))]
#
# need      seq1[171:172] --> [((230, 145, 160.1), '^{', '<inline_math>')]
#           seq2[151:151] --> []
#
# aligned   seq1[172:173] --> [((230, 145, 165), '-', '<inline_math>')]
#           seq2[151:152] --> [((230, 145, 165), '-', (168.29299926757812, 217.53012084960938, 174.8762969970703, 231.35028076171875))]
#
# need      seq1[173:174] --> [((230, 145, 165.1), '}', '<inline_math>')]
#           seq2[152:152] --> []
#
# aligned   seq1[174:175] --> [((230, 145, 170), '\\to ', '<inline_math>')]
#           seq2[152:153] --> [((230, 145, 170), '\\textrightarrow', (175.3780059814453, 219.24325561523438, 186.287109375, 238.17054748535156))]
#
# aligned   seq1[175:176] --> [((230, 145, 175), '\\alpha', '<inline_math>')]
#           seq2[153:154] --> [((230, 145, 175), '\\alpha', (186.28700256347656, 219.5159912109375, 193.25791931152344, 230.4250946044922))]
#
# need      seq1[176:177] --> [((230, 145, 175.1), '^{', '<inline_math>')]
#           seq2[154:154] --> []
#
# aligned   seq1[177:178] --> [((230, 145, 180), '-', '<inline_math>')]
#           seq2[154:155] --> [((230, 145, 180), '-', (193.30599975585938, 217.53012084960938, 199.88929748535156, 231.35028076171875))]
#
# need      seq1[178:179] --> [((230, 145, 180.1), '}', '<inline_math>')]
#           seq2[155:155] --> []
#
# aligned   seq1[179:180] --> [((230, 145, 185), '+', '<inline_math>')]
#           seq2[155:156] --> [((230, 145, 185), '+', (200.39100646972656, 219.5159912109375, 208.86737060546875, 230.4250946044922))]
#
# aligned   seq1[180:181] --> [((230, 145, 190), '\\gamma ', '<inline_math>')]
#           seq2[156:157] --> [((230, 145, 190), '\\gamma', (208.87600708007812, 219.5159912109375, 214.51600646972656, 230.4250946044922))]
#
# need      seq1[181:182] --> [((230, 145, 190.1), '\\)', '<inline_math>')]
#           seq2[157:157] --> []
#
# aligned   seq1[182:183] --> [((230, 145, 195), 'decays', '<text>')]
#           seq2[157:158] --> [((230, 145, 195), 'decays', (214.51600646972656, 219.5159912109375, 249.84304809570312, 230.4250946044922))]
#
# aligned   seq1[183:184] --> [((230, 145, 200), 'in', '<text>')]
#           seq2[158:159] --> [((230, 145, 200), 'in', (249.84304809570312, 219.5159912109375, 262.68304443359375, 230.4250946044922))]
#
# aligned   seq1[184:185] --> [((230, 145, 205), 'the', '<text>')]
#           seq2[159:160] --> [((230, 145, 205), 'the', (262.68304443359375, 219.5159912109375, 281.59942626953125, 230.4250946044922))]
#
# aligned   seq1[185:186] --> [((230, 145, 210), 'minimal', '<text>')]
#           seq2[160:161] --> [((230, 145, 210), 'minimal', (281.59942626953125, 219.5159912109375, 324.38677978515625, 230.4250946044922))]
#
# aligned   seq1[186:187] --> [((230, 145, 215), 'unitarity', '<text>')]
#           seq2[161:162] --> [((230, 145, 215), 'unitarity', (324.38677978515625, 219.5159912109375, 369.8013916015625, 230.4250946044922))]
#
# aligned   seq1[187:188] --> [((230, 145, 220), 'violation', '<text>')]
#           seq2[162:163] --> [((230, 145, 220), 'violation', (369.8013916015625, 219.5159912109375, 414.8123474121094, 230.4250946044922))]
#
# aligned   seq1[188:189] --> [((230, 145, 225), 'scheme', '<text>')]
#           seq2[163:164] --> [((230, 145, 225), 'scheme', (414.8123474121094, 219.5159912109375, 452.21636962890625, 230.4250946044922))]
#
# aligned   seq1[189:190] --> [((230, 145, 230), 'differ', '<text>')]
#           seq2[164:165] --> [((230, 145, 230), 'differ', (452.21636962890625, 219.5159912109375, 480.536376953125, 230.4250946044922))]
#
# aligned   seq1[190:191] --> [((230, 145, 235), 'from', '<text>')]
#           seq2[165:166] --> [((230, 145, 235), 'from', (480.536376953125, 219.5159912109375, 506.4563903808594, 230.4250946044922))]
#
# aligned   seq1[191:192] --> [((230, 145, 240), 'those', '<text>')]
#           seq2[166:167] --> [((230, 145, 240), 'those', (506.4563903808594, 219.5159912109375, 535.114501953125, 230.4250946044922))]
#
# aligned   seq1[192:193] --> [((230, 145, 245), 'obtained', '<text>')]
#           seq2[167:168] --> [((230, 145, 245), 'obtained', (74.9219970703125, 235.09698486328125, 116.13658142089844, 246.00608825683594))]
#
# aligned   seq1[193:194] --> [((230, 145, 250), 'in', '<text>')]
#           seq2[168:169] --> [((230, 145, 250), 'in', (116.13658142089844, 235.09698486328125, 129.0311279296875, 246.00608825683594))]
#
# aligned   seq1[194:195] --> [((230, 150, 0), 'the', '<text>')]
#           seq2[169:170] --> [((230, 150, 0), 'the', (129.0311279296875, 235.09698486328125, 147.99114990234375, 246.00608825683594))]
#
# aligned   seq1[195:196] --> [((230, 150, 5), 'canonical', '<text>')]
#           seq2[170:171] --> [((230, 150, 5), 'canonical', (147.99114990234375, 235.09698486328125, 196.02391052246094, 246.00608825683594))]
#
# aligned   seq1[196:197] --> [((230, 150, 10), 'seesaw', '<text>')]
#           seq2[171:172] --> [((230, 150, 10), 'seesaw', (196.02391052246094, 235.09698486328125, 231.15122985839844, 246.00608825683594))]
#
# aligned   seq1[197:198] --> [((230, 150, 15), 'mechanism', '<text>')]
#           seq2[172:173] --> [((230, 150, 15), 'mechanism', (231.15122985839844, 235.09698486328125, 287.4203796386719, 246.00608825683594))]
#
# aligned   seq1[198:199] --> [((230, 150, 20), 'with', '<text>')]
#           seq2[173:174] --> [((230, 150, 20), 'with', (287.4203796386719, 235.09698486328125, 312.42401123046875, 246.00608825683594))]
#
# need      seq1[199:200] --> [((230, 150, 20.1), '\\(', '<inline_math>')]
#           seq2[174:174] --> []
#
# aligned   seq1[200:201] --> [((230, 150, 25), 'n ', '<inline_math>')]
#           seq2[174:175] --> [((230, 150, 25), 'n', (312.42401123046875, 235.09698486328125, 322.77947998046875, 246.00608825683594))]
#
# need      seq1[201:202] --> [((230, 150, 25.1), '\\)', '<inline_math>')]
#           seq2[175:175] --> []
#
# aligned   seq1[202:203] --> [((230, 150, 30), 'heavy', '<text>')]
#           seq2[175:176] --> [((230, 150, 30), 'heavy', (322.77947998046875, 235.09698486328125, 354.14630126953125, 246.00608825683594))]
#
# aligned   seq1[203:204] --> [((230, 150, 35), 'Majorana', '<text>')]
#           seq2[176:177] --> [((230, 150, 35), 'Majorana', (354.14630126953125, 235.09698486328125, 404.0663757324219, 246.00608825683594))]
#
# aligned   seq1[204:205] --> [((230, 150, 40), 'neutrinos', '<text>')]
#           seq2[177:178] --> [((230, 150, 40), 'neutrinos', (404.0663757324219, 235.09698486328125, 452.2082214355469, 246.00608825683594))]
#
# aligned   seq1[205:206] --> [((230, 150, 45), 'by', '<text>')]
#           seq2[178:179] --> [((230, 150, 45), 'by', (452.2082214355469, 235.09698486328125, 467.513671875, 246.00608825683594))]
#
# aligned   seq1[206:207] --> [((230, 150, 50), 'a', '<text>')]
#           seq2[179:180] --> [((230, 150, 50), 'a', (467.513671875, 235.09698486328125, 476.7755126953125, 246.00608825683594))]
#
# aligned   seq1[207:208] --> [((230, 150, 55), 'factor', '<text>')]
#           seq2[180:181] --> [((230, 150, 55), 'factor', (476.7755126953125, 235.09698486328125, 508.17193603515625, 246.00608825683594))]
#
# need      seq1[208:209] --> [((230, 150, 55.1), '\\(', '<inline_math>')]
#           seq2[181:181] --> []
#
# aligned   seq1[209:210] --> [((230, 150, 60), '5', '<inline_math>')]
#           seq2[181:182] --> [((230, 150, 60), '5', (508.17193603515625, 235.09698486328125, 517.4337158203125, 246.00608825683594))]
#
# aligned   seq1[210:211] --> [((230, 150, 65), '/', '<inline_math>')]
#           seq2[182:183] --> [((230, 150, 65), '/', (517.39599609375, 235.09698486328125, 522.8505249023438, 246.00608825683594))]
#
# aligned   seq1[211:212] --> [((230, 150, 70), '3 ', '<inline_math>')]
#           seq2[183:184] --> [((230, 150, 70), '3', (522.8499755859375, 235.09698486328125, 528.3045043945312, 246.00608825683594))]
#
# need      seq1[212:213] --> [((230, 150, 70.1), '\\)', '<inline_math>')]
#           seq2[184:184] --> []
#
# aligned   seq1[213:214] --> [((230, 150, 75), '.', '<text>')]
#           seq2[184:185] --> [((230, 150, 75), '.', (528.3045043945312, 235.09698486328125, 535.1227416992188, 246.00608825683594))]
#
# aligned   seq1[214:215] --> [((230, 150, 80), 'In', '<text>')]
#           seq2[185:186] --> [((230, 150, 80), 'In', (74.92196655273438, 250.678955078125, 84.91470336914062, 261.5880432128906))]
#
# aligned   seq1[215:216] --> [((230, 150, 85), 'such', '<text>')]
#           seq2[186:187] --> [((230, 150, 85), 'such', (84.91470336914062, 250.678955078125, 109.92927551269531, 261.5880432128906))]
#
# aligned   seq1[216:217] --> [((230, 150, 90), 'a', '<text>')]
#           seq2[187:188] --> [((230, 150, 90), 'a', (109.92927551269531, 250.678955078125, 119.4420166015625, 261.5880432128906))]
#
# aligned   seq1[217:218] --> [((230, 150, 95), 'natural', '<text>')]
#           seq2[188:189] --> [((230, 150, 95), 'natural', (119.4420166015625, 250.678955078125, 158.06021118164062, 261.5880432128906))]
#
# aligned   seq1[218:219] --> [((230, 150, 100), 'seesaw', '<text>')]
#           seq2[189:190] --> [((230, 150, 100), 'seesaw', (158.06021118164062, 250.678955078125, 193.4384307861328, 261.5880432128906))]
#
# aligned   seq1[219:220] --> [((230, 150, 105), 'case', '<text>')]
#           seq2[190:191] --> [((230, 150, 105), 'case', (193.4384307861328, 250.678955078125, 216.92572021484375, 261.5880432128906))]
#
# aligned   seq1[220:221] --> [((230, 150, 110), 'we', '<text>')]
#           seq2[191:192] --> [((230, 150, 110), 'we', (216.92572021484375, 250.678955078125, 233.38755798339844, 261.5880432128906))]
#
# aligned   seq1[221:222] --> [((230, 150, 115), 'show', '<text>')]
#           seq2[192:193] --> [((230, 150, 115), 'show', (233.38755798339844, 250.678955078125, 260.8239440917969, 261.5880432128906))]
#
# aligned   seq1[222:223] --> [((230, 150, 120), 'that', '<text>')]
#           seq2[193:194] --> [((230, 150, 120), 'that', (260.8239440917969, 250.678955078125, 284.8567199707031, 261.5880432128906))]
#
# aligned   seq1[223:224] --> [((230, 150, 125), 'the', '<text>')]
#           seq2[194:195] --> [((230, 150, 125), 'the', (284.8567199707031, 250.678955078125, 304.0676574707031, 261.5880432128906))]
#
# aligned   seq1[224:225] --> [((230, 150, 130), 'rates', '<text>')]
#           seq2[195:196] --> [((230, 150, 130), 'rates', (304.0676574707031, 250.678955078125, 331.2313232421875, 261.5880432128906))]
#
# aligned   seq1[225:226] --> [((230, 150, 135), 'of', '<text>')]
#           seq2[196:197] --> [((230, 150, 135), 'of', (331.2313232421875, 250.678955078125, 344.0604248046875, 261.5880432128906))]
#
# need      seq1[226:227] --> [((230, 150, 135.1), '\\(', '<inline_math>')]
#           seq2[197:197] --> []
#
# aligned   seq1[227:228] --> [((230, 150, 140), '\\beta', '<inline_math>')]
#           seq2[197:198] --> [((230, 150, 140), '\\beta', (344.0604248046875, 250.678955078125, 354.2926025390625, 261.5880432128906))]
#
# need      seq1[228:229] --> [((230, 150, 140.1), '^{', '<inline_math>')]
#           seq2[198:198] --> []
#
# aligned   seq1[229:230] --> [((230, 150, 145), '-', '<inline_math>')]
#           seq2[198:199] --> [((230, 150, 145), '-', (354.8749694824219, 248.69308471679688, 361.4582824707031, 262.51324462890625))]
#
# need      seq1[230:231] --> [((230, 150, 145.1), '}', '<inline_math>')]
#           seq2[199:199] --> []
#
# aligned   seq1[231:232] --> [((230, 150, 150), '\\to', '<inline_math>')]
#           seq2[199:200] --> [((230, 150, 150), '\\textrightarrow', (361.9599609375, 250.40621948242188, 372.8690490722656, 269.3335266113281))]
#
# aligned   seq1[232:233] --> [((230, 150, 155), '\\alpha', '<inline_math>')]
#           seq2[200:201] --> [((230, 150, 155), '\\alpha', (372.86895751953125, 250.678955078125, 379.8398742675781, 261.5880432128906))]
#
# need      seq1[233:234] --> [((230, 150, 155.1), '^{', '<inline_math>')]
#           seq2[201:201] --> []
#
# aligned   seq1[234:235] --> [((230, 150, 160), '-', '<inline_math>')]
#           seq2[201:202] --> [((230, 150, 160), '-', (379.8879699707031, 248.69308471679688, 386.4712829589844, 262.51324462890625))]
#
# need      seq1[235:236] --> [((230, 150, 160.1), '}', '<inline_math>')]
#           seq2[202:202] --> []
#
# aligned   seq1[236:237] --> [((230, 150, 165), '+', '<inline_math>')]
#           seq2[202:203] --> [((230, 150, 165), '+', (386.97198486328125, 250.678955078125, 395.4483642578125, 261.5880432128906))]
#
# aligned   seq1[237:238] --> [((230, 150, 170), '\\gamma ', '<inline_math>')]
#           seq2[203:204] --> [((230, 150, 170), '\\gamma', (395.45697021484375, 250.678955078125, 401.09698486328125, 261.5880432128906))]
#
# need      seq1[238:239] --> [((230, 150, 170.1), '\\)', '<inline_math>')]
#           seq2[204:204] --> []
#
# aligned   seq1[239:240] --> [((230, 150, 175), 'can', '<text>')]
#           seq2[204:205] --> [((230, 150, 175), 'can', (401.09698486328125, 250.678955078125, 422.10870361328125, 261.5880432128906))]
#
# aligned   seq1[240:241] --> [((230, 150, 180), 'be', '<text>')]
#           seq2[205:206] --> [((230, 150, 180), 'be', (422.10870361328125, 250.678955078125, 437.3814392089844, 261.5880432128906))]
#
# aligned   seq1[241:242] --> [((230, 150, 185), 'used', '<text>')]
#           seq2[206:207] --> [((230, 150, 185), 'used', (437.3814392089844, 250.678955078125, 462.67962646484375, 261.5880432128906))]
#
# aligned   seq1[242:243] --> [((230, 150, 190), 'to', '<text>')]
#           seq2[207:208] --> [((230, 150, 190), 'to', (462.67962646484375, 250.678955078125, 476.43603515625, 261.5880432128906))]
#
# aligned   seq1[243:244] --> [((230, 150, 195), 'cleanly', '<text>')]
#           seq2[208:209] --> [((230, 150, 195), 'cleanly', (476.43603515625, 250.678955078125, 513.505126953125, 261.5880432128906))]
#
# aligned   seq1[244:245] --> [((230, 150, 200), 'and', '<text>')]
#           seq2[209:210] --> [((230, 150, 200), 'and', (513.505126953125, 250.678955078125, 535.1378173828125, 261.5880432128906))]
#
# aligned   seq1[245:246] --> [((230, 150, 205), 'strongly', '<text>')]
#           seq2[210:211] --> [((230, 150, 205), 'strongly', (74.92196655273438, 266.25994873046875, 113.49654388427734, 277.1690368652344))]
#
# aligned   seq1[246:247] --> [((230, 150, 210), 'constrain', '<text>')]
#           seq2[211:212] --> [((230, 150, 210), 'constrain', (113.49654388427734, 266.25994873046875, 161.2020263671875, 277.1690368652344))]
#
# aligned   seq1[247:248] --> [((230, 150, 215), 'the', '<text>')]
#           seq2[212:213] --> [((230, 150, 215), 'the', (161.2020263671875, 266.25994873046875, 180.32568359375, 277.1690368652344))]
#
# aligned   seq1[248:249] --> [((230, 150, 220), 'effective', '<text>')]
#           seq2[213:214] --> [((230, 150, 220), 'effective', (180.32568359375, 266.25994873046875, 222.76210021972656, 277.1690368652344))]
#
# aligned   seq1[249:250] --> [((230, 150, 225), 'apex', '<text>')]
#           seq2[214:215] --> [((230, 150, 225), 'apex', (222.76210021972656, 266.25994873046875, 249.15121459960938, 277.1690368652344))]
#
# aligned   seq1[250:251] --> [((230, 150, 230), 'of', '<text>')]
#           seq2[215:216] --> [((230, 150, 230), 'of', (249.15121459960938, 266.25994873046875, 261.91485595703125, 277.1690368652344))]
#
# aligned   seq1[251:252] --> [((230, 150, 235), 'a', '<text>')]
#           seq2[216:217] --> [((230, 150, 235), 'a', (261.91485595703125, 266.25994873046875, 271.34033203125, 277.1690368652344))]
#
# aligned   seq1[252:253] --> [((230, 150, 240), 'unitarity', '<text>')]
#           seq2[217:218] --> [((230, 150, 240), 'unitarity', (271.34033203125, 266.25994873046875, 317.1694641113281, 277.1690368652344))]
#
# aligned   seq1[253:254] --> [((230, 150, 245), 'polygon', '<text>')]
#           seq2[218:219] --> [((230, 150, 245), 'polygon', (317.1694641113281, 266.25994873046875, 358.733154296875, 277.1690368652344))]
#
# aligned   seq1[254:255] --> [((230, 150, 250), ',', '<text>')]
# ...
#           seq2[500:501] --> [((230, 180, 50), 'CKM', (264.3824768066406, 548.0333251953125, 292.6565246582031, 560.0004272460938))]
#
# aligned   seq1[577:578] --> [((230, 180, 55), ')', '<text>')]
#           seq2[501:502] --> [((230, 180, 55), ')', (292.6565246582031, 548.0333251953125, 297.1994934082031, 560.0004272460938))]
#
# aligned   seq1[578:579] --> [((230, 180, 60), 'quark', '<text>')]
#           seq2[502:503] --> [((230, 180, 60), 'quark', (297.1994934082031, 548.0333251953125, 330.7458190917969, 560.0004272460938))]
#
# aligned   seq1[579:580] --> [((230, 180, 65), 'flavor', '<text>')]
#           seq2[503:504] --> [((230, 180, 65), 'flavor', (330.7458190917969, 548.0333251953125, 363.33575439453125, 560.0004272460938))]
#
# aligned   seq1[580:581] --> [((230, 180, 70), 'mixing', '<text>')]
#           seq2[504:505] --> [((230, 180, 70), 'mixing', (363.33575439453125, 548.0333251953125, 402.40533447265625, 560.0004272460938))]
#
# aligned   seq1[581:582] --> [((230, 180, 75), 'matrix', '<text>')]
#           seq2[505:506] --> [((230, 180, 75), 'matrix', (402.40533447265625, 548.0333251953125, 440.84130859375, 560.0004272460938))]
#
# need      seq1[582:583] --> [((230, 180, 75.1), '\\(', '<inline_math>')]
#           seq2[506:506] --> []
#
# aligned   seq1[583:584] --> [((230, 180, 80), 'V ', '<inline_math>')]
#           seq2[506:507] --> [((230, 180, 80), 'V', (440.84130859375, 548.0333251953125, 451.8714599609375, 559.988525390625))]
#
# delete    seq1[584:585] --> [((230, 180, 80.1), '\\)', '<inline_math>')]
#           seq2[507:507] --> []
#
# equal     seq1[585:586] --> [((230, 180, 80.19999999999999), '[', '<text>')]
#           seq2[507:508] --> [((0, 0, 0), '[', (451.8714599609375, 548.0333251953125, 461.9988708496094, 560.0004272460938))]
#
# aligned   seq1[586:587] --> [((230, 180, 85), '6', '<text>')]
#           seq2[508:509] --> [((230, 180, 85), '6', (462.01080322265625, 548.0333251953125, 467.8569030761719, 560.0004272460938))]
#
# equal     seq1[587:588] --> [((230, 180, 85.1), '][', '<text>')]
#           seq2[509:510] --> [((0, 0, 0), '][', (467.8688659667969, 548.0333251953125, 474.36053466796875, 560.0004272460938))]
#
# aligned   seq1[588:589] --> [((230, 180, 90), '7', '<text>')]
#           seq2[510:511] --> [((230, 180, 90), '7', (474.3724670410156, 548.0333251953125, 480.21856689453125, 560.0004272460938))]
#
# equal     seq1[589:590] --> [((230, 180, 90.1), ']', '<text>')]
#           seq2[511:512] --> [((0, 0, 0), ']', (480.23052978515625, 548.0333251953125, 483.47039794921875, 560.0004272460938))]
#
# aligned   seq1[590:591] --> [((230, 180, 95), '.', '<text>')]
#           seq2[512:513] --> [((230, 180, 95), '.', (483.4823303222656, 548.0333251953125, 486.7221984863281, 560.0004272460938))]
#
# aligned   seq1[591:592] --> [((230, 180, 100), 'Moreover', '<text>')]
#           seq2[513:514] --> [((230, 180, 100), 'Moreover', (486.7221984863281, 548.0333251953125, 540.5205688476562, 560.0004272460938))]
#
# aligned   seq1[592:593] --> [((230, 180, 105), ',', '<text>')]
#           seq2[514:515] --> [((230, 180, 105), ',', (540.5325317382812, 548.0333251953125, 543.7723999023438, 560.0004272460938))]
#
# aligned   seq1[593:594] --> [((230, 180, 110), 'the', '<text>')]
#           seq2[515:516] --> [((230, 180, 110), 'the', (543.7723999023438, 548.0333251953125, 564.4190063476562, 560.0004272460938))]
#
# aligned   seq1[594:595] --> [((230, 180, 115), 'PMNS', '<text>')]
#           seq2[516:517] --> [((230, 180, 115), 'PMNS', (45.657012939453125, 564.645263671875, 79.60977935791016, 576.6124267578125))]
#
# aligned   seq1[595:596] --> [((230, 180, 120), 'matrix', '<text>')]
#           seq2[517:518] --> [((230, 180, 120), 'matrix', (79.60977935791016, 564.645263671875, 116.45570373535156, 576.6124267578125))]
#
# need      seq1[596:597] --> [((230, 180, 120.1), '\\(', '<inline_math>')]
#           seq2[518:518] --> []
#
# aligned   seq1[597:598] --> [((230, 180, 125), 'U ', '<inline_math>')]
#           seq2[518:519] --> [((230, 180, 125), 'U', (116.45570373535156, 564.645263671875, 127.1042251586914, 576.6004638671875))]
#
# need      seq1[598:599] --> [((230, 180, 125.1), '\\)', '<inline_math>')]
#           seq2[519:519] --> []
#
# aligned   seq1[599:600] --> [((230, 180, 130), 'is', '<text>')]
#           seq2[519:520] --> [((230, 180, 130), 'is', (127.1042251586914, 564.645263671875, 138.9135284423828, 576.6124267578125))]
#
# aligned   seq1[600:601] --> [((230, 180, 135), 'very', '<text>')]
#           seq2[520:521] --> [((230, 180, 135), 'very', (138.9135284423828, 564.645263671875, 163.38583374023438, 576.6124267578125))]
#
# aligned   seq1[601:602] --> [((230, 180, 140), 'likely', '<text>')]
#           seq2[521:522] --> [((230, 180, 140), 'likely', (163.38583374023438, 564.645263671875, 193.0706024169922, 576.6124267578125))]
#
# aligned   seq1[602:603] --> [((230, 180, 145), 'to', '<text>')]
#           seq2[522:523] --> [((230, 180, 145), 'to', (193.0706024169922, 564.645263671875, 206.1735076904297, 576.6124267578125))]
#
# aligned   seq1[603:604] --> [((230, 180, 150), 'accommodate', '<text>')]
#           seq2[523:524] --> [((230, 180, 150), 'accommodate', (206.1735076904297, 564.645263671875, 278.8013610839844, 576.6124267578125))]
#
# aligned   seq1[604:605] --> [((230, 180, 155), 'significant', '<text>')]
#           seq2[524:525] --> [((230, 180, 155), 'significant', (278.8013610839844, 564.645263671875, 333.2572937011719, 576.6124267578125))]
#
# aligned   seq1[605:606] --> [((230, 180, 160), 'CP', '<text>')]
#           seq2[525:526] --> [((230, 180, 160), 'CP', (333.2572937011719, 564.645263671875, 352.3856201171875, 576.6124267578125))]
#
# aligned   seq1[606:607] --> [((230, 180, 165), 'violation', '<text>')]
#           seq2[526:527] --> [((230, 180, 165), 'violation', (352.3856201171875, 564.645263671875, 399.632568359375, 576.6124267578125))]
#
# aligned   seq1[607:608] --> [((230, 180, 170), 'in', '<text>')]
#           seq2[527:528] --> [((230, 180, 170), 'in', (399.632568359375, 564.645263671875, 412.0779113769531, 576.6124267578125))]
#
# aligned   seq1[608:609] --> [((230, 180, 175), 'the', '<text>')]
#           seq2[528:529] --> [((230, 180, 175), 'the', (412.0779113769531, 564.645263671875, 431.0388488769531, 576.6124267578125))]
#
# aligned   seq1[609:610] --> [((230, 180, 180), 'lepton', '<text>')]
#           seq2[529:530] --> [((230, 180, 180), 'lepton', (431.0388488769531, 564.645263671875, 465.58935546875, 576.6124267578125))]
#
# aligned   seq1[610:611] --> [((230, 180, 185), 'sector', '<text>')]
#           seq2[530:531] --> [((230, 180, 185), 'sector', (465.58935546875, 564.645263671875, 498.2629089355469, 576.6124267578125))]
#
# aligned   seq1[611:612] --> [((230, 180, 190), ',', '<text>')]
#           seq2[531:532] --> [((230, 180, 190), ',', (498.2748718261719, 564.645263671875, 501.5147399902344, 576.6124267578125))]
#
# aligned   seq1[612:613] --> [((230, 180, 195), 'as', '<text>')]
#           seq2[532:533] --> [((230, 180, 195), 'as', (501.5147399902344, 564.645263671875, 514.9404296875, 576.6124267578125))]
#
# aligned   seq1[613:614] --> [((230, 180, 200), 'indicated', '<text>')]
#           seq2[533:534] --> [((230, 180, 200), 'indicated', (514.9404296875, 564.645263671875, 564.4468994140625, 576.6124267578125))]
#
# aligned   seq1[614:615] --> [((230, 180, 205), 'by', '<text>')]
#           seq2[534:535] --> [((230, 180, 205), 'by', (45.657012939453125, 581.25830078125, 58.00673294067383, 593.2254638671875))]
#
# aligned   seq1[615:616] --> [((230, 180, 210), 'the', '<text>')]
#           seq2[535:536] --> [((230, 180, 210), 'the', (58.00673294067383, 581.25830078125, 77.9599609375, 593.2254638671875))]
#
# aligned   seq1[616:617] --> [((230, 180, 215), 'latest', '<text>')]
#           seq2[536:537] --> [((230, 180, 215), 'latest', (77.9599609375, 581.25830078125, 109.66516876220703, 593.2254638671875))]
#
# aligned   seq1[617:618] --> [((230, 180, 220), 'T', '<text>')]
#           seq2[537:538] --> [((230, 180, 220), 'T', (109.66516876220703, 581.25830078125, 121.81165313720703, 593.2254638671875))]
#
# aligned   seq1[618:619] --> [((230, 180, 225), '2', '<text>')]
#           seq2[538:539] --> [((230, 180, 225), '2', (121.81165313720703, 581.25830078125, 127.65774536132812, 593.2254638671875))]
#
# aligned   seq1[619:620] --> [((230, 180, 230), 'K', '<text>')]
#           seq2[539:540] --> [((230, 180, 230), 'K', (127.6697006225586, 581.25830078125, 136.76760864257812, 593.2254638671875))]
#
# aligned   seq1[620:621] --> [((230, 180, 235), 'measurement', '<text>')]
#           seq2[540:541] --> [((230, 180, 235), 'measurement', (136.76760864257812, 581.25830078125, 207.805419921875, 593.2254638671875))]
#
# aligned   seq1[621:622] --> [((230, 180, 240), 'at', '<text>')]
#           seq2[541:542] --> [((230, 180, 240), 'at', (207.805419921875, 581.25830078125, 221.90060424804688, 593.2254638671875))]
#
# aligned   seq1[622:623] --> [((230, 180, 245), 'almost', '<text>')]
#           seq2[542:543] --> [((230, 180, 245), 'almost', (221.90060424804688, 581.25830078125, 259.4757995605469, 593.2254638671875))]
#
# aligned   seq1[623:624] --> [((230, 180, 250), 'the', '<text>')]
#           seq2[543:544] --> [((230, 180, 250), 'the', (259.4757995605469, 581.25830078125, 279.42901611328125, 593.2254638671875))]
#
# need      seq1[624:625] --> [((230, 180, 250.1), '\\(', '<inline_math>')]
#           seq2[544:544] --> []
#
# aligned   seq1[625:626] --> [((230, 185, 0), '3', '<inline_math>')]
#           seq2[544:545] --> [((230, 185, 0), '3', (279.42901611328125, 581.25830078125, 288.9573059082031, 593.2254638671875))]
#
# aligned   seq1[626:627] --> [((230, 185, 5), '\\sigma ', '<inline_math>')]
#           seq2[545:546] --> [((230, 185, 5), '\\sigma', (288.93701171875, 581.25830078125, 295.5841064453125, 593.2135009765625))]
#
# need      seq1[627:628] --> [((230, 185, 5.1), '\\)', '<inline_math>')]
#           seq2[546:546] --> []
#
# aligned   seq1[628:629] --> [((230, 185, 10), 'confidence', '<text>')]
#           seq2[546:547] --> [((230, 185, 10), 'confidence', (295.5841064453125, 581.25830078125, 352.3766174316406, 593.2254638671875))]
#
# aligned   seq1[629:630] --> [((230, 185, 15), 'level', '<text>')]
#           seq2[547:548] --> [((230, 185, 15), 'level', (352.3766174316406, 581.25830078125, 378.7975769042969, 593.2254638671875))]
#
# equal     seq1[630:631] --> [((230, 185, 15.1), '[', '<text>')]
#           seq2[548:549] --> [((0, 0, 0), '[', (378.7975769042969, 581.25830078125, 385.7315673828125, 593.2254638671875))]
#
# aligned   seq1[631:632] --> [((230, 185, 20), '8', '<text>')]
#           seq2[549:550] --> [((230, 185, 20), '8', (385.7434997558594, 581.25830078125, 391.589599609375, 593.2254638671875))]
#
# equal     seq1[632:633] --> [((230, 185, 20.1), ']', '<text>')]
#           seq2[550:551] --> [((0, 0, 0), ']', (391.6015625, 581.25830078125, 394.8414306640625, 593.2254638671875))]
#
# aligned   seq1[633:634] --> [((230, 185, 25), '.', '<text>')]
#           seq2[551:552] --> [((230, 185, 25), '.', (394.8533630371094, 581.25830078125, 398.0932312011719, 593.2254638671875))]
#
# aligned   seq1[634:635] --> [((230, 185, 30), 'Given', '<text>')]
#           seq2[552:553] --> [((230, 185, 30), 'Given', (398.0932312011719, 581.25830078125, 433.2175598144531, 593.2254638671875))]
#
# aligned   seq1[635:636] --> [((230, 185, 35), 'the', '<text>')]
#           seq2[553:554] --> [((230, 185, 35), 'the', (433.2175598144531, 581.25830078125, 453.1707763671875, 593.2254638671875))]
#
# aligned   seq1[636:637] --> [((230, 185, 40), 'unitarity', '<text>')]
#           seq2[554:555] --> [((230, 185, 40), 'unitarity', (453.1707763671875, 581.25830078125, 501.7327880859375, 593.2254638671875))]
#
# aligned   seq1[637:638] --> [((230, 185, 45), 'of', '<text>')]
#           seq2[555:556] --> [((230, 185, 45), 'of', (501.7327880859375, 581.25830078125, 514.859619140625, 593.2254638671875))]
#
# need      seq1[638:639] --> [((230, 185, 45.1), '\\(', '<inline_math>')]
#           seq2[556:556] --> []
#
# aligned   seq1[639:640] --> [((230, 185, 50), 'U ', '<inline_math>')]
#           seq2[556:557] --> [((230, 185, 50), 'U', (514.859619140625, 581.25830078125, 526.4761962890625, 593.2135009765625))]
#
# need      seq1[640:641] --> [((230, 185, 50.1), '\\)', '<inline_math>')]
#           seq2[557:557] --> []
#
# aligned   seq1[641:642] --> [((230, 185, 55), ',', '<text>')]
#           seq2[557:558] --> [((230, 185, 55), ',', (526.4761962890625, 581.25830078125, 534.6468505859375, 593.2254638671875))]
#
# aligned   seq1[642:643] --> [((230, 185, 60), 'there', '<text>')]
#           seq2[558:559] --> [((230, 185, 60), 'there', (534.6468505859375, 581.25830078125, 564.4033203125, 593.2254638671875))]
#
# aligned   seq1[643:644] --> [((230, 185, 65), 'are', '<text>')]
#           seq2[559:560] --> [((230, 185, 65), 'are', (45.656982421875, 597.871337890625, 61.27047348022461, 609.8384399414062))]
#
# aligned   seq1[644:645] --> [((230, 185, 70), 'three', '<text>')]
#           seq2[560:561] --> [((230, 185, 70), 'three', (61.27047348022461, 597.871337890625, 91.18238830566406, 609.8384399414062))]
#
# aligned   seq1[645:646] --> [((230, 185, 75), 'Dirac', '<text>')]
#           seq2[561:562] --> [((230, 185, 75), 'Dirac', (91.18238830566406, 597.871337890625, 122.8995361328125, 609.8384399414062))]
#
# aligned   seq1[646:647] --> [((230, 185, 80), '-', '<text>')]
#           seq2[562:563] --> [((230, 185, 80), '-', (122.89954376220703, 597.871337890625, 126.79693603515625, 609.8384399414062))]
#
# aligned   seq1[647:648] --> [((230, 185, 85), 'type', '<text>')]
#           seq2[563:564] --> [((230, 185, 85), 'type', (126.79693603515625, 597.871337890625, 149.22488403320312, 609.8384399414062))]
#
# aligned   seq1[648:649] --> [((230, 185, 90), 'unitarity', '<text>')]
#           seq2[564:565] --> [((230, 185, 90), 'unitarity', (149.22488403320312, 597.871337890625, 198.00210571289062, 609.8384399414062))]
#
# aligned   seq1[649:650] --> [((230, 185, 95), 'triangles', '<text>')]
#           seq2[565:566] --> [((230, 185, 95), 'triangles', (198.00210571289062, 597.871337890625, 245.57183837890625, 609.8384399414062))]
#
# aligned   seq1[650:651] --> [((230, 185, 100), 'defined', '<text>')]
#           seq2[566:567] --> [((230, 185, 100), 'defined', (245.57183837890625, 597.871337890625, 285.872802734375, 609.8384399414062))]
#
# aligned   seq1[651:652] --> [((230, 185, 105), 'by', '<text>')]
#           seq2[567:568] --> [((230, 185, 105), 'by', (285.872802734375, 597.871337890625, 302.13189697265625, 609.8384399414062))]
#
# aligned   seq1[652:653] --> [((230, 185, 110), 'the', '<text>')]
#           seq2[568:569] --> [((230, 185, 110), 'the', (302.13189697265625, 597.871337890625, 322.3003234863281, 609.8384399414062))]
#
# aligned   seq1[653:654] --> [((230, 185, 115), 'orthogonality', '<text>')]
#           seq2[569:570] --> [((230, 185, 115), 'orthogonality', (322.3003234863281, 597.871337890625, 394.5097961425781, 609.8384399414062))]
#
# aligned   seq1[654:655] --> [((230, 185, 120), 'conditions', '<text>')]
#           seq2[570:571] --> [((230, 185, 120), 'conditions', (394.5097961425781, 597.871337890625, 450.5318908691406, 609.8384399414062))]
#
# equal     seq1[655:656] --> [((230, 185, 120.1), '[', '<text>')]
#           seq2[571:572] --> [((0, 0, 0), '[', (450.5318908691406, 597.871337890625, 457.6691589355469, 609.8384399414062))]
#
# aligned   seq1[656:657] --> [((230, 185, 125), '9', '<text>')]
#           seq2[572:573] --> [((230, 185, 125), '9', (457.68109130859375, 597.871337890625, 463.5271911621094, 609.8384399414062))]
#
# delete    seq1[657:658] --> [((230, 185, 125.1), ']\n\n', '<text>')]
#           seq2[573:573] --> []
#
# insert    seq1[661:661] --> []
#           seq2[574:577] --> [((0, 0, 0), '1', (63.215980529785156, 613.1340942382812, 67.44810485839844, 621.104248046875)), ((230, 195, 205), 'U\\alpha1U*\\beta1+U\\alpha2U*\\beta2+U\\alpha3U*\\beta3= 0', (214.23898315429688, 636.583251953125, 222.18919372558594, 648.5384521484375)), ((0, 0, 0), '(1)', (549.4486694335938, 636.583251953125, 564.4046020507812, 648.5504150390625))]
#
# delete    seq1[661:662] --> [((230, 195, 205.2), '\\]\n', '<block_math>')]
#           seq2[577:577] --> []

# %%
sequence_mmd[true_match[-1][2]-1][2]
# Out:
# '<block_math>'

# %%
align_side = 'left'
if align_side == 'left':
    while true_match[-1][0] == 'delete' and 'math' not in sequence_mmd[true_match[-1][2]-1][2]:
        true_match.pop(-1)
else:
    while true_match[-1][0] != 'aligned' and 'math' not in sequence_mmd[true_match[-1][2]-1][2]:
        true_match.pop(-1)


############## final match align ##################
now_we_add_postion_in_mmd = mmd_sequence_start + true_match[-1][1]
pretext_and_prompts = generate_final_match_table(true_match, sequence1, sequence2, verbose_level=1)

# %%
sequence1o = [(color, text, dtype) for color, (text, dtype) in current_mmd_color_dct.items()]

color_indexes_map = {color:i for i,(color, text, dtype) in enumerate(sequence1o) if color!=(0,0,0) and is_meaningful_markdonw_color(color)}
sequence_pdf = sequence2boxed
color_index_in_pdf = [color_indexes_map[color] for color,_,_ in sequence_pdf if color !=(0,0,0) and color in color_indexes_map] ### some color may appear in caption, then pass
sequence_mmd = [(color, text, dtype) for color, text, dtype in sequence1o[max(0,min(color_index_in_pdf)-1):max(color_index_in_pdf)+1]]
sequence1=sequence_mmd
sequence2=sequence_pdf

# %%
import latex2mathml.commands as commands

# %%
pair = rough_split_by_color_pair(sequence2, sequence1)
fail_to_match = False


while len(pair)>0 and pair[-1][0] == 'need':
    pair.pop(-1)  ### this while totally remove the last sequence match ability but make more accuracte when color is applied properly
if len(pair)==0:
    fail_to_match = True

# %%
for tag, i1, i2, j1, j2 in pair:
    print('{:7}   seq1[{}:{}] --> {}'.format(tag, i1, i2, sequence1[i1:i2]))
    print('          seq2[{}:{}] --> {}\n'.format(j1, j2, sequence2[j1:j2]))
# Out:
# need      seq1[0:1] --> [((0, 0, 0.2), '1:', '<text>')]
#           seq2[0:0] --> []
#
# aligned   seq1[1:2] --> [((10, 165, 155), 'Containment', '<text>')]
#           seq2[0:1] --> [((10, 165, 155), 'Containment', (240.5019073486328, 196.99703979492188, 301.393310546875, 206.9596405029297))]
#
# aligned   seq1[2:3] --> [((10, 165, 160), 'of', '<text>')]
#           seq2[1:2] --> [((10, 165, 160), 'of', (301.393310546875, 196.99703979492188, 312.74072265625, 206.9596405029297))]
#
# aligned   seq1[3:4] --> [((10, 165, 165), 'language', '<text>')]
#           seq2[2:3] --> [((10, 165, 165), 'language', (312.74072265625, 196.99703979492188, 354.2747802734375, 206.9596405029297))]
#
# aligned   seq1[4:5] --> [((10, 165, 170), 'families', '<text>')]
#           seq2[3:4] --> [((10, 165, 170), 'families', (354.2747802734375, 196.99703979492188, 390.5784606933594, 206.9596405029297))]

# %%
order_for_sequence_1 = {}
for tag, i1, i2, j1, j2 in pair:
    if i1 not in order_for_sequence_1:
        order_for_sequence_1[i1] = [(i2, j1, j2, tag)]
    else:
        if i2 - i1 > 0:
            old_i2, old_j1, old_j2, old_tag = order_for_sequence_1[i1][-1]
            old_i1 = i1
            if (j2 - j1) ==0 or (old_j2 - old_j1) ==0 or (old_i2-old_i1)==0:
                # seem add a delete task: lets append and continue
                order_for_sequence_1[i1].append((i2, j1, j2, tag))
            else:
                print("below case since has multiple align")
                print('new:')
                print('   {:7}   seq1[{}:{}] --> {}'.format(tag, i1, i2, sequence1[i1:i2]))
                print('             seq2[{}:{}] --> {}\n'.format(j1, j2, sequence2[j1:j2])) 
                print('old:')
                print('   {:7}   seq1[{}:{}] --> {}'.format(tag, old_i1, old_i2, sequence1[old_i1:old_i2]))
                print('             seq2[{}:{}] --> {}\n'.format(old_j1, old_j2, sequence2[old_j1:old_j2])) 
        else:
            order_for_sequence_1[i1].append((i2, j1, j2, tag))

# %%
order_for_sequence_1
# Out:
# {0: [(1, 0, 0, 'need')],
#  1: [(2, 0, 1, 'aligned')],
#  2: [(3, 1, 2, 'aligned')],
#  3: [(4, 2, 3, 'aligned')],
#  4: [(5, 3, 4, 'aligned')]}

# %%
i1 = i2 = j1 = j2 = 0
new_pair = []
while i2 < len(sequence1) and j2 < len(sequence2):
    if i1 not in order_for_sequence_1:
        i2 = i1 + 1
        new_pair.append(['delete', i1, i2, j2,j2])
        j2+=1
        i1 = i2
        continue
    for i2, j1, j2, tag in order_for_sequence_1[i1]:
        new_pair.append([tag, i1, i2, j1,j2])
    i1 = i2

# %%
for tag, i1, i2, j1, j2 in new_pair:
    print('{:7}   seq1[{}:{}] --> {}'.format(tag, i1, i2, sequence1[i1:i2]))
    print('          seq2[{}:{}] --> {}\n'.format(j1, j2, sequence2[j1:j2]))
# Out:
# need      seq1[0:1] --> [((0, 0, 0.2), '1:', '<text>')]
#           seq2[0:0] --> []
#
# aligned   seq1[1:2] --> [((10, 165, 155), 'Containment', '<text>')]
#           seq2[0:1] --> [((10, 165, 155), 'Containment', (240.5019073486328, 196.99703979492188, 301.393310546875, 206.9596405029297))]
#
# aligned   seq1[2:3] --> [((10, 165, 160), 'of', '<text>')]
#           seq2[1:2] --> [((10, 165, 160), 'of', (301.393310546875, 196.99703979492188, 312.74072265625, 206.9596405029297))]
#
# aligned   seq1[3:4] --> [((10, 165, 165), 'language', '<text>')]
#           seq2[2:3] --> [((10, 165, 165), 'language', (312.74072265625, 196.99703979492188, 354.2747802734375, 206.9596405029297))]
#
# aligned   seq1[4:5] --> [((10, 165, 170), 'families', '<text>')]
#           seq2[3:4] --> [((10, 165, 170), 'families', (354.2747802734375, 196.99703979492188, 390.5784606933594, 206.9596405029297))]

# %%
pair = new_pair

# %%
sequence1_text = []
for c, text, _type in sequence1:

    text = text.strip()
    if _type == '<inline_math>':
        text = regex.sub(fontpattern, lambda m:m[1][1:-1],text)
    sequence1_text.append(text) 
sequence2_text = [t[1].strip() for t in sequence2]

true_match = []
for tag, i1,i2,j1,j2 in pair:
    if tag == 'need':
        
        seq1 = sequence1_text[i1:i2]
        seq2 = sequence2_text[j1:j2]
        if len(seq2) == 0 and len(seq1)>0 and all([t[-1]== '<inline_math>' for t in sequence1[i1:i2]]):
            true_match.append([tag,i1,i2,j1,j2])
            continue
        if len(seq1) == 0 and len(seq2)>0:
            true_match.append([tag,i1,i2,j1,j2])
            continue
        if len(seq1) == 0 and len(seq2) == 0:
            continue
            
        for tag, i1_now, i2_now, j1_now, j2_now in get_real_match(seq1, seq2):
            true_match.append([tag,i1+i1_now, i1+i2_now,j1+j1_now, j1+j2_now])
    else:
        true_match.append([tag,i1, i2,j1, j2])

# %%
for tag, i1, i2, j1, j2 in true_match:
    print('{:7}   seq1[{}:{}] --> {}'.format(tag, i1, i2, sequence1[i1:i2]))
    print('          seq2[{}:{}] --> {}\n'.format(j1, j2, sequence2[j1:j2]))
# Out:
# delete    seq1[0:1] --> [((10, 105, 155), 'then', '<text>')]
#           seq2[0:0] --> []
#
# aligned   seq1[1:2] --> [((10, 105, 160), 'there', '<text>')]
#           seq2[0:1] --> [((10, 105, 160), 'there', (68.4010009765625, 228.82205200195312, 90.01146697998047, 238.78465270996094))]
#
# aligned   seq1[2:3] --> [((10, 105, 165), 'exist', '<text>')]
#           seq2[1:2] --> [((10, 105, 165), 'exist', (90.01146697998047, 228.82205200195312, 113.52487182617188, 238.78465270996094))]
#
# aligned   seq1[3:4] --> [((10, 105, 170), 'two', '<text>')]
#           seq2[2:3] --> [((10, 105, 170), 'two', (113.52487182617188, 228.82205200195312, 132.3416748046875, 238.78465270996094))]
#
# aligned   seq1[4:5] --> [((10, 105, 175), 'distinct', '<text>')]
#           seq2[3:4] --> [((10, 105, 175), 'distinct', (132.3416748046875, 228.82205200195312, 168.49746704101562, 238.78465270996094))]
#
# aligned   seq1[5:6] --> [((10, 105, 180), 'indices', '<text>')]
#           seq2[4:5] --> [((10, 105, 180), 'indices', (168.49746704101562, 228.82205200195312, 202.07215881347656, 238.78465270996094))]
#
# need      seq1[6:7] --> [((10, 105, 180.1), '\\(', '<inline_math>')]
#           seq2[5:5] --> []
#
# aligned   seq1[7:8] --> [((10, 105, 185), 'j', '<inline_math>')]
#           seq2[5:6] --> [((10, 105, 185), 'j', (202.07215881347656, 228.82205200195312, 209.73263549804688, 238.78465270996094))]
#
# need      seq1[8:9] --> [((10, 105, 185.1), '_{', '<inline_math>')]
#           seq2[6:6] --> []
#
# aligned   seq1[9:10] --> [((10, 105, 190), '1', '<inline_math>')]
#           seq2[6:7] --> [((10, 105, 190), '1', (210.31100463867188, 232.55865478515625, 214.2790985107422, 239.53245544433594))]
#
# need      seq1[10:11] --> [((10, 105, 190.1), '}', '<inline_math>')]
#           seq2[7:7] --> []
#
# aligned   seq1[11:12] --> [((10, 105, 195), ',', '<inline_math>')]
#           seq2[7:8] --> [((10, 105, 195), ',', (214.781005859375, 228.82205200195312, 217.5406494140625, 238.78465270996094))]
#
# aligned   seq1[12:13] --> [((10, 105, 200), 'j', '<inline_math>')]
#           seq2[8:9] --> [((10, 105, 200), 'j', (217.5506134033203, 228.82205200195312, 221.64524841308594, 238.78465270996094))]
#
# need      seq1[13:14] --> [((10, 105, 200.1), '_{', '<inline_math>')]
#           seq2[9:9] --> []
#
# aligned   seq1[14:15] --> [((10, 105, 205), '2', '<inline_math>')]
#           seq2[9:10] --> [((10, 105, 205), '2', (222.22100830078125, 232.55865478515625, 226.18910217285156, 239.53245544433594))]
#
# need      seq1[15:16] --> [((10, 105, 205.1), '}', '<inline_math>')]
#           seq2[10:10] --> []
#
# aligned   seq1[16:17] --> [((10, 105, 210), '\\in', '<inline_math>')]
#           seq2[10:11] --> [((10, 105, 210), '\\in', (226.69000244140625, 228.572998046875, 233.32508850097656, 245.8581085205078))]
#
# equal     seq1[17:18] --> [((10, 105, 210.1), '[', '<inline_math>')]
#           seq2[11:12] --> [((0, 0, 0), '[', (233.33200073242188, 228.82205200195312, 236.1357879638672, 238.78465270996094))]
#
# aligned   seq1[18:19] --> [((10, 105, 215), 'd', '<inline_math>')]
#           seq2[12:13] --> [((10, 105, 215), 'd', (236.1439971923828, 228.82205200195312, 241.32455444335938, 238.78465270996094))]
#
# aligned   seq1[19:20] --> [((10, 105, 220), '+', '<inline_math>')]
#           seq2[13:14] --> [((10, 105, 220), '+', (241.32899475097656, 228.82205200195312, 249.06993103027344, 238.78465270996094))]
#
# aligned   seq1[20:21] --> [((10, 105, 225), '1', '<inline_math>')]
#           seq2[14:15] --> [((10, 105, 225), '1', (249.07989501953125, 228.82205200195312, 254.06118774414062, 238.78465270996094))]
#
# delete    seq1[21:22] --> [((10, 105, 225.1), ']', '<inline_math>')]
#           seq2[15:15] --> []
#
# aligned   seq1[23:24] --> [((10, 105, 230), 'such', '<text>')]
#           seq2[16:17] --> [((10, 105, 230), 'such', (256.86279296875, 228.82205200195312, 279.83587646484375, 238.78465270996094))]
#
# aligned   seq1[24:25] --> [((10, 105, 235), 'that', '<text>')]
#           seq2[17:18] --> [((10, 105, 235), 'that', (279.83587646484375, 228.82205200195312, 300.4645080566406, 238.78465270996094))]
#
# aligned   seq1[25:26] --> [((10, 105, 240), ',', '<text>')]
#           seq2[18:19] --> [((10, 105, 240), ',', (300.4645080566406, 228.82205200195312, 303.56182861328125, 238.78465270996094))]
#
# aligned   seq1[26:27] --> [((10, 105, 245), 'for', '<text>')]
#           seq2[19:20] --> [((10, 105, 245), 'for', (303.56182861328125, 228.82205200195312, 319.6760559082031, 238.78465270996094))]
#
# aligned   seq1[27:28] --> [((10, 105, 250), 'any', '<text>')]
#           seq2[20:21] --> [((10, 105, 250), 'any', (319.6760559082031, 228.82205200195312, 339.00909423828125, 238.78465270996094))]
#
# aligned   seq1[28:29] --> [((10, 110, 0), 'three', '<text>')]
#           seq2[21:22] --> [((10, 110, 0), 'three', (339.00909423828125, 228.82205200195312, 363.6763916015625, 238.78465270996094))]
#
# aligned   seq1[29:30] --> [((10, 110, 5), 'nonempty', '<text>')]
#           seq2[22:23] --> [((10, 110, 5), 'nonempty', (363.6763916015625, 228.82205200195312, 410.166748046875, 238.78465270996094))]
#
# aligned   seq1[30:31] --> [((10, 110, 10), 'strings', '<text>')]
#           seq2[23:24] --> [((10, 110, 10), 'strings', (410.166748046875, 228.82205200195312, 443.0936279296875, 238.78465270996094))]
#
# need      seq1[31:32] --> [((10, 110, 10.1), '\\(', '<inline_math>')]
#           seq2[24:24] --> []
#
# aligned   seq1[32:33] --> [((10, 110, 15), 'x', '<inline_math>')]
#           seq2[24:25] --> [((10, 110, 15), 'x', (443.0936279296875, 228.82205200195312, 452.34564208984375, 238.78465270996094))]
#
# delete    seq1[33:36] --> [((10, 110, 20), '{', '<inline_math>'), ((10, 110, 20.1), '^{\\prime}}', '<inline_math>'), ((10, 110, 20.200000000000003), '\\)', '<inline_math>')]
#           seq2[25:25] --> []
#
# insert    seq1[36:36] --> []
#           seq2[25:26] --> [((10, 110, 20), "'", (452.35101318359375, 227.2255096435547, 454.6453857421875, 239.31109619140625))]
#
# aligned   seq1[36:37] --> [((10, 110, 25), ',', '<text>')]
#           seq2[26:27] --> [((10, 110, 25), ',', (458.70599365234375, 228.82205200195312, 461.8033142089844, 238.78465270996094))]
#
# need      seq1[37:38] --> [((10, 110, 25.1), '\\(', '<inline_math>')]
#           seq2[27:27] --> []
#
# aligned   seq1[38:39] --> [((10, 110, 30), 'y ', '<inline_math>')]
#           seq2[27:28] --> [((10, 110, 30), 'y', (461.8033142089844, 228.82205200195312, 470.2536926269531, 238.78465270996094))]
#
# need      seq1[39:40] --> [((10, 110, 30.1), '\\)', '<inline_math>')]
#           seq2[28:28] --> []
#
# aligned   seq1[40:41] --> [((10, 110, 35), ',', '<text>')]
#           seq2[28:29] --> [((10, 110, 35), ',', (470.2536926269531, 228.82205200195312, 477.2723083496094, 238.78465270996094))]
#
# aligned   seq1[41:42] --> [((10, 110, 40), 'and', '<text>')]
#           seq2[29:30] --> [((10, 110, 40), 'and', (477.2723083496094, 228.82205200195312, 496.8786315917969, 238.78465270996094))]
#
# need      seq1[42:43] --> [((10, 110, 40.1), '\\(', '<inline_math>')]
#           seq2[30:30] --> []
#
# aligned   seq1[43:44] --> [((10, 110, 45), 'z ', '<inline_math>')]
#           seq2[30:31] --> [((10, 110, 45), 'z', (496.8786315917969, 228.82205200195312, 505.07159423828125, 238.78465270996094))]
#
# need      seq1[44:45] --> [((10, 110, 45.1), '\\)', '<inline_math>')]
#           seq2[31:31] --> []
#
# aligned   seq1[45:46] --> [((10, 110, 50), ',', '<text>')]
#           seq2[31:32] --> [((10, 110, 50), ',', (505.07159423828125, 228.82205200195312, 512.1683349609375, 238.78465270996094))]
#
# aligned   seq1[46:47] --> [((10, 110, 55), 'if', '<text>')]
#           seq2[32:33] --> [((10, 110, 55), 'if', (512.1683349609375, 228.82205200195312, 521.9462280273438, 238.78465270996094))]
#
# need      seq1[47:48] --> [((10, 110, 55.1), '\\(', '<inline_math>')]
#           seq2[33:33] --> []
#
# aligned   seq1[48:49] --> [((10, 110, 60), 'x', '<inline_math>')]
#           seq2[33:34] --> [((10, 110, 60), 'x', (69.16500091552734, 240.77706909179688, 74.85364532470703, 250.7396697998047))]
#
# delete    seq1[49:51] --> [((10, 110, 65), '{', '<inline_math>'), ((10, 110, 65.1), '^{\\prime}}', '<inline_math>')]
#           seq2[34:34] --> []
#
# insert    seq1[51:51] --> []
#           seq2[34:35] --> [((10, 110, 65), "'", (74.85900115966797, 239.18052673339844, 77.15338134765625, 251.26611328125))]
#
# aligned   seq1[51:52] --> [((10, 110, 70), 'y', '<inline_math>')]
#           seq2[35:36] --> [((10, 110, 70), 'y', (77.65399932861328, 240.77706909179688, 82.53567504882812, 250.7396697998047))]
#
# aligned   seq1[52:53] --> [((10, 110, 75), '=', '<inline_math>')]
#           seq2[36:37] --> [((10, 110, 75), '=', (82.89599609375, 240.77706909179688, 90.63693237304688, 250.7396697998047))]
#
# aligned   seq1[53:54] --> [((10, 110, 80), 'xy', '<inline_math>')]
#           seq2[37:38] --> [((10, 110, 80), 'xy', (90.6449966430664, 240.77706909179688, 101.22528076171875, 250.7396697998047))]
#
# need      seq1[54:55] --> [((10, 110, 80.1), '^{', '<inline_math>')]
#           seq2[38:38] --> []
#
# aligned   seq1[55:56] --> [((10, 110, 85), '(', '<inline_math>')]
#           seq2[38:39] --> [((10, 110, 85), '(', (101.58099365234375, 239.4036865234375, 104.6913070678711, 246.3774871826172))]
#
# aligned   seq1[56:57] --> [((10, 110, 90), 'j', '<inline_math>')]
#           seq2[39:40] --> [((10, 110, 90), 'j', (104.6939926147461, 239.4036865234375, 107.98562622070312, 246.3774871826172))]
#
# need      seq1[57:58] --> [((10, 110, 90.1), '_{', '<inline_math>')]
#           seq2[40:40] --> []
#
# aligned   seq1[58:59] --> [((10, 110, 95), '1', '<inline_math>')]
#           seq2[40:41] --> [((10, 110, 95), '1', (108.39398956298828, 241.89402770996094, 111.7812728881836, 246.87533569335938))]
#
# need      seq1[59:60] --> [((10, 110, 95.1), '}', '<inline_math>')]
#           seq2[41:41] --> []
#
# aligned   seq1[60:61] --> [((10, 110, 100), ')', '<inline_math>')]
#           seq2[41:42] --> [((10, 110, 100), ')', (112.28199005126953, 239.4036865234375, 115.39230346679688, 246.3774871826172))]
#
# need      seq1[61:63] --> [((10, 110, 100.1), '}', '<inline_math>'), ((10, 110, 100.19999999999999), '\\)', '<inline_math>')]
#           seq2[42:42] --> []
#
# aligned   seq1[63:64] --> [((10, 110, 105), 'and', '<text>')]
#           seq2[42:43] --> [((10, 110, 105), 'and', (119.45799255371094, 240.77706909179688, 135.23873901367188, 250.7396697998047))]
#
# need      seq1[64:65] --> [((10, 110, 105.1), '\\(', '<inline_math>')]
#           seq2[43:43] --> []
#
# aligned   seq1[65:66] --> [((10, 110, 110), 'x', '<inline_math>')]
#           seq2[43:44] --> [((10, 110, 110), 'x', (135.23873901367188, 240.77706909179688, 144.49563598632812, 250.7396697998047))]
#
# delete    seq1[66:68] --> [((10, 110, 115), '{', '<inline_math>'), ((10, 110, 115.1), '^{\\prime}}', '<inline_math>')]
#           seq2[44:44] --> []
#
# insert    seq1[68:68] --> []
#           seq2[44:45] --> [((10, 110, 115), "'", (144.50099182128906, 239.18052673339844, 146.79537963867188, 251.26611328125))]
#
# aligned   seq1[68:69] --> [((10, 110, 120), 'z', '<inline_math>')]
#           seq2[45:46] --> [((10, 110, 120), 'z', (147.29598999023438, 240.77706909179688, 151.92860412597656, 250.7396697998047))]
#
# aligned   seq1[69:70] --> [((10, 110, 125), '=', '<inline_math>')]
#           seq2[46:47] --> [((10, 110, 125), '=', (152.3679962158203, 240.77706909179688, 160.1089324951172, 250.7396697998047))]
#
# aligned   seq1[70:71] --> [((10, 110, 130), 'xy', '<inline_math>')]
#           seq2[47:48] --> [((10, 110, 130), 'xy', (160.11599731445312, 240.77706909179688, 170.69627380371094, 250.7396697998047))]
#
# need      seq1[71:72] --> [((10, 110, 130.1), '^{', '<inline_math>')]
#           seq2[48:48] --> []
#
# aligned   seq1[72:73] --> [((10, 110, 135), '(', '<inline_math>')]
#           seq2[48:49] --> [((10, 110, 135), '(', (171.052001953125, 239.4036865234375, 174.16232299804688, 246.3774871826172))]
#
# aligned   seq1[73:74] --> [((10, 110, 140), 'j', '<inline_math>')]
#           seq2[49:50] --> [((10, 110, 140), 'j', (174.16600036621094, 239.4036865234375, 177.4576416015625, 246.3774871826172))]
#
# need      seq1[74:75] --> [((10, 110, 140.1), '_{', '<inline_math>')]
#           seq2[50:50] --> []
#
# aligned   seq1[75:76] --> [((10, 110, 145), '2', '<inline_math>')]
#           seq2[50:51] --> [((10, 110, 145), '2', (177.86500549316406, 241.89402770996094, 181.25228881835938, 246.87533569335938))]
#
# need      seq1[76:77] --> [((10, 110, 145.1), '}', '<inline_math>')]
#           seq2[51:51] --> []
#
# aligned   seq1[77:78] --> [((10, 110, 150), ')', '<inline_math>')]
#           seq2[51:52] --> [((10, 110, 150), ')', (181.7530059814453, 239.4036865234375, 184.8633270263672, 246.3774871826172))]
#
# need      seq1[78:80] --> [((10, 110, 150.1), '}', '<inline_math>'), ((10, 110, 150.2), '\\)', '<inline_math>')]
#           seq2[52:52] --> []
#
# aligned   seq1[80:81] --> [((10, 110, 155), ',', '<text>')]
#           seq2[52:53] --> [((10, 110, 155), ',', (188.9290008544922, 240.77706909179688, 191.97755432128906, 250.7396697998047))]
#
# aligned   seq1[81:82] --> [((10, 110, 160), 'then', '<text>')]
#           seq2[53:54] --> [((10, 110, 160), 'then', (191.97755432128906, 240.77706909179688, 214.13438415527344, 250.7396697998047))]
#
# aligned   seq1[82:83] --> [((10, 110, 165), 'one', '<text>')]
#           seq2[54:55] --> [((10, 110, 165), 'one', (214.13438415527344, 240.77706909179688, 232.97364807128906, 250.7396697998047))]
#
# aligned   seq1[83:84] --> [((10, 110, 170), 'of', '<text>')]
#           seq2[55:56] --> [((10, 110, 170), 'of', (232.97364807128906, 240.77706909179688, 244.66973876953125, 250.7396697998047))]
#
# aligned   seq1[84:85] --> [((10, 110, 175), 'the', '<text>')]
#           seq2[56:57] --> [((10, 110, 175), 'the', (244.66973876953125, 240.77706909179688, 261.2275695800781, 250.7396697998047))]
#
# aligned   seq1[85:86] --> [((10, 110, 180), 'following', '<text>')]
#           seq2[57:58] --> [((10, 110, 180), 'following', (261.2275695800781, 240.77706909179688, 303.4988708496094, 250.7396697998047))]
#
# aligned   seq1[86:87] --> [((10, 110, 185), 'conditions', '<text>')]
#           seq2[58:59] --> [((10, 110, 185), 'conditions', (303.4988708496094, 240.77706909179688, 351.10015869140625, 250.7396697998047))]
#
# aligned   seq1[87:88] --> [((10, 110, 190), '(', '<text>')]
#           seq2[59:60] --> [((10, 110, 190), '(', (351.10015869140625, 240.77706909179688, 358.73150634765625, 250.7396697998047))]
#
# aligned   seq1[88:89] --> [((10, 110, 195), '1', '<text>')]
#           seq2[60:61] --> [((10, 110, 195), '1', (358.7414855957031, 240.77706909179688, 363.8323669433594, 250.7396697998047))]
#
# aligned   seq1[89:90] --> [((10, 110, 200), ')', '<text>')]
#           seq2[61:62] --> [((10, 110, 200), ')', (363.8323669433594, 240.77706909179688, 367.8970947265625, 250.7396697998047))]
#
# aligned   seq1[90:91] --> [((10, 110, 205), '-', '<text>')]
#           seq2[62:63] --> [((10, 110, 205), '-', (367.9070739746094, 240.77706909179688, 371.4637145996094, 250.7396697998047))]
#
# aligned   seq1[91:92] --> [((10, 110, 210), '-', '<text>')]
#           seq2[63:64] --> [((10, 110, 210), '-', (371.47369384765625, 240.77706909179688, 375.03033447265625, 250.7396697998047))]
#
# aligned   seq1[92:93] --> [((10, 110, 215), '(', '<text>')]
#           seq2[64:65] --> [((10, 110, 215), '(', (375.0403137207031, 240.77706909179688, 379.10504150390625, 250.7396697998047))]
#
# aligned   seq1[93:94] --> [((10, 110, 220), '5', '<text>')]
#           seq2[65:66] --> [((10, 110, 220), '5', (379.1150207519531, 240.77706909179688, 384.2059020996094, 250.7396697998047))]
#
# aligned   seq1[94:95] --> [((10, 110, 225), ')', '<text>')]
#           seq2[66:67] --> [((10, 110, 225), ')', (384.2059020996094, 240.77706909179688, 388.2706298828125, 250.7396697998047))]
#
# aligned   seq1[95:96] --> [((10, 110, 230), 'holds', '<text>')]
#           seq2[67:68] --> [((10, 110, 230), 'holds', (388.2706298828125, 240.77706909179688, 413.7350158691406, 250.7396697998047))]
#
# aligned   seq1[96:97] --> [((10, 110, 235), '.\n\n', '<text>')]
#           seq2[68:69] --> [((10, 110, 235), '.', (413.7449951171875, 240.77706909179688, 416.7935485839844, 250.7396697998047))]
#
# delete    seq1[97:98] --> [((0, 0, 3.700000000000002), '1.', '<text>')]
#           seq2[69:69] --> []
#
# aligned   seq1[99:100] --> [((10, 110, 240), 'Either', '<text>')]
#           seq2[70:71] --> [((10, 110, 240), 'Either', (89.08244323730469, 259.8600769042969, 121.06239318847656, 269.82269287109375))]
#
# need      seq1[100:101] --> [((10, 110, 240.1), '\\(', '<inline_math>')]
#           seq2[71:71] --> []
#
# aligned   seq1[101:102] --> [((10, 110, 245), 'x', '<inline_math>')]
#           seq2[71:72] --> [((10, 110, 245), 'x', (121.06239318847656, 259.8600769042969, 130.32363891601562, 269.82269287109375))]
#
# delete    seq1[102:104] --> [((10, 110, 250), '{', '<inline_math>'), ((10, 110, 250.1), '^{\\prime}}', '<inline_math>')]
#           seq2[72:72] --> []
#
# insert    seq1[104:104] --> []
#           seq2[72:73] --> [((10, 110, 250), "'", (130.32899475097656, 258.2635192871094, 132.62338256835938, 270.34912109375))]
#
# aligned   seq1[104:105] --> [((10, 115, 0), 'y ', '<inline_math>')]
#           seq2[73:74] --> [((10, 115, 0), 'y', (133.12399291992188, 259.8600769042969, 138.0056610107422, 269.82269287109375))]
#
# need      seq1[105:106] --> [((10, 115, 0.1), '\\)', '<inline_math>')]
#           seq2[74:74] --> []
#
# aligned   seq1[106:107] --> [((10, 115, 5), 'or', '<text>')]
#           seq2[74:75] --> [((10, 115, 5), 'or', (138.0056610107422, 259.8600769042969, 151.2151336669922, 269.82269287109375))]
#
# need      seq1[107:108] --> [((10, 115, 5.1), '\\(', '<inline_math>')]
#           seq2[75:75] --> []
#
# aligned   seq1[108:109] --> [((10, 115, 10), 'x', '<inline_math>')]
#           seq2[75:76] --> [((10, 115, 10), 'x', (151.2151336669922, 259.8600769042969, 160.4756317138672, 269.82269287109375))]
#
# delete    seq1[109:111] --> [((10, 115, 15), '{', '<inline_math>'), ((10, 115, 15.1), '^{\\prime}}', '<inline_math>')]
#           seq2[76:76] --> []
#
# insert    seq1[111:111] --> []
#           seq2[76:77] --> [((10, 115, 15), "'", (160.48098754882812, 258.2635192871094, 162.77536010742188, 270.34912109375))]
#
# aligned   seq1[111:112] --> [((10, 115, 20), 'z ', '<inline_math>')]
#           seq2[77:78] --> [((10, 115, 20), 'z', (163.27598571777344, 259.8600769042969, 167.90859985351562, 269.82269287109375))]
#
# need      seq1[112:113] --> [((10, 115, 20.1), '\\)', '<inline_math>')]
#           seq2[78:78] --> []
#
# aligned   seq1[113:114] --> [((10, 115, 25), 'has', '<text>')]
#           seq2[78:79] --> [((10, 115, 25), 'has', (167.90859985351562, 259.8600769042969, 186.1584930419922, 269.82269287109375))]
#
# aligned   seq1[114:115] --> [((10, 115, 30), 'no', '<text>')]
#           seq2[79:80] --> [((10, 115, 30), 'no', (186.1584930419922, 259.8600769042969, 200.4249267578125, 269.82269287109375))]
#
# aligned   seq1[115:116] --> [((10, 115, 35), 'nondegenerate', '<text>')]
#           seq2[80:81] --> [((10, 115, 35), 'nondegenerate', (200.4249267578125, 259.8600769042969, 265.4607849121094, 269.82269287109375))]
#
# aligned   seq1[116:117] --> [((10, 115, 40), 'iterative', '<text>')]
#           seq2[81:82] --> [((10, 115, 40), 'iterative', (265.4607849121094, 259.8600769042969, 304.2950439453125, 269.82269287109375))]
#
# aligned   seq1[117:118] --> [((10, 115, 45), 'pair', '<text>')]
#           seq2[82:83] --> [((10, 115, 45), 'pair', (304.2950439453125, 259.8600769042969, 324.7881164550781, 269.82269287109375))]
#
# aligned   seq1[118:119] --> [((10, 115, 50), 'for', '<text>')]
#           seq2[83:84] --> [((10, 115, 50), 'for', (324.7881164550781, 259.8600769042969, 340.6983947753906, 269.82269287109375))]
#
# need      seq1[119:120] --> [((10, 115, 50.1), '\\(', '<inline_math>')]
#           seq2[84:84] --> []
#
# aligned   seq1[120:121] --> [((10, 115, 55), 'L ', '<inline_math>')]
#           seq2[84:85] --> [((10, 115, 55), 'L', (340.6983947753906, 259.8600769042969, 351.049560546875, 269.82269287109375))]
#
# need      seq1[121:122] --> [((10, 115, 55.1), '\\)', '<inline_math>')]
#           seq2[85:85] --> []
#
# aligned   seq1[122:123] --> [((10, 115, 60), '.\n\n', '<text>')]
#           seq2[85:86] --> [((10, 115, 60), '.', (351.049560546875, 259.8600769042969, 357.6685485839844, 269.82269287109375))]
#
# delete    seq1[123:124] --> [((0, 0, 3.900000000000002), '2.', '<text>')]
#           seq2[86:86] --> []
#
# aligned   seq1[125:126] --> [((10, 115, 65), 'There', '<text>')]
#           seq2[87:88] --> [((10, 115, 65), 'There', (89.08243560791016, 274.6500549316406, 118.77172088623047, 284.6126708984375))]
#
# aligned   seq1[126:127] --> [((10, 115, 70), 'are', '<text>')]
#           seq2[88:89] --> [((10, 115, 70), 'are', (118.77172088623047, 274.6500549316406, 135.49334716796875, 284.6126708984375))]
#
# aligned   seq1[127:128] --> [((10, 115, 75), 'two', '<text>')]
#           seq2[89:90] --> [((10, 115, 75), 'two', (135.49334716796875, 274.6500549316406, 153.84396362304688, 284.6126708984375))]
#
# aligned   seq1[128:129] --> [((10, 115, 80), 'factorizations', '<text>')]
#           seq2[90:91] --> [((10, 115, 80), 'factorizations', (153.84396362304688, 274.6500549316406, 215.2056427001953, 284.6126708984375))]
#
# need      seq1[129:130] --> [((10, 115, 80.1), '\\(', '<inline_math>')]
#           seq2[91:91] --> []
#
# aligned   seq1[130:131] --> [((10, 115, 85), 'x', '<inline_math>')]
#           seq2[91:92] --> [((10, 115, 85), 'x', (215.2056427001953, 274.6500549316406, 224.4646453857422, 284.6126708984375))]
#
# delete    seq1[131:133] --> [((10, 115, 90), '{', '<inline_math>'), ((10, 115, 90.1), '^{\\prime}}', '<inline_math>')]
#           seq2[92:92] --> []
#
# insert    seq1[133:133] --> []
#           seq2[92:93] --> [((10, 115, 90), "'", (224.47000122070312, 273.0534973144531, 226.76437377929688, 285.13909912109375))]
#
# aligned   seq1[133:134] --> [((10, 115, 95), '=', '<inline_math>')]
#           seq2[93:94] --> [((10, 115, 95), '=', (227.26499938964844, 274.6500549316406, 235.0059356689453, 284.6126708984375))]
#
# aligned   seq1[134:135] --> [((10, 115, 100), 'x', '<inline_math>')]
#           seq2[94:95] --> [((10, 115, 100), 'x', (235.0139923095703, 274.6500549316406, 240.70263671875, 284.6126708984375))]
#
# need      seq1[135:136] --> [((10, 115, 100.1), '_{', '<inline_math>')]
#           seq2[95:95] --> []
#
# aligned   seq1[136:137] --> [((10, 115, 105), '1', '<inline_math>')]
#           seq2[95:96] --> [((10, 115, 105), '1', (240.70799255371094, 278.38665771484375, 244.67608642578125, 285.3604431152344))]
#
# need      seq1[137:138] --> [((10, 115, 105.1), '}', '<inline_math>')]
#           seq2[96:96] --> []
#
# aligned   seq1[138:139] --> [((10, 115, 110), 'x', '<inline_math>')]
#           seq2[96:97] --> [((10, 115, 110), 'x', (245.17698669433594, 274.6500549316406, 250.86563110351562, 284.6126708984375))]
#
# need      seq1[139:140] --> [((10, 115, 110.1), '_{', '<inline_math>')]
#           seq2[97:97] --> []
#
# aligned   seq1[140:141] --> [((10, 115, 115), '2', '<inline_math>')]
#           seq2[97:98] --> [((10, 115, 115), '2', (250.87098693847656, 278.38665771484375, 254.83908081054688, 285.3604431152344))]
#
# need      seq1[141:142] --> [((10, 115, 115.1), '}', '<inline_math>')]
#           seq2[98:98] --> []
#
# aligned   seq1[142:143] --> [((10, 115, 120), 'x', '<inline_math>')]
#           seq2[98:99] --> [((10, 115, 120), 'x', (255.33998107910156, 274.6500549316406, 261.02862548828125, 284.6126708984375))]
#
# need      seq1[143:144] --> [((10, 115, 120.1), '_{', '<inline_math>')]
#           seq2[99:99] --> []
#
# aligned   seq1[144:145] --> [((10, 115, 125), '3', '<inline_math>')]
#           seq2[99:100] --> [((10, 115, 125), '3', (261.0339660644531, 278.38665771484375, 265.0020446777344, 285.3604431152344))]
#
# need      seq1[145:146] --> [((10, 115, 125.1), '}', '<inline_math>')]
#           seq2[100:100] --> []
#
# aligned   seq1[146:147] --> [((10, 115, 130), 'x', '<inline_math>')]
#           seq2[100:101] --> [((10, 115, 130), 'x', (265.50396728515625, 274.6500549316406, 271.192626953125, 284.6126708984375))]
#
# need      seq1[147:148] --> [((10, 115, 130.1), '_{', '<inline_math>')]
#           seq2[101:101] --> []
#
# aligned   seq1[148:149] --> [((10, 115, 135), '4', '<inline_math>')]
#           seq2[101:102] --> [((10, 115, 135), '4', (271.1979675292969, 278.38665771484375, 275.1660461425781, 285.3604431152344))]
#
# need      seq1[149:150] --> [((10, 115, 135.1), '}', '<inline_math>')]
#           seq2[102:102] --> []
#
# aligned   seq1[150:151] --> [((10, 115, 140), 'x', '<inline_math>')]
#           seq2[102:103] --> [((10, 115, 140), 'x', (275.6669616699219, 274.6500549316406, 281.3555908203125, 284.6126708984375))]
#
# need      seq1[151:152] --> [((10, 115, 140.1), '_{', '<inline_math>')]
#           seq2[103:103] --> []
#
# aligned   seq1[152:153] --> [((10, 115, 145), '5', '<inline_math>')]
#           seq2[103:104] --> [((10, 115, 145), '5', (281.3609619140625, 278.38665771484375, 285.32904052734375, 285.3604431152344))]
#
# need      seq1[153:154] --> [((10, 115, 145.1), '}', '<inline_math>')]
#           seq2[104:104] --> []
#
# aligned   seq1[154:155] --> [((10, 115, 150), '=', '<inline_math>')]
#           seq2[104:105] --> [((10, 115, 150), '=', (285.8299560546875, 274.6500549316406, 293.5708923339844, 284.6126708984375))]
#
# delete    seq1[155:156] --> [((10, 115, 155), '\\hat{x', '<inline_math>')]
#           seq2[105:105] --> []
#
# insert    seq1[157:157] --> []
#           seq2[105:106] --> [((10, 115, 155), '\\textasciicircumx', (293.5789489746094, 274.6500549316406, 299.267578125, 284.6126708984375))]
#
# aligned   seq1[157:158] --> [((10, 115, 160), '1', '<inline_math>')]
#           seq2[106:107] --> [((10, 115, 160), '1', (299.27294921875, 278.38665771484375, 303.24102783203125, 285.3604431152344))]
#
# delete    seq1[158:161] --> [((10, 115, 160.1), '}', '<inline_math>'), ((10, 115, 165), '\\hat{ x', '<inline_math>'), ((10, 115, 165.1), '}_{', '<inline_math>')]
#           seq2[107:107] --> []
#
# insert    seq1[161:161] --> []
#           seq2[107:108] --> [((10, 115, 165), '\\textasciicircumx', (303.741943359375, 274.6500549316406, 309.43060302734375, 284.6126708984375))]
#
# aligned   seq1[161:162] --> [((10, 115, 170), '2', '<inline_math>')]
#           seq2[108:109] --> [((10, 115, 170), '2', (309.4359436035156, 278.38665771484375, 313.4040222167969, 285.3604431152344))]
#
# delete    seq1[162:165] --> [((10, 115, 170.1), '}', '<inline_math>'), ((10, 115, 175), '\\hat{x', '<inline_math>'), ((10, 115, 175.1), '}_{', '<inline_math>')]
#           seq2[109:109] --> []
#
# insert    seq1[165:165] --> []
#           seq2[109:110] --> [((10, 115, 175), '\\textasciicircumx', (313.9049377441406, 274.6500549316406, 319.59356689453125, 284.6126708984375))]
#
# aligned   seq1[165:166] --> [((10, 115, 180), '3', '<inline_math>')]
#           seq2[110:111] --> [((10, 115, 180), '3', (319.59893798828125, 278.38665771484375, 323.5670166015625, 285.3604431152344))]
#
# delete    seq1[166:169] --> [((10, 115, 180.1), '}', '<inline_math>'), ((10, 115, 185), '\\hat{ x', '<inline_math>'), ((10, 115, 185.1), '}_{', '<inline_math>')]
#           seq2[111:111] --> []
#
# insert    seq1[169:169] --> []
#           seq2[111:112] --> [((10, 115, 185), '\\textasciicircumx', (324.0689392089844, 274.6500549316406, 329.757568359375, 284.6126708984375))]
#
# aligned   seq1[169:170] --> [((10, 115, 190), '4', '<inline_math>')]
#           seq2[112:113] --> [((10, 115, 190), '4', (329.762939453125, 278.38665771484375, 333.73101806640625, 285.3604431152344))]
#
# delete    seq1[170:173] --> [((10, 115, 190.1), '}', '<inline_math>'), ((10, 115, 195), '\\hat{x', '<inline_math>'), ((10, 115, 195.1), '}_{', '<inline_math>')]
#           seq2[113:113] --> []
#
# insert    seq1[173:173] --> []
#           seq2[113:114] --> [((10, 115, 195), '\\textasciicircumx', (334.23193359375, 274.6500549316406, 339.92059326171875, 284.6126708984375))]
#
# aligned   seq1[173:174] --> [((10, 115, 200), '5', '<inline_math>')]
#           seq2[114:115] --> [((10, 115, 200), '5', (339.9259338378906, 278.38665771484375, 343.8940124511719, 285.3604431152344))]
#
# need      seq1[174:176] --> [((10, 115, 200.1), '}', '<inline_math>'), ((10, 115, 200.2), '\\)', '<inline_math>')]
#           seq2[115:115] --> []
#
# aligned   seq1[176:177] --> [((10, 115, 205), 'such', '<text>')]
#           seq2[115:116] --> [((10, 115, 205), 'such', (343.8940124511719, 274.6500549316406, 366.76983642578125, 286.107666015625))]
#
# aligned   seq1[177:178] --> [((10, 115, 210), 'that', '<text>')]
#           seq2[116:117] --> [((10, 115, 210), 'that', (366.76983642578125, 274.6500549316406, 386.8769836425781, 284.6126708984375))]
#
# need      seq1[178:179] --> [((10, 115, 210.1), '\\(', '<inline_math>')]
#           seq2[117:117] --> []
#
# aligned   seq1[179:180] --> [((10, 115, 215), '(', '<inline_math>')]
#           seq2[117:118] --> [((10, 115, 215), '(', (386.8769836425781, 274.6500549316406, 394.3084716796875, 284.6126708984375))]
#
# aligned   seq1[180:181] --> [((10, 115, 220), 'x', '<inline_math>')]
#           seq2[118:119] --> [((10, 115, 220), 'x', (394.3179931640625, 274.6500549316406, 400.00665283203125, 284.6126708984375))]
#
# need      seq1[181:182] --> [((10, 115, 220.1), '_{', '<inline_math>')]
#           seq2[119:119] --> []
#
# aligned   seq1[182:183] --> [((10, 115, 225), '2', '<inline_math>')]
#           seq2[119:120] --> [((10, 115, 225), '2', (400.0119934082031, 278.38665771484375, 403.9800720214844, 285.3604431152344))]
#
# need      seq1[183:184] --> [((10, 115, 225.1), '}', '<inline_math>')]
#           seq2[120:120] --> []
#
# aligned   seq1[184:185] --> [((10, 115, 230), ',', '<inline_math>')]
#           seq2[120:121] --> [((10, 115, 230), ',', (404.4809875488281, 274.6500549316406, 407.2406311035156, 284.6126708984375))]
#
# aligned   seq1[185:186] --> [((10, 115, 235), 'x', '<inline_math>')]
#           seq2[121:122] --> [((10, 115, 235), 'x', (407.2505798339844, 274.6500549316406, 412.939208984375, 284.6126708984375))]
#
# need      seq1[186:187] --> [((10, 115, 235.1), '_{', '<inline_math>')]
#           seq2[122:122] --> []
#
# aligned   seq1[187:188] --> [((10, 115, 240), '4', '<inline_math>')]
#           seq2[122:123] --> [((10, 115, 240), '4', (412.9419860839844, 278.38665771484375, 416.9100646972656, 285.3604431152344))]
#
# need      seq1[188:189] --> [((10, 115, 240.1), '}', '<inline_math>')]
#           seq2[123:123] --> []
#
# aligned   seq1[189:190] --> [((10, 115, 245), ') ', '<inline_math>')]
#           seq2[123:124] --> [((10, 115, 245), ')', (417.4119873046875, 274.6500549316406, 421.2774658203125, 284.6126708984375))]
#
# need      seq1[190:191] --> [((10, 115, 245.1), '\\)', '<inline_math>')]
#           seq2[124:124] --> []
#
# aligned   seq1[191:192] --> [((10, 115, 250), 'and', '<text>')]
#           seq2[124:125] --> [((10, 115, 250), 'and', (421.2774658203125, 274.6500549316406, 440.3930358886719, 284.6126708984375))]
#
# need      seq1[192:193] --> [((10, 115, 250.1), '\\(', '<inline_math>')]
#           seq2[125:125] --> []
#
# aligned   seq1[193:194] --> [((10, 120, 0), '(', '<inline_math>')]
#           seq2[125:126] --> [((10, 120, 0), '(', (440.3930358886719, 274.6500549316406, 447.8254699707031, 284.6126708984375))]
#
# delete    seq1[194:195] --> [((10, 120, 5), '\\hat{x', '<inline_math>')]
#           seq2[126:126] --> []
#
# insert    seq1[196:196] --> []
#           seq2[126:127] --> [((10, 120, 5), '\\textasciicircumx', (447.833984375, 274.6500549316406, 453.52264404296875, 284.6126708984375))]
#
# aligned   seq1[196:197] --> [((10, 120, 10), '2', '<inline_math>')]
#           seq2[127:128] --> [((10, 120, 10), '2', (453.5279846191406, 278.38665771484375, 457.4960632324219, 285.3604431152344))]
#
# need      seq1[197:198] --> [((10, 120, 10.1), '}', '<inline_math>')]
#           seq2[128:128] --> []
#
# aligned   seq1[198:199] --> [((10, 120, 15), ',', '<inline_math>')]
#           seq2[128:129] --> [((10, 120, 15), ',', (457.99798583984375, 274.6500549316406, 460.75762939453125, 284.6126708984375))]
#
# delete    seq1[199:200] --> [((10, 120, 20), '\\hat{x', '<inline_math>')]
#           seq2[129:129] --> []
#
# insert    seq1[201:201] --> []
#           seq2[129:130] --> [((10, 120, 20), '\\textasciicircumx', (460.7649841308594, 274.6500549316406, 466.45361328125, 284.6126708984375))]
#
# aligned   seq1[201:202] --> [((10, 120, 25), '4', '<inline_math>')]
#           seq2[130:131] --> [((10, 120, 25), '4', (466.458984375, 278.38665771484375, 470.42706298828125, 285.3604431152344))]
#
# need      seq1[202:203] --> [((10, 120, 25.1), '}', '<inline_math>')]
#           seq2[131:131] --> []
#
# aligned   seq1[203:204] --> [((10, 120, 30), ') ', '<inline_math>')]
#           seq2[131:132] --> [((10, 120, 30), ')', (470.927978515625, 274.6500549316406, 474.79345703125, 284.6126708984375))]
#
# need      seq1[204:205] --> [((10, 120, 30.1), '\\)', '<inline_math>')]
#           seq2[132:132] --> []
#
# aligned   seq1[205:206] --> [((10, 120, 35), 'are', '<text>')]
#           seq2[132:133] --> [((10, 120, 35), 'are', (474.79345703125, 274.6500549316406, 491.5244445800781, 284.6126708984375))]
#
# aligned   seq1[206:207] --> [((10, 120, 40), 'respectively', '<text>')]
#           seq2[133:134] --> [((10, 120, 40), 'respectively', (491.5244445800781, 274.6500549316406, 523.7705078125, 284.6126708984375))]
#
# aligned   seq1[207:208] --> [((10, 120, 45), 'nondegenerate', '<text>')]
#           seq2[134:135] --> [((10, 120, 45), 'nondegenerate', (116.22197723388672, 286.6050720214844, 181.2777557373047, 296.56768798828125))]
#
# aligned   seq1[208:209] --> [((10, 120, 50), 'iterative', '<text>')]
#           seq2[135:136] --> [((10, 120, 50), 'iterative', (181.2777557373047, 286.6050720214844, 220.10203552246094, 296.56768798828125))]
#
# aligned   seq1[209:210] --> [((10, 120, 55), 'pairs', '<text>')]
#           seq2[136:137] --> [((10, 120, 55), 'pairs', (220.10203552246094, 286.6050720214844, 244.6697998046875, 296.56768798828125))]
#
# aligned   seq1[210:211] --> [((10, 120, 60), 'of', '<text>')]
#           seq2[137:138] --> [((10, 120, 60), 'of', (244.6697998046875, 286.6050720214844, 256.3858337402344, 296.56768798828125))]
#
# need      seq1[211:212] --> [((10, 120, 60.1), '\\(', '<inline_math>')]
#           seq2[138:138] --> []
#
# aligned   seq1[212:213] --> [((10, 120, 65), 'x', '<inline_math>')]
#           seq2[138:139] --> [((10, 120, 65), 'x', (256.3858337402344, 286.6050720214844, 265.63165283203125, 296.56768798828125))]
#
# delete    seq1[213:215] --> [((10, 120, 70), '{', '<inline_math>'), ((10, 120, 70.1), '^{\\prime}}', '<inline_math>')]
#           seq2[139:139] --> []
#
# insert    seq1[215:215] --> []
#           seq2[139:140] --> [((10, 120, 70), "'", (265.6369934082031, 285.0085144042969, 267.9313659667969, 297.0941162109375))]
#
# aligned   seq1[215:216] --> [((10, 120, 75), 'y ', '<inline_math>')]
#           seq2[140:141] --> [((10, 120, 75), 'y', (268.4320068359375, 286.6050720214844, 273.3136901855469, 296.56768798828125))]
#
# need      seq1[216:217] --> [((10, 120, 75.1), '\\)', '<inline_math>')]
#           seq2[141:141] --> []
#
# aligned   seq1[217:218] --> [((10, 120, 80), 'and', '<text>')]
#           seq2[141:142] --> [((10, 120, 80), 'and', (273.3136901855469, 286.6050720214844, 293.01873779296875, 296.56768798828125))]
#
# need      seq1[218:219] --> [((10, 120, 80.1), '\\(', '<inline_math>')]
#           seq2[142:142] --> []
#
# aligned   seq1[219:220] --> [((10, 120, 85), 'x', '<inline_math>')]
#           seq2[142:143] --> [((10, 120, 85), 'x', (293.01873779296875, 286.6050720214844, 302.27667236328125, 296.56768798828125))]
#
# delete    seq1[220:222] --> [((10, 120, 90), '{', '<inline_math>'), ((10, 120, 90.1), '^{\\prime}}', '<inline_math>')]
#           seq2[143:143] --> []
#
# insert    seq1[222:222] --> []
#           seq2[143:144] --> [((10, 120, 90), "'", (302.2820129394531, 285.0085144042969, 304.5763854980469, 297.0941162109375))]
#
# aligned   seq1[222:223] --> [((10, 120, 95), 'z ', '<inline_math>')]
#           seq2[144:145] --> [((10, 120, 95), 'z', (305.0770263671875, 286.6050720214844, 309.7096252441406, 296.56768798828125))]
#
# need      seq1[223:224] --> [((10, 120, 95.1), '\\)', '<inline_math>')]
#           seq2[145:145] --> []
#
# aligned   seq1[224:225] --> [((10, 120, 100), 'for', '<text>')]
#           seq2[145:146] --> [((10, 120, 100), 'for', (309.7096252441406, 286.6050720214844, 326.0556945800781, 296.56768798828125))]
#
# need      seq1[225:226] --> [((10, 120, 100.1), '\\(', '<inline_math>')]
#           seq2[146:146] --> []
#
# aligned   seq1[226:227] --> [((10, 120, 105), 'L ', '<inline_math>')]
#           seq2[146:147] --> [((10, 120, 105), 'L', (326.0556945800781, 286.6050720214844, 336.39959716796875, 296.56768798828125))]
#
# need      seq1[227:228] --> [((10, 120, 105.1), '\\)', '<inline_math>')]
#           seq2[147:147] --> []
#
# aligned   seq1[228:229] --> [((10, 120, 110), '.\n\n', '<text>')]
#           seq2[147:148] --> [((10, 120, 110), '.', (336.39959716796875, 286.6050720214844, 343.017578125, 296.56768798828125))]
#
# delete    seq1[229:230] --> [((0, 0, 4.100000000000001), '3.', '<text>')]
#           seq2[148:148] --> []
#
# aligned   seq1[231:232] --> [((10, 120, 115), 'There', '<text>')]
#           seq2[149:150] --> [((10, 120, 115), 'There', (89.08246612548828, 301.3950500488281, 118.64635467529297, 311.357666015625))]
#
# aligned   seq1[232:233] --> [((10, 120, 120), 'are', '<text>')]
#           seq2[150:151] --> [((10, 120, 120), 'are', (118.64635467529297, 301.3950500488281, 135.1757049560547, 311.357666015625))]
#
# aligned   seq1[233:234] --> [((10, 120, 125), 'four', '<text>')]
#           seq2[151:152] --> [((10, 120, 125), 'four', (135.1757049560547, 301.3950500488281, 155.9618682861328, 311.357666015625))]
#
# aligned   seq1[234:235] --> [((10, 120, 130), 'factorizations', '<text>')]
#           seq2[152:153] --> [((10, 120, 130), 'factorizations', (155.9618682861328, 301.3950500488281, 216.9144287109375, 311.357666015625))]
#
# need      seq1[235:236] --> [((10, 120, 130.1), '\\(', '<inline_math>')]
#           seq2[153:153] --> []
#
# aligned   seq1[236:237] --> [((10, 120, 135), 'x', '<inline_math>')]
#           seq2[153:154] --> [((10, 120, 135), 'x', (216.9144287109375, 301.3950500488281, 226.04164123535156, 311.357666015625))]
#
# delete    seq1[237:239] --> [((10, 120, 140), '{', '<inline_math>'), ((10, 120, 140.1), '^{ \\prime}}', '<inline_math>')]
#           seq2[154:154] --> []
#
# insert    seq1[239:239] --> []
#           seq2[154:155] --> [((10, 120, 140), "'", (226.0469970703125, 299.7984924316406, 228.34136962890625, 311.88409423828125))]
#
# aligned   seq1[239:240] --> [((10, 120, 145), '=', '<inline_math>')]
#           seq2[155:156] --> [((10, 120, 145), '=', (228.8419952392578, 301.3950500488281, 236.5829315185547, 311.357666015625))]
#
# aligned   seq1[240:241] --> [((10, 120, 150), 'x', '<inline_math>')]
#           seq2[156:157] --> [((10, 120, 150), 'x', (236.5909881591797, 301.3950500488281, 242.27963256835938, 311.357666015625))]
#
# need      seq1[241:242] --> [((10, 120, 150.1), '_{', '<inline_math>')]
#           seq2[157:157] --> []
#
# aligned   seq1[242:243] --> [((10, 120, 155), '1', '<inline_math>')]
#           seq2[157:158] --> [((10, 120, 155), '1', (242.2849884033203, 305.13165283203125, 246.25308227539062, 312.1054382324219))]
#
# need      seq1[243:244] --> [((10, 120, 155.1), '}', '<inline_math>')]
#           seq2[158:158] --> []
#
# aligned   seq1[244:245] --> [((10, 120, 160), 'x', '<inline_math>')]
#           seq2[158:159] --> [((10, 120, 160), 'x', (246.7539825439453, 301.3950500488281, 252.442626953125, 311.357666015625))]
#
# need      seq1[245:246] --> [((10, 120, 160.1), '_{', '<inline_math>')]
#           seq2[159:159] --> []
#
# aligned   seq1[246:247] --> [((10, 120, 165), '2', '<inline_math>')]
#           seq2[159:160] --> [((10, 120, 165), '2', (252.44798278808594, 305.13165283203125, 256.41607666015625, 312.1054382324219))]
#
# need      seq1[247:248] --> [((10, 120, 165.1), '}', '<inline_math>')]
#           seq2[160:160] --> []
#
# aligned   seq1[248:249] --> [((10, 120, 170), 'x', '<inline_math>')]
#           seq2[160:161] --> [((10, 120, 170), 'x', (256.9169921875, 301.3950500488281, 262.60565185546875, 311.357666015625))]
#
# need      seq1[249:250] --> [((10, 120, 170.1), '_{', '<inline_math>')]
#           seq2[161:161] --> []
#
# aligned   seq1[250:251] --> [((10, 120, 175), '3', '<inline_math>')]
#           seq2[161:162] --> [((10, 120, 175), '3', (262.6109924316406, 305.13165283203125, 266.5790710449219, 312.1054382324219))]
#
# need      seq1[251:252] --> [((10, 120, 175.1), '}', '<inline_math>')]
#           seq2[162:162] --> []
#
# aligned   seq1[252:253] --> [((10, 120, 180), '=', '<inline_math>')]
#           seq2[162:163] --> [((10, 120, 180), '=', (267.0799865722656, 301.3950500488281, 274.8209228515625, 311.357666015625))]
#
# delete    seq1[253:254] --> [((10, 120, 185), '\\hat{x', '<inline_math>')]
#           seq2[163:163] --> []
#
# insert    seq1[255:255] --> []
#           seq2[163:164] --> [((10, 120, 185), '\\textasciicircumx', (274.8289794921875, 301.3950500488281, 280.51763916015625, 311.357666015625))]
#
# aligned   seq1[255:256] --> [((10, 120, 190), '1', '<inline_math>')]
#           seq2[164:165] --> [((10, 120, 190), '1', (280.5229797363281, 305.13165283203125, 284.4910583496094, 312.1054382324219))]
#
# delete    seq1[256:259] --> [((10, 120, 190.1), '}', '<inline_math>'), ((10, 120, 195), '\\hat{x', '<inline_math>'), ((10, 120, 195.1), '}_{', '<inline_math>')]
#           seq2[165:165] --> []
#
# insert    seq1[259:259] --> []
#           seq2[165:166] --> [((10, 120, 195), '\\textasciicircumx', (284.99298095703125, 301.3950500488281, 290.681640625, 311.357666015625))]
#
# aligned   seq1[259:260] --> [((10, 120, 200), '2', '<inline_math>')]
#           seq2[166:167] --> [((10, 120, 200), '2', (290.68597412109375, 305.13165283203125, 294.654052734375, 312.1054382324219))]
#
# delete    seq1[260:263] --> [((10, 120, 200.1), '}', '<inline_math>'), ((10, 120, 205), '\\hat{x', '<inline_math>'), ((10, 120, 205.1), '}_ {', '<inline_math>')]
#           seq2[167:167] --> []
#
# insert    seq1[263:263] --> []
#           seq2[167:168] --> [((10, 120, 205), '\\textasciicircumx', (295.1559753417969, 301.3950500488281, 300.8446044921875, 311.357666015625))]
#
# aligned   seq1[263:264] --> [((10, 120, 210), '3', '<inline_math>')]
#           seq2[168:169] --> [((10, 120, 210), '3', (300.8499755859375, 305.13165283203125, 304.81805419921875, 312.1054382324219))]
#
# need      seq1[264:266] --> [((10, 120, 210.1), '}', '<inline_math>'), ((10, 120, 210.2), '\\)', '<inline_math>')]
#           seq2[169:169] --> []
#
# aligned   seq1[266:267] --> [((10, 120, 215), ',', '<text>')]
#           seq2[169:170] --> [((10, 120, 215), ',', (304.81805419921875, 301.3950500488281, 311.7505798339844, 312.8526611328125))]
#
# need      seq1[267:268] --> [((10, 120, 215.1), '\\(', '<inline_math>')]
#           seq2[170:170] --> []
#
# aligned   seq1[268:269] --> [((10, 120, 220), 'y', '<inline_math>')]
#           seq2[170:171] --> [((10, 120, 220), 'y', (311.7505798339844, 301.3950500488281, 320.1056823730469, 311.357666015625))]
#
# aligned   seq1[269:270] --> [((10, 120, 225), '=', '<inline_math>')]
#           seq2[171:172] --> [((10, 120, 225), '=', (320.46600341796875, 301.3950500488281, 328.2069396972656, 311.357666015625))]
#
# aligned   seq1[270:271] --> [((10, 120, 230), 'y', '<inline_math>')]
#           seq2[172:173] --> [((10, 120, 230), 'y', (328.2149963378906, 301.3950500488281, 333.0966796875, 311.357666015625))]
#
# need      seq1[271:272] --> [((10, 120, 230.1), '_{', '<inline_math>')]
#           seq2[173:173] --> []
#
# aligned   seq1[272:273] --> [((10, 120, 235), '1', '<inline_math>')]
#           seq2[173:174] --> [((10, 120, 235), '1', (333.4570007324219, 305.13165283203125, 337.4250793457031, 312.1054382324219))]
#
# need      seq1[273:274] --> [((10, 120, 235.1), '}', '<inline_math>')]
#           seq2[174:174] --> []
#
# aligned   seq1[274:275] --> [((10, 120, 240), 'y', '<inline_math>')]
#           seq2[174:175] --> [((10, 120, 240), 'y', (337.9259948730469, 301.3950500488281, 342.80767822265625, 311.357666015625))]
#
# need      seq1[275:276] --> [((10, 120, 240.1), '_{', '<inline_math>')]
#           seq2[175:175] --> []
#
# aligned   seq1[276:277] --> [((10, 120, 245), '2', '<inline_math>')]
#           seq2[175:176] --> [((10, 120, 245), '2', (343.1679992675781, 305.13165283203125, 347.1360778808594, 312.1054382324219))]
#
# need      seq1[277:278] --> [((10, 120, 245.1), '}', '<inline_math>')]
#           seq2[176:176] --> []
#
# aligned   seq1[278:279] --> [((10, 120, 250), 'y', '<inline_math>')]
#           seq2[176:177] --> [((10, 120, 250), 'y', (347.63800048828125, 301.3950500488281, 352.5196838378906, 311.357666015625))]
#
# need      seq1[279:280] --> [((10, 120, 250.1), '_{', '<inline_math>')]
#           seq2[177:177] --> []
#
# aligned   seq1[280:281] --> [((10, 125, 0), '3', '<inline_math>')]
#           seq2[177:178] --> [((10, 125, 0), '3', (352.8789978027344, 305.13165283203125, 356.8470764160156, 312.1054382324219))]
#
# need      seq1[281:283] --> [((10, 125, 0.1), '}', '<inline_math>'), ((10, 125, 0.2), '\\)', '<inline_math>')]
#           seq2[178:178] --> []
#
# aligned   seq1[283:284] --> [((10, 125, 5), ',', '<text>')]
#           seq2[178:179] --> [((10, 125, 5), ',', (356.8470764160156, 301.3950500488281, 363.7795715332031, 312.8526611328125))]
#
# aligned   seq1[284:285] --> [((10, 125, 10), 'and', '<text>')]
#           seq2[179:180] --> [((10, 125, 10), 'and', (363.7795715332031, 301.3950500488281, 382.7204895019531, 311.357666015625))]
#
# need      seq1[285:286] --> [((10, 125, 10.1), '\\(', '<inline_math>')]
#           seq2[180:180] --> []
#
# aligned   seq1[286:287] --> [((10, 125, 15), 'z', '<inline_math>')]
#           seq2[180:181] --> [((10, 125, 15), 'z', (382.7204895019531, 301.3950500488281, 390.7995910644531, 311.357666015625))]
#
# aligned   seq1[287:288] --> [((10, 125, 20), '=', '<inline_math>')]
#           seq2[181:182] --> [((10, 125, 20), '=', (391.2380065917969, 301.3950500488281, 398.97894287109375, 311.357666015625))]
#
# aligned   seq1[288:289] --> [((10, 125, 25), 'z', '<inline_math>')]
#           seq2[182:183] --> [((10, 125, 25), 'z', (398.98699951171875, 301.3950500488281, 403.6195983886719, 311.357666015625))]
#
# need      seq1[289:290] --> [((10, 125, 25.1), '_{', '<inline_math>')]
#           seq2[183:183] --> []
#
# aligned   seq1[290:291] --> [((10, 125, 30), '1', '<inline_math>')]
#           seq2[183:184] --> [((10, 125, 30), '1', (404.0580139160156, 305.13165283203125, 408.0260925292969, 312.1054382324219))]
#
# need      seq1[291:292] --> [((10, 125, 30.1), '}', '<inline_math>')]
#           seq2[184:184] --> []
#
# aligned   seq1[292:293] --> [((10, 125, 35), 'z', '<inline_math>')]
#           seq2[184:185] --> [((10, 125, 35), 'z', (408.52801513671875, 301.3950500488281, 413.1606140136719, 311.357666015625))]
#
# need      seq1[293:294] --> [((10, 125, 35.1), '_{', '<inline_math>')]
#           seq2[185:185] --> []
#
# aligned   seq1[294:295] --> [((10, 125, 40), '2', '<inline_math>')]
#           seq2[185:186] --> [((10, 125, 40), '2', (413.5990295410156, 305.13165283203125, 417.5671081542969, 312.1054382324219))]
#
# need      seq1[295:296] --> [((10, 125, 40.1), '}', '<inline_math>')]
#           seq2[186:186] --> []
#
# aligned   seq1[296:297] --> [((10, 125, 45), 'z', '<inline_math>')]
#           seq2[186:187] --> [((10, 125, 45), 'z', (418.0680236816406, 301.3950500488281, 422.70062255859375, 311.357666015625))]
#
# need      seq1[297:298] --> [((10, 125, 45.1), '_{', '<inline_math>')]
#           seq2[187:187] --> []
#
# aligned   seq1[298:299] --> [((10, 125, 50), '3', '<inline_math>')]
#           seq2[187:188] --> [((10, 125, 50), '3', (423.1390380859375, 305.13165283203125, 427.10711669921875, 312.1054382324219))]
#
# need      seq1[299:301] --> [((10, 125, 50.1), '}', '<inline_math>'), ((10, 125, 50.2), '\\)', '<inline_math>')]
#           seq2[188:188] --> []
#
# aligned   seq1[301:302] --> [((10, 125, 55), 'such', '<text>')]
#           seq2[188:189] --> [((10, 125, 55), 'such', (427.10711669921875, 301.3950500488281, 449.7683410644531, 312.8526611328125))]
#
# aligned   seq1[302:303] --> [((10, 125, 60), 'that', '<text>')]
#           seq2[189:190] --> [((10, 125, 60), 'that', (449.7683410644531, 301.3950500488281, 469.6758117675781, 311.357666015625))]
#
# need      seq1[303:304] --> [((10, 125, 60.1), '\\(', '<inline_math>')]
#           seq2[190:190] --> []
#
# aligned   seq1[304:305] --> [((10, 125, 65), '(', '<inline_math>')]
# ...
#
# aligned   seq1[1250:1251] --> [((10, 190, 20), '(', '<text>')]
#           seq2[856:857] --> [((10, 190, 20), '(', (249.1199188232422, 667.1911010742188, 255.9249725341797, 677.1536865234375))]
#
# aligned   seq1[1251:1252] --> [((10, 190, 25), '3', '<text>')]
#           seq2[857:858] --> [((10, 190, 25), '3', (255.9347381591797, 667.1911010742188, 260.81640625, 677.1536865234375))]
#
# aligned   seq1[1252:1253] --> [((10, 190, 30), ')', '<text>')]
#           seq2[858:859] --> [((10, 190, 30), ')', (260.81640625, 667.1911010742188, 264.6045837402344, 677.1536865234375))]
#
# aligned   seq1[1253:1254] --> [((10, 190, 35), '.', '<text>')]
#           seq2[859:860] --> [((10, 190, 35), '.', (264.6143493652344, 667.1911010742188, 267.31878662109375, 677.1536865234375))]
#
# aligned   seq1[1254:1255] --> [((10, 190, 40), 'From', '<text>')]
#           seq2[860:861] --> [((10, 190, 40), 'From', (267.31878662109375, 667.1911010742188, 294.04107666015625, 677.1536865234375))]
#
# aligned   seq1[1255:1256] --> [((10, 190, 45), 'Theorem', '<text>')]
#           seq2[861:862] --> [((10, 190, 45), 'Theorem', (294.04107666015625, 667.1911010742188, 335.03741455078125, 677.1536865234375))]
#
# aligned   seq1[1256:1257] --> [((10, 190, 50), '(', '<text>')]
#           seq2[862:863] --> [((10, 190, 50), '(', (335.03741455078125, 667.1911010742188, 341.83270263671875, 677.1536865234375))]
#
# aligned   seq1[1257:1258] --> [((10, 190, 55), '2', '<text>')]
#           seq2[863:864] --> [((10, 190, 55), '2', (341.84246826171875, 667.1911010742188, 346.7241516113281, 677.1536865234375))]
#
# aligned   seq1[1258:1259] --> [((10, 190, 60), ')', '<text>')]
#           seq2[864:865] --> [((10, 190, 60), ')', (346.7241516113281, 667.1911010742188, 350.5123291015625, 677.1536865234375))]
#
# aligned   seq1[1259:1260] --> [((10, 190, 65), ',', '<text>')]
#           seq2[865:866] --> [((10, 190, 65), ',', (350.5220947265625, 667.1911010742188, 353.2265319824219, 677.1536865234375))]
#
# aligned   seq1[1260:1261] --> [((10, 190, 70), 'we', '<text>')]
#           seq2[866:867] --> [((10, 190, 70), 'we', (353.2265319824219, 667.1911010742188, 367.4126892089844, 677.1536865234375))]
#
# aligned   seq1[1261:1262] --> [((10, 190, 75), 'instantly', '<text>')]
#           seq2[867:868] --> [((10, 190, 75), 'instantly', (367.4126892089844, 667.1911010742188, 407.8915710449219, 677.1536865234375))]
#
# aligned   seq1[1262:1263] --> [((10, 190, 80), 'obtain', '<text>')]
#           seq2[868:869] --> [((10, 190, 80), 'obtain', (407.8915710449219, 667.1911010742188, 438.03106689453125, 677.1536865234375))]
#
# aligned   seq1[1263:1264] --> [((10, 190, 85), 'the', '<text>')]
#           seq2[869:870] --> [((10, 190, 85), 'the', (438.03106689453125, 667.1911010742188, 454.6092529296875, 677.1536865234375))]
#
# aligned   seq1[1264:1265] --> [((10, 190, 90), 'aforementioned', '<text>')]
#           seq2[870:871] --> [((10, 190, 90), 'aforementioned', (454.6092529296875, 667.1911010742188, 522.7281494140625, 677.1536865234375))]
#
# aligned   seq1[1265:1266] --> [((10, 190, 95), 'consequence', '<text>')]
#           seq2[871:872] --> [((10, 190, 95), 'consequence', (69.16500091552734, 679.1461181640625, 121.00839233398438, 689.1087036132812))]
#
# aligned   seq1[1266:1267] --> [((10, 190, 100), 'of', '<text>')]
#           seq2[872:873] --> [((10, 190, 100), 'of', (121.00839233398438, 679.1461181640625, 131.90428161621094, 689.1087036132812))]
#
# aligned   seq1[1267:1268] --> [((10, 190, 105), 'Wotschke', '<text>')]
#           seq2[873:874] --> [((10, 190, 105), 'Wotschke', (131.90428161621094, 679.1461181640625, 175.38047790527344, 689.1087036132812))]
#
# equal     seq1[1268:1269] --> [((10, 190, 105.1), '[', '<text>')]
#           seq2[874:875] --> [((0, 0, 0), '[', (175.38047790527344, 679.1461181640625, 181.111572265625, 689.1087036132812))]
#
# aligned   seq1[1269:1270] --> [((10, 190, 110), '3', '<text>')]
#           seq2[875:876] --> [((10, 190, 110), '3', (181.121337890625, 679.1461181640625, 186.0030059814453, 689.1087036132812))]
#
# equal     seq1[1270:1271] --> [((10, 190, 110.1), '][', '<text>')]
#           seq2[876:877] --> [((0, 0, 0), '][', (186.0030059814453, 679.1461181640625, 191.4216766357422, 689.1087036132812))]
#
# aligned   seq1[1271:1272] --> [((10, 190, 115), '4', '<text>')]
#           seq2[877:878] --> [((10, 190, 115), '4', (191.4314422607422, 679.1461181640625, 196.3131103515625, 689.1087036132812))]
#
# equal     seq1[1272:1273] --> [((10, 190, 115.1), ']', '<text>')]
#           seq2[878:879] --> [((0, 0, 0), ']', (196.3131103515625, 679.1461181640625, 199.01756286621094, 689.1087036132812))]
#
# aligned   seq1[1273:1274] --> [((10, 190, 120), ',', '<text>')]
#           seq2[879:880] --> [((10, 190, 120), ',', (199.02732849121094, 679.1461181640625, 201.73178100585938, 689.1087036132812))]
#
# aligned   seq1[1274:1275] --> [((10, 190, 125), 'stated', '<text>')]
#           seq2[880:881] --> [((10, 190, 125), 'stated', (201.73178100585938, 679.1461181640625, 230.9144287109375, 689.1087036132812))]
#
# aligned   seq1[1275:1276] --> [((10, 190, 130), 'as', '<text>')]
#           seq2[881:882] --> [((10, 190, 130), 'as', (230.9144287109375, 679.1461181640625, 242.67926025390625, 689.1087036132812))]
#
# aligned   seq1[1276:1277] --> [((10, 190, 135), 'follows', '<text>')]
#           seq2[882:883] --> [((10, 190, 135), 'follows', (242.67926025390625, 679.1461181640625, 274.5175476074219, 689.1087036132812))]
#
# aligned   seq1[1277:1278] --> [((10, 190, 140), '.', '<text>')]
#           seq2[883:884] --> [((10, 190, 140), '.', (274.5175476074219, 679.1461181640625, 277.22198486328125, 689.1087036132812))]
#
# aligned   seq1[1278:1279] --> [((10, 190, 145), 'The', '<text>')]
#           seq2[884:885] --> [((10, 190, 145), 'The', (277.22198486328125, 679.1461181640625, 298.3694152832031, 689.1087036132812))]
#
# aligned   seq1[1279:1280] --> [((10, 190, 150), 'statement', '<text>')]
#           seq2[885:886] --> [((10, 190, 150), 'statement', (298.3694152832031, 679.1461181640625, 343.47613525390625, 689.1087036132812))]
#
# aligned   seq1[1280:1281] --> [((10, 190, 155), 'directly', '<text>')]
#           seq2[886:887] --> [((10, 190, 155), 'directly', (343.47613525390625, 679.1461181640625, 378.8097229003906, 689.1087036132812))]
#
# aligned   seq1[1281:1282] --> [((10, 190, 160), 'comes', '<text>')]
#           seq2[887:888] --> [((10, 190, 160), 'comes', (378.8097229003906, 679.1461181640625, 407.3870849609375, 689.1087036132812))]
#
# aligned   seq1[1282:1283] --> [((10, 190, 165), 'from', '<text>')]
#           seq2[888:889] --> [((10, 190, 165), 'from', (407.3870849609375, 679.1461181640625, 430.24310302734375, 689.1087036132812))]
#
# aligned   seq1[1283:1284] --> [((10, 190, 170), 'Theorem', '<text>')]
#           seq2[889:890] --> [((10, 190, 170), 'Theorem', (430.24310302734375, 679.1461181640625, 471.26873779296875, 689.1087036132812))]
#
# aligned   seq1[1284:1285] --> [((10, 190, 175), '(', '<text>')]
#           seq2[890:891] --> [((10, 190, 175), '(', (471.26873779296875, 679.1461181640625, 478.09332275390625, 689.1087036132812))]
#
# aligned   seq1[1285:1286] --> [((10, 190, 180), '2', '<text>')]
#           seq2[891:892] --> [((10, 190, 180), '2', (478.10308837890625, 679.1461181640625, 482.9847717285156, 689.1087036132812))]
#
# aligned   seq1[1286:1287] --> [((10, 190, 185), ')', '<text>')]
#           seq2[892:893] --> [((10, 190, 185), ')', (482.9847717285156, 679.1461181640625, 486.77294921875, 689.1087036132812))]
#
# aligned   seq1[1287:1288] --> [((10, 190, 190), 'because', '<text>')]
#           seq2[893:894] --> [((10, 190, 190), 'because', (486.77294921875, 679.1461181640625, 522.6825561523438, 689.1087036132812))]
#
# delete    seq1[1288:1289] --> [((10, 190, 190.1), '\\(', '<inline_math>')]
#           seq2[894:894] --> []
#
# equal     seq1[1289:1290] --> [((10, 190, 190.2), '\\mathrm{DCFL}', '<inline_math>')]
#           seq2[894:895] --> [((0, 0, 0), 'DCFL', (69.16500091552734, 693.0390625, 96.70162963867188, 703.0016479492188))]
#
# aligned   seq1[1290:1291] --> [((10, 190, 195), '(', '<inline_math>')]
#           seq2[895:896] --> [((10, 190, 195), '(', (96.70162963867188, 693.0390625, 100.5671157836914, 703.0016479492188))]
#
# aligned   seq1[1291:1292] --> [((10, 190, 200), 'd', '<inline_math>')]
#           seq2[896:897] --> [((10, 190, 200), 'd', (100.57499694824219, 693.0390625, 105.75554656982422, 703.0016479492188))]
#
# aligned   seq1[1292:1293] --> [((10, 190, 205), ') ', '<inline_math>')]
#           seq2[897:898] --> [((10, 190, 205), ')', (105.76099395751953, 693.0390625, 109.62648010253906, 703.0016479492188))]
#
# need      seq1[1293:1294] --> [((10, 190, 205.1), '\\)', '<inline_math>')]
#           seq2[898:898] --> []
#
# aligned   seq1[1294:1295] --> [((10, 190, 210), 'contains', '<text>')]
#           seq2[898:899] --> [((10, 190, 210), 'contains', (109.62648010253906, 693.0390625, 148.70974731445312, 703.0016479492188))]
#
# aligned   seq1[1295:1296] --> [((10, 190, 215), 'both', '<text>')]
#           seq2[899:900] --> [((10, 190, 215), 'both', (148.70974731445312, 693.0390625, 172.24139404296875, 703.0016479492188))]
#
# need      seq1[1296:1297] --> [((10, 190, 215.1), '\\(', '<inline_math>')]
#           seq2[900:900] --> []
#
# aligned   seq1[1297:1298] --> [((10, 190, 220), 'L', '<inline_math>')]
#           seq2[900:901] --> [((10, 190, 220), 'L', (172.24139404296875, 693.0390625, 182.32955932617188, 703.0016479492188))]
#
# need      seq1[1298:1299] --> [((10, 190, 220.1), '_{', '<inline_math>')]
#           seq2[901:901] --> []
#
# aligned   seq1[1299:1300] --> [((10, 190, 225), 'd', '<inline_math>')]
#           seq2[904:905] --> [((10, 190, 225), 'd', (182.3350067138672, 698.28564453125, 186.47744750976562, 705.2594604492188))]
#
# need      seq1[1300:1301] --> [((10, 190, 225.1), '}^{', '<inline_math>')]
#           seq2[905:905] --> []
#
# aligned   seq1[1301:1302] --> [((10, 190, 230), '(', '<inline_math>')]
#           seq2[901:902] --> [((10, 190, 230), '(', (182.33499145507812, 690.1056518554688, 185.4453125, 697.0794677734375))]
#
# aligned   seq1[1302:1303] --> [((10, 190, 235), '\\leq', '<inline_math>')]
#           seq2[902:903] --> [((10, 190, 235), '\\leq', (185.447998046875, 689.8825073242188, 191.6686248779297, 701.9680786132812))]
#
# aligned   seq1[1303:1304] --> [((10, 190, 240), ')', '<inline_math>')]
#           seq2[903:904] --> [((10, 190, 240), ')', (191.6750030517578, 690.1056518554688, 194.7853240966797, 697.0794677734375))]
#
# delete    seq1[1304:1305] --> [((10, 190, 240.1), '}', '<inline_math>')]
#           seq2[904:904] --> []
#
# delete    seq1[1305:1306] --> [((10, 190, 240.2), '\\)', '<inline_math>')]
#           seq2[905:905] --> []
#
# aligned   seq1[1306:1307] --> [((10, 190, 245), 'and', '<text>')]
#           seq2[905:906] --> [((10, 190, 245), 'and', (198.6070098876953, 693.0390625, 214.65673828125, 703.0016479492188))]
#
# need      seq1[1307:1308] --> [((10, 190, 245.1), '\\(', '<inline_math>')]
#           seq2[906:906] --> []
#
# aligned   seq1[1308:1309] --> [((10, 190, 250), 'NPal', '<inline_math>')]
#           seq2[906:907] --> [((10, 190, 250), 'NPal', (214.65673828125, 693.0390625, 243.0947265625, 703.0016479492188))]
#
# delete    seq1[1309:1310] --> [((10, 190, 250.1), '_{', '<inline_math>')]
#           seq2[907:907] --> []
#
# insert    seq1[1310:1310] --> []
#           seq2[907:908] --> [((0, 0, 0), '#', (243.28500366210938, 690.49267578125, 249.82643127441406, 697.4664916992188))]
#
# aligned   seq1[1310:1311] --> [((10, 195, 0), 'd', '<inline_math>')]
#           seq2[908:909] --> [((10, 195, 0), 'd', (243.28500366210938, 698.28564453125, 247.4274444580078, 705.2594604492188))]
#
# need      seq1[1311:1313] --> [((10, 195, 0.1), '}^{\\#}', '<inline_math>'), ((10, 195, 0.2), '\\)', '<inline_math>')]
#           seq2[909:909] --> []
#
# aligned   seq1[1313:1314] --> [((10, 195, 10), '.\n\n', '<text>')]
#           seq2[909:910] --> [((10, 195, 10), '.', (253.64801025390625, 693.0390625, 256.40765380859375, 703.0016479492188))]
#
# insert    seq1[1315:1315] --> []
#           seq2[910:911] --> [((0, 0, 0), 'Corollary 1.4', (69.16500854492188, 713.458251953125, 136.0339813232422, 723.460693359375))]
#
# delete    seq1[1315:1316] --> [((0, 0, 5.099999999999998), '1.4', '<text>')]
#           seq2[910:910] --> []
#
# equal     seq1[1317:1318] --> [((0, 0, 5.299999999999997), '[3][4]\n\n', '<text>')]
#           seq2[911:912] --> [((0, 0, 0), '[3][4]', (136.0339813232422, 713.4981079101562, 162.0320587158203, 723.460693359375))]
#
# aligned   seq1[1318:1319] --> [((10, 195, 15), 'The', '<text>')]
#           seq2[912:913] --> [((10, 195, 15), 'The', (84.10900115966797, 725.453125, 100.84868621826172, 735.4157104492188))]
#
# aligned   seq1[1319:1320] --> [((10, 195, 20), 'intersection', '<text>')]
#           seq2[913:914] --> [((10, 195, 20), 'intersection', (100.84868621826172, 725.453125, 154.7490692138672, 735.4157104492188))]
#
# aligned   seq1[1320:1321] --> [((10, 195, 25), 'hierarchy', '<text>')]
#           seq2[914:915] --> [((10, 195, 25), 'hierarchy', (154.7490692138672, 725.453125, 197.8634033203125, 735.4157104492188))]
#
# aligned   seq1[1321:1322] --> [((10, 195, 30), 'of', '<text>')]
#           seq2[915:916] --> [((10, 195, 30), 'of', (197.8634033203125, 725.453125, 209.54248046875, 735.4157104492188))]
#
# aligned   seq1[1322:1323] --> [((10, 195, 35), 'dcf', '<text>')]
#           seq2[916:917] --> [((10, 195, 35), 'dcf', (209.54248046875, 725.453125, 225.78602600097656, 735.4157104492188))]
#
# aligned   seq1[1323:1324] --> [((10, 195, 40), 'languages', '<text>')]
#           seq2[917:918] --> [((10, 195, 40), 'languages', (225.78602600097656, 725.453125, 270.676513671875, 735.4157104492188))]
#
# aligned   seq1[1324:1325] --> [((10, 195, 45), 'and', '<text>')]
#           seq2[918:919] --> [((10, 195, 45), 'and', (270.676513671875, 725.453125, 289.9663391113281, 735.4157104492188))]
#
# aligned   seq1[1325:1326] --> [((10, 195, 50), 'the', '<text>')]
#           seq2[919:920] --> [((10, 195, 50), 'the', (289.9663391113281, 725.453125, 306.4579162597656, 735.4157104492188))]
#
# aligned   seq1[1326:1327] --> [((10, 195, 55), 'union', '<text>')]
#           seq2[920:921] --> [((10, 195, 55), 'union', (306.4579162597656, 725.453125, 334.61871337890625, 735.4157104492188))]
#
# aligned   seq1[1327:1328] --> [((10, 195, 60), 'hierarchy', '<text>')]
#           seq2[921:922] --> [((10, 195, 60), 'hierarchy', (334.61871337890625, 725.453125, 377.7429504394531, 735.4157104492188))]
#
# aligned   seq1[1328:1329] --> [((10, 195, 65), 'of', '<text>')]
#           seq2[922:923] --> [((10, 195, 65), 'of', (377.7429504394531, 725.453125, 389.4120788574219, 735.4157104492188))]
#
# aligned   seq1[1329:1330] --> [((10, 195, 70), 'dcf', '<text>')]
#           seq2[923:924] --> [((10, 195, 70), 'dcf', (389.4120788574219, 725.453125, 405.6556091308594, 735.4157104492188))]
#
# aligned   seq1[1330:1331] --> [((10, 195, 75), 'languages', '<text>')]
#           seq2[924:925] --> [((10, 195, 75), 'languages', (405.6556091308594, 725.453125, 450.5560607910156, 735.4157104492188))]
#
# aligned   seq1[1331:1332] --> [((10, 195, 80), 'are', '<text>')]
#           seq2[925:926] --> [((10, 195, 80), 'are', (450.5560607910156, 725.453125, 467.4445495605469, 735.4157104492188))]
#
# aligned   seq1[1332:1333] --> [((10, 195, 85), 'both', '<text>')]
#           seq2[926:927] --> [((10, 195, 85), 'both', (467.4445495605469, 725.453125, 488.49066162109375, 735.4157104492188))]
#
# aligned   seq1[1333:1334] --> [((10, 195, 90), 'infinite', '<text>')]
#           seq2[927:928] --> [((10, 195, 90), 'infinite', (488.49066162109375, 725.453125, 522.734130859375, 735.4157104492188))]
#
# aligned   seq1[1334:1335] --> [((10, 195, 95), 'hierarchies', '<text>')]
#           seq2[928:929] --> [((10, 195, 95), 'hierarchies', (68.65599822998047, 737.4080810546875, 115.25106811523438, 747.3706665039062))]
#
# aligned   seq1[1335:1336] --> [((10, 195, 100), '.\n\n', '<text>')]
#           seq2[929:930] --> [((10, 195, 100), '.', (115.26103210449219, 737.4080810546875, 118.30958557128906, 747.3706665039062))]

# %%
def generate_final_match_table(true_match, sequence_mmd, sequence2boxed, verbose_level=1):
    """
    Get output type [ markdown_text, pdf_text, status, text_type, text_bbox]
    """
    pretext_and_prompts = []
    color_table_seq_pdf = {c: i for i, (c,_,_) in enumerate(sequence2boxed) if c != (0,0,0) and is_meaningful_markdonw_color(c)}
    for tag, i1, i2, j1, j2 in true_match:

        markdown_parts = sequence1o[i1:i2]
        pdf_color_box  = sequence2boxed[j1:j2]
        pdf_text       = " ".join([t[1] for t in pdf_color_box]) ### <--- pdf text
        
        if len(markdown_parts)==0: ### <--- then it be an insect case
            if len(pdf_text.strip())==0:continue
            if not all([sum(t[0])==0 for t in pdf_color_box]):

                logging.debug(f"({tag}, {i1}, {i2}, {j1}, {j2})This an empty markdown text but not empty pdf color box, throw it: the pdf box data is:")
                for data in pdf_color_box:
                    logging.debug(f"color={data[0]}, text= {data[1]}")
                logging.debug("=========================")
            else:
                logging.info(f"safe throw: markdown_text={markdown_parts} pdf_text={pdf_text}")
            continue
        
        if len(pdf_color_box) == 0: ### <--- then it be an delete case
            for c, text, _type in markdown_parts:
                if len(text.strip())==0:continue
                if invisable_symbol(text,_type):
                    pretext_and_prompts.append([text,"", "invisable", _type ,(-1,-1,-1)])
                else:
                    if verbose_level>0:
                        if is_meaningful_markdonw_color(c):
                            logging.debug(f"[Important] why you throw a meaningful markdown color={c} text={text}")
                        else:
                            logging.info(f"it seem you have to throw a text to match. The text={text} with color={c}")
            continue
        if len(markdown_parts)>1:
            raise NotImplementedError(f"seem has problem for this mardown text: {markdown_parts} ")
            
            
        (color,markdown_text, markdown_type) =  markdown_parts[0]

        if tag in ['equal','aligned']:
            merged_bbox   = merge_bboxes([t[2] for t in pdf_color_box])
            if merged_bbox is None:merged_bbox = pdf_color_box[0][2]
            char_markdown = re.sub(r'[ -]+', '', markdown_text).lower()
            char_pdf = re.sub(r'[ -]+', '', "".join(pdf_text)).lower()
            if  (char_markdown != char_pdf and 
                not  char_markdown.startswith(char_pdf) and 
                not  char_pdf.startswith(char_markdown) and
                not  char_markdown.endswith(char_pdf) and
                not  char_pdf.endswith(char_markdown) and
                not  invisable_symbol(markdown_text,markdown_type)
                ):

                if any([isinstance(c,float) for c in color]) :
                    pretext_and_prompts.append([markdown_text, pdf_text, 'throw', markdown_type, (-1, -1, -1)])
                    print(f"bad match!!! throw {markdown_type}:{markdown_text.strip()}<=>{pdf_text.strip()} char level is {char_markdown}<=>{char_pdf} {[int(l) for l in merged_bbox]}")
                else:
                    pretext_and_prompts.append([markdown_text, pdf_text, 'invisable', markdown_type, (-1, -1, -1)])
                    print(f"bad match!!! but {markdown_text.strip()} is a invisable sign, skip")
                continue
            if merged_bbox is None:
                ### is may due to the Line breaks such as 
                ###  xxxxxxxxxx out-
                ###  side xxxxxxxxxx
                ###  xxxxxxxxxxxxxxx
                ### for those case, lets divide the markdown_text
                if char_markdown != char_pdf:
                    logging.info(f"mismatch?? [{markdown_text}] <=> [{pdf_text}]")
                for color_box in pdf_color_box:
                    markdown_text = pdf_text = color_box[1]
                    merged_bbox   = color_box[2]
                    pretext_and_prompts.append([markdown_text, pdf_text, 'match' ,markdown_type,merged_bbox])
                    logging.info(f"{tag:7s} {markdown_text.strip():20s} {pdf_text.strip():20s} {[int(l) for l in merged_bbox]}")

            else:
                pretext_and_prompts.append([markdown_text, pdf_text, 'match' ,markdown_type,merged_bbox])
                logging.info(f"{tag:7s} {markdown_text.strip():20s} {pdf_text.strip():20s} {[int(l) for l in merged_bbox]}")

        elif tag == 'delete':
            if is_this_part_is_invisable_symbol_in_markdown(markdown_text):
                logging.info("this is the invisable markdown text", markdown_text.strip(),pdf_text.strip() )
                pretext_and_prompts.append([markdown_text, pdf_text, "invisable" ,markdown_type, (-1,-1,-1)])
            elif any([isinstance(c,float) for c in color]):

                if all([t['color']==0 for t in pdf_color_box]):
                    ### this mean there is symbol in markdown is not get colored by pdf engine like µ
                    ### lets put it back to last markdown slot
                    ##### since we pre caption already, this still should not appear here 
                    raise NotImplementedError(f"why you throw a symbol but no color source: markdown_text={markdown_text.strip()} pdf_text={pdf_text.strip()}")
                    if pretext_and_prompts and pretext_and_prompts[-1][2]!='throw':
                        pretext_and_prompts[-1][0]+=' '+markdown_text
                    logging.info("put the symbol to last markdone slot", markdown_text.strip(),pdf_text.strip() )
                else:
                    logging.info(f"safe throw as it is a black symbol but no markdown source: markdown_text={markdown_text.strip()} pdf_text={pdf_text.strip()}")
            elif color in color_table_seq_pdf:
                target_j = color_table_seq_pdf[color]
                pdf_text = sequence2boxed[target_j]['text']
                merged_bbox = sequence2boxed[target_j]['bbox']
                # but it should not match here since we pre match caption already, lets throw
                logging.debug(f"==> [this should not appear] color match {target_j} <===",markdown_text.strip(),pdf_text.strip(), [int(l) for l in merged_bbox])

            else:
                logging.debug("==> unsave throw <===",markdown_text.strip(),pdf_text.strip() )
                ## then we will use color find the correct part
        
        else:

            logging.debug(tag,markdown_text,pdf_text )

    return pretext_and_prompts

# %%
pretext_and_prompts = generate_final_match_table(true_match, sequence_mmd, sequence2, verbose_level=1)

# %%
pretext_and_prompts
# Out:
# [['there',
#   'there',
#   'match',
#   '<text>',
#   (68.4010009765625,
#    228.82205200195312,
#    90.01146697998047,
#    238.78465270996094)],
#  ['exist',
#   'exist',
#   'match',
#   '<text>',
#   (90.01146697998047,
#    228.82205200195312,
#    113.52487182617188,
#    238.78465270996094)],
#  ['two',
#   'two',
#   'match',
#   '<text>',
#   (113.52487182617188,
#    228.82205200195312,
#    132.3416748046875,
#    238.78465270996094)],
#  ['distinct',
#   'distinct',
#   'match',
#   '<text>',
#   (132.3416748046875,
#    228.82205200195312,
#    168.49746704101562,
#    238.78465270996094)],
#  ['indices',
#   'indices',
#   'match',
#   '<text>',
#   (168.49746704101562,
#    228.82205200195312,
#    202.07215881347656,
#    238.78465270996094)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['j',
#   'j',
#   'match',
#   '<inline_math>',
#   (202.07215881347656,
#    228.82205200195312,
#    209.73263549804688,
#    238.78465270996094)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (210.31100463867188,
#    232.55865478515625,
#    214.2790985107422,
#    239.53245544433594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (214.781005859375,
#    228.82205200195312,
#    217.5406494140625,
#    238.78465270996094)],
#  ['j',
#   'j',
#   'match',
#   '<inline_math>',
#   (217.5506134033203,
#    228.82205200195312,
#    221.64524841308594,
#    238.78465270996094)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (222.22100830078125,
#    232.55865478515625,
#    226.18910217285156,
#    239.53245544433594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\in',
#   '\\in',
#   'match',
#   '<inline_math>',
#   (226.69000244140625,
#    228.572998046875,
#    233.32508850097656,
#    245.8581085205078)],
#  ['[',
#   '[',
#   'match',
#   '<inline_math>',
#   (233.33200073242188,
#    228.82205200195312,
#    236.1357879638672,
#    238.78465270996094)],
#  ['d',
#   'd',
#   'match',
#   '<inline_math>',
#   (236.1439971923828,
#    228.82205200195312,
#    241.32455444335938,
#    238.78465270996094)],
#  ['+',
#   '+',
#   'match',
#   '<inline_math>',
#   (241.32899475097656,
#    228.82205200195312,
#    249.06993103027344,
#    238.78465270996094)],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (249.07989501953125,
#    228.82205200195312,
#    254.06118774414062,
#    238.78465270996094)],
#  [']', '', 'invisable', '<inline_math>', None],
#  ['such',
#   'such',
#   'match',
#   '<text>',
#   (256.86279296875,
#    228.82205200195312,
#    279.83587646484375,
#    238.78465270996094)],
#  ['that',
#   'that',
#   'match',
#   '<text>',
#   (279.83587646484375,
#    228.82205200195312,
#    300.4645080566406,
#    238.78465270996094)],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (300.4645080566406,
#    228.82205200195312,
#    303.56182861328125,
#    238.78465270996094)],
#  ['for',
#   'for',
#   'match',
#   '<text>',
#   (303.56182861328125,
#    228.82205200195312,
#    319.6760559082031,
#    238.78465270996094)],
#  ['any',
#   'any',
#   'match',
#   '<text>',
#   (319.6760559082031,
#    228.82205200195312,
#    339.00909423828125,
#    238.78465270996094)],
#  ['three',
#   'three',
#   'match',
#   '<text>',
#   (339.00909423828125,
#    228.82205200195312,
#    363.6763916015625,
#    238.78465270996094)],
#  ['nonempty',
#   'nonempty',
#   'match',
#   '<text>',
#   (363.6763916015625,
#    228.82205200195312,
#    410.166748046875,
#    238.78465270996094)],
#  ['strings',
#   'strings',
#   'match',
#   '<text>',
#   (410.166748046875,
#    228.82205200195312,
#    443.0936279296875,
#    238.78465270996094)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (443.0936279296875,
#    228.82205200195312,
#    452.34564208984375,
#    238.78465270996094)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (458.70599365234375,
#    228.82205200195312,
#    461.8033142089844,
#    238.78465270996094)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['y ',
#   'y',
#   'match',
#   '<inline_math>',
#   (461.8033142089844,
#    228.82205200195312,
#    470.2536926269531,
#    238.78465270996094)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (470.2536926269531,
#    228.82205200195312,
#    477.2723083496094,
#    238.78465270996094)],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (477.2723083496094,
#    228.82205200195312,
#    496.8786315917969,
#    238.78465270996094)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['z ',
#   'z',
#   'match',
#   '<inline_math>',
#   (496.8786315917969,
#    228.82205200195312,
#    505.07159423828125,
#    238.78465270996094)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (505.07159423828125,
#    228.82205200195312,
#    512.1683349609375,
#    238.78465270996094)],
#  ['if',
#   'if',
#   'match',
#   '<text>',
#   (512.1683349609375,
#    228.82205200195312,
#    521.9462280273438,
#    238.78465270996094)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (69.16500091552734,
#    240.77706909179688,
#    74.85364532470703,
#    250.7396697998047)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['y',
#   'y',
#   'match',
#   '<inline_math>',
#   (77.65399932861328,
#    240.77706909179688,
#    82.53567504882812,
#    250.7396697998047)],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (82.89599609375, 240.77706909179688, 90.63693237304688, 250.7396697998047)],
#  ['xy',
#   'xy',
#   'match',
#   '<inline_math>',
#   (90.6449966430664,
#    240.77706909179688,
#    101.22528076171875,
#    250.7396697998047)],
#  ['^{', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (101.58099365234375,
#    239.4036865234375,
#    104.6913070678711,
#    246.3774871826172)],
#  ['j',
#   'j',
#   'match',
#   '<inline_math>',
#   (104.6939926147461,
#    239.4036865234375,
#    107.98562622070312,
#    246.3774871826172)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (108.39398956298828,
#    241.89402770996094,
#    111.7812728881836,
#    246.87533569335938)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [')',
#   ')',
#   'match',
#   '<inline_math>',
#   (112.28199005126953,
#    239.4036865234375,
#    115.39230346679688,
#    246.3774871826172)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (119.45799255371094,
#    240.77706909179688,
#    135.23873901367188,
#    250.7396697998047)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (135.23873901367188,
#    240.77706909179688,
#    144.49563598632812,
#    250.7396697998047)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['z',
#   'z',
#   'match',
#   '<inline_math>',
#   (147.29598999023438,
#    240.77706909179688,
#    151.92860412597656,
#    250.7396697998047)],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (152.3679962158203,
#    240.77706909179688,
#    160.1089324951172,
#    250.7396697998047)],
#  ['xy',
#   'xy',
#   'match',
#   '<inline_math>',
#   (160.11599731445312,
#    240.77706909179688,
#    170.69627380371094,
#    250.7396697998047)],
#  ['^{', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (171.052001953125,
#    239.4036865234375,
#    174.16232299804688,
#    246.3774871826172)],
#  ['j',
#   'j',
#   'match',
#   '<inline_math>',
#   (174.16600036621094,
#    239.4036865234375,
#    177.4576416015625,
#    246.3774871826172)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (177.86500549316406,
#    241.89402770996094,
#    181.25228881835938,
#    246.87533569335938)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [')',
#   ')',
#   'match',
#   '<inline_math>',
#   (181.7530059814453,
#    239.4036865234375,
#    184.8633270263672,
#    246.3774871826172)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (188.9290008544922,
#    240.77706909179688,
#    191.97755432128906,
#    250.7396697998047)],
#  ['then',
#   'then',
#   'match',
#   '<text>',
#   (191.97755432128906,
#    240.77706909179688,
#    214.13438415527344,
#    250.7396697998047)],
#  ['one',
#   'one',
#   'match',
#   '<text>',
#   (214.13438415527344,
#    240.77706909179688,
#    232.97364807128906,
#    250.7396697998047)],
#  ['of',
#   'of',
#   'match',
#   '<text>',
#   (232.97364807128906,
#    240.77706909179688,
#    244.66973876953125,
#    250.7396697998047)],
#  ['the',
#   'the',
#   'match',
#   '<text>',
#   (244.66973876953125,
#    240.77706909179688,
#    261.2275695800781,
#    250.7396697998047)],
#  ['following',
#   'following',
#   'match',
#   '<text>',
#   (261.2275695800781,
#    240.77706909179688,
#    303.4988708496094,
#    250.7396697998047)],
#  ['conditions',
#   'conditions',
#   'match',
#   '<text>',
#   (303.4988708496094,
#    240.77706909179688,
#    351.10015869140625,
#    250.7396697998047)],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (351.10015869140625,
#    240.77706909179688,
#    358.73150634765625,
#    250.7396697998047)],
#  ['1',
#   '1',
#   'match',
#   '<text>',
#   (358.7414855957031,
#    240.77706909179688,
#    363.8323669433594,
#    250.7396697998047)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (363.8323669433594,
#    240.77706909179688,
#    367.8970947265625,
#    250.7396697998047)],
#  ['-',
#   '-',
#   'match',
#   '<text>',
#   (367.9070739746094,
#    240.77706909179688,
#    371.4637145996094,
#    250.7396697998047)],
#  ['-',
#   '-',
#   'match',
#   '<text>',
#   (371.47369384765625,
#    240.77706909179688,
#    375.03033447265625,
#    250.7396697998047)],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (375.0403137207031,
#    240.77706909179688,
#    379.10504150390625,
#    250.7396697998047)],
#  ['5',
#   '5',
#   'match',
#   '<text>',
#   (379.1150207519531,
#    240.77706909179688,
#    384.2059020996094,
#    250.7396697998047)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (384.2059020996094,
#    240.77706909179688,
#    388.2706298828125,
#    250.7396697998047)],
#  ['holds',
#   'holds',
#   'match',
#   '<text>',
#   (388.2706298828125,
#    240.77706909179688,
#    413.7350158691406,
#    250.7396697998047)],
#  ['.\n\n',
#   '.',
#   'match',
#   '<text>',
#   (413.7449951171875,
#    240.77706909179688,
#    416.7935485839844,
#    250.7396697998047)],
#  ['Either',
#   'Either',
#   'match',
#   '<text>',
#   (89.08244323730469,
#    259.8600769042969,
#    121.06239318847656,
#    269.82269287109375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (121.06239318847656,
#    259.8600769042969,
#    130.32363891601562,
#    269.82269287109375)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['y ',
#   'y',
#   'match',
#   '<inline_math>',
#   (133.12399291992188,
#    259.8600769042969,
#    138.0056610107422,
#    269.82269287109375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['or',
#   'or',
#   'match',
#   '<text>',
#   (138.0056610107422,
#    259.8600769042969,
#    151.2151336669922,
#    269.82269287109375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (151.2151336669922,
#    259.8600769042969,
#    160.4756317138672,
#    269.82269287109375)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['z ',
#   'z',
#   'match',
#   '<inline_math>',
#   (163.27598571777344,
#    259.8600769042969,
#    167.90859985351562,
#    269.82269287109375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['has',
#   'has',
#   'match',
#   '<text>',
#   (167.90859985351562,
#    259.8600769042969,
#    186.1584930419922,
#    269.82269287109375)],
#  ['no',
#   'no',
#   'match',
#   '<text>',
#   (186.1584930419922,
#    259.8600769042969,
#    200.4249267578125,
#    269.82269287109375)],
#  ['nondegenerate',
#   'nondegenerate',
#   'match',
#   '<text>',
#   (200.4249267578125,
#    259.8600769042969,
#    265.4607849121094,
#    269.82269287109375)],
#  ['iterative',
#   'iterative',
#   'match',
#   '<text>',
#   (265.4607849121094,
#    259.8600769042969,
#    304.2950439453125,
#    269.82269287109375)],
#  ['pair',
#   'pair',
#   'match',
#   '<text>',
#   (304.2950439453125,
#    259.8600769042969,
#    324.7881164550781,
#    269.82269287109375)],
#  ['for',
#   'for',
#   'match',
#   '<text>',
#   (324.7881164550781,
#    259.8600769042969,
#    340.6983947753906,
#    269.82269287109375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['L ',
#   'L',
#   'match',
#   '<inline_math>',
#   (340.6983947753906,
#    259.8600769042969,
#    351.049560546875,
#    269.82269287109375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['.\n\n',
#   '.',
#   'match',
#   '<text>',
#   (351.049560546875,
#    259.8600769042969,
#    357.6685485839844,
#    269.82269287109375)],
#  ['There',
#   'There',
#   'match',
#   '<text>',
#   (89.08243560791016,
#    274.6500549316406,
#    118.77172088623047,
#    284.6126708984375)],
#  ['are',
#   'are',
#   'match',
#   '<text>',
#   (118.77172088623047,
#    274.6500549316406,
#    135.49334716796875,
#    284.6126708984375)],
#  ['two',
#   'two',
#   'match',
#   '<text>',
#   (135.49334716796875,
#    274.6500549316406,
#    153.84396362304688,
#    284.6126708984375)],
#  ['factorizations',
#   'factorizations',
#   'match',
#   '<text>',
#   (153.84396362304688,
#    274.6500549316406,
#    215.2056427001953,
#    284.6126708984375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (215.2056427001953,
#    274.6500549316406,
#    224.4646453857422,
#    284.6126708984375)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (227.26499938964844,
#    274.6500549316406,
#    235.0059356689453,
#    284.6126708984375)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (235.0139923095703, 274.6500549316406, 240.70263671875, 284.6126708984375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (240.70799255371094,
#    278.38665771484375,
#    244.67608642578125,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (245.17698669433594,
#    274.6500549316406,
#    250.86563110351562,
#    284.6126708984375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (250.87098693847656,
#    278.38665771484375,
#    254.83908081054688,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (255.33998107910156,
#    274.6500549316406,
#    261.02862548828125,
#    284.6126708984375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (261.0339660644531,
#    278.38665771484375,
#    265.0020446777344,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (265.50396728515625,
#    274.6500549316406,
#    271.192626953125,
#    284.6126708984375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['4',
#   '4',
#   'match',
#   '<inline_math>',
#   (271.1979675292969,
#    278.38665771484375,
#    275.1660461425781,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (275.6669616699219,
#    274.6500549316406,
#    281.3555908203125,
#    284.6126708984375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['5',
#   '5',
#   'match',
#   '<inline_math>',
#   (281.3609619140625,
#    278.38665771484375,
#    285.32904052734375,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (285.8299560546875,
#    274.6500549316406,
#    293.5708923339844,
#    284.6126708984375)],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (299.27294921875,
#    278.38665771484375,
#    303.24102783203125,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\hat{ x', '', 'invisable', '<inline_math>', None],
#  ['}_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (309.4359436035156,
#    278.38665771484375,
#    313.4040222167969,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['}_{', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (319.59893798828125,
#    278.38665771484375,
#    323.5670166015625,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\hat{ x', '', 'invisable', '<inline_math>', None],
#  ['}_{', '', 'invisable', '<inline_math>', None],
#  ['4',
#   '4',
#   'match',
#   '<inline_math>',
#   (329.762939453125,
#    278.38665771484375,
#    333.73101806640625,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['}_{', '', 'invisable', '<inline_math>', None],
#  ['5',
#   '5',
#   'match',
#   '<inline_math>',
#   (339.9259338378906,
#    278.38665771484375,
#    343.8940124511719,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['such',
#   'such',
#   'match',
#   '<text>',
#   (343.8940124511719,
#    274.6500549316406,
#    366.76983642578125,
#    286.107666015625)],
#  ['that',
#   'that',
#   'match',
#   '<text>',
#   (366.76983642578125,
#    274.6500549316406,
#    386.8769836425781,
#    284.6126708984375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (386.8769836425781,
#    274.6500549316406,
#    394.3084716796875,
#    284.6126708984375)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (394.3179931640625,
#    274.6500549316406,
#    400.00665283203125,
#    284.6126708984375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (400.0119934082031,
#    278.38665771484375,
#    403.9800720214844,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (404.4809875488281,
#    274.6500549316406,
#    407.2406311035156,
#    284.6126708984375)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (407.2505798339844, 274.6500549316406, 412.939208984375, 284.6126708984375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['4',
#   '4',
#   'match',
#   '<inline_math>',
#   (412.9419860839844,
#    278.38665771484375,
#    416.9100646972656,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (417.4119873046875,
#    274.6500549316406,
#    421.2774658203125,
#    284.6126708984375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (421.2774658203125,
#    274.6500549316406,
#    440.3930358886719,
#    284.6126708984375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (440.3930358886719,
#    274.6500549316406,
#    447.8254699707031,
#    284.6126708984375)],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (453.5279846191406,
#    278.38665771484375,
#    457.4960632324219,
#    285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (457.99798583984375,
#    274.6500549316406,
#    460.75762939453125,
#    284.6126708984375)],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['4',
#   '4',
#   'match',
#   '<inline_math>',
#   (466.458984375, 278.38665771484375, 470.42706298828125, 285.3604431152344)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (470.927978515625, 274.6500549316406, 474.79345703125, 284.6126708984375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['are',
#   'are',
#   'match',
#   '<text>',
#   (474.79345703125, 274.6500549316406, 491.5244445800781, 284.6126708984375)],
#  ['respectively',
#   'respectively',
#   'match',
#   '<text>',
#   (491.5244445800781, 274.6500549316406, 523.7705078125, 284.6126708984375)],
#  ['nondegenerate',
#   'nondegenerate',
#   'match',
#   '<text>',
#   (116.22197723388672,
#    286.6050720214844,
#    181.2777557373047,
#    296.56768798828125)],
#  ['iterative',
#   'iterative',
#   'match',
#   '<text>',
#   (181.2777557373047,
#    286.6050720214844,
#    220.10203552246094,
#    296.56768798828125)],
#  ['pairs',
#   'pairs',
#   'match',
#   '<text>',
#   (220.10203552246094,
#    286.6050720214844,
#    244.6697998046875,
#    296.56768798828125)],
#  ['of',
#   'of',
#   'match',
#   '<text>',
#   (244.6697998046875,
#    286.6050720214844,
#    256.3858337402344,
#    296.56768798828125)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (256.3858337402344,
#    286.6050720214844,
#    265.63165283203125,
#    296.56768798828125)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['y ',
#   'y',
#   'match',
#   '<inline_math>',
#   (268.4320068359375,
#    286.6050720214844,
#    273.3136901855469,
#    296.56768798828125)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (273.3136901855469,
#    286.6050720214844,
#    293.01873779296875,
#    296.56768798828125)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (293.01873779296875,
#    286.6050720214844,
#    302.27667236328125,
#    296.56768798828125)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['z ',
#   'z',
#   'match',
#   '<inline_math>',
#   (305.0770263671875,
#    286.6050720214844,
#    309.7096252441406,
#    296.56768798828125)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['for',
#   'for',
#   'match',
#   '<text>',
#   (309.7096252441406,
#    286.6050720214844,
#    326.0556945800781,
#    296.56768798828125)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['L ',
#   'L',
#   'match',
#   '<inline_math>',
#   (326.0556945800781,
#    286.6050720214844,
#    336.39959716796875,
#    296.56768798828125)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['.\n\n',
#   '.',
#   'match',
#   '<text>',
#   (336.39959716796875, 286.6050720214844, 343.017578125, 296.56768798828125)],
#  ['There',
#   'There',
#   'match',
#   '<text>',
#   (89.08246612548828,
#    301.3950500488281,
#    118.64635467529297,
#    311.357666015625)],
#  ['are',
#   'are',
#   'match',
#   '<text>',
#   (118.64635467529297,
#    301.3950500488281,
#    135.1757049560547,
#    311.357666015625)],
#  ['four',
#   'four',
#   'match',
#   '<text>',
#   (135.1757049560547, 301.3950500488281, 155.9618682861328, 311.357666015625)],
#  ['factorizations',
#   'factorizations',
#   'match',
#   '<text>',
#   (155.9618682861328, 301.3950500488281, 216.9144287109375, 311.357666015625)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (216.9144287109375,
#    301.3950500488281,
#    226.04164123535156,
#    311.357666015625)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{ \\prime}}', '', 'invisable', '<inline_math>', None],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (228.8419952392578, 301.3950500488281, 236.5829315185547, 311.357666015625)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (236.5909881591797,
#    301.3950500488281,
#    242.27963256835938,
#    311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (242.2849884033203,
#    305.13165283203125,
#    246.25308227539062,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (246.7539825439453, 301.3950500488281, 252.442626953125, 311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (252.44798278808594,
#    305.13165283203125,
#    256.41607666015625,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (256.9169921875, 301.3950500488281, 262.60565185546875, 311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (262.6109924316406,
#    305.13165283203125,
#    266.5790710449219,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (267.0799865722656, 301.3950500488281, 274.8209228515625, 311.357666015625)],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (280.5229797363281,
#    305.13165283203125,
#    284.4910583496094,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['}_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (290.68597412109375,
#    305.13165283203125,
#    294.654052734375,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['}_ {', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (300.8499755859375,
#    305.13165283203125,
#    304.81805419921875,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (304.81805419921875,
#    301.3950500488281,
#    311.7505798339844,
#    312.8526611328125)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['y',
#   'y',
#   'match',
#   '<inline_math>',
#   (311.7505798339844, 301.3950500488281, 320.1056823730469, 311.357666015625)],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (320.46600341796875,
#    301.3950500488281,
#    328.2069396972656,
#    311.357666015625)],
#  ['y',
#   'y',
#   'match',
#   '<inline_math>',
#   (328.2149963378906, 301.3950500488281, 333.0966796875, 311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (333.4570007324219,
#    305.13165283203125,
#    337.4250793457031,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['y',
#   'y',
#   'match',
#   '<inline_math>',
#   (337.9259948730469,
#    301.3950500488281,
#    342.80767822265625,
#    311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (343.1679992675781,
#    305.13165283203125,
#    347.1360778808594,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['y',
#   'y',
#   'match',
#   '<inline_math>',
#   (347.63800048828125,
#    301.3950500488281,
#    352.5196838378906,
#    311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (352.8789978027344,
#    305.13165283203125,
#    356.8470764160156,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (356.8470764160156,
#    301.3950500488281,
#    363.7795715332031,
#    312.8526611328125)],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (363.7795715332031, 301.3950500488281, 382.7204895019531, 311.357666015625)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['z',
#   'z',
#   'match',
#   '<inline_math>',
#   (382.7204895019531, 301.3950500488281, 390.7995910644531, 311.357666015625)],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (391.2380065917969,
#    301.3950500488281,
#    398.97894287109375,
#    311.357666015625)],
#  ['z',
#   'z',
#   'match',
#   '<inline_math>',
#   (398.98699951171875,
#    301.3950500488281,
#    403.6195983886719,
#    311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (404.0580139160156,
#    305.13165283203125,
#    408.0260925292969,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['z',
#   'z',
#   'match',
#   '<inline_math>',
#   (408.52801513671875,
#    301.3950500488281,
#    413.1606140136719,
#    311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (413.5990295410156,
#    305.13165283203125,
#    417.5671081542969,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['z',
#   'z',
#   'match',
#   '<inline_math>',
#   (418.0680236816406,
#    301.3950500488281,
#    422.70062255859375,
#    311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (423.1390380859375,
#    305.13165283203125,
#    427.10711669921875,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['such',
#   'such',
#   'match',
#   '<text>',
#   (427.10711669921875,
#    301.3950500488281,
#    449.7683410644531,
#    312.8526611328125)],
#  ['that',
#   'that',
#   'match',
#   '<text>',
#   (449.7683410644531, 301.3950500488281, 469.6758117675781, 311.357666015625)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (469.6758117675781, 301.3950500488281, 476.9854736328125, 311.357666015625)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (476.9939880371094, 301.3950500488281, 482.6826171875, 311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (482.68798828125,
#    305.13165283203125,
#    486.65606689453125,
#    312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (487.156982421875, 301.3950500488281, 489.9166259765625, 311.357666015625)],
#  ['y',
#   'y',
#   'match',
#   '<inline_math>',
#   (489.92657470703125,
#    301.3950500488281,
#    494.8082580566406,
#    311.357666015625)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (495.1669921875, 305.13165283203125, 499.13507080078125, 312.1054382324219)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (499.635986328125, 301.3950500488281, 503.50146484375, 311.357666015625)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (503.50146484375, 301.3950500488281, 522.419189453125, 311.357666015625)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (92.90599822998047, 313.3500671386719, 96.771484375, 323.31268310546875)],
#  ['\\hat{x', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (102.4739990234375,
#    317.086669921875,
#    106.44209289550781,
#    324.0604553222656)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (106.94400024414062,
#    313.3500671386719,
#    109.70364379882812,
#    323.31268310546875)],
#  ['z',
#   'z',
#   'match',
#   '<inline_math>',
#   (109.7136001586914,
#    313.3500671386719,
#    114.34620666503906,
#    323.31268310546875)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (114.78299713134766,
#    317.086669921875,
#    118.75109100341797,
#    324.0604553222656)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (119.25199890136719,
#    313.3500671386719,
#    123.11748504638672,
#    323.31268310546875)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['are',
#   'are',
#   'match',
#   '<text>',
#   (123.11748504638672,
#    313.3500671386719,
#    140.06082153320312,
#    323.31268310546875)],
#  ['respectively',
#   'respectively',
#   'match',
#   '<text>',
#   (140.06082153320312,
#    313.3500671386719,
#    192.12538146972656,
#    323.31268310546875)],
#  ['nondegenerate',
#   'nondegenerate',
#   'match',
#   '<text>',
#   (192.12538146972656,
#    313.3500671386719,
#    257.1811828613281,
#    323.31268310546875)],
#  ['iterative',
#   'iterative',
#   'match',
#   '<text>',
#   (257.1811828613281,
#    313.3500671386719,
#    296.0054931640625,
#    323.31268310546875)],
#  ['pairs',
#   'pairs',
#   'match',
#   '<text>',
#   (296.0054931640625,
#    313.3500671386719,
#    320.5732727050781,
#    323.31268310546875)],
#  ['of',
#   'of',
#   'match',
#   '<text>',
#   (320.5732727050781,
#    313.3500671386719,
#    332.289306640625,
#    323.31268310546875)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (332.289306640625,
#    313.3500671386719,
#    341.53265380859375,
#    323.31268310546875)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['y ',
#   'y',
#   'match',
#   '<inline_math>',
#   (344.3329772949219,
#    313.3500671386719,
#    349.21466064453125,
#    323.31268310546875)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (349.21466064453125,
#    313.3500671386719,
#    368.9197082519531,
#    323.31268310546875)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (368.9197082519531,
#    313.3500671386719,
#    378.1766357421875,
#    323.31268310546875)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['z ',
#   'z',
#   'match',
#   '<inline_math>',
#   (380.97698974609375,
#    313.3500671386719,
#    385.6095886230469,
#    323.31268310546875)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['for',
#   'for',
#   'match',
#   '<text>',
#   (385.6095886230469,
#    313.3500671386719,
#    401.9566345214844,
#    323.31268310546875)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['L ',
#   'L',
#   'match',
#   '<inline_math>',
#   (401.9566345214844,
#    313.3500671386719,
#    412.2995300292969,
#    323.31268310546875)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['.\n\n',
#   '.',
#   'match',
#   '<text>',
#   (412.2995300292969,
#    313.3500671386719,
#    418.91851806640625,
#    323.31268310546875)],
#  ['There',
#   'There',
#   'match',
#   '<text>',
#   (89.08240509033203,
#    328.14007568359375,
#    119.15949249267578,
#    338.1026916503906)],
#  ['exists',
#   'exists',
#   'match',
#   '<text>',
#   (119.15949249267578,
#    328.14007568359375,
#    146.43710327148438,
#    338.1026916503906)],
#  ['a',
#   'a',
#   'match',
#   '<text>',
#   (146.43710327148438,
#    328.14007568359375,
#    155.0946044921875,
#    338.1026916503906)],
#  ['string',
#   'string',
#   'match',
#   '<text>',
#   (155.0946044921875,
#    328.14007568359375,
#    183.48802185058594,
#    338.1026916503906)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (183.48802185058594,
#    328.14007568359375,
#    192.73757934570312,
#    338.1026916503906)],
#  ['\\in',
#   '\\in',
#   'match',
#   '<inline_math>',
#   (192.74197387695312,
#    327.8910217285156,
#    199.37705993652344,
#    345.1761169433594)],
#  ['\\{', '', 'invisable', '<inline_math>', None],
#  ['y',
#   'y',
#   'match',
#   '<inline_math>',
#   (204.36497497558594,
#    328.14007568359375,
#    209.24664306640625,
#    338.1026916503906)],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (209.6053009033203,
#    328.14007568359375,
#    212.3649444580078,
#    338.1026916503906)],
#  ['z',
#   'z',
#   'match',
#   '<inline_math>',
#   (212.37490844726562,
#    328.14007568359375,
#    217.0075225830078,
#    338.1026916503906)],
#  ['\\}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['such',
#   'such',
#   'match',
#   '<text>',
#   (222.42726135253906,
#    328.14007568359375,
#    245.09027099609375,
#    338.1026916503906)],
#  ['that',
#   'that',
#   'match',
#   '<text>',
#   (245.09027099609375,
#    328.14007568359375,
#    265.4538269042969,
#    338.1026916503906)],
#  ['one',
#   'one',
#   'match',
#   '<text>',
#   (265.4538269042969,
#    328.14007568359375,
#    284.2930908203125,
#    338.1026916503906)],
#  ['of',
#   'of',
#   'match',
#   '<text>',
#   (284.2930908203125,
#    328.14007568359375,
#    295.9891662597656,
#    338.1026916503906)],
#  ['the',
#   'the',
#   'match',
#   '<text>',
#   (295.9891662597656,
#    328.14007568359375,
#    312.5470275878906,
#    338.1026916503906)],
#  ['following',
#   'following',
#   'match',
#   '<text>',
#   (312.5470275878906,
#    328.14007568359375,
#    354.8183288574219,
#    338.1026916503906)],
#  ['cases',
#   'cases',
#   'match',
#   '<text>',
#   (354.8183288574219,
#    328.14007568359375,
#    380.27276611328125,
#    338.1026916503906)],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (380.27276611328125,
#    328.14007568359375,
#    387.90411376953125,
#    338.1026916503906)],
#  ['a',
#   'a',
#   'match',
#   '<text>',
#   (387.9140930175781,
#    328.14007568359375,
#    393.0049743652344,
#    338.1026916503906)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (393.0049743652344,
#    328.14007568359375,
#    397.0697021484375,
#    338.1026916503906)],
#  ['-',
#   '-',
#   'match',
#   '<text>',
#   (397.0796813964844,
#    328.14007568359375,
#    400.6363220214844,
#    338.1026916503906)],
#  ['-',
#   '-',
#   'match',
#   '<text>',
#   (400.64630126953125,
#    328.14007568359375,
#    404.20294189453125,
#    338.1026916503906)],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (404.2129211425781,
#    328.14007568359375,
#    408.27764892578125,
#    338.1026916503906)],
#  ['c',
#   'c',
#   'match',
#   '<text>',
#   (408.2876281738281,
#    328.14007568359375,
#    412.87042236328125,
#    338.1026916503906)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (412.87042236328125,
#    328.14007568359375,
#    416.9351501464844,
#    338.1026916503906)],
#  ['occurs',
#   'occurs',
#   'match',
#   '<text>',
#   (416.9351501464844,
#    328.14007568359375,
#    447.37091064453125,
#    338.1026916503906)],
#  ['.',
#   '.',
#   'match',
#   '<text>',
#   (447.3808898925781,
#    328.14007568359375,
#    450.429443359375,
#    338.1026916503906)],
#  ['010,130,105(',
#   '010,130,105(',
#   'match',
#   '<text>',
#   (115.1240005493164, 343.2380676269531, 171.3477783203125, 353.20068359375)],
#  ['a',
#   'a',
#   'match',
#   '<text>',
#   (171.3577880859375, 343.2380676269531, 176.4690399169922, 353.20068359375)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (176.4690399169922, 343.2380676269531, 180.55003356933594, 353.20068359375)],
#  [']',
#   ']',
#   'match',
#   '<text>',
#   (180.56004333496094,
#    343.2380676269531,
#    183.62078857421875,
#    353.20068359375)],
#  ['There',
#   'There',
#   'match',
#   '<text>',
#   (183.62078857421875,
#    343.2380676269531,
#    212.38783264160156,
#    353.20068359375)],
#  ['are',
#   'are',
#   'match',
#   '<text>',
#   (212.38783264160156,
#    343.2380676269531,
#    229.38198852539062,
#    353.20068359375)],
#  ['two',
#   'two',
#   'match',
#   '<text>',
#   (229.38198852539062, 343.2380676269531, 248.0265655517578, 353.20068359375)],
#  ['factorizations',
#   'factorizations',
#   'match',
#   '<text>',
#   (248.0265655517578, 343.2380676269531, 310.5118713378906, 353.20068359375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (310.5118713378906, 343.2380676269531, 319.7706298828125, 353.20068359375)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (322.5710144042969, 343.2380676269531, 330.31195068359375, 353.20068359375)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (330.32000732421875, 343.2380676269531, 336.0086669921875, 353.20068359375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (336.0140075683594,
#    346.97467041015625,
#    339.9820861816406,
#    353.9484558105469)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (340.4830017089844, 343.2380676269531, 346.171630859375, 353.20068359375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (346.177001953125,
#    346.97467041015625,
#    350.14508056640625,
#    353.9484558105469)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (350.14508056640625,
#    343.2380676269531,
#    370.05987548828125,
#    354.6956787109375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (370.05987548828125, 343.2380676269531, 379.3326110839844, 353.20068359375)],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (379.3370056152344, 343.2380676269531, 387.07794189453125, 353.20068359375)],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (387.08599853515625,
#    343.2380676269531,
#    392.78460693359375,
#    353.20068359375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (392.78900146484375,
#    346.97467041015625,
#    396.757080078125,
#    353.9484558105469)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (397.25799560546875,
#    343.2380676269531,
#    402.95660400390625,
#    353.20068359375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (402.9620056152344,
#    346.97467041015625,
#    406.9300842285156,
#    353.9484558105469)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (407.4309997558594, 343.2380676269531, 413.1296081542969, 353.20068359375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (413.1340026855469,
#    346.97467041015625,
#    417.1020812988281,
#    353.9484558105469)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (417.60400390625, 343.2380676269531, 423.3026123046875, 353.20068359375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['4',
#   '4',
#   'match',
#   '<inline_math>',
#   (423.3070068359375,
#    346.97467041015625,
#    427.27508544921875,
#    353.9484558105469)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['with',
#   'with',
#   'match',
#   '<text>',
#   (427.27508544921875,
#    343.2380676269531,
#    449.49041748046875,
#    354.6956787109375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['|',
#   '|',
#   'match',
#   '<inline_math>',
#   (449.49041748046875,
#    342.989013671875,
#    455.8236389160156,
#    360.27410888671875)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (455.8320007324219, 343.2380676269531, 461.5206298828125, 353.20068359375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (461.5260009765625,
#    346.97467041015625,
#    465.49407958984375,
#    353.9484558105469)],
#  ['}|', '', 'invisable', '<inline_math>', None],
#  ['}|',
#   '|',
#   'match',
#   '<inline_math>',
#   (465.9949951171875, 342.989013671875, 468.754638671875, 360.27410888671875)],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (468.76300048828125,
#    343.2380676269531,
#    471.52264404296875,
#    353.20068359375)],
#  ['|',
#   '|',
#   'match',
#   '<inline_math>',
#   (471.5299987792969,
#    342.989013671875,
#    474.2896423339844,
#    360.27410888671875)],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (474.2969970703125, 343.2380676269531, 479.99560546875, 353.20068359375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (480.0010070800781,
#    346.97467041015625,
#    483.9690856933594,
#    353.9484558105469)],
#  ['}|', '', 'invisable', '<inline_math>', None],
#  ['}|',
#   '|',
#   'match',
#   '<inline_math>',
#   (484.4700012207031,
#    342.989013671875,
#    487.2296447753906,
#    360.27410888671875)],
#  ['\\geq ',
#   '\\geq',
#   'match',
#   '<inline_math>',
#   (487.2395935058594,
#    342.989013671875,
#    494.98052978515625,
#    360.27410888671875)],
#  ['1 ',
#   '1',
#   'match',
#   '<inline_math>',
#   (494.9859924316406, 343.2380676269531, 499.96728515625, 353.20068359375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['such',
#   'such',
#   'match',
#   '<text>',
#   (499.96728515625, 343.2380676269531, 522.7117309570312, 353.20068359375)],
#  ['that',
#   'that',
#   'match',
#   '<text>',
#   (115.22599792480469,
#    355.1940612792969,
#    132.02294921875,
#    365.15667724609375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (132.02294921875,
#    355.1940612792969,
#    139.45948791503906,
#    365.15667724609375)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (139.46798706054688,
#    355.1940612792969,
#    145.15663146972656,
#    365.15667724609375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (145.1619873046875,
#    358.9296569824219,
#    149.1300811767578,
#    365.9034423828125)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (149.6309814453125, 355.1940612792969, 155.32958984375, 365.15667724609375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (155.33497619628906,
#    358.9296569824219,
#    159.30307006835938,
#    365.9034423828125)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (159.80397033691406,
#    355.1940612792969,
#    162.56361389160156,
#    365.15667724609375)],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (162.57357788085938,
#    355.1940612792969,
#    168.27218627929688,
#    365.15667724609375)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (168.27496337890625,
#    358.9296569824219,
#    172.24305725097656,
#    365.9034423828125)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (172.74395751953125,
#    355.1940612792969,
#    176.6094512939453,
#    365.15667724609375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['is',
#   'is',
#   'match',
#   '<text>',
#   (176.6094512939453,
#    355.1940612792969,
#    187.30621337890625,
#    365.15667724609375)],
#  ['a',
#   'a',
#   'match',
#   '<text>',
#   (187.30621337890625,
#    355.1940612792969,
#    195.97366333007812,
#    365.15667724609375)],
#  ['nondegenerate',
#   'nondegenerate',
#   'match',
#   '<text>',
#   (195.97366333007812,
#    355.1940612792969,
#    261.009521484375,
#    365.15667724609375)],
#  ['iterative',
#   'iterative',
#   'match',
#   '<text>',
#   (261.009521484375,
#    355.1940612792969,
#    299.8437805175781,
#    365.15667724609375)],
#  ['pair',
#   'pair',
#   'match',
#   '<text>',
#   (299.8437805175781,
#    355.1940612792969,
#    320.33685302734375,
#    365.15667724609375)],
#  ['of',
#   'of',
#   'match',
#   '<text>',
#   (320.33685302734375,
#    355.1940612792969,
#    332.04290771484375,
#    365.15667724609375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (332.04290771484375,
#    355.1940612792969,
#    341.3035888671875,
#    365.15667724609375)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['u ',
#   'u',
#   'match',
#   '<inline_math>',
#   (344.1039733886719,
#    355.1940612792969,
#    349.8025817871094,
#    365.15667724609375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['for',
#   'for',
#   'match',
#   '<text>',
#   (349.8025817871094,
#    355.1940612792969,
#    365.71563720703125,
#    365.15667724609375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['L ',
#   'L',
#   'match',
#   '<inline_math>',
#   (365.71563720703125,
#    355.1940612792969,
#    376.05853271484375,
#    365.15667724609375)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['.',
#   '.',
#   'match',
#   '<text>',
#   (376.05853271484375,
#    355.1940612792969,
#    382.6775207519531,
#    365.15667724609375)],
#  ['010,135,130(',
#   '010,135,130(',
#   'match',
#   '<text>',
#   (115.1240005493164,
#    369.9830627441406,
#    171.51577758789062,
#    379.9456787109375)],
#  ['b',
#   'b',
#   'match',
#   '<text>',
#   (171.5258026123047,
#    369.9830627441406,
#    176.1406707763672,
#    379.9456787109375)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (176.1406707763672,
#    369.9830627441406,
#    180.23387145996094,
#    379.9456787109375)],
#  [']',
#   ']',
#   'match',
#   '<text>',
#   (180.243896484375, 369.9830627441406, 183.3137969970703, 379.9456787109375)],
#  ['There',
#   'There',
#   'match',
#   '<text>',
#   (183.3137969970703,
#    369.9830627441406,
#    212.13668823242188,
#    379.9456787109375)],
#  ['are',
#   'are',
#   'match',
#   '<text>',
#   (212.13668823242188,
#    369.9830627441406,
#    229.16156005859375,
#    379.9456787109375)],
#  ['two',
#   'two',
#   'match',
#   '<text>',
#   (229.16156005859375,
#    369.9830627441406,
#    247.8317413330078,
#    379.9456787109375)],
#  ['factorizations',
#   'factorizations',
#   'match',
#   '<text>',
#   (247.8317413330078,
#    369.9830627441406,
#    310.47369384765625,
#    379.9456787109375)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (310.47369384765625,
#    369.9830627441406,
#    319.71563720703125,
# ...
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (398.052978515625, 480.4140625, 403.74163818359375, 490.3766784667969)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['7',
#   '7',
#   'match',
#   '<inline_math>',
#   (403.7459716796875,
#    484.1506652832031,
#    407.71405029296875,
#    491.12445068359375)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (407.71405029296875, 480.4140625, 428.75640869140625, 491.8716735839844)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (428.75640869140625, 480.4140625, 438.9026184082031, 490.3766784667969)],
#  ['=',
#   '=',
#   'match',
#   '<inline_math>',
#   (438.9070129394531, 480.4140625, 446.64794921875, 490.3766784667969)],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (446.656005859375, 480.4140625, 452.3546142578125, 490.3766784667969)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['1',
#   '1',
#   'match',
#   '<inline_math>',
#   (452.3590087890625,
#    484.1506652832031,
#    456.32708740234375,
#    491.12445068359375)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (456.8290100097656, 480.4140625, 462.5276184082031, 490.3766784667969)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (462.5320129394531,
#    484.1506652832031,
#    466.5000915527344,
#    491.12445068359375)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (467.0010070800781, 480.4140625, 472.6996154785156, 490.3766784667969)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['3',
#   '3',
#   'match',
#   '<inline_math>',
#   (472.70501708984375,
#    484.1506652832031,
#    476.673095703125,
#    491.12445068359375)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['such',
#   'such',
#   'match',
#   '<text>',
#   (476.673095703125, 480.4140625, 501.0982666015625, 491.8716735839844)],
#  ['that',
#   'that',
#   'match',
#   '<text>',
#   (501.0982666015625, 480.4140625, 522.671875, 490.3766784667969)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (114.8239974975586,
#    492.37005615234375,
#    118.68948364257812,
#    502.3326721191406)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (118.697998046875,
#    492.37005615234375,
#    124.38664245605469,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['5',
#   '5',
#   'match',
#   '<inline_math>',
#   (124.39199829101562,
#    496.10565185546875,
#    128.36009216308594,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (128.86199951171875,
#    492.37005615234375,
#    134.55064392089844,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['6',
#   '6',
#   'match',
#   '<inline_math>',
#   (134.55599975585938,
#    496.10565185546875,
#    138.5240936279297,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (139.02499389648438,
#    492.37005615234375,
#    141.78463745117188,
#    502.3326721191406)],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (141.7946014404297,
#    492.37005615234375,
#    147.4932098388672,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (147.49598693847656,
#    496.10565185546875,
#    151.46408081054688,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (151.96498107910156,
#    492.37005615234375,
#    155.83047485351562,
#    502.3326721191406)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (155.83047485351562,
#    492.37005615234375,
#    174.65414428710938,
#    502.3326721191406)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (174.65414428710938,
#    492.37005615234375,
#    181.8734893798828,
#    502.3326721191406)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (181.88198852539062,
#    492.37005615234375,
#    187.5706329345703,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (187.57598876953125,
#    496.10565185546875,
#    191.54408264160156,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (192.04498291015625,
#    492.37005615234375,
#    194.80462646484375,
#    502.3326721191406)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (194.81459045410156,
#    492.37005615234375,
#    200.50323486328125,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['4',
#   '4',
#   'match',
#   '<inline_math>',
#   (200.50698852539062,
#    496.10565185546875,
#    204.47508239746094,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (204.97598266601562,
#    492.37005615234375,
#    210.6646270751953,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['5',
#   '5',
#   'match',
#   '<inline_math>',
#   (210.66998291015625,
#    496.10565185546875,
#    214.63807678222656,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (215.13897705078125,
#    492.37005615234375,
#    219.0044708251953,
#    502.3326721191406)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (219.0044708251953,
#    492.37005615234375,
#    226.34645080566406,
#    502.3326721191406)],
#  ['or',
#   'or',
#   'match',
#   '<text>',
#   (226.35621643066406,
#    492.37005615234375,
#    235.45565795898438,
#    502.3326721191406)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (235.45565795898438,
#    492.37005615234375,
#    242.67649841308594,
#    502.3326721191406)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (242.68600463867188,
#    492.37005615234375,
#    248.37464904785156,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['6',
#   '6',
#   'match',
#   '<inline_math>',
#   (248.3800048828125,
#    496.10565185546875,
#    252.3480987548828,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (252.8489990234375,
#    492.37005615234375,
#    255.608642578125,
#    502.3326721191406)],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (255.6186065673828,
#    492.37005615234375,
#    261.31719970703125,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (261.32000732421875, 496.10565185546875, 265.2880859375, 503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (265.78900146484375,
#    492.37005615234375,
#    269.65447998046875,
#    502.3326721191406)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (269.65447998046875,
#    492.37005615234375,
#    288.4781494140625,
#    502.3326721191406)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (288.4781494140625,
#    492.37005615234375,
#    295.6974792480469,
#    502.3326721191406)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (295.70599365234375,
#    492.37005615234375,
#    301.3946533203125,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['2',
#   '2',
#   'match',
#   '<inline_math>',
#   (301.3999938964844,
#    496.10565185546875,
#    305.3680725097656,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [',',
#   ',',
#   'match',
#   '<inline_math>',
#   (305.8689880371094,
#    492.37005615234375,
#    308.6286315917969,
#    502.3326721191406)],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (308.6385803222656,
#    492.37005615234375,
#    314.32720947265625,
#    502.3326721191406)],
#  ['_{', '', 'invisable', '<inline_math>', None],
#  ['4',
#   '4',
#   'match',
#   '<inline_math>',
#   (314.33099365234375,
#    496.10565185546875,
#    318.299072265625,
#    503.0794372558594)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  [') ',
#   ')',
#   'match',
#   '<inline_math>',
#   (318.79998779296875,
#    492.37005615234375,
#    322.66546630859375,
#    502.3326721191406)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (322.66546630859375,
#    492.37005615234375,
#    330.0074462890625,
#    502.3326721191406)],
#  ['are',
#   'are',
#   'match',
#   '<text>',
#   (330.0074462890625,
#    492.37005615234375,
#    346.45867919921875,
#    502.3326721191406)],
#  ['respectively',
#   'respectively',
#   'match',
#   '<text>',
#   (346.45867919921875,
#    492.37005615234375,
#    397.3062438964844,
#    502.3326721191406)],
#  ['nondegenerate',
#   'nondegenerate',
#   'match',
#   '<text>',
#   (397.3062438964844,
#    492.37005615234375,
#    460.8949890136719,
#    502.3326721191406)],
#  ['iterative',
#   'iterative',
#   'match',
#   '<text>',
#   (460.8949890136719,
#    492.37005615234375,
#    498.79632568359375,
#    502.3326721191406)],
#  ['pairs',
#   'pairs',
#   'match',
#   '<text>',
#   (498.79632568359375,
#    492.37005615234375,
#    522.716552734375,
#    502.3326721191406)],
#  ['of',
#   'of',
#   'match',
#   '<text>',
#   (115.19499969482422,
#    504.3250732421875,
#    123.33444213867188,
#    514.2876586914062)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (123.33444213867188,
#    504.3250732421875,
#    132.59564208984375,
#    514.2876586914062)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['u ',
#   'u',
#   'match',
#   '<inline_math>',
#   (135.39599609375, 504.3250732421875, 141.0946044921875, 514.2876586914062)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['and',
#   'and',
#   'match',
#   '<text>',
#   (141.0946044921875,
#    504.3250732421875,
#    160.44374084472656,
#    514.2876586914062)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['x',
#   'x',
#   'match',
#   '<inline_math>',
#   (160.44374084472656,
#    504.3250732421875,
#    169.70164489746094,
#    514.2876586914062)],
#  ['{', '', 'invisable', '<inline_math>', None],
#  ['^{\\prime}}', '', 'invisable', '<inline_math>', None],
#  ['u',
#   'u',
#   'match',
#   '<inline_math>',
#   (172.5019989013672,
#    504.3250732421875,
#    178.2006072998047,
#    514.2876586914062)],
#  ['^{', '', 'invisable', '<inline_math>', None],
#  ['(',
#   '(',
#   'match',
#   '<inline_math>',
#   (178.2050018310547, 502.95068359375, 181.31532287597656, 509.9244689941406)],
#  ['op',
#   'op',
#   'match',
#   '<inline_math>',
#   (181.31800842285156,
#    502.95068359375,
#    189.35183715820312,
#    509.9244689941406)],
#  [')',
#   ')',
#   'match',
#   '<inline_math>',
#   (189.35800170898438,
#    502.95068359375,
#    192.46832275390625,
#    509.9244689941406)],
#  ['}', '', 'invisable', '<inline_math>', None],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['for',
#   'for',
#   'match',
#   '<text>',
#   (196.53399658203125,
#    504.3250732421875,
#    208.87767028808594,
#    514.2876586914062)],
#  ['\\(', '', 'invisable', '<inline_math>', None],
#  ['L ',
#   'L',
#   'match',
#   '<inline_math>',
#   (208.87767028808594,
#    504.3250732421875,
#    219.22056579589844,
#    514.2876586914062)],
#  ['\\)', '', 'invisable', '<inline_math>', None],
#  ['.\n\n',
#   '.',
#   'match',
#   '<text>',
#   (219.22056579589844,
#    504.3250732421875,
#    225.8395538330078,
#    514.2876586914062)],
#  ['The',
#   'The',
#   'match',
#   '<text>',
#   (68.80699920654297,
#    526.2431030273438,
#    86.30571746826172,
#    536.2056884765625)],
#  ['proof',
#   'proof',
#   'match',
#   '<text>',
#   (86.30571746826172,
#    526.2431030273438,
#    113.8951416015625,
#    536.2056884765625)],
#  ['of',
#   'of',
#   'match',
#   '<text>',
#   (113.8951416015625,
#    526.2431030273438,
#    126.49583435058594,
#    536.2056884765625)],
#  ['Lemma',
#   'Lemma',
#   'match',
#   '<text>',
#   (126.49583435058594,
#    526.2431030273438,
#    163.7898406982422,
#    536.2056884765625)],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (163.7898406982422,
#    526.2431030273438,
#    172.15304565429688,
#    536.2056884765625)],
#  ['1',
#   '1',
#   'match',
#   '<text>',
#   (172.1632080078125, 526.2431030273438, 177.244140625, 536.2056884765625)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (177.244140625, 526.2431030273438, 181.1869354248047, 536.2056884765625)],
#  ['will',
#   'will',
#   'match',
#   '<text>',
#   (181.1869354248047,
#    526.2431030273438,
#    201.40902709960938,
#    536.2056884765625)],
#  ['be',
#   'be',
#   'match',
#   '<text>',
#   (201.40902709960938,
#    526.2431030273438,
#    216.27581787109375,
#    536.2056884765625)],
#  ['given',
#   'given',
#   'match',
#   '<text>',
#   (216.27581787109375,
#    526.2431030273438,
#    243.83477783203125,
#    536.2056884765625)],
#  ['in',
#   'in',
#   'match',
#   '<text>',
#   (243.83477783203125,
#    526.2431030273438,
#    256.73016357421875,
#    536.2056884765625)],
#  ['Section',
#   'Section',
#   'match',
#   '<text>',
#   (256.73016357421875,
#    526.2431030273438,
#    293.3230285644531,
#    536.2056884765625)],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (293.3230285644531,
#    526.2431030273438,
#    301.6862487792969,
#    536.2056884765625)],
#  ['9',
#   '9',
#   'match',
#   '<text>',
#   (301.6964111328125, 526.2431030273438, 306.77734375, 536.2056884765625)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (306.77734375, 526.2431030273438, 310.72015380859375, 536.2056884765625)],
#  ['.',
#   '.',
#   'match',
#   '<text>',
#   (310.7303161621094,
#    526.2431030273438,
#    313.5451354980469,
#    536.2056884765625)],
#  ['For',
#   'For',
#   'match',
#   '<text>',
#   (313.5451354980469,
#    526.2431030273438,
#    336.1247863769531,
#    536.2056884765625)],
#  ['the',
#   'the',
#   'match',
#   '<text>',
#   (336.1247863769531,
#    526.2431030273438,
#    354.6701965332031,
#    536.2056884765625)],
#  ['proof',
#   'proof',
#   'match',
#   '<text>',
#   (354.6701965332031, 526.2431030273438, 382.24951171875, 536.2056884765625)],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (382.2596740722656,
#    526.2431030273438,
#    385.0744934082031,
#    536.2056884765625)],
#  ['we',
#   'we',
#   'match',
#   '<text>',
#   (385.0744934082031,
#    526.2431030273438,
#    401.3435974121094,
#    536.2056884765625)],
#  ['need',
#   'need',
#   'match',
#   '<text>',
#   (401.3435974121094,
#    526.2431030273438,
#    426.07757568359375,
#    536.2056884765625)],
#  ['a',
#   'a',
#   'match',
#   '<text>',
#   (426.07757568359375,
#    526.2431030273438,
#    435.57891845703125,
#    536.2056884765625)],
#  ['technical',
#   'technical',
#   'match',
#   '<text>',
#   (435.57891845703125,
#    526.2431030273438,
#    479.2240905761719,
#    536.2056884765625)],
#  ['assertion',
#   'assertion',
#   'match',
#   '<text>',
#   (479.2240905761719,
#    526.2431030273438,
#    522.7372436523438,
#    536.2056884765625)],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (68.0, 538.1981201171875, 71.88095092773438, 548.1607055664062)],
#  ['Proposition',
#   'Proposition',
#   'match',
#   '<text>',
#   (71.89095306396484, 538.1981201171875, 122.413330078125, 548.1607055664062)],
#  ['(',
#   '(',
#   'match',
#   '<text>',
#   (122.413330078125,
#    538.1981201171875,
#    129.62509155273438,
#    548.1607055664062)],
#  ['13',
#   '13',
#   'match',
#   '<text>',
#   (129.63510131835938,
#    538.1981201171875,
#    139.63754272460938,
#    548.1607055664062)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (139.63754272460938,
#    538.1981201171875,
#    143.51849365234375,
#    548.1607055664062)],
#  [')',
#   ')',
#   'match',
#   '<text>',
#   (143.52850341796875,
#    538.1981201171875,
#    147.40945434570312,
#    548.1607055664062)],
#  [',',
#   ',',
#   'match',
#   '<text>',
#   (147.41946411132812,
#    538.1981201171875,
#    150.1901397705078,
#    548.1607055664062)],
#  ['which',
#   'which',
#   'match',
#   '<text>',
#   (150.1901397705078,
#    538.1981201171875,
#    178.80715942382812,
#    548.1607055664062)],
#  ['links',
#   'links',
#   'match',
#   '<text>',
#   (178.80715942382812,
#    538.1981201171875,
#    202.4829559326172,
#    548.1607055664062)],
#  ['a',
#   'a',
#   'match',
#   '<text>',
#   (202.4829559326172,
#    538.1981201171875,
#    210.80499267578125,
#    548.1607055664062)],
#  ...]

# %%
import pandas as pd
df = pd.DataFrame(pretext_and_prompts, columns=['markdown','pdf','status','text_type','bbox'])

# %%
df.iloc[680:690]
# Out:
#     markdown pdf     status      text_type  \
# 680       \{      invisable  <inline_math>
# 681        a   a      match  <inline_math>
# 682       _{      invisable  <inline_math>
# 683        n   n      match  <inline_math>
# 684       _{      invisable  <inline_math>
# 685        1   1      match  <inline_math>
# 686        1   1      match  <inline_math>
# 687      }^{      invisable  <inline_math>
# 688        a   a      match  <inline_math>
# 689       _{      invisable  <inline_math>
#
#                                                   bbox
# 680                                       (-1, -1, -1)
# 681  (292.8959655761719, 553.5670776367188, 298.156...
# 682                                       (-1, -1, -1)
# 683  (298.1619567871094, 551.380615234375, 303.0854...
# 684                                       (-1, -1, -1)
# 685  (303.0869445800781, 553.8720703125, 306.474243...
# 686  (298.1619567871094, 558.4656982421875, 302.130...
# 687                                       (-1, -1, -1)
# 688  (307.47296142578125, 553.5670776367188, 312.73...
# 689                                       (-1, -1, -1)

# %%
df[(df['markdown'].str.strip()!=df['pdf'].str.strip()) & (df['text_type']=='<inline_math>')]
# Out:
#            markdown   pdf     status      text_type  \
# 61               \(        invisable  <inline_math>
# 67               \)        invisable  <inline_math>
# 78               \(        invisable  <inline_math>
# 80               \)        invisable  <inline_math>
# 87               \(        invisable  <inline_math>
# ...             ...   ...        ...            ...
# 1179             \(        invisable  <inline_math>
# 1180  \mathrm{DCFL}  DCFL      match  <inline_math>
# 1181             \)        invisable  <inline_math>
# 1189             \(        invisable  <inline_math>
# 1191             \)        invisable  <inline_math>
#
#                                                    bbox
# 61                                         (-1, -1, -1)
# 67                                         (-1, -1, -1)
# 78                                         (-1, -1, -1)
# 80                                         (-1, -1, -1)
# 87                                         (-1, -1, -1)
# ...                                                 ...
# 1179                                       (-1, -1, -1)
# 1180  (203.0467987060547, 742.008056640625, 233.8996...
# 1181                                       (-1, -1, -1)
# 1189                                       (-1, -1, -1)
# 1191                                       (-1, -1, -1)
#
# [199 rows x 5 columns]

# %%
sequence1=sequence_mmd
sequence2=sequence_pdf

# %%
sequence1[670:690]
# Out:
# [((5, 55, 150.1), '_{', '<inline_math>'),
#  ((5, 55, 155), 'd', '<inline_math>'),
#  ((5, 55, 155.1), '}', '<inline_math>'),
#  ((5, 55, 160), '=', '<inline_math>'),
#  ((5, 55, 160.1), '\\{', '<inline_math>'),
#  ((5, 55, 170), 'a', '<inline_math>'),
#  ((5, 55, 170.1), '_{', '<inline_math>'),
#  ((5, 55, 175), '1', '<inline_math>'),
#  ((5, 55, 180), 'n', '<inline_math>'),
#  ((5, 55, 185), '1', '<inline_math>'),
#  ((5, 55, 185.1), '}}', '<inline_math>'),
#  ((5, 55, 190), 'a', '<inline_math>'),
#  ((5, 55, 190.1), '_{', '<inline_math>'),
#  ((5, 55, 195), '2', '<inline_math>'),
#  ((5, 55, 195.1), '}^{', '<inline_math>'),
#  ((5, 55, 200), 'n', '<inline_math>'),
#  ((5, 55, 200.1), '_{', '<inline_math>'),
#  ((5, 55, 205), '2', '<inline_math>'),
#  ((5, 55, 205.1), '}}\\cdots', '<inline_math>'),
#  ((5, 55, 210), 'a', '<inline_math>')]

# %%
for tag, i1,i2,j1,j2 in true_match:
    if sequence1[i1][-1] != '<inline_math>':continue
    print('{:7}   seq1[{}:{}] --> {}'.format(tag, i1, i2, sequence1[i1:i2]))
    print('          seq2[{}:{}] --> {}\n'.format(j1, j2, sequence2[j1:j2]))
# Out:
# delete    seq1[61:62] --> [((5, 5, 25.1), '\\(', '<inline_math>')]
#           seq2[60:60] --> []
#
# aligned   seq1[62:63] --> [((5, 5, 30), '(', '<inline_math>')]
#           seq2[60:61] --> [((5, 5, 30), '(', (176.9597625732422, 161.9031982421875, 184.02659606933594, 170.86959838867188))]
#
# aligned   seq1[63:64] --> [((5, 5, 35), 'd', '<inline_math>')]
#           seq2[61:62] --> [((5, 5, 35), 'd', (184.0330047607422, 161.9031982421875, 188.80313110351562, 170.86959838867188))]
#
# aligned   seq1[64:65] --> [((5, 5, 40), ' +', '<inline_math>')]
#           seq2[62:63] --> [((5, 5, 40), '+', (188.80799865722656, 161.9031982421875, 195.97215270996094, 170.86959838867188))]
#
# aligned   seq1[65:66] --> [((5, 5, 45), '1', '<inline_math>')]
#           seq2[63:64] --> [((5, 5, 45), '1', (195.97215270996094, 161.9031982421875, 200.57191467285156, 170.86959838867188))]
#
# aligned   seq1[66:67] --> [((5, 5, 50), ')', '<inline_math>')]
#           seq2[64:65] --> [((5, 5, 50), ')', (200.5808868408203, 161.9031982421875, 204.15847778320312, 170.86959838867188))]
#
# delete    seq1[67:68] --> [((5, 5, 50.1), '\\)', '<inline_math>')]
#           seq2[65:65] --> []
#
# delete    seq1[78:79] --> [((5, 5, 100.1), '\\(', '<inline_math>')]
#           seq2[75:75] --> []
#
# aligned   seq1[79:80] --> [((5, 5, 105), 'd', '<inline_math>')]
#           seq2[75:76] --> [((5, 5, 105), 'd', (473.7677917480469, 161.9031982421875, 482.01910400390625, 170.86959838867188))]
#
# delete    seq1[80:81] --> [((5, 5, 105.1), '\\)', '<inline_math>')]
#           seq2[76:76] --> []
#
# delete    seq1[87:88] --> [((5, 5, 135.1), '\\(', '<inline_math>')]
#           seq2[82:82] --> []
#
# aligned   seq1[88:89] --> [((5, 5, 140), 'd', '<inline_math>')]
#           seq2[82:83] --> [((5, 5, 140), 'd', (227.815673828125, 172.86224365234375, 235.6561279296875, 181.82864379882812))]
#
# delete    seq1[89:90] --> [((5, 5, 140.1), '\\)', '<inline_math>')]
#           seq2[83:83] --> []
#
# delete    seq1[155:156] --> [((5, 10, 200.1), '\\(', '<inline_math>')]
#           seq2[148:148] --> []
#
# aligned   seq1[156:157] --> [((5, 10, 205), 'd', '<inline_math>')]
#           seq2[148:149] --> [((5, 10, 205), 'd', (346.6403503417969, 205.73822021484375, 355.2961120605469, 214.70462036132812))]
#
# delete    seq1[157:158] --> [((5, 10, 205.1), '\\)', '<inline_math>')]
#           seq2[149:149] --> []
#
# delete    seq1[361:364] --> [((5, 30, 175.1), '\\(', '<inline_math>'), ((5, 30, 175.2), '\\mathrm{CFL}', '<inline_math>'), ((5, 30, 175.29999999999998), '\\)', '<inline_math>')]
#           seq2[351:351] --> []
#
# delete    seq1[372:375] --> [((5, 30, 215.1), '\\(', '<inline_math>'), ((5, 30, 215.2), '\\mathrm{REG}', '<inline_math>'), ((5, 30, 215.29999999999998), '\\)', '<inline_math>')]
#           seq2[360:360] --> []
#
# delete    seq1[413:416] --> [((5, 35, 150.1), '\\(', '<inline_math>'), ((5, 35, 150.2), '\\mathrm{CFL}', '<inline_math>'), ((5, 35, 150.29999999999998), '\\)', '<inline_math>')]
#           seq2[399:399] --> []
#
# delete    seq1[429:432] --> [((5, 35, 215.1), '\\(', '<inline_math>'), ((5, 35, 215.2), '\\mathrm{CFL}', '<inline_math>'), ((5, 35, 215.29999999999998), '\\)', '<inline_math>')]
#           seq2[413:413] --> []
#
# delete    seq1[453:454] --> [((5, 40, 65.1), '\\(', '<inline_math>')]
#           seq2[435:435] --> []
#
# aligned   seq1[454:455] --> [((5, 40, 70), 'L', '<inline_math>')]
#           seq2[435:436] --> [((5, 40, 70), 'L', (264.6824035644531, 481.8360595703125, 274.7735595703125, 491.7986755371094))]
#
# delete    seq1[455:456] --> [((5, 40, 70.1), '_{', '<inline_math>')]
#           seq2[436:436] --> []
#
# aligned   seq1[456:457] --> [((5, 40, 75), 'abc', '<inline_math>')]
#           seq2[436:437] --> [((5, 40, 75), 'abc', (274.77899169921875, 485.5716552734375, 286.1602478027344, 492.5454406738281))]
#
# delete    seq1[457:458] --> [((5, 40, 75.1), '}', '<inline_math>')]
#           seq2[437:437] --> []
#
# aligned   seq1[458:459] --> [((5, 40, 80), ' =', '<inline_math>')]
#           seq2[437:438] --> [((5, 40, 80), '=', (286.6629943847656, 481.8360595703125, 294.4039306640625, 491.7986755371094))]
#
# delete    seq1[459:460] --> [((5, 40, 80.1), '\\{', '<inline_math>')]
#           seq2[438:438] --> []
#
# aligned   seq1[460:461] --> [((5, 40, 90), 'a', '<inline_math>')]
#           seq2[438:439] --> [((5, 40, 90), 'a', (299.3929748535156, 481.8360595703125, 304.6532287597656, 491.7986755371094))]
#
# delete    seq1[461:462] --> [((5, 40, 90.1), '^{', '<inline_math>')]
#           seq2[439:439] --> []
#
# aligned   seq1[462:463] --> [((5, 40, 95), ' n', '<inline_math>')]
#           seq2[439:440] --> [((5, 40, 95), 'n', (304.6589660644531, 480.4626770019531, 309.58245849609375, 487.43646240234375))]
#
# aligned   seq1[463:464] --> [((5, 40, 100), 'b', '<inline_math>')]
#           seq2[440:441] --> [((5, 40, 100), 'b', (310.08197021484375, 481.8360595703125, 314.3559265136719, 491.7986755371094))]
#
# aligned   seq1[464:465] --> [((5, 40, 105), 'n', '<inline_math>')]
#           seq2[441:442] --> [((5, 40, 105), 'n', (314.35797119140625, 480.4626770019531, 319.2814636230469, 487.43646240234375))]
#
# delete    seq1[465:466] --> [((5, 40, 105.1), '}', '<inline_math>')]
#           seq2[442:442] --> []
#
# aligned   seq1[466:467] --> [((5, 40, 110), ' c', '<inline_math>')]
#           seq2[442:443] --> [((5, 40, 110), 'c', (319.7809753417969, 481.8360595703125, 324.0848083496094, 491.7986755371094))]
#
# aligned   seq1[467:468] --> [((5, 40, 115), 'n', '<inline_math>')]
#           seq2[443:444] --> [((5, 40, 115), 'n', (324.09197998046875, 480.4626770019531, 329.0154724121094, 487.43646240234375))]
#
# delete    seq1[468:469] --> [((5, 40, 120), ' \\mid', '<inline_math>')]
#           seq2[444:444] --> []
#
# insert    seq1[469:469] --> []
#           seq2[444:445] --> [((5, 40, 120), '|', (329.5149841308594, 481.5870056152344, 332.2746276855469, 498.8721008300781))]
#
# aligned   seq1[469:470] --> [((5, 40, 125), 'n', '<inline_math>')]
#           seq2[445:446] --> [((5, 40, 125), 'n', (332.2829895019531, 481.8360595703125, 338.26055908203125, 491.7986755371094))]
#
# aligned   seq1[470:471] --> [((5, 40, 130), '\\geq', '<inline_math>')]
#           seq2[446:447] --> [((5, 40, 130), '\\geq', (338.2619934082031, 481.5870056152344, 346.0029296875, 498.8721008300781))]
#
# aligned   seq1[471:472] --> [((5, 40, 135), ' 0', '<inline_math>')]
#           seq2[447:448] --> [((5, 40, 135), '0', (346.010986328125, 481.8360595703125, 350.9922790527344, 491.7986755371094))]
#
# delete    seq1[472:474] --> [((5, 40, 135.1), '\\}', '<inline_math>'), ((5, 40, 135.2), '\\)', '<inline_math>')]
#           seq2[448:448] --> []
#
# delete    seq1[493:494] --> [((5, 40, 235.1), '\\(', '<inline_math>')]
#           seq2[467:467] --> []
#
# aligned   seq1[494:495] --> [((5, 40, 240), 'A', '<inline_math>')]
#           seq2[467:468] --> [((5, 40, 240), 'A', (319.35089111328125, 493.7910461425781, 329.6279602050781, 503.753662109375))]
#
# delete    seq1[495:496] --> [((5, 40, 240.1), '_{', '<inline_math>')]
#           seq2[468:468] --> []
#
# aligned   seq1[496:497] --> [((5, 40, 245), '1', '<inline_math>')]
#           seq2[468:469] --> [((5, 40, 245), '1', (329.62799072265625, 497.52764892578125, 333.5960693359375, 504.5014343261719))]
#
# delete    seq1[497:498] --> [((5, 40, 245.1), '}', '<inline_math>')]
#           seq2[469:469] --> []
#
# aligned   seq1[498:499] --> [((5, 40, 250), ' =', '<inline_math>')]
#           seq2[469:470] --> [((5, 40, 250), '=', (334.09698486328125, 493.7910461425781, 341.8379211425781, 503.753662109375))]
#
# aligned   seq1[499:500] --> [((5, 45, 5), 'a', '<inline_math>')]
#           seq2[470:471] --> [((5, 45, 5), 'a', (346.82696533203125, 493.7910461425781, 352.08721923828125, 503.753662109375))]
#
# aligned   seq1[500:501] --> [((5, 45, 10), 'n', '<inline_math>')]
#           seq2[471:472] --> [((5, 45, 10), 'n', (352.09295654296875, 492.41766357421875, 357.0164489746094, 499.3914489746094))]
#
# delete    seq1[501:502] --> [((5, 45, 10.1), '}', '<inline_math>')]
#           seq2[472:472] --> []
#
# aligned   seq1[502:503] --> [((5, 45, 15), 'b', '<inline_math>')]
#           seq2[472:473] --> [((5, 45, 15), 'b', (357.5159606933594, 493.7910461425781, 361.7899169921875, 503.753662109375))]
#
# delete    seq1[503:504] --> [((5, 45, 15.1), '^{', '<inline_math>')]
#           seq2[473:473] --> []
#
# aligned   seq1[504:505] --> [((5, 45, 20), 'n', '<inline_math>')]
#           seq2[473:474] --> [((5, 45, 20), 'n', (361.7919616699219, 492.41766357421875, 366.7154541015625, 499.3914489746094))]
#
# delete    seq1[505:506] --> [((5, 45, 20.1), '}', '<inline_math>')]
#           seq2[474:474] --> []
#
# aligned   seq1[506:507] --> [((5, 45, 25), 'c', '<inline_math>')]
#           seq2[474:475] --> [((5, 45, 25), 'c', (367.2149658203125, 493.7910461425781, 371.518798828125, 503.753662109375))]
#
# delete    seq1[507:508] --> [((5, 45, 25.1), '^{', '<inline_math>')]
#           seq2[475:475] --> []
#
# aligned   seq1[508:509] --> [((5, 45, 30), 'p', '<inline_math>')]
#           seq2[475:476] --> [((5, 45, 30), 'p', (371.5259704589844, 492.41766357421875, 375.6265563964844, 499.3914489746094))]
#
# delete    seq1[509:511] --> [((5, 45, 30.1), '}', '<inline_math>'), ((5, 45, 35), '\\mid', '<inline_math>')]
#           seq2[476:476] --> []
#
# insert    seq1[511:511] --> []
#           seq2[476:477] --> [((5, 45, 35), '|', (376.1309814453125, 493.5419921875, 378.890625, 510.82708740234375))]
#
# aligned   seq1[511:512] --> [((5, 45, 40), 'n', '<inline_math>')]
#           seq2[477:478] --> [((5, 45, 40), 'n', (378.89898681640625, 493.7910461425781, 384.8765563964844, 503.753662109375))]
#
# aligned   seq1[512:513] --> [((5, 45, 45), ' ,', '<inline_math>')]
#           seq2[478:479] --> [((5, 45, 45), ',', (384.8765563964844, 493.7910461425781, 387.6361999511719, 503.753662109375))]
#
# aligned   seq1[513:514] --> [((5, 45, 50), 'p', '<inline_math>')]
#           seq2[479:480] --> [((5, 45, 50), 'p', (387.6461486816406, 493.7910461425781, 392.6573486328125, 503.753662109375))]
#
# aligned   seq1[514:515] --> [((5, 45, 55), '\\geq', '<inline_math>')]
#           seq2[480:481] --> [((5, 45, 55), '\\geq', (392.65899658203125, 493.5419921875, 400.3999328613281, 510.82708740234375))]
#
# aligned   seq1[515:516] --> [((5, 45, 60), '0', '<inline_math>')]
#           seq2[481:482] --> [((5, 45, 60), '0', (400.406982421875, 493.7910461425781, 405.3882751464844, 503.753662109375))]
#
# delete    seq1[516:518] --> [((5, 45, 60.1), '\\}', '<inline_math>'), ((5, 45, 60.2), '\\)', '<inline_math>')]
#           seq2[482:482] --> []
#
# delete    seq1[519:520] --> [((5, 45, 70.1), '\\(', '<inline_math>')]
#           seq2[483:483] --> []
#
# aligned   seq1[520:521] --> [((5, 45, 75), 'A', '<inline_math>')]
#           seq2[483:484] --> [((5, 45, 75), 'A', (428.9097900390625, 493.7910461425781, 439.1939392089844, 503.753662109375))]
#
# delete    seq1[521:522] --> [((5, 45, 75.1), '_{', '<inline_math>')]
#           seq2[484:484] --> []
#
# aligned   seq1[522:523] --> [((5, 45, 80), '2', '<inline_math>')]
#           seq2[484:485] --> [((5, 45, 80), '2', (439.1939697265625, 497.52764892578125, 443.16204833984375, 504.5014343261719))]
#
# delete    seq1[523:524] --> [((5, 45, 80.1), '}', '<inline_math>')]
#           seq2[485:485] --> []
#
# aligned   seq1[524:525] --> [((5, 45, 85), ' =', '<inline_math>')]
#           seq2[485:486] --> [((5, 45, 85), '=', (443.6629638671875, 493.7910461425781, 451.4039001464844, 503.753662109375))]
#
# delete    seq1[525:526] --> [((5, 45, 85.1), '\\{ ', '<inline_math>')]
#           seq2[486:486] --> []
#
# aligned   seq1[526:527] --> [((5, 45, 95), 'a', '<inline_math>')]
#           seq2[486:487] --> [((5, 45, 95), 'a', (456.3929443359375, 493.7910461425781, 461.6531982421875, 503.753662109375))]
#
# delete    seq1[527:528] --> [((5, 45, 95.1), '^{', '<inline_math>')]
#           seq2[487:487] --> []
#
# aligned   seq1[528:529] --> [((5, 45, 100), 'n', '<inline_math>')]
#           seq2[487:488] --> [((5, 45, 100), 'n', (461.658935546875, 492.41766357421875, 466.5824279785156, 499.3914489746094))]
#
# delete    seq1[529:530] --> [((5, 45, 100.1), '}', '<inline_math>')]
#           seq2[488:488] --> []
#
# aligned   seq1[530:531] --> [((5, 45, 105), 'b', '<inline_math>')]
#           seq2[488:489] --> [((5, 45, 105), 'b', (467.0819396972656, 493.7910461425781, 471.35589599609375, 503.753662109375))]
#
# delete    seq1[531:532] --> [((5, 45, 105.1), '^{', '<inline_math>')]
#           seq2[489:489] --> []
#
# aligned   seq1[532:533] --> [((5, 45, 110), 'p', '<inline_math>')]
#           seq2[489:490] --> [((5, 45, 110), 'p', (471.3579406738281, 492.41766357421875, 475.4585266113281, 499.3914489746094))]
#
# delete    seq1[533:534] --> [((5, 45, 110.1), '}', '<inline_math>')]
#           seq2[490:490] --> []
#
# aligned   seq1[534:535] --> [((5, 45, 115), 'c', '<inline_math>')]
#           seq2[490:491] --> [((5, 45, 115), 'c', (475.96295166015625, 493.7910461425781, 480.26678466796875, 503.753662109375))]
#
# delete    seq1[535:536] --> [((5, 45, 115.1), '^{', '<inline_math>')]
#           seq2[491:491] --> []
#
# aligned   seq1[536:537] --> [((5, 45, 120), 'p', '<inline_math>')]
#           seq2[491:492] --> [((5, 45, 120), 'p', (480.2739562988281, 492.41766357421875, 484.3745422363281, 499.3914489746094))]
#
# delete    seq1[537:539] --> [((5, 45, 120.1), '}', '<inline_math>'), ((5, 45, 125), ' \\mid', '<inline_math>')]
#           seq2[492:492] --> []
#
# insert    seq1[539:539] --> []
#           seq2[492:493] --> [((5, 45, 125), '|', (484.87994384765625, 493.5419921875, 487.63958740234375, 510.82708740234375))]
#
# aligned   seq1[539:540] --> [((5, 45, 130), 'n', '<inline_math>')]
#           seq2[493:494] --> [((5, 45, 130), 'n', (487.6469421386719, 493.7910461425781, 493.62451171875, 503.753662109375))]
#
# aligned   seq1[540:541] --> [((5, 45, 135), ',', '<inline_math>')]
#           seq2[494:495] --> [((5, 45, 135), ',', (493.62451171875, 493.7910461425781, 496.3841552734375, 503.753662109375))]
#
# aligned   seq1[541:542] --> [((5, 45, 140), ' p', '<inline_math>')]
#           seq2[495:496] --> [((5, 45, 140), 'p', (496.39410400390625, 493.7910461425781, 501.4053039550781, 503.753662109375))]
#
# aligned   seq1[542:543] --> [((5, 45, 145), '\\geq', '<inline_math>')]
#           seq2[496:497] --> [((5, 45, 145), '\\geq', (501.4069519042969, 493.5419921875, 509.14788818359375, 510.82708740234375))]
#
# aligned   seq1[543:544] --> [((5, 45, 150), '0', '<inline_math>')]
#           seq2[497:498] --> [((5, 45, 150), '0', (509.15594482421875, 493.7910461425781, 514.1372680664062, 503.753662109375))]
#
# delete    seq1[544:546] --> [((5, 45, 150.1), '\\}', '<inline_math>'), ((5, 45, 150.2), '\\)', '<inline_math>')]
#           seq2[498:498] --> []
#
# delete    seq1[560:561] --> [((5, 45, 225.1), '\\(', '<inline_math>')]
#           seq2[512:512] --> []
#
# aligned   seq1[561:562] --> [((5, 45, 230), 'd', '<inline_math>')]
#           seq2[512:513] --> [((5, 45, 230), 'd', (386.3503112792969, 505.7460632324219, 394.60552978515625, 515.7086791992188))]
#
# delete    seq1[562:563] --> [((5, 45, 230.1), '\\)', '<inline_math>')]
#           seq2[513:513] --> []
#
# delete    seq1[564:565] --> [((5, 45, 235.1), '\\(', '<inline_math>')]
#           seq2[514:514] --> []
#
# aligned   seq1[565:566] --> [((5, 45, 240), '\\geq', '<inline_math>')]
#           seq2[514:515] --> [((5, 45, 240), '\\geq', (401.503173828125, 505.49700927734375, 412.3579406738281, 522.7821044921875))]
#
# aligned   seq1[566:567] --> [((5, 45, 245), '1', '<inline_math>')]
#           seq2[515:516] --> [((5, 45, 245), '1', (412.364990234375, 505.7460632324219, 417.3462829589844, 515.7086791992188))]
#
# delete    seq1[567:568] --> [((5, 45, 245.1), '\\)', '<inline_math>')]
#           seq2[516:516] --> []
#
# delete    seq1[582:583] --> [((5, 50, 60.1), '\\(', '<inline_math>')]
#           seq2[530:530] --> []
#
# equal     seq1[583:584] --> [((5, 50, 60.2), '\\mathrm{CFL}', '<inline_math>')]
#           seq2[530:531] --> [((0, 0, 0), 'CFL', (281.181884765625, 517.7020874023438, 305.0242004394531, 527.6646728515625))]
#
# aligned   seq1[584:585] --> [((5, 50, 65), '(', '<inline_math>')]
#           seq2[531:532] --> [((5, 50, 65), '(', (305.0242004394531, 517.7020874023438, 308.8896789550781, 527.6646728515625))]
#
# aligned   seq1[585:586] --> [((5, 50, 70), 'd', '<inline_math>')]
#           seq2[532:533] --> [((5, 50, 70), 'd', (308.89898681640625, 517.7020874023438, 314.07952880859375, 527.6646728515625))]
#
# aligned   seq1[586:587] --> [((5, 50, 75), ' )', '<inline_math>')]
#           seq2[533:534] --> [((5, 50, 75), ')', (314.083984375, 517.7020874023438, 317.949462890625, 527.6646728515625))]
#
# delete    seq1[587:588] --> [((5, 50, 75.1), '\\)', '<inline_math>')]
#           seq2[534:534] --> []
#
# delete    seq1[601:602] --> [((5, 50, 140.1), '\\(', '<inline_math>')]
#           seq2[547:547] --> []
#
# aligned   seq1[602:603] --> [((5, 50, 145), 'd', '<inline_math>')]
#           seq2[547:548] --> [((5, 50, 145), 'd', (153.93516540527344, 529.6571044921875, 162.55955505371094, 539.6196899414062))]
#
# delete    seq1[603:604] --> [((5, 50, 145.1), '\\)', '<inline_math>')]
#           seq2[548:548] --> []
#
# delete    seq1[607:610] --> [((5, 50, 160.1), '\\(', '<inline_math>'), ((5, 50, 160.2), '\\mathrm{CFL}', '<inline_math>'), ((5, 50, 160.29999999999998), '\\)', '<inline_math>')]
#           seq2[551:551] --> []
#
# delete    seq1[640:641] --> [((5, 55, 45.1), '\\(', '<inline_math>')]
#           seq2[582:582] --> []
#
# aligned   seq1[641:642] --> [((5, 55, 50), 'L', '<inline_math>')]
#           seq2[582:583] --> [((5, 55, 50), 'L', (301.5275573730469, 541.612060546875, 311.60858154296875, 551.5746459960938))]
#
# delete    seq1[642:643] --> [((5, 55, 50.1), '_{', '<inline_math>')]
#           seq2[583:583] --> []
#
# aligned   seq1[643:644] --> [((5, 55, 55), 'abc', '<inline_math>')]
#           seq2[583:584] --> [((5, 55, 55), 'abc', (311.614013671875, 545.34765625, 322.9952697753906, 552.3214721679688))]
#
# delete    seq1[644:646] --> [((5, 55, 55.1), '}', '<inline_math>'), ((5, 55, 55.2), '\\)', '<inline_math>')]
#           seq2[584:584] --> []
#
# delete    seq1[650:651] --> [((5, 55, 75.1), '\\(', '<inline_math>')]
#           seq2[588:588] --> []
#
# equal     seq1[651:652] --> [((5, 55, 75.19999999999999), '\\mathrm{CFL}', '<inline_math>')]
#           seq2[588:589] --> [((0, 0, 0), 'CFL', (431.4178771972656, 541.612060546875, 454.66619873046875, 551.5746459960938))]
#
# aligned   seq1[652:653] --> [((5, 55, 80), '(', '<inline_math>')]
#           seq2[589:590] --> [((5, 55, 80), '(', (454.66619873046875, 541.612060546875, 458.53167724609375, 551.5746459960938))]
#
# aligned   seq1[653:654] --> [((5, 55, 85), '2', '<inline_math>')]
#           seq2[590:591] --> [((5, 55, 85), '2', (458.5416564941406, 541.612060546875, 463.52294921875, 551.5746459960938))]
#
# aligned   seq1[654:655] --> [((5, 55, 90), ')', '<inline_math>')]
#           seq2[591:592] --> [((5, 55, 90), ')', (463.52294921875, 541.612060546875, 467.388427734375, 551.5746459960938))]
#
# aligned   seq1[655:656] --> [((5, 55, 95), '-', '<inline_math>')]
#           seq2[592:593] --> [((5, 55, 95), '-', (467.3970031738281, 541.3629760742188, 475.137939453125, 558.6480712890625))]
#
# equal     seq1[656:657] --> [((5, 55, 95.1), '\\mathrm{CFL}', '<inline_math>')]
#           seq2[593:594] --> [((0, 0, 0), 'CFL', (475.1449890136719, 541.612060546875, 495.0701904296875, 551.5746459960938))]
#
# delete    seq1[657:658] --> [((5, 55, 95.19999999999999), '\\)', '<inline_math>')]
#           seq2[594:594] --> []
#
# delete    seq1[668:669] --> [((5, 55, 145.1), '\\(', '<inline_math>')]
#           seq2[604:604] --> []
#
# aligned   seq1[669:670] --> [((5, 55, 150), 'L', '<inline_math>')]
#           seq2[604:605] --> [((5, 55, 150), 'L', (265.1973571777344, 553.5670776367188, 275.5145568847656, 563.5296630859375))]
#
# delete    seq1[670:671] --> [((5, 55, 150.1), '_{', '<inline_math>')]
#           seq2[605:605] --> []
#
# aligned   seq1[671:672] --> [((5, 55, 155), 'd', '<inline_math>')]
#           seq2[605:606] --> [((5, 55, 155), 'd', (275.52099609375, 557.3026123046875, 279.6634216308594, 564.2764282226562))]
#
# delete    seq1[672:673] --> [((5, 55, 155.1), '}', '<inline_math>')]
#           seq2[606:606] --> []
#
# aligned   seq1[673:674] --> [((5, 55, 160), '=', '<inline_math>')]
#           seq2[606:607] --> [((5, 55, 160), '=', (280.1659851074219, 553.5670776367188, 287.90692138671875, 563.5296630859375))]
#
# delete    seq1[674:675] --> [((5, 55, 160.1), '\\{', '<inline_math>')]
#           seq2[607:607] --> []
#
# aligned   seq1[675:676] --> [((5, 55, 170), 'a', '<inline_math>')]
#           seq2[607:608] --> [((5, 55, 170), 'a', (292.8959655761719, 553.5670776367188, 298.1562194824219, 563.5296630859375))]
#
# delete    seq1[676:677] --> [((5, 55, 170.1), '_{', '<inline_math>')]
#           seq2[608:608] --> []
#
# aligned   seq1[678:679] --> [((5, 55, 180), 'n', '<inline_math>')]
#           seq2[608:609] --> [((5, 55, 180), 'n', (298.1619567871094, 551.380615234375, 303.08544921875, 558.3544311523438))]
#
# aligned   seq1[679:680] --> [((5, 55, 185), '1', '<inline_math>')]
#           seq2[609:610] --> [((5, 55, 185), '1', (303.0869445800781, 553.8720703125, 306.4742431640625, 558.8533325195312))]
#
# aligned   seq1[677:678] --> [((5, 55, 175), '1', '<inline_math>')]
#           seq2[610:611] --> [((5, 55, 175), '1', (298.1619567871094, 558.4656982421875, 302.1300354003906, 565.4395141601562))]
#
# aligned   seq1[681:682] --> [((5, 55, 190), 'a', '<inline_math>')]
#           seq2[611:612] --> [((5, 55, 190), 'a', (307.47296142578125, 553.5670776367188, 312.73321533203125, 563.5296630859375))]
#
# delete    seq1[682:683] --> [((5, 55, 190.1), '_{', '<inline_math>')]
#           seq2[612:612] --> []
#
# aligned   seq1[685:686] --> [((5, 55, 200), 'n', '<inline_math>')]
#           seq2[612:613] --> [((5, 55, 200), 'n', (312.7399597167969, 551.380615234375, 317.6634521484375, 558.3544311523438))]
#
# delete    seq1[686:687] --> [((5, 55, 200.1), '_{', '<inline_math>')]
#           seq2[613:613] --> []
#
# aligned   seq1[687:688] --> [((5, 55, 205), '2', '<inline_math>')]
#           seq2[613:614] --> [((5, 55, 205), '2', (317.6639709472656, 553.8720703125, 321.05126953125, 558.8533325195312))]
#
# aligned   seq1[683:684] --> [((5, 55, 195), '2', '<inline_math>')]
#           seq2[614:615] --> [((5, 55, 195), '2', (312.7399597167969, 558.4656982421875, 316.7080383300781, 565.4395141601562))]
#
# delete    seq1[684:685] --> [((5, 55, 195.1), '}^{', '<inline_math>')]
#           seq2[615:615] --> []
#
# insert    seq1[685:685] --> []
#           seq2[615:616] --> [((0, 0, 0), '\\cdots', (323.7109680175781, 553.3179931640625, 335.32733154296875, 570.6030883789062))]
#
# aligned   seq1[689:690] --> [((5, 55, 210), 'a', '<inline_math>')]
#           seq2[616:617] --> [((5, 55, 210), 'a', (335.32733154296875, 553.5670776367188, 342.2552185058594, 563.5296630859375))]
#
# delete    seq1[690:691] --> [((5, 55, 210.1), '_{', '<inline_math>')]
#           seq2[617:617] --> []
#
# aligned   seq1[693:694] --> [((5, 55, 220), 'n', '<inline_math>')]
#           seq2[617:618] --> [((5, 55, 220), 'n', (342.2609558105469, 551.3196411132812, 347.1844482421875, 558.29345703125))]
#
# delete    seq1[694:695] --> [((5, 55, 220.1), '_{', '<inline_math>')]
#           seq2[618:618] --> []
#
# aligned   seq1[695:696] --> [((5, 55, 225), 'd', '<inline_math>')]
#           seq2[618:619] --> [((5, 55, 225), 'd', (347.1859436035156, 553.8720703125, 350.86712646484375, 558.8533325195312))]
#
# aligned   seq1[691:692] --> [((5, 55, 215), 'd', '<inline_math>')]
#           seq2[619:620] --> [((5, 55, 215), 'd', (342.2609558105469, 558.8136596679688, 346.40338134765625, 565.7874755859375))]
#
# delete    seq1[692:693] --> [((5, 55, 215.1), '}^{', '<inline_math>')]
#           seq2[620:620] --> []
#
# aligned   seq1[697:698] --> [((5, 55, 230), 'b', '<inline_math>')]
#           seq2[620:621] --> [((5, 55, 230), 'b', (351.866943359375, 553.5670776367188, 356.1408996582031, 563.5296630859375))]
#
# delete    seq1[698:699] --> [((5, 55, 230.1), '_{', '<inline_math>')]
#           seq2[621:621] --> []
#
# aligned   seq1[701:702] --> [((5, 55, 240), 'n', '<inline_math>')]
#           seq2[621:622] --> [((5, 55, 240), 'n', (356.1419372558594, 551.380615234375, 361.0654296875, 558.3544311523438))]
#
# delete    seq1[702:703] --> [((5, 55, 240.1), '_{', '<inline_math>')]
#           seq2[622:622] --> []
#
# aligned   seq1[703:704] --> [((5, 55, 245), '1', '<inline_math>')]
#           seq2[622:623] --> [((5, 55, 245), '1', (361.0669250488281, 553.8720703125, 364.4542236328125, 558.8533325195312))]
#
# aligned   seq1[699:700] --> [((5, 55, 235), '1', '<inline_math>')]
#           seq2[623:624] --> [((5, 55, 235), '1', (356.1419372558594, 558.4656982421875, 360.1100158691406, 565.4395141601562))]
#
# delete    seq1[700:701] --> [((5, 55, 235.1), '}^{', '<inline_math>')]
#           seq2[624:624] --> []
#
# aligned   seq1[705:706] --> [((5, 55, 250), 'b', '<inline_math>')]
#           seq2[624:625] --> [((5, 55, 250), 'b', (365.4539489746094, 553.5670776367188, 369.7279052734375, 563.5296630859375))]
#
# delete    seq1[706:707] --> [((5, 55, 250.1), '_{', '<inline_math>')]
#           seq2[625:625] --> []
#
# aligned   seq1[709:710] --> [((5, 60, 5), 'n', '<inline_math>')]
#           seq2[625:626] --> [((5, 60, 5), 'n', (369.72894287109375, 551.380615234375, 374.6524353027344, 558.3544311523438))]
#
# delete    seq1[710:711] --> [((5, 60, 5.1), '_{', '<inline_math>')]
#           seq2[626:626] --> []
#
# aligned   seq1[711:712] --> [((5, 60, 10), ' 2', '<inline_math>')]
#           seq2[626:627] --> [((5, 60, 10), '2', (374.6539306640625, 553.8720703125, 378.0412292480469, 558.8533325195312))]
#
# aligned   seq1[707:708] --> [((5, 60, 0), ' 2', '<inline_math>')]
#           seq2[627:628] --> [((5, 60, 0), '2', (369.72894287109375, 558.4656982421875, 373.697021484375, 565.4395141601562))]
#
# delete    seq1[708:709] --> [((5, 60, 0.1), '}^{', '<inline_math>')]
#           seq2[628:628] --> []
#
# insert    seq1[709:709] --> []
#           seq2[628:629] --> [((0, 0, 0), '\\cdots', (380.700927734375, 553.3179931640625, 392.3172912597656, 570.6030883789062))]
#
# aligned   seq1[713:714] --> [((5, 60, 15), 'b', '<inline_math>')]
#           seq2[629:630] --> [((5, 60, 15), 'b', (392.3172912597656, 553.5670776367188, 398.25787353515625, 563.5296630859375))]
#
# delete    seq1[714:715] --> [((5, 60, 15.1), '_{', '<inline_math>')]
#           seq2[630:630] --> []
#
# aligned   seq1[717:718] --> [((5, 60, 25), ' n', '<inline_math>')]
#           seq2[630:631] --> [((5, 60, 25), 'n', (398.2599182128906, 551.3196411132812, 403.18341064453125, 558.29345703125))]
#
# aligned   seq1[718:719] --> [((5, 60, 30), 'd', '<inline_math>')]
#           seq2[631:632] --> [((5, 60, 30), 'd', (403.1849060058594, 553.8720703125, 406.8660888671875, 558.8533325195312))]
#
# aligned   seq1[715:716] --> [((5, 60, 20), 'd', '<inline_math>')]
#           seq2[632:633] --> [((5, 60, 20), 'd', (398.2599182128906, 558.8136596679688, 402.40234375, 565.7874755859375))]
#
# delete    seq1[716:717] --> [((5, 60, 20.1), '}^{', '<inline_math>')]
#           seq2[633:633] --> []
#
# insert    seq1[717:717] --> []
#           seq2[633:634] --> [((5, 60, 35), '|', (407.86590576171875, 553.3179931640625, 410.62554931640625, 570.6030883789062))]
#
# aligned   seq1[720:721] --> [((5, 60, 40), ' n', '<inline_math>')]
#           seq2[634:635] --> [((5, 60, 40), 'n', (410.6329040527344, 553.5670776367188, 416.6104736328125, 563.5296630859375))]
#
# aligned   seq1[721:722] --> [((5, 60, 45), '1', '<inline_math>')]
#           seq2[635:636] --> [((5, 60, 45), '1', (416.6129150390625, 557.3026123046875, 420.58099365234375, 564.2764282226562))]
#
# aligned   seq1[722:723] --> [((5, 60, 50), ',', '<inline_math>')]
#           seq2[636:637] --> [((5, 60, 50), ',', (421.0819091796875, 553.5670776367188, 423.841552734375, 563.5296630859375))]
#
# aligned   seq1[723:724] --> [((5, 60, 55), ' n', '<inline_math>')]
#           seq2[637:638] --> [((5, 60, 55), 'n', (423.85150146484375, 553.5670776367188, 429.8290710449219, 563.5296630859375))]
#
# aligned   seq1[724:725] --> [((5, 60, 60), '2', '<inline_math>')]
#           seq2[638:639] --> [((5, 60, 60), '2', (429.82989501953125, 557.3026123046875, 433.7979736328125, 564.2764282226562))]
#
# aligned   seq1[725:726] --> [((5, 60, 65), ',', '<inline_math>')]
#           seq2[639:640] --> [((5, 60, 65), ',', (434.29888916015625, 553.5670776367188, 437.05853271484375, 563.5296630859375))]
#
# delete    seq1[726:727] --> [((5, 60, 65.1), '\\ldots', '<inline_math>')]
#           seq2[640:640] --> []
#
# insert    seq1[727:727] --> []
#           seq2[640:643] --> [((0, 0, 0), '. . .', (437.05853271484375, 553.5670776367188, 450.3486022949219, 563.5296630859375)), ((5, 60, 70), ',', (450.3486022949219, 553.5670776367188, 454.7819519042969, 563.5296630859375)), ((5, 60, 75), 'n', (454.7919006347656, 553.5670776367188, 460.76947021484375, 563.5296630859375))]
#
# aligned   seq1[727:728] --> [((5, 60, 70), ',', '<inline_math>')]
#           seq2[641:642] --> [((5, 60, 70), ',', (450.3486022949219, 553.5670776367188, 454.7819519042969, 563.5296630859375))]
#
# aligned   seq1[728:729] --> [((5, 60, 75), ' n', '<inline_math>')]
#           seq2[642:643] --> [((5, 60, 75), 'n', (454.7919006347656, 553.5670776367188, 460.76947021484375, 563.5296630859375))]
#
# aligned   seq1[729:730] --> [((5, 60, 80), 'd', '<inline_math>')]
#           seq2[643:644] --> [((5, 60, 80), 'd', (460.75787353515625, 557.3026123046875, 464.9002990722656, 564.2764282226562))]
#
# aligned   seq1[730:731] --> [((5, 60, 85), ' \\geq', '<inline_math>')]
#           seq2[644:645] --> [((5, 60, 85), '\\geq', (465.4028625488281, 553.3179931640625, 473.143798828125, 570.6030883789062))]
#
# aligned   seq1[731:732] --> [((5, 60, 90), '0', '<inline_math>')]
#           seq2[645:646] --> [((5, 60, 90), '0', (473.15185546875, 553.5670776367188, 478.1331481933594, 563.5296630859375))]
#
# delete    seq1[732:733] --> [((5, 60, 90.1), '\\)', '<inline_math>')]
#           seq2[646:646] --> []
#
# delete    seq1[736:738] --> [((5, 60, 110.1), '\\(', '<inline_math>'), ((5, 60, 110.19999999999999), '\\{', '<inline_math>')]
#           seq2[649:649] --> []
#
# aligned   seq1[738:739] --> [((5, 60, 120), 'a', '<inline_math>')]
#           seq2[649:650] --> [((5, 60, 120), 'a', (115.53600311279297, 565.5220947265625, 120.79625701904297, 575.4846801757812))]
#
# delete    seq1[739:740] --> [((5, 60, 120.1), '_{', '<inline_math>')]
#           seq2[650:650] --> []
#
# aligned   seq1[740:741] --> [((5, 60, 125), '1', '<inline_math>')]
#           seq2[650:651] --> [((5, 60, 125), '1', (120.8030014038086, 569.2586669921875, 124.7710952758789, 576.2324829101562))]
#
# delete    seq1[741:742] --> [((5, 60, 125.1), '}', '<inline_math>')]
#           seq2[651:651] --> []
#
# aligned   seq1[742:743] --> [((5, 60, 130), ' ,', '<inline_math>')]
#           seq2[651:652] --> [((5, 60, 130), ',', (125.27200317382812, 565.5220947265625, 128.03164672851562, 575.4846801757812))]
#
# aligned   seq1[743:744] --> [((5, 60, 135), 'a', '<inline_math>')]
#           seq2[652:653] --> [((5, 60, 135), 'a', (128.04161071777344, 565.5220947265625, 133.30186462402344, 575.4846801757812))]
#
# aligned   seq1[744:745] --> [((5, 60, 140), '2', '<inline_math>')]
#           seq2[653:654] --> [((5, 60, 140), '2', (133.3050079345703, 569.2586669921875, 137.27310180664062, 576.2324829101562))]
#
# delete    seq1[745:746] --> [((5, 60, 140.1), '}', '<inline_math>')]
#           seq2[654:654] --> []
#
# aligned   seq1[746:747] --> [((5, 60, 145), ' ,', '<inline_math>')]
#           seq2[654:655] --> [((5, 60, 145), ',', (137.77500915527344, 565.5220947265625, 140.53465270996094, 575.4846801757812))]
#
# delete    seq1[747:748] --> [((5, 60, 145.1), ' \\ldots', '<inline_math>')]
#           seq2[655:655] --> []
#
# insert    seq1[748:748] --> []
#           seq2[655:658] --> [((0, 0, 0), '. . .', (140.53465270996094, 565.5220947265625, 153.8247833251953, 575.4846801757812)), ((5, 60, 150), ',', (153.8247833251953, 565.5220947265625, 158.25814819335938, 575.4846801757812)), ((5, 60, 155), 'a', (158.2681121826172, 565.5220947265625, 163.5283660888672, 575.4846801757812))]
#
# aligned   seq1[748:749] --> [((5, 60, 150), ',', '<inline_math>')]
#           seq2[656:657] --> [((5, 60, 150), ',', (153.8247833251953, 565.5220947265625, 158.25814819335938, 575.4846801757812))]
#
# aligned   seq1[749:750] --> [((5, 60, 155), 'a', '<inline_math>')]
#           seq2[657:658] --> [((5, 60, 155), 'a', (158.2681121826172, 565.5220947265625, 163.5283660888672, 575.4846801757812))]
#
# delete    seq1[750:751] --> [((5, 60, 155.1), '_{', '<inline_math>')]
#           seq2[658:658] --> []
#
# aligned   seq1[751:752] --> [((5, 60, 160), ' d', '<inline_math>')]
#           seq2[658:659] --> [((5, 60, 160), 'd', (163.52000427246094, 569.2586669921875, 167.66244506835938, 576.2324829101562))]
#
# aligned   seq1[752:753] --> [((5, 60, 165), ',', '<inline_math>')]
#           seq2[659:660] --> [((5, 60, 165), ',', (168.16500854492188, 565.5220947265625, 170.92465209960938, 575.4846801757812))]
#
# aligned   seq1[753:754] --> [((5, 60, 170), 'b', '<inline_math>')]
#           seq2[660:661] --> [((5, 60, 170), 'b', (170.9346160888672, 565.5220947265625, 175.2085723876953, 575.4846801757812))]
#
# delete    seq1[754:755] --> [((5, 60, 170.1), '_{', '<inline_math>')]
#           seq2[661:661] --> []
#
# aligned   seq1[755:756] --> [((5, 60, 175), ' 1', '<inline_math>')]
#           seq2[661:662] --> [((5, 60, 175), '1', (175.2080078125, 569.2586669921875, 179.1761016845703, 576.2324829101562))]
#
# delete    seq1[756:757] --> [((5, 60, 175.1), '}', '<inline_math>')]
#           seq2[662:662] --> []
#
# aligned   seq1[757:758] --> [((5, 60, 180), ',', '<inline_math>')]
#           seq2[662:663] --> [((5, 60, 180), ',', (179.677001953125, 565.5220947265625, 182.4366455078125, 575.4846801757812))]
#
# aligned   seq1[758:759] --> [((5, 60, 185), ' b', '<inline_math>')]
#           seq2[663:664] --> [((5, 60, 185), 'b', (182.4466094970703, 565.5220947265625, 186.72056579589844, 575.4846801757812))]
#
# aligned   seq1[759:760] --> [((5, 60, 190), '2', '<inline_math>')]
#           seq2[664:665] --> [((5, 60, 190), '2', (186.72000122070312, 569.2586669921875, 190.68809509277344, 576.2324829101562))]
#
# aligned   seq1[760:761] --> [((5, 60, 195), ',', '<inline_math>')]
#           seq2[665:666] --> [((5, 60, 195), ',', (191.19000244140625, 565.5220947265625, 193.94964599609375, 575.4846801757812))]
#
# delete    seq1[761:762] --> [((5, 60, 195.1), '\\ldots', '<inline_math>')]
#           seq2[666:666] --> []
#
# insert    seq1[762:762] --> []
#           seq2[666:669] --> [((0, 0, 0), '. . .', (193.94964599609375, 565.5220947265625, 207.23977661132812, 575.4846801757812)), ((5, 60, 200), ',', (207.23977661132812, 565.5220947265625, 211.6731414794922, 575.4846801757812)), ((5, 60, 205), 'b', (211.68310546875, 565.5220947265625, 215.95706176757812, 575.4846801757812))]
#
# aligned   seq1[762:763] --> [((5, 60, 200), ',', '<inline_math>')]
#           seq2[667:668] --> [((5, 60, 200), ',', (207.23977661132812, 565.5220947265625, 211.6731414794922, 575.4846801757812))]
#
# aligned   seq1[763:764] --> [((5, 60, 205), ' b', '<inline_math>')]
#           seq2[668:669] --> [((5, 60, 205), 'b', (211.68310546875, 565.5220947265625, 215.95706176757812, 575.4846801757812))]
#
# aligned   seq1[764:765] --> [((5, 60, 210), 'd', '<inline_math>')]
#           seq2[669:670] --> [((5, 60, 210), 'd', (215.94400024414062, 569.2586669921875, 220.08644104003906, 576.2324829101562))]
#
# delete    seq1[765:766] --> [((5, 60, 210.1), '\\)', '<inline_math>')]
#           seq2[670:670] --> []
#
# delete    seq1[768:769] --> [((5, 60, 225.1), '\\(', '<inline_math>')]
#           seq2[672:672] --> []
#
# equal     seq1[769:770] --> [((5, 60, 225.2), '\\mathrm{CFL}', '<inline_math>')]
#           seq2[672:673] --> [((0, 0, 0), 'CFL', (266.74627685546875, 565.5220947265625, 289.98321533203125, 575.4846801757812))]
#
# aligned   seq1[770:771] --> [((5, 60, 230), '(', '<inline_math>')]
#           seq2[673:674] --> [((5, 60, 230), '(', (289.98321533203125, 565.5220947265625, 293.84869384765625, 575.4846801757812))]
#
# aligned   seq1[771:772] --> [((5, 60, 235), 'd', '<inline_math>')]
#           seq2[674:675] --> [((5, 60, 235), 'd', (293.8580017089844, 565.5220947265625, 299.0385437011719, 575.4846801757812))]
#
# aligned   seq1[772:773] --> [((5, 60, 240), ' )', '<inline_math>')]
#           seq2[675:676] --> [((5, 60, 240), ')', (299.0429992675781, 565.5220947265625, 302.9084777832031, 575.4846801757812))]
#
# delete    seq1[773:774] --> [((5, 60, 240.1), '\\)', '<inline_math>')]
#           seq2[676:676] --> []
#
# delete    seq1[775:776] --> [((5, 60, 245.1), '\\(', '<inline_math>')]
#           seq2[677:677] --> []
#
# aligned   seq1[776:777] --> [((5, 60, 250), 'L', '<inline_math>')]
#           seq2[677:678] --> [((5, 60, 250), 'L', (339.91229248046875, 565.5220947265625, 350.017578125, 575.4846801757812))]
#
# delete    seq1[777:778] --> [((5, 60, 250.1), '_{', '<inline_math>')]
#           seq2[678:678] --> []
#
# aligned   seq1[778:779] --> [((5, 65, 0), 'd', '<inline_math>')]
#           seq2[678:679] --> [((5, 65, 0), 'd', (350.0240173339844, 569.2586669921875, 354.16644287109375, 576.2324829101562))]
#
# delete    seq1[779:781] --> [((5, 65, 0.1), '}', '<inline_math>'), ((5, 65, 0.2), '\\)', '<inline_math>')]
#           seq2[679:679] --> []
#
# delete    seq1[788:789] --> [((5, 65, 35.1), '\\(', '<inline_math>')]
#           seq2[686:686] --> []
#
# aligned   seq1[789:790] --> [((5, 65, 40), 'd', '<inline_math>')]
#           seq2[686:687] --> [((5, 65, 40), 'd', (69.16500091552734, 577.47705078125, 74.34555053710938, 587.4396362304688))]
#
# delete    seq1[790:791] --> [((5, 65, 40.1), '\\)', '<inline_math>')]
#           seq2[687:687] --> []
#
# delete    seq1[798:800] --> [((5, 65, 75.1), '\\(', '<inline_math>'), ((5, 65, 75.19999999999999), '\\{', '<inline_math>')]
#           seq2[694:694] --> []
#
# aligned   seq1[800:801] --> [((5, 65, 85), 'a', '<inline_math>')]
#           seq2[694:695] --> [((5, 65, 85), 'a', (237.84800720214844, 577.47705078125, 243.10826110839844, 587.4396362304688))]
#
# delete    seq1[801:802] --> [((5, 65, 85.1), '_{', '<inline_math>')]
#           seq2[695:695] --> []
#
# aligned   seq1[804:805] --> [((5, 65, 95), 'n', '<inline_math>')]
#           seq2[695:696] --> [((5, 65, 95), 'n', (243.114013671875, 575.2916259765625, 248.0375213623047, 582.2654418945312))]
#
# delete    seq1[805:806] --> [((5, 65, 95.1), '_{', '<inline_math>')]
#           seq2[696:696] --> []
#
# aligned   seq1[806:807] --> [((5, 65, 100), '1', '<inline_math>')]
#           seq2[696:697] --> [((5, 65, 100), '1', (248.0390167236328, 577.7820434570312, 251.42630004882812, 582.7633056640625))]
#
# aligned   seq1[802:803] --> [((5, 65, 90), '1', '<inline_math>')]
#           seq2[697:698] --> [((5, 65, 90), '1', (243.114013671875, 582.3756713867188, 247.0821075439453, 589.3494873046875))]
#
# delete    seq1[803:804] --> [((5, 65, 90.1), '}^{', '<inline_math>')]
#           seq2[698:698] --> []
#
# aligned   seq1[808:809] --> [((5, 65, 105), 'a', '<inline_math>')]
#           seq2[698:699] --> [((5, 65, 105), 'a', (252.42601013183594, 577.47705078125, 257.6862487792969, 587.4396362304688))]
#
# delete    seq1[809:810] --> [((5, 65, 105.1), '_{', '<inline_math>')]
#           seq2[699:699] --> []
#
# aligned   seq1[812:813] --> [((5, 65, 115), 'n', '<inline_math>')]
#           seq2[699:700] --> [((5, 65, 115), 'n', (257.6920166015625, 575.2916259765625, 262.6155090332031, 582.2654418945312))]
#
# delete    seq1[813:814] --> [((5, 65, 115.1), '_{', '<inline_math>')]
#           seq2[700:700] --> []
#
# aligned   seq1[814:815] --> [((5, 65, 120), '2', '<inline_math>')]
#           seq2[700:701] --> [((5, 65, 120), '2', (262.61700439453125, 577.7820434570312, 266.0043029785156, 582.7633056640625))]
#
# aligned   seq1[810:811] --> [((5, 65, 110), '2', '<inline_math>')]
#           seq2[701:702] --> [((5, 65, 110), '2', (257.6920166015625, 582.3756713867188, 261.66009521484375, 589.3494873046875))]
#
# delete    seq1[811:812] --> [((5, 65, 110.1), '}^{', '<inline_math>')]
#           seq2[702:702] --> []
#
# insert    seq1[812:812] --> []
#           seq2[702:703] --> [((0, 0, 0), '\\cdots', (268.66400146484375, 577.2279663085938, 280.2803649902344, 594.5130615234375))]
#
# aligned   seq1[816:817] --> [((5, 65, 125), 'a', '<inline_math>')]
#           seq2[703:704] --> [((5, 65, 125), 'a', (280.2803649902344, 577.47705078125, 287.2072448730469, 587.4396362304688))]
#
# delete    seq1[817:818] --> [((5, 65, 125.1), '_{', '<inline_math>')]
#           seq2[704:704] --> []
#
# aligned   seq1[820:821] --> [((5, 65, 135), 'n', '<inline_math>')]
#           seq2[704:705] --> [((5, 65, 135), 'n', (287.2129821777344, 575.2306518554688, 292.136474609375, 582.2044677734375))]
#
# delete    seq1[821:822] --> [((5, 65, 135.1), '_{', '<inline_math>')]
#           seq2[705:705] --> []
#
# aligned   seq1[822:823] --> [((5, 65, 140), 'd', '<inline_math>')]
#           seq2[705:706] --> [((5, 65, 140), 'd', (292.1379699707031, 577.7820434570312, 295.81915283203125, 582.7633056640625))]
#
# aligned   seq1[818:819] --> [((5, 65, 130), 'd', '<inline_math>')]
#           seq2[706:707] --> [((5, 65, 130), 'd', (287.2129821777344, 582.7246704101562, 291.35540771484375, 589.698486328125))]
#
# delete    seq1[819:820] --> [((5, 65, 130.1), '}^{', '<inline_math>')]
#           seq2[707:707] --> []
#
# aligned   seq1[824:825] --> [((5, 65, 145), 'b', '<inline_math>')]
#           seq2[707:708] --> [((5, 65, 145), 'b', (296.8189697265625, 577.47705078125, 301.0929260253906, 587.4396362304688))]
#
# delete    seq1[825:826] --> [((5, 65, 145.1), '_{', '<inline_math>')]
#           seq2[708:708] --> []
#
# aligned   seq1[828:829] --> [((5, 65, 155), 'm', '<inline_math>')]
#           seq2[708:709] --> [((5, 65, 155), 'm', (301.094970703125, 575.2916259765625, 308.159423828125, 582.2654418945312))]
#
# delete    seq1[829:830] --> [((5, 65, 155.1), '_{', '<inline_math>')]
#           seq2[709:709] --> []
#
# aligned   seq1[830:831] --> [((5, 65, 160), '1', '<inline_math>')]
#           seq2[709:710] --> [((5, 65, 160), '1', (308.1639709472656, 577.7820434570312, 311.55126953125, 582.7633056640625))]
#
# aligned   seq1[826:827] --> [((5, 65, 150), '1', '<inline_math>')]
#           seq2[710:711] --> [((5, 65, 150), '1', (301.094970703125, 582.3756713867188, 305.06304931640625, 589.3494873046875))]
#
# delete    seq1[827:828] --> [((5, 65, 150.1), '}^{', '<inline_math>')]
#           seq2[711:711] --> []
#
# aligned   seq1[832:833] --> [((5, 65, 165), 'b', '<inline_math>')]
#           seq2[711:712] --> [((5, 65, 165), 'b', (312.55096435546875, 577.47705078125, 316.8249206542969, 587.4396362304688))]
#
# delete    seq1[833:834] --> [((5, 65, 165.1), '_{', '<inline_math>')]
#           seq2[712:712] --> []
#
# aligned   seq1[836:837] --> [((5, 65, 175), 'm', '<inline_math>')]
#           seq2[712:713] --> [((5, 65, 175), 'm', (316.8259582519531, 575.2916259765625, 323.8904113769531, 582.2654418945312))]
#
# delete    seq1[837:838] --> [((5, 65, 175.1), '_{', '<inline_math>')]
#           seq2[713:713] --> []
#
# aligned   seq1[838:839] --> [((5, 65, 180), '2', '<inline_math>')]
#           seq2[713:714] --> [((5, 65, 180), '2', (323.8959655761719, 577.7820434570312, 327.28326416015625, 582.7633056640625))]
#
# aligned   seq1[834:835] --> [((5, 65, 170), '2', '<inline_math>')]
#           seq2[714:715] --> [((5, 65, 170), '2', (316.8259582519531, 582.3756713867188, 320.7940368652344, 589.3494873046875))]
#
# delete    seq1[835:836] --> [((5, 65, 170.1), '}^{', '<inline_math>')]
#           seq2[715:715] --> []
#
# insert    seq1[836:836] --> []
#           seq2[715:716] --> [((0, 0, 0), '\\cdots', (329.9429626464844, 577.2279663085938, 341.559326171875, 594.5130615234375))]
#
# aligned   seq1[840:841] --> [((5, 65, 185), 'a', '<inline_math>')]
#           seq2[716:717] --> [((5, 65, 185), 'a', (341.559326171875, 577.47705078125, 348.4862060546875, 587.4396362304688))]
#
# delete    seq1[841:842] --> [((5, 65, 185.1), '_{', '<inline_math>')]
#           seq2[717:717] --> []
#
# aligned   seq1[844:845] --> [((5, 65, 195), 'm', '<inline_math>')]
#           seq2[717:718] --> [((5, 65, 195), 'm', (348.491943359375, 575.2306518554688, 355.556396484375, 582.2044677734375))]
#
# delete    seq1[845:846] --> [((5, 65, 195.1), '_{', '<inline_math>')]
#           seq2[718:718] --> []
#
# aligned   seq1[846:847] --> [((5, 65, 200), 'd', '<inline_math>')]
#           seq2[718:719] --> [((5, 65, 200), 'd', (355.56195068359375, 577.7820434570312, 359.2431335449219, 582.7633056640625))]
#
# aligned   seq1[842:843] --> [((5, 65, 190), 'd', '<inline_math>')]
#           seq2[719:720] --> [((5, 65, 190), 'd', (348.491943359375, 582.7246704101562, 352.6343688964844, 589.698486328125))]
#
# delete    seq1[843:844] --> [((5, 65, 190.1), '}^{', '<inline_math>')]
#           seq2[720:720] --> []
#
# insert    seq1[844:844] --> []
#           seq2[720:721] --> [((5, 65, 205), '|', (360.2429504394531, 577.2279663085938, 363.0025939941406, 594.5130615234375))]
#
# aligned   seq1[849:850] --> [((5, 65, 210), 'n', '<inline_math>')]
#           seq2[721:722] --> [((5, 65, 210), 'n', (363.00994873046875, 577.47705078125, 368.9875183105469, 587.4396362304688))]
#
# delete    seq1[850:851] --> [((5, 65, 210.1), '_{', '<inline_math>')]
#           seq2[722:722] --> []
#
# aligned   seq1[851:852] --> [((5, 65, 215), 'k', '<inline_math>')]
#           seq2[722:723] --> [((5, 65, 215), 'k', (368.9899597167969, 581.213623046875, 373.2230529785156, 588.1874389648438))]
#
# delete    seq1[852:853] --> [((5, 65, 215.1), '}', '<inline_math>')]
#           seq2[723:723] --> []
#
# aligned   seq1[853:854] --> [((5, 65, 220), '=', '<inline_math>')]
#           seq2[723:724] --> [((5, 65, 220), '=', (373.8919677734375, 577.47705078125, 381.6329040527344, 587.4396362304688))]
#
# aligned   seq1[854:855] --> [((5, 65, 225), 'm', '<inline_math>')]
#           seq2[724:725] --> [((5, 65, 225), 'm', (381.6409606933594, 577.47705078125, 390.38812255859375, 587.4396362304688))]
#
# aligned   seq1[855:856] --> [((5, 65, 230), 'k', '<inline_math>')]
#           seq2[725:726] --> [((5, 65, 230), 'k', (390.3879699707031, 581.213623046875, 394.6210632324219, 588.1874389648438))]
#
# delete    seq1[856:858] --> [((5, 65, 230.1), '}\\}', '<inline_math>'), ((5, 65, 230.2), '\\)', '<inline_math>')]
#           seq2[726:726] --> []
#
# delete    seq1[862:863] --> [((5, 70, 0.1), '\\(', '<inline_math>')]
#           seq2[730:730] --> []
#
# aligned   seq1[863:864] --> [((5, 70, 5), 'k', '<inline_math>')]
#           seq2[730:731] --> [((5, 70, 5), 'k', (490.6708679199219, 577.47705078125, 499.23553466796875, 587.4396362304688))]
#
# delete    seq1[864:865] --> [((5, 70, 5.1), '\\)', '<inline_math>')]
#           seq2[731:731] --> []
#
# delete    seq1[866:867] --> [((5, 70, 10.1), '\\(', '<inline_math>')]
#           seq2[732:732] --> []
#
# aligned   seq1[867:868] --> [((5, 70, 15), '1', '<inline_math>')]
#           seq2[732:733] --> [((5, 70, 15), '1', (68.66699981689453, 589.43310546875, 73.64830017089844, 599.3956909179688))]
#
# aligned   seq1[868:869] --> [((5, 70, 20), '\\leq', '<inline_math>')]
#           seq2[733:734] --> [((5, 70, 20), '\\leq', (73.64800262451172, 589.1840209960938, 81.38894653320312, 606.4691162109375))]
#
# aligned   seq1[869:870] --> [((5, 70, 25), 'k', '<inline_math>')]
#           seq2[734:735] --> [((5, 70, 25), 'k', (81.39700317382812, 589.43310546875, 86.57755279541016, 599.3956909179688))]
#
# aligned   seq1[870:871] --> [((5, 70, 30), ' \\leq', '<inline_math>')]
#           seq2[735:736] --> [((5, 70, 30), '\\leq', (86.89700317382812, 589.1840209960938, 94.637939453125, 606.4691162109375))]
#
# aligned   seq1[871:872] --> [((5, 70, 35), 'd', '<inline_math>')]
#           seq2[736:737] --> [((5, 70, 35), 'd', (94.64600372314453, 589.43310546875, 99.82655334472656, 599.3956909179688))]
#
# delete    seq1[872:873] --> [((5, 70, 35.1), '\\)', '<inline_math>')]
#           seq2[737:737] --> []
#
# delete    seq1[875:876] --> [((5, 70, 45.1), '\\(', '<inline_math>')]
#           seq2[739:739] --> []
#
# aligned   seq1[876:877] --> [((5, 70, 50), 'n', '<inline_math>')]
#           seq2[739:740] --> [((5, 70, 50), 'n', (133.8131866455078, 589.43310546875, 142.9265594482422, 599.3956909179688))]
#
# delete    seq1[877:878] --> [((5, 70, 50.1), '_{', '<inline_math>')]
#           seq2[740:740] --> []
#
# aligned   seq1[878:879] --> [((5, 70, 55), '1', '<inline_math>')]
# ...
#
# aligned   seq1[882:883] --> [((5, 70, 70), '2', '<inline_math>')]
#           seq2[743:744] --> [((5, 70, 70), '2', (156.14599609375, 593.168701171875, 160.1140899658203, 600.1425170898438))]
#
# delete    seq1[883:884] --> [((5, 70, 70.1), '}', '<inline_math>')]
#           seq2[744:744] --> []
#
# aligned   seq1[884:885] --> [((5, 70, 75), ',', '<inline_math>')]
#           seq2[744:745] --> [((5, 70, 75), ',', (160.614990234375, 589.43310546875, 163.3746337890625, 599.3956909179688))]
#
# delete    seq1[885:886] --> [((5, 70, 75.1), ' \\ldots', '<inline_math>')]
#           seq2[745:745] --> []
#
# insert    seq1[886:886] --> []
#           seq2[745:748] --> [((0, 0, 0), '. . .', (163.3746337890625, 589.43310546875, 176.66476440429688, 599.3956909179688)), ((5, 70, 80), ',', (176.66476440429688, 589.43310546875, 181.09812927246094, 599.3956909179688)), ((5, 70, 85), 'n', (181.10809326171875, 589.43310546875, 187.0856475830078, 599.3956909179688))]
#
# aligned   seq1[886:887] --> [((5, 70, 80), ',', '<inline_math>')]
#           seq2[746:747] --> [((5, 70, 80), ',', (176.66476440429688, 589.43310546875, 181.09812927246094, 599.3956909179688))]
#
# aligned   seq1[887:888] --> [((5, 70, 85), 'n', '<inline_math>')]
#           seq2[747:748] --> [((5, 70, 85), 'n', (181.10809326171875, 589.43310546875, 187.0856475830078, 599.3956909179688))]
#
# delete    seq1[888:889] --> [((5, 70, 85.1), '_{', '<inline_math>')]
#           seq2[748:748] --> []
#
# aligned   seq1[889:890] --> [((5, 70, 90), 'd', '<inline_math>')]
#           seq2[748:749] --> [((5, 70, 90), 'd', (187.07398986816406, 593.168701171875, 191.2164306640625, 600.1425170898438))]
#
# delete    seq1[890:891] --> [((5, 70, 90.1), '}', '<inline_math>')]
#           seq2[749:749] --> []
#
# aligned   seq1[891:892] --> [((5, 70, 95), ',', '<inline_math>')]
#           seq2[749:750] --> [((5, 70, 95), ',', (191.718994140625, 589.43310546875, 194.4786376953125, 599.3956909179688))]
#
# aligned   seq1[892:893] --> [((5, 70, 100), 'm', '<inline_math>')]
#           seq2[750:751] --> [((5, 70, 100), 'm', (194.4886016845703, 589.43310546875, 203.2357635498047, 599.3956909179688))]
#
# aligned   seq1[893:894] --> [((5, 70, 105), '1', '<inline_math>')]
#           seq2[751:752] --> [((5, 70, 105), '1', (203.23399353027344, 593.168701171875, 207.20208740234375, 600.1425170898438))]
#
# delete    seq1[894:895] --> [((5, 70, 105.1), '}', '<inline_math>')]
#           seq2[752:752] --> []
#
# aligned   seq1[895:896] --> [((5, 70, 110), ',', '<inline_math>')]
#           seq2[752:753] --> [((5, 70, 110), ',', (207.70298767089844, 589.43310546875, 210.46263122558594, 599.3956909179688))]
#
# aligned   seq1[896:897] --> [((5, 70, 115), 'm', '<inline_math>')]
#           seq2[753:754] --> [((5, 70, 115), 'm', (210.47259521484375, 589.43310546875, 219.21975708007812, 599.3956909179688))]
#
# aligned   seq1[897:898] --> [((5, 70, 120), '2', '<inline_math>')]
#           seq2[754:755] --> [((5, 70, 120), '2', (219.21798706054688, 593.168701171875, 223.1860809326172, 600.1425170898438))]
#
# delete    seq1[898:899] --> [((5, 70, 120.1), '}', '<inline_math>')]
#           seq2[755:755] --> []
#
# aligned   seq1[899:900] --> [((5, 70, 125), ' ,', '<inline_math>')]
#           seq2[755:756] --> [((5, 70, 125), ',', (223.68698120117188, 589.43310546875, 226.44662475585938, 599.3956909179688))]
#
# delete    seq1[900:901] --> [((5, 70, 125.1), ' \\ldots', '<inline_math>')]
#           seq2[756:756] --> []
#
# insert    seq1[901:901] --> []
#           seq2[756:759] --> [((0, 0, 0), '. . .', (226.44662475585938, 589.43310546875, 239.73675537109375, 599.3956909179688)), ((5, 70, 130), ',', (239.73675537109375, 589.43310546875, 244.1701202392578, 599.3956909179688)), ((5, 70, 135), 'm', (244.18008422851562, 589.43310546875, 252.92724609375, 599.3956909179688))]
#
# aligned   seq1[901:902] --> [((5, 70, 130), ',', '<inline_math>')]
#           seq2[757:758] --> [((5, 70, 130), ',', (239.73675537109375, 589.43310546875, 244.1701202392578, 599.3956909179688))]
#
# aligned   seq1[902:903] --> [((5, 70, 135), 'm', '<inline_math>')]
#           seq2[758:759] --> [((5, 70, 135), 'm', (244.18008422851562, 589.43310546875, 252.92724609375, 599.3956909179688))]
#
# delete    seq1[903:904] --> [((5, 70, 135.1), '_{', '<inline_math>')]
#           seq2[759:759] --> []
#
# aligned   seq1[904:905] --> [((5, 70, 140), ' d', '<inline_math>')]
#           seq2[759:760] --> [((5, 70, 140), 'd', (252.91297912597656, 593.168701171875, 257.055419921875, 600.1425170898438))]
#
# aligned   seq1[905:906] --> [((5, 70, 145), '\\geq', '<inline_math>')]
#           seq2[760:761] --> [((5, 70, 145), '\\geq', (257.5589904785156, 589.1840209960938, 265.2999267578125, 606.4691162109375))]
#
# aligned   seq1[906:907] --> [((5, 70, 150), '0', '<inline_math>')]
#           seq2[761:762] --> [((5, 70, 150), '0', (265.3069763183594, 589.43310546875, 270.28826904296875, 599.3956909179688))]
#
# delete    seq1[907:908] --> [((5, 70, 150.1), '\\)', '<inline_math>')]
#           seq2[762:762] --> []
#
# delete    seq1[942:943] --> [((5, 75, 50.1), '\\(', '<inline_math>')]
#           seq2[796:796] --> []
#
# aligned   seq1[943:944] --> [((5, 75, 55), 'd', '<inline_math>')]
#           seq2[796:797] --> [((5, 75, 55), 'd', (170.35562133789062, 617.9000854492188, 178.84254455566406, 627.8626708984375))]
#
# aligned   seq1[944:945] --> [((5, 75, 60), '\\geq', '<inline_math>')]
#           seq2[797:798] --> [((5, 75, 60), '\\geq', (178.84799194335938, 617.6510009765625, 186.58892822265625, 634.9360961914062))]
#
# aligned   seq1[945:946] --> [((5, 75, 65), '2', '<inline_math>')]
#           seq2[798:799] --> [((5, 75, 65), '2', (186.59698486328125, 617.9000854492188, 191.57827758789062, 627.8626708984375))]
#
# delete    seq1[946:947] --> [((5, 75, 65.1), '\\)', '<inline_math>')]
#           seq2[799:799] --> []
#
# delete    seq1[950:951] --> [((5, 75, 80.1), '\\(', '<inline_math>')]
#           seq2[802:802] --> []
#
# aligned   seq1[951:952] --> [((5, 75, 85), 'L', '<inline_math>')]
#           seq2[802:803] --> [((5, 75, 85), 'L', (256.3451232910156, 617.9000854492188, 266.4305419921875, 627.8626708984375))]
#
# delete    seq1[952:953] --> [((5, 75, 85.1), '_{', '<inline_math>')]
#           seq2[803:803] --> []
#
# aligned   seq1[953:954] --> [((5, 75, 90), 'd', '<inline_math>')]
#           seq2[803:804] --> [((5, 75, 90), 'd', (266.43597412109375, 621.6356811523438, 270.5783996582031, 628.6094970703125))]
#
# delete    seq1[954:956] --> [((5, 75, 90.1), '}', '<inline_math>'), ((5, 75, 90.19999999999999), '\\)', '<inline_math>')]
#           seq2[804:804] --> []
#
# delete    seq1[960:961] --> [((5, 75, 110.1), '\\(', '<inline_math>')]
#           seq2[808:808] --> []
#
# equal     seq1[961:962] --> [((5, 75, 110.19999999999999), '\\mathrm{CFL}', '<inline_math>')]
#           seq2[808:809] --> [((0, 0, 0), 'CFL', (361.4063720703125, 617.9000854492188, 384.6590576171875, 627.8626708984375))]
#
# aligned   seq1[962:963] --> [((5, 75, 115), '(', '<inline_math>')]
#           seq2[809:810] --> [((5, 75, 115), '(', (384.6590576171875, 617.9000854492188, 388.5245361328125, 627.8626708984375))]
#
# aligned   seq1[963:964] --> [((5, 75, 120), 'd', '<inline_math>')]
#           seq2[810:811] --> [((5, 75, 120), 'd', (388.52996826171875, 617.9000854492188, 393.71051025390625, 627.8626708984375))]
#
# aligned   seq1[964:965] --> [((5, 75, 125), ' -', '<inline_math>')]
#           seq2[811:812] --> [((5, 75, 125), '-', (393.7159729003906, 617.6510009765625, 401.4569091796875, 634.9360961914062))]
#
# aligned   seq1[965:966] --> [((5, 75, 130), '1', '<inline_math>')]
#           seq2[812:813] --> [((5, 75, 130), '1', (401.4639587402344, 617.9000854492188, 406.44525146484375, 627.8626708984375))]
#
# aligned   seq1[966:967] --> [((5, 75, 135), ')', '<inline_math>')]
#           seq2[813:814] --> [((5, 75, 135), ')', (406.44525146484375, 617.9000854492188, 410.31072998046875, 627.8626708984375))]
#
# delete    seq1[967:968] --> [((5, 75, 135.1), '\\)', '<inline_math>')]
#           seq2[814:814] --> []
#
# delete    seq1[979:981] --> [((5, 75, 185.1), '\\(', '<inline_math>'), ((5, 75, 185.2), '\\{\\mathrm{CFL}', '<inline_math>')]
#           seq2[825:825] --> []
#
# equal     seq1[981:982] --> [((5, 75, 195), '(', '<inline_math>')]
#           seq2[825:826] --> [((0, 0, 0), 'CFL', (293.6569519042969, 634.412109375, 313.5821533203125, 644.3746948242188))]
#
# aligned   seq1[981:982] --> [((5, 75, 195), '(', '<inline_math>')]
#           seq2[826:827] --> [((5, 75, 195), '(', (313.5821533203125, 634.412109375, 317.4476318359375, 644.3746948242188))]
#
# aligned   seq1[982:983] --> [((5, 75, 200), 'd', '<inline_math>')]
#           seq2[827:828] --> [((5, 75, 200), 'd', (317.4569396972656, 634.412109375, 322.6374816894531, 644.3746948242188))]
#
# aligned   seq1[983:984] --> [((5, 75, 205), ')', '<inline_math>')]
#           seq2[828:829] --> [((5, 75, 205), ')', (322.6419372558594, 634.412109375, 326.5074157714844, 644.3746948242188))]
#
# delete    seq1[984:985] --> [((5, 75, 210), '\\mid', '<inline_math>')]
#           seq2[829:829] --> []
#
# insert    seq1[985:985] --> []
#           seq2[829:830] --> [((5, 75, 210), '|', (326.51593017578125, 634.1630249023438, 329.27557373046875, 651.4481201171875))]
#
# aligned   seq1[985:986] --> [((5, 75, 215), 'd', '<inline_math>')]
#           seq2[830:831] --> [((5, 75, 215), 'd', (329.283935546875, 634.412109375, 334.4644775390625, 644.3746948242188))]
#
# aligned   seq1[986:987] --> [((5, 75, 220), ' \\geq ', '<inline_math>')]
#           seq2[831:832] --> [((5, 75, 220), '\\geq', (334.46893310546875, 634.1630249023438, 342.2098693847656, 651.4481201171875))]
#
# aligned   seq1[987:988] --> [((5, 75, 225), '1', '<inline_math>')]
#           seq2[832:833] --> [((5, 75, 225), '1', (342.2179260253906, 634.412109375, 347.19921875, 644.3746948242188))]
#
# delete    seq1[988:990] --> [((5, 75, 225.1), '\\}', '<inline_math>'), ((5, 75, 225.2), '\\)', '<inline_math>')]
#           seq2[833:833] --> []
#
# delete    seq1[1073:1076] --> [((5, 85, 125.1), '\\(', '<inline_math>'), ((5, 85, 125.19999999999999), '\\mathrm{CFL}', '<inline_math>'), ((5, 85, 125.29999999999998), '\\)', '<inline_math>')]
#           seq2[916:916] --> []
#
# delete    seq1[1079:1080] --> [((5, 85, 140.1), '\\(', '<inline_math>')]
#           seq2[920:920] --> []
#
# equal     seq1[1080:1081] --> [((5, 85, 140.2), '\\mathrm{DCFL}', '<inline_math>')]
#           seq2[920:921] --> [((0, 0, 0), 'DCFL', (112.30924224853516, 694.1881103515625, 142.85462951660156, 704.1506958007812))]
#
# delete    seq1[1081:1082] --> [((5, 85, 140.29999999999998), '\\)', '<inline_math>')]
#           seq2[921:921] --> []
#
# delete    seq1[1103:1104] --> [((5, 85, 245.1), '\\(', '<inline_math>')]
#           seq2[942:942] --> []
#
# aligned   seq1[1104:1105] --> [((5, 85, 250), 'd', '<inline_math>')]
#           seq2[942:943] --> [((5, 85, 250), 'd', (150.88421630859375, 706.14306640625, 159.04556274414062, 716.1056518554688))]
#
# delete    seq1[1105:1106] --> [((5, 85, 250.1), '\\)', '<inline_math>')]
#           seq2[943:943] --> []
#
# delete    seq1[1118:1119] --> [((5, 90, 55.1), '\\(', '<inline_math>')]
#           seq2[955:955] --> []
#
# aligned   seq1[1119:1120] --> [((5, 90, 60), 'd', '<inline_math>')]
#           seq2[955:956] --> [((5, 90, 60), 'd', (426.0827331542969, 706.14306640625, 434.22955322265625, 716.1056518554688))]
#
# delete    seq1[1120:1121] --> [((5, 90, 60.1), '\\)', '<inline_math>')]
#           seq2[956:956] --> []
#
# delete    seq1[1136:1137] --> [((5, 90, 135.1), '\\(', '<inline_math>')]
#           seq2[971:971] --> []
#
# aligned   seq1[1137:1138] --> [((5, 90, 140), 'd', '<inline_math>')]
#           seq2[971:972] --> [((5, 90, 140), 'd', (312.2724304199219, 718.0980834960938, 320.2625427246094, 728.0606689453125))]
#
# delete    seq1[1138:1139] --> [((5, 90, 140.1), '\\)', '<inline_math>')]
#           seq2[972:972] --> []
#
# delete    seq1[1145:1146] --> [((5, 90, 170.1), '\\(', '<inline_math>')]
#           seq2[978:978] --> []
#
# aligned   seq1[1146:1147] --> [((5, 90, 175), 'd', '<inline_math>')]
#           seq2[978:979] --> [((5, 90, 175), 'd', (453.7839660644531, 718.0980834960938, 461.7435302734375, 728.0606689453125))]
#
# delete    seq1[1147:1148] --> [((5, 90, 175.1), '\\)', '<inline_math>')]
#           seq2[979:979] --> []
#
# delete    seq1[1158:1159] --> [((5, 90, 225.1), '\\(', '<inline_math>')]
#           seq2[989:989] --> []
#
# equal     seq1[1159:1160] --> [((5, 90, 225.2), '\\mathrm{DCFL}', '<inline_math>')]
#           seq2[989:990] --> [((0, 0, 0), 'DCFL', (218.64315795898438, 730.0531005859375, 249.48861694335938, 740.0156860351562))]
#
# aligned   seq1[1160:1161] --> [((5, 90, 230), '(', '<inline_math>')]
#           seq2[990:991] --> [((5, 90, 230), '(', (249.48861694335938, 730.0531005859375, 253.35411071777344, 740.0156860351562))]
#
# aligned   seq1[1161:1162] --> [((5, 90, 235), 'd', '<inline_math>')]
#           seq2[991:992] --> [((5, 90, 235), 'd', (253.36199951171875, 730.0531005859375, 258.54254150390625, 740.0156860351562))]
#
# aligned   seq1[1162:1163] --> [((5, 90, 240), ' )', '<inline_math>')]
#           seq2[992:993] --> [((5, 90, 240), ')', (258.5480041503906, 730.0531005859375, 262.4134826660156, 740.0156860351562))]
#
# delete    seq1[1163:1164] --> [((5, 90, 240.1), '\\)', '<inline_math>')]
#           seq2[993:993] --> []
#
# delete    seq1[1165:1166] --> [((5, 90, 245.1), '\\(', '<inline_math>')]
#           seq2[994:994] --> []
#
# equal     seq1[1166:1167] --> [((5, 90, 245.2), '\\mathrm{DCFL}[', '<inline_math>')]
#           seq2[994:995] --> [((0, 0, 0), 'DCFL', (281.7596740722656, 730.0531005859375, 312.61761474609375, 740.0156860351562))]
#
# insert    seq1[1167:1167] --> []
#           seq2[995:995] --> []
#
# equal     seq1[1167:1168] --> [((5, 90, 250), 'd', '<inline_math>')]
#           seq2[995:996] --> [((0, 0, 0), '[', (312.6159973144531, 730.0531005859375, 315.3701171875, 740.0156860351562))]
#
# aligned   seq1[1167:1168] --> [((5, 90, 250), 'd', '<inline_math>')]
#           seq2[996:997] --> [((5, 90, 250), 'd', (315.37799072265625, 730.0531005859375, 320.55853271484375, 740.0156860351562))]
#
# equal     seq1[1168:1169] --> [((5, 90, 250.1), ']', '<inline_math>')]
#           seq2[997:998] --> [((0, 0, 0), ']', (320.5639953613281, 730.0531005859375, 323.318115234375, 740.0156860351562))]
#
# delete    seq1[1169:1170] --> [((5, 90, 250.2), '\\)', '<inline_math>')]
#           seq2[998:998] --> []
#
# delete    seq1[1174:1175] --> [((5, 95, 15.1), '\\(', '<inline_math>')]
#           seq2[1002:1002] --> []
#
# aligned   seq1[1175:1176] --> [((5, 95, 20), 'd', '<inline_math>')]
#           seq2[1002:1003] --> [((5, 95, 20), 'd', (424.26617431640625, 730.0531005859375, 432.76654052734375, 740.0156860351562))]
#
# delete    seq1[1176:1177] --> [((5, 95, 20.1), '\\)', '<inline_math>')]
#           seq2[1003:1003] --> []
#
# delete    seq1[1183:1184] --> [((5, 95, 50.1), '\\(', '<inline_math>')]
#           seq2[1009:1009] --> []
#
# aligned   seq1[1184:1185] --> [((5, 95, 55), 'd', '<inline_math>')]
#           seq2[1009:1010] --> [((5, 95, 55), 'd', (117.59638977050781, 742.008056640625, 126.0875473022461, 751.9706420898438))]
#
# delete    seq1[1185:1186] --> [((5, 95, 55.1), '\\)', '<inline_math>')]
#           seq2[1010:1010] --> []
#
# delete    seq1[1190:1191] --> [((5, 95, 75.1), '\\(', '<inline_math>')]
#           seq2[1014:1014] --> []
#
# equal     seq1[1191:1192] --> [((5, 95, 75.19999999999999), '\\mathrm{DCFL}', '<inline_math>')]
#           seq2[1014:1015] --> [((0, 0, 0), 'DCFL', (203.0467987060547, 742.008056640625, 233.89962768554688, 751.9706420898438))]
#
# delete    seq1[1192:1193] --> [((5, 95, 75.29999999999998), '\\)', '<inline_math>')]
#           seq2[1015:1015] --> []
#
# delete    seq1[1200:1201] --> [((5, 95, 110.1), '\\(', '<inline_math>')]
#           seq2[1022:1022] --> []
#
# aligned   seq1[1201:1202] --> [((5, 95, 115), 'd', '<inline_math>')]
#           seq2[1022:1023] --> [((5, 95, 115), 'd', (352.0692443847656, 742.008056640625, 360.56353759765625, 751.9706420898438))]
#
# delete    seq1[1202:1203] --> [((5, 95, 115.1), '\\)', '<inline_math>')]
#           seq2[1023:1023] --> []
