# %%
# %cd ../
# Out:
# /nas/zhangtianning.di/projects/unique_data_build
# /home/zhangtianning.di/anaconda3/envs/arxive/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os,json
from tqdm.auto import tqdm

# %%
import sys
import pathlib
import traceback

from python_script.reference_reterive.Reference import *
import os,json
from tqdm.auto import tqdm

# %% [markdown]
# # Unarxive Records

# %% [markdown]
# unarxive itself has record many "searched" doi. ( "searched" means, it is not verified indeed)

# %%
done_file_names = [x.name for x in Path('dataset/unarXive_clear_20230705/').glob('**/*.jsonl')]
    all_raw_files   = list(Path('dataset/unarXive_230324/').glob('**/*.jsonl'))
    total_length    = len(all_raw_files)
    all_files       = [x.as_posix() for x in all_raw_files if x.name not in done_file_names]

# %%
from typing import Optional
from dataclasses import dataclass
from typing import Dict

# %%
@dataclass
class UniqueID:
    doi: Optional[str] = None
    openalex: Optional[str] = None
    pubmed: Optional[str] = None
    semopenalex: Optional[str] = None
    arxiv: Optional[str] = None
    dblp: Optional[str] = None
    def is_same(a, b):
        if a.doi is not None and b.doi is not None:
            if a.doi == b.doi:
                return True
        if a.openalex is not None and b.openalex is not None:
            if a.openalex == b.openalex:
                return True
        if a.pubmed is not None and b.pubmed is not None:
            if a.pubmed == b.pubmed:
                return True
        if a.semopenalex is not None and b.semopenalex is not None:
            if a.semopenalex == b.semopenalex:
                return True
        return False


    def isnan(self):
        return all([v is None for v in self.__dict__.values()])
    
    @staticmethod
    def from_dict(d:Dict[str,str]):
        
        
        if 'crossref_doi' in d:
            d = d.get('ids',{})|{'doi':d['crossref_doi']}
        elif 'corssref_doi' in d:
            d = d.get('ids',{})|{'doi':d['corssref_doi']}
        elif 'ids' in d: 
            d = d['ids']
            
        
        for key in ["DOI", "ArXiv", "DBLP",'PubMed','PMID','PMC','MagID','Pii','Pmcid','ArXivId','ISBN','ISSN','PMCID']:
            _id = d.get(f'externalids.{key}',None)
            if _id is not None:
                new_ids[key.lower().replace('id',"")] = _id.lower()

        for k,v in d.items():
            v = str(v)
            v = v.lower()
            if len(v) ==0:continue
            k = k.lower().replace('_',"").replace('id',"")
        
            if k == 'openalex':
                v = v.replace('https://openalex.org/','')
            elif k == 'semopenalex':
                v = v.replace('https://semopenalex.org/work/','')
            elif k == 'pubmed':
                v = v.replace('https://pubmed.ncbi.nlm.nih.gov/','')
            elif k == 'arxiv':
                v = v
            elif k == 'doi':
                v = v
            else:
                continue
            
            new_ids[k] = v
        #print(new_ids)
        return UniqueID(**new_ids)
    def __repr__(self):
        info = "\n".join([f"{key} |-> {val}" for key, val in self.to_dict().items() if val is not None])
        return f"Paper:\n{info}"  
    def to_dict(self):
        return {k:v for k,v in vars(self).items() if v is not None}

# %%
###
Analysys={'Missing_Structured.JSON':0,
              'Missing_Reterive.Citation':0,
              'No_RecommendFile':0,
              'Has_RecommendFile':0,
              'Recommend_None':0,
              'Good_PassDoubleCheck':0,
              'Good_FailDoubleCheck':0,
              'Good_TotalDoubleCheck':0,
              'Extra_PassDoubleCheck':0,
              'Extra_FailDoubleCheck':0,
              'Extra_TotalDoubleCheck':0
        }
ROOT = "/nvme/zhangtianning.di/sharefold/whole_arxiv_old_quant_ph"
ROOTDIR = os.path.join(ROOT,'unprocessed_json')
arxiv_id_list = os.listdir(ROOTDIR)
unarxive_missing_list = []
undo_for_double_check = []
for arxiv_id in tqdm(arxiv_id_list):
    arxiv_id = arxiv_id.strip()
    paper_fold = os.path.join(ROOTDIR, arxiv_id)
    paper_files= os.listdir(paper_fold)
    if 'reference.structured.jsonl' not in paper_files:
        Analysys['Missing_Structured.JSON']+=1
        continue
    if 'reference.es_semantic_scholar.json' not in paper_files:
        Analysys['Missing_Reterive.Citation']+=1
        continue   

    Recommend_Citation_Path = os.path.join(paper_fold,'reference.recommend.mapping.json')
    if not os.path.exists(Recommend_Citation_Path):
        Analysys['No_RecommendFile']+=1
        continue
    else:
        Analysys['Has_RecommendFile']+=1

    done_reference_strings = read_jsonl(os.path.join(paper_fold,'reference.structured.jsonl.done'))
    done_reterive_results  = read_jsonl(os.path.join(paper_fold,'reference.es_semantic_scholar.json.done'))
    done_reference_keys    = read_linefile(os.path.join(paper_fold,'reference.keys.done'))
    done_reference_txts    = read_linefile(os.path.join(paper_fold,'reference.txt.done'))

    undo_reference_strings = read_jsonl(os.path.join(paper_fold,'reference.structured.jsonl'))
    undo_reterive_results  = read_jsonl(os.path.join(paper_fold,'reference.es_semantic_scholar.json'))
    undo_reference_keys    = read_linefile(os.path.join(paper_fold,'reference.keys'))
    undo_reference_txts    = read_linefile(os.path.join(paper_fold,'reference.txt'))

    # reference_strings = reference_strings + done_reference_strings
    # reterive_results  = reterive_results + done_reterive_results
    # reference_keys    = reference_keys + done_reference_keys
    # reference_txts    = reference_txts + done_reference_txts

    with open(Recommend_Citation_Path,'r') as f:
        recommend_doi_reterive = json.load(f)
    extra_good_ids = {'Good':[], 'Extra':[]}
    for part, series in [['Good', zip(done_reference_keys, done_reference_txts, done_reference_strings, done_reterive_results)],
                         ['Extra',zip(undo_reference_keys, undo_reference_txts, undo_reference_strings, undo_reterive_results)]]:
        for slot, (reference_key, reference_string, reference_query, reference_result) in enumerate(series):

            if reference_key not in recommend_doi_reterive:continue
            retrieved_result = reference_result
            retrieved_unique_id = UniqueID.from_dict(retrieved_result)
            recommend_unqiue_id = UniqueID.from_dict(recommend_doi_reterive[reference_key])
            if recommend_unqiue_id.isnan():
                Analysys['Recommend_None']+=1
                continue
            DoubleCheck = retrieved_unique_id.is_same(recommend_unqiue_id)
            Analysys[f'{part}_TotalDoubleCheck']+=1
            if not DoubleCheck:
                if part == 'Good':
                    undo_for_double_check.append(
                    {
                        'arxiv_id': arxiv_id,
                        'citation_string': reference_string,
                        'recommend_string': bib_info['bib_entry_raw'],
                        'retrieve_query':reference_query,
                        'retrieve_result': reference_result,
                        'recommend_ids': recommend_unqiue_id.to_dict(),
                        'retrieve_ids':retrieved_unique_id.to_dict(),

                    }
                    )
                Analysys[f'{part}_FailDoubleCheck']+=1
            else:
                Analysys[f'{part}_PassDoubleCheck']+=1
                if part == 'Extra':
                    extra_good_ids['Extra'].append(slot)
                    #print("=======")

 
    if len(extra_good_ids['Extra'])>0:
        extra_reference_keys =[  v for i, v in enumerate(undo_reference_keys)       if i in extra_good_ids['Extra']]
        extra_reference_txts =[  v for i, v in enumerate(undo_reference_txts)       if i in extra_good_ids['Extra']]
        extra_reference_strings =[  v for i, v in enumerate(undo_reference_strings) if i in extra_good_ids['Extra']]
        extra_reterive_results =[  v for i, v in enumerate(undo_reterive_results)   if i in extra_good_ids['Extra']]
        
        done_reference_keys.extend(extra_reference_keys)
        done_reference_txts.extend(extra_reference_txts)
        done_reference_strings.extend(extra_reference_strings)
        done_reterive_results.extend(extra_reterive_results)
        
        undo_reference_keys    =[    v for i, v in enumerate(undo_reference_keys) if i not in extra_good_ids['Extra']]
        undo_reference_txts    =[    v for i, v in enumerate(undo_reference_txts) if i not in extra_good_ids['Extra']]
        undo_reference_strings =[ v for i, v in enumerate(undo_reference_strings) if i not in extra_good_ids['Extra']]
        undo_reterive_results  =[  v for i, v in enumerate(undo_reterive_results) if i not in extra_good_ids['Extra']]
        
        
        save_linefile(os.path.join(paper_fold,'reference.keys.done'),done_reference_keys)
        save_linefile(os.path.join(paper_fold,'reference.txt.done'),done_reference_txts)
        save_jsonl(os.path.join(paper_fold,'reference.structured.jsonl.done'),done_reference_strings)
        save_jsonl(os.path.join(paper_fold,'reference.es_semantic_scholar.json.done'),done_reterive_results)

        save_linefile(os.path.join(paper_fold,'reference.keys'),undo_reference_keys)
        save_linefile(os.path.join(paper_fold,'reference.txt'),undo_reference_txts)
        save_jsonl(os.path.join(paper_fold,'reference.structured.jsonl'),undo_reference_strings)
        save_jsonl(os.path.join(paper_fold,'reference.es_semantic_scholar.json'),undo_reterive_results)
# Out:
#   0%|          | 0/61001 [00:00<?, ?it/s]

# %%
for k,v in Analysys.items():
    if isinstance(v, list):
        print(f"{k}=>{len(v)}")
    else:
        print(f"{k}=>{v}")
# Out:
# Missing_Structured.JSON=>0
# Missing_Reterive.Citation=>3
# No_RecommendFile=>38274
# Has_RecommendFile=>22724
# Recommend_None=>0
# Good_PassDoubleCheck=>604528
# Good_FailDoubleCheck=>14301
# Good_TotalDoubleCheck=>618829
# Extra_PassDoubleCheck=>30812
# Extra_FailDoubleCheck=>1123
# Extra_TotalDoubleCheck=>31935

# %%
arxiv_id = "0909.2673"
arxiv_id = arxiv_id.strip()
paper_fold = os.path.join(ROOTDIR, arxiv_id)
paper_files= os.listdir(paper_fold)
done_reference_strings = read_jsonl(os.path.join(paper_fold,'reference.structured.jsonl.done'))
done_reterive_results  = read_jsonl(os.path.join(paper_fold,'reference.es_semantic_scholar.json.done'))
done_reference_keys    = read_linefile(os.path.join(paper_fold,'reference.keys.done'))
done_reference_txts    = read_linefile(os.path.join(paper_fold,'reference.txt.done'))

reference_strings = read_jsonl(os.path.join(paper_fold,'reference.structured.jsonl'))
reterive_results  = read_jsonl(os.path.join(paper_fold,'reference.es_semantic_scholar.json'))
reference_keys    = read_linefile(os.path.join(paper_fold,'reference.keys'))
reference_txts    = read_linefile(os.path.join(paper_fold,'reference.txt'))

reference_strings = reference_strings + done_reference_strings
reterive_results  = reterive_results + done_reterive_results
reference_keys    = reference_keys + done_reference_keys
reference_txts    = reference_txts + done_reference_txts

old_reference_keys= read_linefile(os.path.join(paper_fold,'reference.keys.bk'))
old_reference_txts= read_linefile(os.path.join(paper_fold,'reference.txt.bk'))
citation_pool_unarxive = []
for idx in range(num_of_ref_for_unarxive_paper[arxiv_id]):
    citation_pool_unarxive.append(unarxive_mongo.from_bib_idx(f'Ref.{idx} of ArXiv:{arxiv_id}'))

# %%
print(f"{len(old_reference_keys)} == {len(old_reference_txts)} == {len(citation_pool_unarxive)} ")
# Out:
# 44 == 44 == 74

# %%
# for now_key, now_citation, query_pool, retreive_result in zip(reference_keys, reference_txts, reference_strings,reterive_results):
#     if now_key not in recommend_doi_reterive:continue
#     print(now_citation)
#     print(retreive_result['externalids.DOI'].lower(),retreive_result['score'])
#     print(recommend_doi_reterive[now_key])
#     print("=============")

# %%
for t in old_reference_txts:print(t)
# Out:
# H. Everett III, “ ‘Relative state’ formulation of quantum mechanics,” Rev. Mod. Phys. 29 454-462 (1957). Reprinted in B. S. DeWitt and N. Graham, eds., The Many Worlds Interpretation of Quantum Mechanics (Princeton University Press, Princeton, NJ, 1973).
# J. S. Bell, “On the Einstein-Podolsky-Rosen paradox,” Physics 1 195-200 (1964), reprinted in J. S. Bell, Speakable and Unspeakable in Quantum Mechanics (Cambridge University Press, Cambridge, 1987).
# L. Vaidman, “Many-worlds interpretation of quantum mechanics,” in Stanford Encyclopedia of Philosophy (Summer 2002 Edition), E. N. Zalta, ed., http://plato.stanford.edu/archives/sum2002/entries/qm-manyworlds.
# C. Hewitt-Horsman, “An introduction to many worlds in quantum computation,” Found. Phys. 39 , 826-902 (2009);arXiv:0802.2504.
# H. Reichenbach, The Direction of Time (Dover Publications, Inc., New York, 1999).
# D. Bohm, Quantum Theory (Prentice-Hall, Englewood Cliffs, NJ, 1951).
# ...

# %%
_=[print(t['bib_entry_raw']) for t in  citation_pool_unarxive]
# Out:
# H. Everett III, “ `Relative state' formulation of quantum mechanics,” Rev. Mod. Phys. 29 454-462 (1957). Reprinted in B. S. DeWitt and N. Graham, eds., The Many Worlds Interpretation of Quantum Mechanics (Princeton University Press, Princeton, NJ, 1973).
# J. S. Bell, “On the Einstein-Podolsky-Rosen paradox,” Physics 1 195-200 (1964), reprinted in J. S. Bell, Speakable and Unspeakable in Quantum Mechanics (Cambridge University Press, Cambridge, 1987).
# L. Vaidman, “Many-worlds interpretation of quantum mechanics,” in Stanford Encyclopedia of Philosophy (Summer 2002 Edition), E. N. Zalta, ed., http://plato.stanford.edu/archives/sum2002/entries/qm-manyworlds.
# H. D. Zeh, “On the interpretation of measurement in quantum theory,” Found. Phys. 1, 69-76, (1970).
# H. P. Stapp, “Locality and reality,” Found. Phys. 10, 767-795 (1980).
# D. N. Page, “The Einstein-Podolsky-Rosen physical reality is completely described by quantum mechanics,” Phys. Lett. 91A, 57-60 (1982).
# ...

# %%
print(f"{len(reference_strings)} == {len(reterive_results)} == {len(reference_keys)} == {len(reference_txts)}")
# Out:
# 18 == 18 == 18 == 18

# %%
class Unarxive_Mongo:
    def __init__(
        self,
        uri="mongodb://10.140.24.12:20034",
        db_name="unarxive",
        collection_name="bib",
    ):
        from pymongo.mongo_client import MongoClient
        from pymongo.server_api import ServerApi

        self._client = MongoClient(uri, server_api=ServerApi("1"))
        self._db = self._client[db_name]
        self._collection = self._db[collection_name]

    def from_hash_code(self, hash_code):
        """get bib entry from hash code in unarxive
        example of hash code: c617b28926bfdb5d456ce1888bfdfe3db47f09ca"""
        return self._collection.find_one(
            {
                "_id": hash_code,
            }
        )

    def from_bib_idx(self, bib_idx):
        """get bib entry from bib idx
        example of bib_idx: 'Ref.32 of ArXiv:1402.0451'"""
        return self._collection.find_one(
            {
                "idx": bib_idx,
            }
        )

    def find_and_update_by_hash_code(self, hash_code, new_values):
        """find and update by hash code"""
        return self._collection.find_one_and_update(
            {
                "_id": hash_code,
            },
            new_values,
        )

unarxive_mongo = Unarxive_Mongo()
# Out:
# {'_id': '61ec233f3821c630624da550bbd9a8402e50232e',
#  'bib_entry_raw': 'Y. I. Manin, Vychislimoe i nevychislimoe (Sov. radio, 1980).',
#  'contained_arXiv_ids': [],
#  'contained_links': [],
#  'discipline': '',
#  'ids': {'open_alex_id': '',
#   'sem_open_alex_id': '',
#   'pubmed_id': '',
#   'pmc_id': '',
#   'doi': '',
#   'arxiv_id': ''},
#  'unarxive_bib_hash_code': '61ec233f3821c630624da550bbd9a8402e50232e',
#  'idx': 'Ref.0 of ArXiv:1906.07635',
#  'parent_paper_id': 'ArXiv:1906.07635',
#  'corssref_doi': '10.1070/pu1980v023n07abeh005129',
#  'crossref_doi': '10.1070/pu1980v023n07abeh005129'}

# %% [markdown]
# # Crossref Reterive

# %%
from googleapiclient.discovery import build
import pprint

my_api_key = "AIzaSyC91WWPoWObGZEJ1va3mKrb0lmEPKX8P78"
my_cse_id = "45f28e600b3b84456"

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search('C. A. Fuchs, Ph. D. Thesis, University of New Mexico (1995). site:scholar.google.com', my_api_key, my_cse_id, num=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 12
#       9     res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
#      10     return res['items']
# ---> 12 results = google_search('C. A. Fuchs, Ph. D. Thesis, University of New Mexico (1995).', my_api_key, my_cse_id, num=1)
#
# Cell In[134], line 10, in google_search(search_term, api_key, cse_id, **kwargs)
#       8 service = build("customsearch", "v1", developerKey=api_key)
#       9 res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
# ---> 10 return res['items']
#
# KeyError: 'items'

# %%
results[0]
# Out:
# {'kind': 'customsearch#result',
#  'title': 'Distinguishability and Accessible Information in Quantum Theory',
#  'htmlTitle': 'Distinguishability and Accessible Information in Quantum Theory',
#  'link': 'https://arxiv.org/abs/quant-ph/9601020',
#  'displayLink': 'arxiv.org',
#  'snippet': 'Jan 23, 1996 ... Ph. D. Dissertation, University of New Mexico, prepared in LaTeX, 174 pages in single-space format, 640 equations, 528 references, 11\xa0...',
#  'htmlSnippet': 'Jan 23, 1996 <b>...</b> <b>Ph</b>. <b>D</b>. <b>Dissertation</b>, <b>University</b> of <b>New Mexico</b>, prepared in LaTeX, 174 pages in single-space format, 640 equations, 528 references, 11&nbsp;...',
#  'cacheId': 'aldJ1K3I6WsJ',
#  'formattedUrl': 'https://arxiv.org/abs/quant-ph/9601020',
#  'htmlFormattedUrl': 'https://arxiv.org/abs/quant-<b>ph</b>/9601020',
#  'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcStsc5IszP_UC7vkymrk7PhjHGOFQhTh862xtJcQkxDem2IteJQXpob6_Vb',
# ...

# %%
C. A. Fuchs, Ph. D. Thesis, University of New Mexico (1995).

# %%
results[0]
# Out:
# {'kind': 'customsearch#result',
#  'title': 'Distinguishability and Accessible Information in Quantum Theory',
#  'htmlTitle': 'Distinguishability and Accessible Information in Quantum Theory',
#  'link': 'https://arxiv.org/abs/quant-ph/9601020',
#  'displayLink': 'arxiv.org',
#  'snippet': 'Jan 23, 1996 ... Ph. D. Dissertation, University of New Mexico, prepared in LaTeX, 174 pages in single-space format, 640 equations, 528 references, 11\xa0...',
#  'htmlSnippet': 'Jan 23, 1996 <b>...</b> <b>Ph</b>. <b>D</b>. <b>Dissertation</b>, <b>University</b> of <b>New Mexico</b>, prepared in LaTeX, 174 pages in single-space format, 640 equations, 528 references, 11&nbsp;...',
#  'cacheId': 'aldJ1K3I6WsJ',
#  'formattedUrl': 'https://arxiv.org/abs/quant-ph/9601020',
#  'htmlFormattedUrl': 'https://arxiv.org/abs/quant-<b>ph</b>/9601020',
#  'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcStsc5IszP_UC7vkymrk7PhjHGOFQhTh862xtJcQkxDem2IteJQXpob6_Vb',
# ...

# %%
from serpapi import GoogleSearch, GoogleScholarSearch

params = {
  "q": "C. A. Fuchs, Ph. D. Thesis, University of New Mexico (1995).",
  "engine": "google_scholar",
  "api_key": "5f373326430b7eda32f5eb4ff480a2d625cbcc9d84a8125fa678173c2d9d48ac"
}

search = GoogleScholarSearch(params)
results = search.get_dict()

# %%
results['organic_results'][0]
# Out:
# {'position': 0,
#  'title': 'Distinguishability and Accessible Information in Quantum Theory Ph. D',
#  'result_id': 'ps05Dc0SWQcJ',
#  'type': 'Citation',
#  'snippet': '',
#  'publication_info': {'summary': 'CA Fuchs - 1995 - thesis, University of New Mexico',
#   'authors': [{'name': 'CA Fuchs',
#     'link': 'https://scholar.google.com/citations?user=fe9uXzkAAAAJ&hl=en&oi=sra',
#     'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=fe9uXzkAAAAJ&engine=google_scholar_author&hl=en',
#     'author_id': 'fe9uXzkAAAAJ'}]},
#  'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=ps05Dc0SWQcJ',
#   'cited_by': {'total': 2,
#    'link': 'https://scholar.google.com/scholar?cites=529475103092231590&as_sdt=2005&sciodt=0,5&hl=en',
#    'cites_id': '529475103092231590',
#    'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=529475103092231590&engine=google_scholar&hl=en'},
# ...

# %%
from serpapi import GoogleSearch

params = {
  "q": "C. A. Fuchs, Ph. D. Thesis, University of New Mexico (1995).",
  "location": "Austin, Texas, United States",
  "hl": "en",
  "gl": "us",
  "google_domain": "google.com",
  "api_key": "5f373326430b7eda32f5eb4ff480a2d625cbcc9d84a8125fa678173c2d9d48ac"
}

search = GoogleSearch(params)
results = search.get_dict()

# %%
# Out:
# [{'position': 1,
#   'title': 'Distinguishability and Accessible Information in Quantum ...',
#   'link': 'https://arxiv.org/abs/quant-ph/9601020',
#   'redirect_link': 'https://www.google.comhttps://arxiv.org/abs/quant-ph/9601020',
#   'displayed_link': 'https://arxiv.org › quant-ph',
#   'favicon': 'https://serpapi.com/searches/65e44e3496f5d73420e890d6/images/12740e3f6e246a4ca418f4e21c59d9299ed6f9bb5ff4319c0e6cf0880c459b8b.png',
#   'author': 'by CA Fuchs',
#   'cited_by': 'Cited by 260',
#   'extracted_cited_by': 260,
#   'date': '1996',
#   'snippet': 'Ph. D. Dissertation, University of New Mexico, prepared in LaTeX, 174 pages in single-space format, 640 equations, 528 references, 11 ...',
#   'snippet_highlighted_words': ['Ph',
#    'D',
#    'Dissertation',
#    'University',
#    'New Mexico'],
#   'source': 'arXiv'},
#  {'position': 2,
#   'title': 'Distinguishability and Accessible Information in Quantum ...',
#   'link': 'https://arxiv.org/pdf/quant-ph/9601020',
# ...

# %%
from collections.abc import Iterator
from threading import Lock
import time
from functools import wraps
import numpy as np
from tqdm.auto import tqdm, trange
from concurrent.futures import ThreadPoolExecutor
import jsonlines
################ set crossref ######################
from habanero import Crossref
crossref_agent = Crossref(mailto='zhangtianning110@outlook.com', ua_string='Shanghai AI Lab; https://www.shlab.org.cn/')
####################################################

def get_all_searching_quries(jsonl_path):
    """ all paper_ids should be arxiv paper """
    with jsonlines.open(jsonl_path) as f:
        data = []
        for x in f.read():
            data.append(x)

def rate_limited(interval):
    class RateLimiter(Iterator):
        """Iterator that yields a value at most once every 'interval' seconds."""
        def __init__(self):
            self.lock = Lock()
            self.next_yield = 0

        def __next__(self):
            with self.lock:
                t = time.monotonic()
                if t < self.next_yield:
                    time.sleep(self.next_yield - t)
                    t = time.monotonic()
                self.next_yield = t + interval

    rate_limiter = RateLimiter()

    def decorator(f):
        @wraps(f)
        def wrapper(*args, **kwargs):
            next(rate_limiter)
            return f(*args, **kwargs)
        return wrapper

    return decorator

@rate_limited(0.03)
def work_func_query_crossref(crossref_agent, bib_info, db_collection, pbar):
    try:
        x = crossref_agent.works(query_bibliographic = bib_info['bib_entry_raw'], limit = 1)
        bib_info['crossref_query_result'] = x
    except:
        pass
    else:
        db_collection.find_one_and_delete({'bib_key': bib_info['bib_key']})
        db_collection.insert_one(bib_info)
    pbar.update(1)

# %%
crossref_agent.works(query_bibliographic = "C. A. Fuchs, Ph. D. Thesis, University of New Mexico (1995).", limit = 1)
# Out:
# {'status': 'ok',
#  'message-type': 'work-list',
#  'message-version': '1.0.0',
#  'message': {'facets': {},
#   'total-results': 985442,
#   'items': [{'indexed': {'date-parts': [[2024, 3, 1]],
#      'date-time': '2024-03-01T17:15:16Z',
#      'timestamp': 1709313316765},
#     'reference-count': 10,
#     'publisher': 'World Scientific Pub Co Pte Lt',
#     'issue': '01',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Int. J. Quantum Inform.'],
#     'published-print': {'date-parts': [[2004, 3]]},
# ...

# %%
On a measure of divergence between two statistical populations defined by their probability distribution

# %%
x
# Out:
# {'status': 'ok',
#  'message-type': 'work-list',
#  'message-version': '1.0.0',
#  'message': {'facets': {},
#   'total-results': 5732338,
#   'items': [{'indexed': {'date-parts': [[2022, 4, 3]],
#      'date-time': '2022-04-03T19:01:28Z',
#      'timestamp': 1649012488029},
#     'reference-count': 0,
#     'publisher': 'American Mathematical Society (AMS)',
#     'issue': '2',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Bull. Amer. Math. Soc.'],
#     'published-print': {'date-parts': [[1943, 2, 1]]},
#     'DOI': '10.1090/s0002-9904-1943-07847-0',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2008, 2, 28]],
#      'date-time': '2008-02-28T21:34:15Z',
#      'timestamp': 1204234455000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Miscellaneous front pages, Bull. Amer. Math. Soc., Volume 49, Number 2 (1943)'],
#     'prefix': '10.1090',
#     'volume': '49',
# ...

# %% [markdown]
# # Reterive

# %%
from python_script.reference_reterive.citation_string_to_reference import *

# %%
import numpy as np
#selected_engine = np.random.choice(["http://10.140.52.118:9200","http://10.140.52.123:9200","http://10.140.52.107:20017"], p=[0.6,0.2,0.2])
selected_engine = "http://10.140.52.124:9200"
print(f"use engine at {selected_engine}")
es = Elasticsearch(selected_engine,request_timeout=1000)
es.indices.refresh(index='integrate20240311')
# Out:
# use engine at http://10.140.52.124:9200
# ObjectApiResponse({'_shards': {'total': 2, 'successful': 1, 'failed': 0}})

# %%
rowdata = {
        "title": [
            "Biva: A very deep hierarchy of latent variables for generative modeling"
        ],
    }

# %%
rowdata = {
        "author": [
            "L.M Nieto",
            "N.A Atakishiyev",
            "S.M Chumakov",
            "K.B Wolf"
        ],
        "imprint": {
            "volume": "31",
            "page": "3875",
            "date": "1998"
        },
        "journal": "J. Phys. A",
        "content": "L. M. Nieto, N. A. Atakishiyev, S. M. Chumakov, and K. B. Wolf, J. Phys. A 31 , 3875 (1998)."
    }

# %%
query_ref = Reference.load_from_dict(rowdata)
query = anystyle_ref_search_integrate.get_es_query_dict_from_Reference(query_ref)
result= anystyle_ref_search_integrate.search(es,query,10)['hits']['hits'][0]['_source']
result_ref= Reference.load_from_dict( result)
print(query_ref)
print(result_ref)
print(similarity_structured(result_ref,query_ref))
# Out:
# Reference:
# title |-> Biva: A very deep hierarchy of latent variables for generative modeling
# Reference:
# unique_id |-> Paper:
#    mag |-> 2787840125
# title |-> Learning Deep Generative Models With Discrete Latent Variables
# author |-> ['H. Hu', 'R. Salakhutdinov']
# year |-> 2018
# 0

# %%
json.dumps(anystyle_ref_search_integrate.search(es,query,10))
# Out:
# '{"took": 49, "timed_out": false, "_shards": {"total": 1, "successful": 1, "skipped": 0, "failed": 0}, "hits": {"total": {"value": 10000, "relation": "gte"}, "max_score": 34.54876, "hits": [{"_index": "integrate20240311", "_id": "143348387", "_score": 34.54876, "_source": {"unique_id.mag": "2787840125", "title": "Learning Deep Generative Models With Discrete Latent Variables", "journal": null, "journal_volume": null, "journal_page": null, "year": 2018, "publisher": null, "content": null, "author.0": "H. Hu", "author.1": "R. Salakhutdinov"}}, {"_index": "integrate20240311", "_id": "UA.SS2234.part_bl.40772", "_score": 34.54876, "_source": {"unique_id.dblp": "phd/basesearch/miladinovic21", "title": "On Training Deep Generative Models with Latent Variables", "journal": null, "journal_volume": null, "journal_page": null, "year": 2021, "publisher": null, "content": null, "author.0": "D. Miladinovic"}}, {"_index": "integrate20240311", "_id": "19528435", "_score": 34.51088, "_source": {"uniq
# ...

# %%
result
# Out:
# {'unique_id.mag': '2787840125',
#  'title': 'Learning Deep Generative Models With Discrete Latent Variables',
#  'journal': None,
#  'journal_volume': None,
#  'journal_page': None,
#  'year': 2018,
#  'publisher': None,
#  'content': None,
#  'author.0': 'H. Hu',
#  'author.1': 'R. Salakhutdinov'}

# %%
query_ref = Reference.load_from_dict(rowdata)
query = anystyle_ref_search_sentense.get_es_query_dict_from_Reference(query_ref)
result= anystyle_ref_search_sentense.search(es,query,1)['hits']['hits'][0]['_source']
result_ref= Reference.load_from_dict( result)
print(query_ref)
print(result_ref)
print(similarity_structured(result_ref,query_ref))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 2
#       1 query_ref = Reference.load_from_dict(rowdata)
# ----> 2 query = anystyle_ref_search_sentense.get_es_query_dict_from_Reference(query_ref)
#       3 result= anystyle_ref_search_sentense.search(es,query,1)['hits']['hits'][0]['_source']
#       4 result_ref= Reference.load_from_dict( result)
#
# File /nas/zhangtianning.di/projects/unique_data_build/python_script/reference_reterive/citation_string_to_reference.py:238, in anystyle_ref_search_sentense.get_es_query_dict_from_Reference(ref)
#     236 search_should = []
#     237 flags = defaultdict(int)
# --> 238 assert ref.content
#     240 search_should.append({
#     241     "multi_match": {"query": "{}".format(ref.content),"fields": ["content", "short_content"],"type": "best_fields"}
#     242 })
#     243 flags['author'] += 1
#
# AssertionError:

# %%
scored_result = []
for t in result['hits']['hits']:
    t = t['_source']
    candidate = Reference.load_from_dict(t)
    score = similarity_structured(candidate,ref)
    scored_result.append(t|{'score':score})

# %%
result['hits']['hits'][0]
# Out:
# {'_index': 's2-papers-v2.1',
#  '_id': '125589117',
#  '_score': 54.742672,
#  '_source': {'externalids.DOI': '10.1007/BFB0110000',
#   'title': 'Examples of hybrid dynamical systems',
#   'year': 2000,
#   'jpages': '35-56',
#   'author.0': 'A. Schaft',
#   'author.1': 'H. Schumacher'}}

# %% [markdown]
# # Update Version from 1.0 to 2.0

# %%
def get_real_keys(keys):
    real_keys = []
    unique_key_count = {}
    for key in done_reference_keys:
        if key not in unique_key_count:unique_key_count[key]=0
        real_key = f"key@@@{unique_key_count[key]}"
        unique_key_count[key]+=1
        real_keys.append(real_key)
    return real_keys

# %%
ROOTDIR = "/nvme/zhangtianning.di/sharefold/whole_arxiv_all_cs/"
alread_processing_file_list = os.listdir(os.path.join(ROOTDIR, 'unprocessed_json'))
ROOT = ROOTDIR
mode = sys.argv[2]  if len(sys.argv) >= 3 else 'normal'  
ROOTDIR = os.path.join(ROOT, 'unprocessed_json')
ArxivIDs= alread_processing_file_list
Analysys={'Missing_Structured.JSON':[],
          'Missing_Reterive.Citation':[],
          'Pass.DifferentLength':[],
          'Pass.HasFailFactCheck':[],
          'Reterive.AllDone':[],
          'Reterive.Part':[],
          'Reterive.Finish.Rows':0,
          'Reterive.Missing.Rows':0,
          'Fail_Case':[]
        }
count = 0

for i,arxiv_id in enumerate(tqdm(ArxivIDs)):

    paper_fold = os.path.join(ROOTDIR, arxiv_id)
    paper_files= os.listdir(paper_fold)
    if mode != 'remove_retrevied_citation':
        if 'reference.structured.jsonl' not in paper_files:
            Analysys['Missing_Structured.JSON'].append(arxiv_id)
            continue
        if f'reference.es_retrived_citation.json' not in paper_files:
            Analysys['Missing_Reterive.Citation'].append(arxiv_id)
            continue   


    path = os.path.join(paper_fold,'reference.structured.jsonl.done')
    

    done_reference_strings = read_jsonl(os.path.join(paper_fold,'reference.structured.jsonl.done'))
    done_reterive_results  = read_jsonl(os.path.join(paper_fold,f'reference.es_retrived_citation.json.done'))
    done_reference_keys    = read_linefile(os.path.join(paper_fold,'reference.keys.done'))
    done_reference_txts    = read_linefile(os.path.join(paper_fold,'reference.txt.done'))
    real_keys = []
    unique_key_count = {}
    for key in done_reference_keys:
        if key not in unique_key_count:unique_key_count[key]=0
        real_key = f"key@@@{unique_key_count[key]}"
        unique_key_count[key]+=1
        real_keys.append(real_key)
        
    done_key2plain_citation      = {key:citation_string for zip(real_keys,done_reference_txts )}
    done_key2structured_citation = {key:citation_string for zip(real_keys,done_reference_strings )}
    done_key2retreived_result    = {key:citation_string for zip(real_keys,done_reterive_results )}
    
    reference_strings = read_jsonl(os.path.join(paper_fold,'reference.structured.jsonl'))
    reterive_results  = read_jsonl(os.path.join(paper_fold,f'reference.es_retrived_citation.json'))
    reference_keys    = read_linefile(os.path.join(paper_fold,'reference.keys'))
    reference_txts    = read_linefile(os.path.join(paper_fold,'reference.txt'))
    
   

    if len(reference_strings) != len(reterive_results):
        Analysys['Pass.DifferentLength'].append(arxiv_id)
        continue

    fail_reference_keys=[]
    fail_reference_txts=[]
    fail_reference_strings = []
    fail_reterive_results = []
    for index, (structured_citation, paper_information, citation_txt, citation_key) in enumerate(zip(reference_strings, reterive_results,reference_txts, reference_keys)):
        ref       = Reference.load_from_dict(structured_citation) 
        #print(paper_information)
        if isinstance(paper_information,list):
            result = paper_information
        elif isinstance(paper_information,dict):
            if 'hits' in paper_information:
                if len(paper_information['hits']['hits'])<1:
                    result = None
                else:
                    result = paper_information['hits']['hits'][0]['_source']
            else:
                result = paper_information
            result = [result]
        else:
            raise ValueError(f"paper_information type is {type(paper_information)}")

        scored_result = []
        for t in result:
            if t is None:
                scored_result.append({'NotFind': 1,'score':0})
                break
            if 'unique_id' in t: 
                scored_result.append(t|{'score':1})
                break
            if '_source' in t: t=t['_source']
            candidate = Reference.load_from_dict(t)
            if 'score' not in t or force_recompute_score:
                score = similarity_structured(candidate,ref)
                t['score']=score
            scored_result.append(t)
        scored_result.sort(key=lambda x:x['score'],reverse=True)    

        result = scored_result[0]
        score  = result['score']
        #print("======")
        passQ = score> 0.8
        if passQ:
            done_reference_keys.append(citation_key)
            done_reference_txts.append(citation_txt)
            done_reterive_results.append(result|{'score':score})
            done_reference_strings.append(structured_citation)
        else:
            fail_reference_keys.append(citation_key)
            fail_reference_txts.append(citation_txt)
            fail_reterive_results.append(result|{'score':score})
            fail_reference_strings.append(structured_citation)

# %% [markdown]
# # analysis

# %%
from python_script.reference_reterive.evaluate_reterive_quality import *

# %%
ROOTDIR = "/nvme/zhangtianning.di/sharefold/whole_arxiv_old_quant_ph/unprocessed_json/"
ArxivIDs= os.listdir(ROOTDIR)

# %%
###
###
Analysys={'Missing_Reference.TXT':[],
          'Missing_Grobid.XML':[],
          'Missing_Structured.JSON':[],
          'Missing_Reterive.Citation':[],
          'Pass.DifferentLength':[],
          'Pass.HasFailFactCheck':[],
          'Pass.AllPass':[],
          'Reterive.AllDone':[],
          'Reterive.Part':[],
          'Leak':[]
         }
count = 0
for i,arxiv_id in enumerate(tqdm(ArxivIDs)):
    paper_fold = os.path.join(ROOTDIR, arxiv_id)
    paper_files= os.listdir(paper_fold)
    if 'reference.structured.jsonl' in paper_files:
        os.remove(os.path.join(paper_fold,'reference.structured.jsonl'))
        Analysys['Missing_Structured.JSON'].append(arxiv_id)
        #continue
    if 'reference.es_semantic_scholar.json' in paper_files:
        os.remove(os.path.join(paper_fold,'reference.es_semantic_scholar.json'))
        Analysys['Missing_Reterive.Citation'].append(arxiv_id)
        #continue  
    done_reference_strings = read_jsonl(os.path.join(paper_fold,'reference.structured.jsonl.done'))
    done_reterive_results  = read_jsonl(os.path.join(paper_fold,'reference.es_semantic_scholar.json.done'))
    done_reference_keys    = read_linefile(os.path.join(paper_fold,'reference.keys.done'))
    done_reference_txts    = read_linefile(os.path.join(paper_fold,'reference.txt.done'))

    undo_reference_strings = read_jsonl(os.path.join(paper_fold,'reference.structured.jsonl'))
    undo_reterive_results  = read_jsonl(os.path.join(paper_fold,'reference.es_semantic_scholar.json'))
    undo_reference_keys    = read_linefile(os.path.join(paper_fold,'reference.keys'))
    undo_reference_txts    = read_linefile(os.path.join(paper_fold,'reference.txt'))

    citation_keys    = read_linefile(os.path.join(paper_fold,'reference.keys.bk'))
    citation_string  = read_linefile(os.path.join(paper_fold,'reference.txt.bk'))
    single_citation_string = []
    single_citation_keys   = []
    for key, citation in zip(citation_keys,citation_string):
        citation = citation.strip().strip(';').strip()
        for string in citation.split(';'):
            string = string.strip()
            if len(string)==0:continue
            single_citation_string.append(string)
            single_citation_keys.append(key)
    if len(done_reference_keys) + len(undo_reference_keys) != len(single_citation_keys):
        Analysys['Leak'].append(arxiv_id)
# Out:
#   0%|          | 0/61001 [00:00<?, ?it/s]

# %%
ROOTDIR
# Out:
# '/nvme/zhangtianning.di/sharefold/whole_arxiv_old_quant_ph/unprocessed_json/'

# %%
with open('/nvme/zhangtianning.di/sharefold/whole_arxiv_old_quant_ph/start_from_parser_structure.filelist','w') as f:
    for line in Analysys['Leak']:
        f.write(line+'\n')

# %%
ROOTDIR = "/nvme/zhangtianning.di/sharefold/whole_arxiv_old_quant_ph/unprocessed_json/"
ArxivIDs= os.listdir(ROOTDIR)

# %%
for filename in tqdm(ArxivIDs):
    filepath = os.path.join(ROOTDIR,filename)
    filelist = os.listdir(filepath)
    splited_ref =False
    if os.path.exists(os.path.join(filepath,'reference.keys.bk')):

        # below is clean processing
        os.rename(os.path.join(filepath,'reference.keys.bk'),os.path.join(filepath,'reference.keys'))
        os.rename(os.path.join(filepath,'reference.txt.bk'),os.path.join(filepath,'reference.txt'))
        name_list =  ['reference.keys.done','reference.txt.done',
                      'reference.structured.jsonl.done','reference.es_semantic_scholar.json.done', 'reference.grobid.tei.xml',
                      'reference.structured.jsonl', 'reference.es_semantic_scholar.json']
        for name in name_list:
            path = os.path.join(filepath,name)
            if os.path.exists(path):
                os.remove(f"{path}")


    with open(os.path.join(filepath,'reference.keys'),'r') as f: citation_keys = [line.strip() for line in f ]
    with open(os.path.join(filepath,'reference.txt'),'r') as f:  citation_string = [line.strip() for line in f ]

    ### we will check the citation string and split then via ;
    single_citation_string = []
    single_citation_keys   = []
    for key, citation in zip(citation_keys,citation_string):
        citation = citation.strip().strip(';').strip()
        for string in citation.split(';'):
            string = string.strip()
            if len(string)==0:continue
            single_citation_string.append(string)
            single_citation_keys.append(key)
    os.rename(os.path.join(filepath,'reference.keys'),os.path.join(filepath,'reference.keys.bk'))
    os.rename(os.path.join(filepath,'reference.txt'),os.path.join(filepath,'reference.txt.bk'))
    with open(os.path.join(filepath,'reference.keys'),'w') as f: 
        for line in single_citation_keys: f.write(line+'\n')
    with open(os.path.join(filepath,'reference.txt'), 'w') as f:  
        for line in single_citation_string: f.write(line+'\n')
# Out:
#   0%|          | 0/61001 [00:00<?, ?it/s]

# %%
ROOTDIR = "/nvme/zhangtianning.di/sharefold/whole_arxiv_all_cs/unprocessed_json/"
ArxivIDs= os.listdir(ROOTDIR)

# %%
arxiv_id = '1812.05824'
paper_fold = os.path.join(ROOTDIR, arxiv_id)
paper_files= os.listdir(paper_fold)
#     if 'reference.txt' not in paper_files:
#         Analysys['Missing_Reference.TXT'].append(arxiv_id)
#         continue
#     if 'reference.grobid.tei.xml' not in paper_files:
#         Analysys['Missing_Grobid.XML'].append(arxiv_id)
#         continue

# with open(os.path.join(paper_fold,'reference.structured.jsonl.done'),'r') as f:
#     done_reference_strings = json.load(f)
# with open(os.path.join(paper_fold,'reference.es_semantic_scholar.json.done'),'r') as f:
#     done_reterive_results  = json.load(f)
# with open(os.path.join(paper_fold,'reference.keys.done'),'r') as f:
#     done_reference_keys = [t.strip() for t in f]
# with open(os.path.join(paper_fold,'reference.txt.done'),'r') as f:
#     done_reference_txt  = [t.strip() for t in f]     

with open(os.path.join(paper_fold,'reference.structured.jsonl'),'r') as f:
    reference_strings = json.load(f)
with open(os.path.join(paper_fold,'reference.es_retrived_citation.json'),'r') as f:
    reterive_results  = json.load(f)
with open(os.path.join(paper_fold,'reference.keys'),'r') as f:
    reference_keys = [t.strip() for t in f]
with open(os.path.join(paper_fold,'reference.txt'),'r') as f:
    reference_txt  = [t.strip() for t in f]
assert len(reference_strings) == len(reterive_results)

# %%
paper_information   =  reterive_results[0]
structured_citation = reference_strings[0]

# %%
from python_script.reference_reterive.Reference import *

# %%
def similarity_structured(candidate:Reference, ref:Reference):
    # weights for generalized jaccard similarity
    cand_set = {}
    str_set = {}

    # weights of volume
    if ref.journal_volume:update_weights_one('volume', candidate.journal_volume,ref.journal_volume, cand_set, str_set)
    
    if ref.journal_page:update_weights_one('page', candidate.journal_page, ref.journal_page, cand_set, str_set)
    
    # weights for year
    if ref.year:
        update_weights_one('year', candidate.year, ref.year, cand_set, str_set)
        if 'year' in str_set and str_set['year'] < 1 and candidate.year  and ref.year:
            year1 = int(candidate.year) ## some reference will refresh the year, thuse the year may large than origin
            year2 = int(ref.year)
            if ref.author is None and ref.title is None:
                str_set['year'] = int(year1==year2) 
            else:
                if abs(year1 - year2) < 2:
                    str_set['year'] = 1
                elif year1 > year2:
                    str_set['year'] = 1
            
    # weights for title
    if ref.title:
        a = Reference.get_norm_attr(candidate.title).lower()
        b = Reference.get_norm_attr(ref.title).lower()
        cand_set['title'] = 1
        str_set['title'] = fuzz.ratio(a, b) / 100

    # weights for container-title
    if ref.journal:
        b = Reference.get_norm_attr(ref.journal).lower()
        cand_set['ctitle'] = 1
        aa = Reference.get_norm_attr(candidate.journal).lower()
        score = fuzz.ratio(aa, b)
        for a in aa.split(','): 
            score = max(score, fuzz.ratio(a, b))
        str_set['ctitle'] = score/ 100

    # weights for volume-title
    if ref.journal_volume:
        a = Reference.get_norm_attr(candidate.journal_volume)
        b = Reference.get_norm_attr(ref.journal_volume)
        title_ratio = fuzz.ratio(a, b)
        
        a = Reference.get_norm_attr(candidate.journal)
        ctitle_ratio = fuzz.ratio(a, b)
        cand_set['vtitle'] = 1
        str_set['vtitle'] = max(title_ratio, ctitle_ratio) / 100

    # weights for author
    if ref.author:
        if candidate.author:
            cand_set['author'] = 1
            author_score = []
            for ref_author in ref.author:
                b = Reference.get_norm_attr(ref_author)
                scores = []
                for candidate_author in candidate.author:
                    a = Reference.get_norm_attr(candidate_author)
                    scores.append(fuzz.ratio(a, b)/ 100)
                author_score.append(np.max(scores))
                
            
            str_set['author'] = np.mean(author_score)
        else:
            cand_set['author'] = 0
            str_set['author']  = 0
    
    escape_score = 0
    can_content = candidate.content
    ref_content = ref.content
    if can_content and ref_content:
        if isinstance(can_content, str):can_content = can_content.split('|')
        if isinstance(ref_content, str):ref_content = ref_content.split('|')
        content_score = []
        for can_c in can_content:
            for ref_c in ref_content:
                content_score.append(fuzz.ratio(ref_c, can_c)/ 100)
        content_score = max(content_score)
        escape_score = content_score
    
    if 'title' in str_set and str_set['title']>=0.98:
        return 1
    if ref.title and candidate.title:
        if len(ref.title) > len(candidate.title):
            shorter_title = candidate.title
            longer_title  = ref.title
        else:
            shorter_title = ref.title
            longer_title  = candidate.title
        if longer_title.endswith(shorter_title) or longer_title.startswith(shorter_title):
            return 1
        return 0 ## title is different
    if ref.author and cand_set['author']:
        if str_set['author']<0.5:
            return escape_score
        
    support = 0
    for k, v in str_set.items():
        if k == 'year' and v > 0 and cand_set[k] > 0:
            support = support + 1
        if k == 'volume' and v == 1 and cand_set[k] > 0:
            support = support + 1
        if k == 'title' and v > 0.9:
            support = support + 1
        if k == 'ctitle' and v > 0.6:
            support = support + 1
        if k == 'vtitle' and v > 0.6:
            support = support + 1
        if k == 'author' and v > 0.9:
            support = support + 1
        if k == 'page' and v == 1 and cand_set[k] > 0:
            support = support + 1
    
    if ref.author is None and ref.title is None:
        ## then it must be a full journal ref, other wise it fails
        if ref.journal is not None and ref.journal_volume is not None and ref.journal_page is not None:
            pass
        else:
            return escape_score ## how do you identify it since no title and not journal?
    
    if support < 2:
        #print(f" fact check fail due to too less bingo={support}")
        return escape_score
    
    # generalized Jaccard similarity
    # print(cand_set)
    # print(str_set)
    num = sum([min(cand_set[n], str_set[n]) for n in cand_set.keys()])

    den = sum([max(cand_set[n], str_set[n]) for n in cand_set.keys()])
    
    if den == 0:
        return 1
    return num/den

# %%
@dataclass
class Reference(ReferenceBase):     
    
    @staticmethod
    def load_from_dict(pool):
        unique_id      = Reference.get_unique_id(pool)
        title          = Reference.resolve_list(Reference.get_title(pool))
        author         = Reference.get_author(pool)
        journal        = Reference.resolve_list(Reference.get_journal(pool))
        journal_volume = Reference.resolve_list(Reference.get_journal_volume(pool))
        journal_page   = Reference.resolve_list(Reference.get_journal_page(pool))
        year           = Reference.resolve_list(Reference.get_year(pool))
        publisher      = Reference.resolve_list(Reference.get_publisher(pool))
        content        = Reference.resolve_list(Reference.get_content(pool))

        return Reference(unique_id, title, author,  journal, journal_volume, journal_page, year, publisher, content)
    
    @staticmethod
    def resolve_list(string):
        while isinstance(string, list):
            string = string[0]
        if isinstance(string,str):
            string = string.strip()
            if len(string) ==0 :
                string = None
        return string

    @staticmethod
    def get_unique_id(pool):
        ids = (pool.get('unique_id', None) or pool.get('externalids',None))
        
        if ids:
            if 'CorpusId' in ids:del ids['CorpusId']
            return UniqueID.from_dict(ids)
        
        ids = {}
        for key,val  in pool.items():
            if 'unique_id.' not in key and key not in ['doi', 'DOI', 'arxiv', 'arxiv_id']: continue
            key = key.replace('unique_id.','')
            ids[key] = val
        if ids:
            return UniqueID.from_dict(ids)
        
    @staticmethod
    def get_title(pool):
        return pool.get('title', None)
        
    @staticmethod
    def format_a_human_name(given_name=None,family_name=None):
        if given_name and family_name:
            name = HumanName(" ".join([given_name, family_name]).strip(), initials_format="{first} {middle}")
            name = name.initials() + ' ' + name.last
        elif not given_name and family_name:
            name = family_name
        elif given_name and not family_name:
            
            if len(given_name.split()) == 1:
                name = given_name
            else:
                name = HumanName(full_name=given_name, initials_format="{first} {middle}")
                name = name.initials() + ' ' + name.last
        else:
            name = ""
        return name

    @staticmethod
    def get_author(pool):
        author = None
        if 'author' in pool and pool['author']:
            if isinstance(pool['author'], list):
                author = []
                for author_i in pool['author'][:3]:
                    if isinstance(author_i,dict):
                        given_name = (author_i.get("given", None) or 
                                      author_i.get("first", None) or 
                                      author_i.get('forename',None) or 
                                      author_i.get('name',None))
                        family_name= author_i.get("family", None) or author_i.get("last", None) or author_i.get('surname',None)
                        name = Reference.format_a_human_name(given_name=given_name,family_name=family_name )
                        if author_i.get('literal',None):
                            names = re.split(r'\s*,\s*|\s*and\s*', author_i['literal'])
                            author.extend(names)
                            continue
                    elif isinstance(author_i, str):
                        name = Reference.format_a_human_name(given_name=author_i,family_name=None )
                    else:
                        raise NotImplementedError
                    if name:
                        author.append(name)
                if len(author)==0 and len(pool['author'])>0:
                    print(f"no author find for this pool {pool}")
                #author = ','.join(author)
            elif isinstance(pool['author'], dict):
                name = " ".join([pool['author'].get("given", ""), pool['author'].get("family", "")]).strip()
                name = Reference.format_a_human_name(given_name=name,family_name=None )
                author = [name]
            elif isinstance(pool['author'], str):
                name = Reference.format_a_human_name(given_name=pool['author'],family_name=None )
                author = [name]
            else:
                raise ValueError(f"Author type not supported: {type(pool['author'])} for {pool['author']}")
        if author is None and 'author.0' in pool:
            author = [pool[key] for key in ['author.0','author.1','author.2'] if key in pool]
        
        if 'authors' in pool and pool['authors']:
            author=[]
            if isinstance(pool['authors'],list):
                assert isinstance(pool['authors'][0],dict)
                for author_pool in pool['authors']:
                    author.append(Reference.format_a_human_name(given_name=author_pool['name'],family_name=None ))
            elif isinstance(pool['authors'],str):
                author.extend(pool['authors'].split(','))
            else:
                raise NotImplementedError(f"author type not supported {type(pool['authors'])}")
        
        if isinstance(author, list) and len(author) ==0 : author = None
        return author
       
    @staticmethod
    def get_journal(pool):
        journal = (pool.get('journal', None) or pool.get('jname', None) or 
                   pool.get('journal_name', None) or pool.get('container-title', None) or 
                   pool.get('j_name', None))
        if not journal and 'imprint' in pool and pool['imprint'] and 'journal' in pool['imprint']:
            journal = pool['imprint']['journal']
        journal = (journal or pool.get('publisher', None))
        if isinstance(journal, dict):
            journal = journal['name']
            

        return journal

    @staticmethod
    def get_journal_volume(pool):
        volume = (pool.get('volume', None) or pool.get('jvol', None) or 
                   pool.get('journal_volume', None) or 
                   pool.get('j_vol', None))
        if not volume and 'imprint' in pool and pool['imprint'] and 'volume' in pool['imprint']:
            volume = pool['imprint']['volume']
        if not volume:
            journal = (pool.get('journal', {}))
            if isinstance(journal, dict): volume = journal.get('volume', None)

        return volume
    
    @staticmethod
    def get_journal_page(pool):
        page = (pool.get('page', None) or pool.get('jpage', None) or 
                   pool.get('journal_page', None) or 
                   pool.get('j_page', None))
        if not page and 'imprint' in pool and pool['imprint'] and 'page' in pool['imprint']:
            page = pool['imprint']['page']
        if not page:
            journal = (pool.get('journal', {}))
            if isinstance(journal, dict): page = journal.get('pages', None)

        return page
    
    @staticmethod
    def get_year(pool):
        year =  (pool.get('year', None) or pool.get('date', None))
        if not year and 'issued' in pool and pool['issued'] and 'date-parts' in pool['issued']:
            date_part = pool['issued']['date-parts']
            while isinstance(date_part, list):
                date_part = date_part[0] 
            year = date_part
        if not year and 'imprint' in pool and pool['imprint'] and 'date' in pool['imprint']:
            date_part = pool['imprint']['date']
            while isinstance(date_part, list):
                date_part = date_part[0] 
            year = date_part

        if year:
            try:
                year = parser.parse(str(year)).year
            except:
                year = extract_four_digit_number(str(year))
        return year
    
    @staticmethod
    def get_publisher(pool):
        publisher = pool.get('publisher', None)
        if not publisher and 'imprint' in pool and pool['imprint'] and 'publisher' in pool['imprint']:
            publisher = pool['imprint']['publisher']
            publisher = publisher
        return publisher
    @staticmethod
    def get_content(pool):
        contents = []
        for key in ['content', 'short_content' , 'long_content']:
            content =  pool.get(key, None)
            if content:contents.append(content)
        if len(contents)==0:
            return None
        return contents

    @staticmethod
    def get_norm_attr(string):
        string = (string or "")
        string = str(string)
        return unidecode.unidecode(string).lower().strip()
    

    def addtition_information(old_ref:ReferenceBase, new_ref:ReferenceBase):
        #### firstly deal with None value
        old_pool = old_ref.to_dict()
        new_pool = new_ref.to_dict()
        total_key = vars(old_ref).keys()
        new_information = {}
        for key in total_key:
            if old_pool.get(key, None) is None and new_pool.get(key, None) is not None:
                new_information[key] = new_pool[key]
            elif old_pool.get(key, None) is not None and new_pool.get(key, None) is not None:
                continue
                if key in ['unique_id']:continue
                a = old_pool[key]
                b = new_pool[key]
                if key == 'journal':
                    a = a.lower()
                    b = b.lower()
                    if b not in a:
                        print(f"{key}: a={a} b={b}")
                else:
                    if a !=b :
                        print(f"{key}: a={a} b={b}")

        return new_information

    def __repr__(self):
        info = "\n".join([f"{key} |-> {val}" for key, val in self.to_dict().items() if val is not None])
        return f"Reference:\n{info}"

# %%
result    = paper_information
ref       = Reference.load_from_dict(structured_citation) 
candidate = Reference.load_from_dict(result)

print(ref)
print("====")
print(candidate)
score     = similarity_structured(candidate, ref) 
print(score)
# Out:
# Reference:
# title |-> Char-net: A character-aware neural network for distorted scene text
# author |-> ['W. Liu', 'C. Chen', 'K. K. Wong']
# journal |-> AAAI
# year |-> 2018
# ====
# Reference:
# unique_id |-> Paper:
#    doi |-> 10.1609/aaai.v32i1.12246
#    dblp |-> conf/aaai/liucw18
#    mag |-> 2788069964
# title |-> Char-Net: A Character-Aware Neural Network for Distorted Scene Text Recognition
# author |-> ['W. Liu', 'C. Chen', 'K. K. Wong']
# journal |-> proceedings of the aaai conference on artificial intelligence
# journal_volume |-> 32
# journal_page |-> 7154-7161
# year |-> 2018
# publisher |-> Association for the Advancement of Artificial Intelligence (AAAI)
# content |-> W. Liu , C. Chen and K.-Y. Wong , Proceedings of the AAAI Conference on Artificial Intelligence, vol. 32. Apr. 27, 2018.
# 0.76

# %%
if ref.title and candidate.title and str_set['title']<0.9:
    if len(ref.title) > len(candidate.title):
        shorter_title = candidate.title.lower()
        longer_title  = ref.title.lower()
    else:
        shorter_title = ref.title.lower()
        longer_title  = candidate.title.lower()
    if longer_title.endswith(shorter_title) or longer_title.startswith(shorter_title):
        return 1
    return 0 ## title is different
# Out:
#   Cell In[17], line 9
#     return 1
#     ^
# SyntaxError: 'return' outside function

# %%
from python_script.reference_reterive.citation_string_to_reference import *
selected_engine = f"http://localhost:9200"
es = Elasticsearch(selected_engine,request_timeout=1000)
es.indices.refresh(index='s2-papers-v2.1')
result = anystyle_ref_search_v21(es,ref.to_dict())
print(result)
# Out:
# {'took': 17, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 10000, 'relation': 'gte'}, 'max_score': 42.611618, 'hits': [{'_index': 's2-papers-v2.1', '_id': '4517687', '_score': 42.611618, '_source': {'externalids.DOI': '10.1109/CVPR.2014.49', 'externalids.DBLP': 'conf/cvpr/ArbelaezPBMM14', 'title': 'Multiscale Combinatorial Grouping', 'year': 2014, 'jname': '2014 ieee conference on computer vision and pattern recognition', 'jpages': '328-335', 'author.0': 'P. Arbeláez', 'author.1': 'J. Pont-Tuset', 'author.2': 'J. T. Barron'}}]}}

# %% [markdown]
# # deal with fail case

# %%
candidate = Reference.load_from_dict(paper_information['hits']['hits'][0]['_source'])

# %%
pool = paper_information['hits']['hits'][0]['_source']

# %%
ARXIV_URL_PATT = re.compile(
    r'arxiv\.org\/[a-z0-9-]{1,10}\/(([a-z0-9-]{1,15}\/)?[\d\.]{4,9}\d)',
    re.I
)
ARXIV_ID_PATT = re.compile(
    r'arXiv:(([a-z0-9-]{1,15}\/)?[\d\.]{4,9}\d)',
    re.I
)
ARXIV_ID_PATT_DATE = re.compile(
    r'^([a-zA-Z-\.]+)?\/?(\d\d)(\d\d)(.*)$'
)



def find_arxiv_id(text):
    """ Loor for an arXiv ID within the given text.
    """

    match = ARXIV_ID_PATT.search(text)
    if match:
        return match.group(1)
    else:
        match = ARXIV_URL_PATT.search(text)
        if match:
            return match.group(1)
    return False
import re

def contains_arxiv_id(text):
    # Regular expression pattern for matching ArXiv IDs
    # It matches both the new format (a four-digit year followed by a dot and a sequence of 4 or 5 digits)
    # and the old format (category name like quant-ph, followed by a slash and a seven-digit number)
    text = text.lower().replace("preprent","").replace("  "," ")
    arxiv_pattern = r'(?:arxiv\s*preprint\s*)?(arxiv:?\s*)?(\d{4}\.\d{4,5}|[a-z\-]+/\d{7})(v\d+)?'
    match = re.search(arxiv_pattern, text, re.IGNORECASE)
    if match is not None:
        # Return the complete matched string
        return match.group()
    else:
        return None
text = "s. b. bravyi and a. y. kitaev, “quantum codes on a lattice with boundary,” arxiv:10.1103/physrevb.88.045102, 1998"
print(contains_arxiv_id(text))
# Out:
# None

# %%
import re

def contains_arxiv_id(text):
    # This regular expression pattern matches arXiv IDs in both new and old formats,
    # with optional prefixes like "arXiv:" or "arXiv preprint ".
    arxiv_pattern = r'(?:arxiv\s*(?:preprint\s*)?:?\s*)?(\d{4}\.[0-9]{4,5}|[a-z\-]+/[0-9]{7})(v[0-9]+)?'
    match = re.search(arxiv_pattern, text, re.IGNORECASE)
    if match is not None:
        # Return the complete matched string without the prefix
        return match.group(1) + (match.group(2) or '')  # include versioning if present
    else:
        return None

# %% [markdown]
# # Move the Done Reterive back into content

# %%
for i,arxiv_id in enumerate(tqdm(Analysys['Reterive.AllDone'])):
    paper_fold = os.path.join(ROOTDIR, arxiv_id)
    paper_files= os.listdir(paper_fold)
    paper_content_path = os.path.join(paper_fold , f"{arxiv_id}.json")
    with open(paper_content_path,'r') as f:
        paper_content = json.load(f)
    break
# Out:
#   0%|          | 0/53264 [00:00<?, ?it/s]

# %%
# for section in paper_content['sections']:
#     for paragraph in section['section_content']:
#         for sentence in paragraph:
#             print(sentence)
